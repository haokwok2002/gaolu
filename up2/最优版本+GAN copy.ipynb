# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")


import base 
# 基础库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
import os
import datetime
import pickle
# 机器学习库
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import rbf_kernel
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler
# 优化相关库
from skopt import gp_minimize
from scipy.optimize import minimize

# 深度学习库
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim

# 忽略警告
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# 中文字体设置
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径

# 其他路径设置
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")

# 自定义模块
import base

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='剔除直线输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='单SI_0.2_0.8') 
# print(df_sheet_yuansu.info())
# print(df_sheet_yuansu.columns)

excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_params = pd.read_excel(excel_path, sheet_name='1h_mean_all') 

# print(df_sheet_params.info())
# print(df_sheet_params.columns)

# %%
# 检查 DataFrame 中是否包含 NaN 值
def check_if_NaN(data):
    print(data.shape)
    contains_nan = data.isna().any().any()
    if contains_nan:
        print("数据包含 NaN 值")
    else:
        print("数据不包含 NaN 值")
check_if_NaN(df_sheet_yuansu)
check_if_NaN(df_sheet_params)
# Out:
# (7398, 4)
# 数据不包含 NaN 值
# (7377, 38)
# 数据不包含 NaN 值

# %%
input_term =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term = ['铁水温度[MIT]', '铁水硅含量[SI]']
time_term= '时间戳h'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_yuansu_process = df_sheet_yuansu.copy()
df_sheet_params_process = df_sheet_params.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 2.5 * y.std()
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value

# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[3]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[4]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[5]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[6]])

# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[0]])
# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[1]])

plt.figure(figsize=(15, 4))
for idx, column in enumerate(input_term):
    plt.subplot(len(input_term), 1, idx+1)
    plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params[column].values,df_sheet_params_process[column].values,column)

plt.figure(figsize=(15, 2))
for idx, column in enumerate(output_term):
    plt.subplot(len(output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu[column].values,df_sheet_yuansu_process[column].values,column)
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_3416\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r.', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 400


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 6))
for idx, column in enumerate(output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_params_process[input_term[0]].values,
    input_term[1]:   df_sheet_params_process[input_term[1]].values,
    input_term[2]:   df_sheet_params_process[input_term[2]].values,
    input_term[3]:   df_sheet_params_process[input_term[3]].values,
    # input_term[4]:   df_sheet_params_process[input_term[4]].values,
    # input_term[5]:   df_sheet_params_process[input_term[5]].values,
    # input_term[6]:   df_sheet_params_process[input_term[6]].values,
    output_term[0]:  df_sheet_yuansu_process[output_term[0]].values,
    output_term[1]:  df_sheet_yuansu_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每浓度的输出差：',(data3-data1))
# Out:
# [0.0341569]
# [1500.]
# [0.1523575]
# [1510.]
# 每摄氏度的输出差： [0.01182006]
# [-0.53242879]
# [0.5]
# [-0.4247456]
# [0.6]
# 每浓度的输出差： [0.1076832]

# %%
isShuffle = True
isShuffle = False
time_steps = 2
test_size = 0.15
val_size = 0.15
train_size = 1-val_size-test_size

# %%
# 组合训练数据--拆分训练、测试集

# 定义时间步数和特征数

# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data,index_fanwei):
    X = np.column_stack((u1_data,u2_data,u3_data,u4_data))
    y = np.column_stack((y1_data, y2_data))

    X_modified = []
    y_modified = []
    
    for i in range(3,len(y1_data)):
        if i in index_fanwei:
            # print(i)
            # print(df_sheet_yuansu[time_term][i])
            yuansu_time = df_sheet_yuansu[time_term][i]
            closest_10 = df_sheet_params[df_sheet_params[time_term] <= yuansu_time].nlargest(time_steps, time_term)
            # print(closest_10)
            
            index = closest_10.index
            # print(index)
            # print(closest_10.iloc[-1][time_term])
            if closest_10.iloc[-1][time_term] < yuansu_time - time_steps + 1:
                print(i,yuansu_time,'errloss')
            else:

                # print(X[index, :])
                new_x_sample = np.concatenate([X[i, :] for i in index],axis=0)
                # print(new_x_sample)
                y_last = y[i-1, :]
                # print(y_last, 'y_last time : ',df_sheet_yuansu[time_term][i-1])
                new_x_sample = np.concatenate([new_x_sample,y_last],axis=0)
                # print(new_x_sample)
                y_sample = y[i, :]  
                X_modified.append(new_x_sample)
                y_modified.append(y_sample)
                print(i,yuansu_time,index[0],index[-1], end='\r')
                # break

    # 将列表转换为 NumPy 数组
    X_modified = np.array(X_modified)
    y_modified = np.array(y_modified)
    X_reshaped = X_modified.reshape((X_modified.shape[0], X_modified.shape[1]))

    # 打印新数据的形状
    print("Modified Input Shape:", X_reshaped.shape)
    print("Modified Output Shape:", y_modified.shape)


    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_modified, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def symmetrical_moving_average(data, N):
    """
    使用对称的移动平均滤波，当前值由其自身及其前后的值决定。
    
    :param data: 输入的数据序列，一般为列表或者NumPy数组。
    :return: 经过滤波处理的数据序列。
    """
    filtered_data = []
    N = 9
    percent = 0.8
    # 遍历数据，从索引1开始到倒数第二个元素结束
    for i in range(1, len(data) - 1):
        # 计算当前值及其前后值的平均
        average = (data[i - 1]*(1-percent)/2 + data[i]*percent + data[i + 1]*(1-percent)/2)
        filtered_data.append(average)
    
    # 对于序列的第一个和最后一个元素，直接使用原始值
    # 或者可以使用其他边界处理策略
    filtered_data.insert(0, data[0])
    filtered_data.append(data[-1])
    
    return np.array(filtered_data)

# 示例数据
data = [2, 4, 6, 8, 10, 12, 14]
filtered_data = symmetrical_moving_average(data,9)
print(filtered_data)
# Out:
# [ 2.  4.  6.  8. 10. 12. 14.]

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)

print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_gaolu)



# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_predict)
# Out:
# 高炉模型数据
# 36 51 35 34
# Modified Input Shape: (398, 10)2
# Modified Output Shape: (398, 2)
# 训练数量： (278, 10) (278, 2)
# 验证数量： (60, 10) (60, 2)
# 测试数量： (60, 10) (60, 2)
# 预测模型数据
# Modified Input Shape: (401, 10)
# Modified Output Shape: (401, 2)
# 训练数量： (279, 10) (279, 2)
# 验证数量： (61, 10) (61, 2)
# 测试数量： (61, 10) (61, 2)

# %%
epoch_once_time = 50
ischuangxin = True
# ischuangxin = False
cengshu = 3

# %%
# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyNeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, if_chuangxin = False,gamma = 0.1):
        self.if_chuangxin = if_chuangxin
        super(MyNeuralNetwork, self).__init__()
        if cengshu == 3:    
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()
        elif cengshu == 2:  
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()


    def forward(self, x0):
        if cengshu == 3:    
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                x4 = x + x2 + x3
                output = self.fc4(x4)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                output = self.fc4(x3)
        elif cengshu == 2:  
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = x + x2
                output = self.fc3(x3)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                output = self.fc3(x2)
        return output
        
        return output
    
    

    
    def custom_loss(self, y_true, y_pred):

        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse
    

    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    def model_update(self, 
                X_train, y_train, 
                epochs=1, batch_size=32, lr=0.001,ifprint = False):
        optimizer = optim.Adam(self.parameters(), lr=lr)
        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            if(ifprint):print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}')
            
            
        return 0
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
# 建立高炉模型实例
input_size = 10  # 输入特征大小
hidden_size = 16  # 32
output_size = 2  # 输出大小
# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyNeuralNetwork(input_size, 
                            hidden_size,
                            output_size,
                            ischuangxin,
                            gamma = 0.1)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0292, 验证误差: 0.0133
# epoch_sum: 50

# %%
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
input_term333 =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term333 = ['铁水温度MIT', '铁水硅含量[Si]']
time_term= '时间戳h'
print(input_term333)
print(output_term333)
input_term222 =        ['富氧流量/(m\u00b3/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
output_term222 = ['铁水温度MIT/℃', '铁水硅含量[Si]/%']
time_term= '时间戳h'
print(input_term222)
print(output_term222)
# Out:
# ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
# ['铁水温度MIT', '铁水硅含量[Si]']
# ['富氧流量/(m³/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
# ['铁水温度MIT/℃', '铁水硅含量[Si]/%']

# %%
ditem = -0.65

# %%
def double_control_train_test_result(scalers, output_term, y_test, y_pred_0, y_pred_1, y_test_2, y_pred_0_2, y_pred_1_2,ditem,a,b):
    y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    plt.figure(figsize=(9, 8))
    
    
    ax = plt.subplot(4, 1, 1)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    ax.legend(prop=font, loc='upper right', bbox_to_anchor=(a, b), ncol=4) 
    
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[0]} {output_term333[0]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('训练样本', fontproperties=font)  




    ax = plt.subplot(4, 1, 2)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font) 

    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[1]} {output_term333[1]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    
    ax.set_xlabel('训练样本', fontproperties=font)  




    y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1_2).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    ax = plt.subplot(4, 1, 3)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[2]} {output_term333[0]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  



    ax = plt.subplot(4, 1, 4)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[3]} {output_term333[1]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  




    plt.subplots_adjust(hspace=0.6)  # 调整子图之间的垂直间距
    plt.tight_layout()  # 自动调整子图布局
    plt.show()

# %%
# 高炉模型建模效果
y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_gaolu_train)
y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_gaolu_test)

double_control_train_test_result(scalers,  output_term,
                                        y_gaolu_train,  y_train_pred_0, y_train_pred_1,
                                        y_gaolu_test ,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.63, b = 0.38 )

# base.double_control_train_test_result(scalers,  output_term,
#                                         y_gaolu_train[:-1],  y_train_pred_0[1:], y_train_pred_1[1:],
#                                         y_gaolu_test[:-1] ,   y_test_pred_0[1:],  y_test_pred_1[1:])

# %%
# 创建预测模型实例
# 设置随机种子
torch.manual_seed(0)
model_predict = MyNeuralNetwork(input_size, hidden_size, output_size,ischuangxin)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model_predict.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0279, 验证误差: 0.0335
# epoch_sum: 0

# %%
# 预测模型建模效果
y_train_pred_0,y_train_pred_1 = model_predict.my_predict(X_predict_train)


y_test_pred_0,y_test_pred_1 = model_predict.my_predict(X_predict_test)

double_control_train_test_result(scalers,  output_term,
                                        y_predict_train,  y_train_pred_0, y_train_pred_1,
                                        y_predict_test,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.31, b = 0.38 )

# %%
base.gaolu_predict_raw(scalers,output_term,model_predict,model_gaolu,X_predict_test,y_predict_test)

# %%
# 使用NumPy重新构建神经网络架构
class MyNeuralNetworkNumpy:
    def __init__(self, model, input_size, hidden_size, output_size,ifchuangxin):
        self.ifchuangxin = ifchuangxin
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        params = {name: param.detach().numpy() for name, param in model.state_dict().items()}
        if cengshu == 3:    
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
            self.weights_fc4 = params['fc4.weight']
            self.bias_fc4 = params['fc4.bias']
        elif cengshu == 2:  
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
        
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    def relu(self, x):
        return np.maximum(0, x)

    def forward(self, x):
        if cengshu == 3:    
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                hidden4 = hidden1 + hidden2 + hidden3
                output = np.dot(hidden4, self.weights_fc4.T) + self.bias_fc4

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                output = np.dot(hidden3, self.weights_fc4.T) + self.bias_fc4
        elif cengshu == 2:  
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = hidden1 + hidden2
                output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3
                # hidden2 = self.relu(hidden2)

                # hidden3 = np.concatenate([x, hidden1, hidden2], axis=1)  # 按列连接
                # output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                output = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3


            
        return output
    
    
    def my_predict(self, data_input):
        input = data_input  # 随机初始化一个输入序列
        output_prediction = model_numpy.forward(input)
        return output_prediction[:,0], output_prediction[:,1]

# 使用NumPy模型进行预测
model_numpy = MyNeuralNetworkNumpy(model_predict, input_size, hidden_size, output_size,ischuangxin)


y_pred_0, y_pred_1 = model_numpy.my_predict(X_predict_test)

# 计算 RMSE、MRE
y_test = y_predict_test


base.double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁水温度[MIT]: 14.3563 , 铁水硅含量[SI]: 0.1251
# MAPE:  铁水温度[MIT]: 0.8042% , 铁水硅含量[SI]: 30.1320%
# MRE :  铁水温度[MIT]: 0.0080  , 铁水硅含量[SI]: 0.3013
# per :  铁水温度[MIT]: 0.4754  , 铁水硅含量[SI]: 0.7049

# %% [markdown]
# GAN

# %%
# 绘制叠加的散点图矩阵。
def plot_scatter_matrix(X_df_normal, X_df_normal_index_gaolu, figsize=(10, 8),font=font, save_path=None):
    """
    绘制叠加的散点图矩阵。

    参数:
    X_df_normal (DataFrame): 第一组数据。
    X_df_normal_index_gaolu (DataFrame): 第二组数据。
    font (FontProperties, optional): 字体属性，用于设置标签的字体。
    """
    # 设置颜色和标记
    color_left = 'blue'
    color_right = 'red'
    marker_left = '.'
    marker_right = '.'

    # 设置数据
    df_left = X_df_normal  # 第一组数据
    df_right = X_df_normal_index_gaolu  # 第二组数据

    # 绘制叠加的散点图矩阵
    plt.figure(figsize = figsize)
    num_cols = len(df_left.columns)
    
    for i, col1 in enumerate(df_left.columns):
        for j, col2 in enumerate(df_left.columns):
            ax = plt.subplot(num_cols, num_cols, i * num_cols + j + 1)
            
            if i != j:
                ax.scatter(df_left[col1], df_left[col2], color=color_left, alpha=0.5, marker=marker_left, label='Left Data' if i == 0 and j == 1 else "")
                ax.scatter(df_right[col1], df_right[col2], color=color_right, alpha=0.5, marker=marker_right, label='Right Data' if i == 0 and j == 1 else "")
                ax.set_xlim([-1, 1])
                ax.set_ylim([-1, 1])
            else:
                ax.hist(df_left[col1], bins=50, alpha=0.5, color=color_left)
                ax.hist(df_right[col1], bins=50, alpha=0.5, color=color_right)
                ax.set_xlim([-1, 1])

            if i == num_cols - 1:
                ax.set_xlabel(col2, fontproperties=font)
            if j == 0:
                ax.set_ylabel(col1, fontproperties=font)

    # # 添加图例
    # plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1))
    # 手动添加图例
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.5, 1))

    # 添加标题并调整布局
    plt.suptitle('Overlaid Scatter Matrix of Features', y=1.02)
    plt.tight_layout()
    
    # 如果提供了保存路径，则保存图像
    if save_path:
        plt.savefig(save_path)
        plt.close()  # 关闭当前的图像，以节省内存
    else:
        plt.show()  # 否则显示图像

# %%
# 绘制散点图矩阵
# 转换为DataFrame
print('高炉部分数据')


# 转换为DataFrame
print('全部数据')
X_df_normal = pd.DataFrame(normalized_data_dict, columns=input_term)
print(X_df_normal.shape)
# check_if_NaN(X_df_normal)
Y_df_normal = pd.DataFrame(normalized_data_dict, columns=output_term)
# check_if_NaN(Y_df_normal)


# 绘制散点图矩阵
plot_scatter_matrix(X_df_normal, X_df_normal.loc[index_gaolu], font=font, figsize=(10, 8))
# # 绘制散点图矩阵
plot_scatter_matrix(Y_df_normal, Y_df_normal.loc[index_gaolu], font=font, figsize=(5, 4))
# Out:
# 高炉部分数据
# 全部数据
# (7377, 4)

# %%
# 将历史数据转换为 PyTorch 张量
data_item = X_df_normal
# data_item = data_test

data = torch.tensor(data_item.values, dtype=torch.float32)
df_GAN = data_item
test_sample_num = data.shape[0]

# %%
# LS-GAN超参数
z_dim = 4  # 随机噪声维度
data_dim = data.shape[1]  # 数据维度，4
learning_rate = 0.0002
num_epochs = 200
n_critic = 5  # 每次更新生成器前，更新 Critic 的次数

print_piture_d = 10

# 设置数据加载器
batch_size = 512
data_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)

# %%
# LS-GAN模型定义和训练
class LSGANGenerator(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LSGANGenerator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 256),
            nn.ReLU(True),
            nn.Linear(256, output_dim),
            nn.Tanh()
        )

    def forward(self, x):
        return self.model(x)

# LSGAN的判别器
class LSGANDiscriminator(nn.Module):
    def __init__(self, input_dim):
        super(LSGANDiscriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return self.model(x)

# LSGAN的损失函数
def generator_loss(fake_output):
    return torch.mean((fake_output - 1) ** 2)

def discriminator_loss(real_output, fake_output):
    real_loss = torch.mean((real_output - 1) ** 2)
    fake_loss = torch.mean(fake_output ** 2)
    return real_loss + fake_loss

# LSGAN训练
def train_lsgan(generator, discriminator, data_loader, num_epochs, z_dim, optimizer_G, optimizer_D, output_dir):
    output_dir = r"data\train_output_picture\LS-GAN_training_output2"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    for epoch in range(num_epochs):
        for real_data in data_loader:
            batch_size = real_data.size(0)

            # 生成数据
            z = torch.randn(batch_size, z_dim)
            fake_data = generator(z)

            # 判别器前向传播
            real_output = discriminator(real_data)
            fake_output = discriminator(fake_data.detach())

            # 计算判别器损失
            d_loss = discriminator_loss(real_output, fake_output)
            optimizer_D.zero_grad()
            d_loss.backward()
            optimizer_D.step()

            # 生成器前向传播
            fake_output = discriminator(fake_data)

            # 计算生成器损失
            g_loss = generator_loss(fake_output)
            optimizer_G.zero_grad()
            g_loss.backward()
            optimizer_G.step()

        print(f"LS-GAN_training Epoch [{epoch}/{num_epochs}], D_loss: {d_loss.item():.4f}, G_loss: {g_loss.item():.4f}")

        if epoch % print_piture_d == print_piture_d-1:
            # 生成数据test_sample_num
            z = torch.randn(test_sample_num, z_dim)
            generated_data = generator(z).detach().numpy()

            # 将生成的数据转换为 DataFrame
            generated_df = pd.DataFrame(generated_data, columns=df_GAN.columns)

            # 获取当前时间
            current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

            # 构建保存路径和文件名
            filename = f"{current_time}_LSGAN_Epoch_{epoch+1}_D_loss_{d_loss.item():.4f}_G_loss_{g_loss.item():.4f}.png"
            save_path = os.path.join(output_dir, filename)

            # 可视化生成的数据分布（你可以实现自己的可视化函数）
            plot_scatter_matrix(df_GAN, generated_df, figsize=(10, 8), font=font, save_path=save_path)

# %%
# 初始化LSGAN优化器  训练
# # 使用WGAN生成的数据初始化LSGAN
lsgan_generator = LSGANGenerator(input_dim=z_dim, output_dim=data_dim)
lsgan_discriminator = LSGANDiscriminator(input_dim=data_dim)

optimizer_G = optim.Adam(lsgan_generator.parameters(), lr=learning_rate, betas=(0.2, 0.999))
optimizer_D = optim.Adam(lsgan_discriminator.parameters(), lr=learning_rate, betas=(0.2, 0.999))

# 使用WGAN生成的数据作为输入进行LSGAN训练
train_lsgan(lsgan_generator, lsgan_discriminator, data_loader, 
                num_epochs=num_epochs, z_dim=z_dim, 
                optimizer_G=optimizer_G, optimizer_D=optimizer_D, 
                output_dir="lsgan_outputs")
# Out:
# LS-GAN_training Epoch [0/200], D_loss: 0.3202, G_loss: 0.5166
# LS-GAN_training Epoch [1/200], D_loss: 0.4190, G_loss: 0.2843
# LS-GAN_training Epoch [2/200], D_loss: 0.5050, G_loss: 0.2681
# LS-GAN_training Epoch [3/200], D_loss: 0.4968, G_loss: 0.2741
# LS-GAN_training Epoch [4/200], D_loss: 0.4886, G_loss: 0.2756
# LS-GAN_training Epoch [5/200], D_loss: 0.4832, G_loss: 0.2732
# LS-GAN_training Epoch [6/200], D_loss: 0.4740, G_loss: 0.2787
# LS-GAN_training Epoch [7/200], D_loss: 0.4987, G_loss: 0.2762
# LS-GAN_training Epoch [8/200], D_loss: 0.4737, G_loss: 0.2789
# LS-GAN_training Epoch [9/200], D_loss: 0.4891, G_loss: 0.2692
# LS-GAN_training Epoch [10/200], D_loss: 0.4644, G_loss: 0.2911
# LS-GAN_training Epoch [11/200], D_loss: 0.4750, G_loss: 0.2933
# LS-GAN_training Epoch [12/200], D_loss: 0.4750, G_loss: 0.2868
# LS-GAN_training Epoch [13/200], D_loss: 0.4859, G_loss: 0.2704
# LS-GAN_training Epoch [14/200], D_loss: 0.4857, G_loss: 0.2643
# LS-GAN_training Epoch [15/200], D_loss: 0.4863, G_loss: 0.2688
# LS-GAN_training Epoch [16/200], D_loss: 0.5519, G_loss: 0.2365
# LS-GAN_training Epoch [17/200], D_loss: 0.4918, G_loss: 0.2425
# LS-GAN_training Epoch [18/200], D_loss: 0.4804, G_loss: 0.2649
# LS-GAN_training Epoch [19/200], D_loss: 0.4984, G_loss: 0.2602
# LS-GAN_training Epoch [20/200], D_loss: 0.4963, G_loss: 0.2650
# LS-GAN_training Epoch [21/200], D_loss: 0.4909, G_loss: 0.2545
# LS-GAN_training Epoch [22/200], D_loss: 0.4926, G_loss: 0.2545
# LS-GAN_training Epoch [23/200], D_loss: 0.4921, G_loss: 0.2612
# LS-GAN_training Epoch [24/200], D_loss: 0.4910, G_loss: 0.2555
# LS-GAN_training Epoch [25/200], D_loss: 0.4907, G_loss: 0.2512
# LS-GAN_training Epoch [26/200], D_loss: 0.4943, G_loss: 0.2564
# LS-GAN_training Epoch [27/200], D_loss: 0.4893, G_loss: 0.2608
# LS-GAN_training Epoch [28/200], D_loss: 0.4951, G_loss: 0.2506
# LS-GAN_training Epoch [29/200], D_loss: 0.4969, G_loss: 0.2507
# LS-GAN_training Epoch [30/200], D_loss: 0.4952, G_loss: 0.2550
# LS-GAN_training Epoch [31/200], D_loss: 0.4951, G_loss: 0.2520
# LS-GAN_training Epoch [32/200], D_loss: 0.4933, G_loss: 0.2532
# LS-GAN_training Epoch [33/200], D_loss: 0.4987, G_loss: 0.2474
# LS-GAN_training Epoch [34/200], D_loss: 0.4961, G_loss: 0.2502
# LS-GAN_training Epoch [35/200], D_loss: 0.4964, G_loss: 0.2460
# LS-GAN_training Epoch [36/200], D_loss: 0.4906, G_loss: 0.2642
# LS-GAN_training Epoch [37/200], D_loss: 0.4954, G_loss: 0.2509
# LS-GAN_training Epoch [38/200], D_loss: 0.4951, G_loss: 0.2586
# LS-GAN_training Epoch [39/200], D_loss: 0.4979, G_loss: 0.2518
# LS-GAN_training Epoch [40/200], D_loss: 0.4956, G_loss: 0.2508
# LS-GAN_training Epoch [41/200], D_loss: 0.4927, G_loss: 0.2609
# LS-GAN_training Epoch [42/200], D_loss: 0.4936, G_loss: 0.2594
# LS-GAN_training Epoch [43/200], D_loss: 0.4945, G_loss: 0.2470
# LS-GAN_training Epoch [44/200], D_loss: 0.4955, G_loss: 0.2519
# LS-GAN_training Epoch [45/200], D_loss: 0.4949, G_loss: 0.2574
# LS-GAN_training Epoch [46/200], D_loss: 0.4950, G_loss: 0.2566
# LS-GAN_training Epoch [47/200], D_loss: 0.4924, G_loss: 0.2635
# LS-GAN_training Epoch [48/200], D_loss: 0.4955, G_loss: 0.2535
# LS-GAN_training Epoch [49/200], D_loss: 0.4897, G_loss: 0.2597
# LS-GAN_training Epoch [50/200], D_loss: 0.4945, G_loss: 0.2577
# LS-GAN_training Epoch [51/200], D_loss: 0.4980, G_loss: 0.2399
# LS-GAN_training Epoch [52/200], D_loss: 0.4927, G_loss: 0.2592
# LS-GAN_training Epoch [53/200], D_loss: 0.4955, G_loss: 0.2511
# LS-GAN_training Epoch [54/200], D_loss: 0.4970, G_loss: 0.2528
# LS-GAN_training Epoch [55/200], D_loss: 0.4951, G_loss: 0.2621
# LS-GAN_training Epoch [56/200], D_loss: 0.4968, G_loss: 0.2410
# LS-GAN_training Epoch [57/200], D_loss: 0.4957, G_loss: 0.2450
# LS-GAN_training Epoch [58/200], D_loss: 0.4952, G_loss: 0.2657
# LS-GAN_training Epoch [59/200], D_loss: 0.4924, G_loss: 0.2645
# LS-GAN_training Epoch [60/200], D_loss: 0.4948, G_loss: 0.2697
# LS-GAN_training Epoch [61/200], D_loss: 0.4964, G_loss: 0.2419
# LS-GAN_training Epoch [62/200], D_loss: 0.5001, G_loss: 0.2534
# LS-GAN_training Epoch [63/200], D_loss: 0.4957, G_loss: 0.2760
# LS-GAN_training Epoch [64/200], D_loss: 0.5009, G_loss: 0.2594
# LS-GAN_training Epoch [65/200], D_loss: 0.4965, G_loss: 0.2512
# LS-GAN_training Epoch [66/200], D_loss: 0.4923, G_loss: 0.2484
# LS-GAN_training Epoch [67/200], D_loss: 0.4989, G_loss: 0.2538
# LS-GAN_training Epoch [68/200], D_loss: 0.4924, G_loss: 0.2577
# LS-GAN_training Epoch [69/200], D_loss: 0.4985, G_loss: 0.2463
# LS-GAN_training Epoch [70/200], D_loss: 0.4956, G_loss: 0.2434
# LS-GAN_training Epoch [71/200], D_loss: 0.4959, G_loss: 0.2602
# LS-GAN_training Epoch [72/200], D_loss: 0.4978, G_loss: 0.2508
# LS-GAN_training Epoch [73/200], D_loss: 0.4941, G_loss: 0.2579
# LS-GAN_training Epoch [74/200], D_loss: 0.4992, G_loss: 0.2421
# LS-GAN_training Epoch [75/200], D_loss: 0.5006, G_loss: 0.2487
# LS-GAN_training Epoch [76/200], D_loss: 0.4915, G_loss: 0.2798
# LS-GAN_training Epoch [77/200], D_loss: 0.5050, G_loss: 0.2419
# LS-GAN_training Epoch [78/200], D_loss: 0.4962, G_loss: 0.2580
# LS-GAN_training Epoch [79/200], D_loss: 0.4992, G_loss: 0.2750
# LS-GAN_training Epoch [80/200], D_loss: 0.4959, G_loss: 0.2456
# LS-GAN_training Epoch [81/200], D_loss: 0.4954, G_loss: 0.2597
# LS-GAN_training Epoch [82/200], D_loss: 0.5017, G_loss: 0.2626
# LS-GAN_training Epoch [83/200], D_loss: 0.4934, G_loss: 0.2631
# LS-GAN_training Epoch [84/200], D_loss: 0.4983, G_loss: 0.2668
# LS-GAN_training Epoch [85/200], D_loss: 0.4978, G_loss: 0.2620
# LS-GAN_training Epoch [86/200], D_loss: 0.5005, G_loss: 0.2508
# LS-GAN_training Epoch [87/200], D_loss: 0.4962, G_loss: 0.2532
# LS-GAN_training Epoch [88/200], D_loss: 0.4970, G_loss: 0.2692
# LS-GAN_training Epoch [89/200], D_loss: 0.4958, G_loss: 0.2510
# LS-GAN_training Epoch [90/200], D_loss: 0.4979, G_loss: 0.2492
# LS-GAN_training Epoch [91/200], D_loss: 0.4970, G_loss: 0.2669
# LS-GAN_training Epoch [92/200], D_loss: 0.4961, G_loss: 0.2628
# LS-GAN_training Epoch [93/200], D_loss: 0.4966, G_loss: 0.2462
# LS-GAN_training Epoch [94/200], D_loss: 0.5013, G_loss: 0.2455
# LS-GAN_training Epoch [95/200], D_loss: 0.4978, G_loss: 0.2480
# LS-GAN_training Epoch [96/200], D_loss: 0.4980, G_loss: 0.2798
# LS-GAN_training Epoch [97/200], D_loss: 0.5004, G_loss: 0.2530
# LS-GAN_training Epoch [98/200], D_loss: 0.5038, G_loss: 0.2523
# LS-GAN_training Epoch [99/200], D_loss: 0.4987, G_loss: 0.2724
# LS-GAN_training Epoch [100/200], D_loss: 0.4984, G_loss: 0.2455
# LS-GAN_training Epoch [101/200], D_loss: 0.5101, G_loss: 0.2514
# LS-GAN_training Epoch [102/200], D_loss: 0.4934, G_loss: 0.2673
# LS-GAN_training Epoch [103/200], D_loss: 0.4942, G_loss: 0.2536
# LS-GAN_training Epoch [104/200], D_loss: 0.5057, G_loss: 0.2566
# LS-GAN_training Epoch [105/200], D_loss: 0.4966, G_loss: 0.2723
# LS-GAN_training Epoch [106/200], D_loss: 0.5006, G_loss: 0.2572
# LS-GAN_training Epoch [107/200], D_loss: 0.5014, G_loss: 0.2423
# LS-GAN_training Epoch [108/200], D_loss: 0.4987, G_loss: 0.2398
# LS-GAN_training Epoch [109/200], D_loss: 0.4961, G_loss: 0.2531
# LS-GAN_training Epoch [110/200], D_loss: 0.5009, G_loss: 0.2577
# LS-GAN_training Epoch [111/200], D_loss: 0.5001, G_loss: 0.2414
# LS-GAN_training Epoch [112/200], D_loss: 0.5000, G_loss: 0.2632
# LS-GAN_training Epoch [113/200], D_loss: 0.4935, G_loss: 0.2536
# LS-GAN_training Epoch [114/200], D_loss: 0.4996, G_loss: 0.2436
# LS-GAN_training Epoch [115/200], D_loss: 0.4979, G_loss: 0.2338
# LS-GAN_training Epoch [116/200], D_loss: 0.4986, G_loss: 0.2580
# LS-GAN_training Epoch [117/200], D_loss: 0.4972, G_loss: 0.2831
# LS-GAN_training Epoch [118/200], D_loss: 0.4995, G_loss: 0.2510
# LS-GAN_training Epoch [119/200], D_loss: 0.4992, G_loss: 0.2419
# LS-GAN_training Epoch [120/200], D_loss: 0.5008, G_loss: 0.2352
# LS-GAN_training Epoch [121/200], D_loss: 0.4990, G_loss: 0.2482
# LS-GAN_training Epoch [122/200], D_loss: 0.5014, G_loss: 0.2238
# LS-GAN_training Epoch [123/200], D_loss: 0.4968, G_loss: 0.2334
# LS-GAN_training Epoch [124/200], D_loss: 0.5005, G_loss: 0.2587
# LS-GAN_training Epoch [125/200], D_loss: 0.4957, G_loss: 0.2663
# LS-GAN_training Epoch [126/200], D_loss: 0.4978, G_loss: 0.2602
# LS-GAN_training Epoch [127/200], D_loss: 0.5010, G_loss: 0.2664
# LS-GAN_training Epoch [128/200], D_loss: 0.5014, G_loss: 0.2828
# LS-GAN_training Epoch [129/200], D_loss: 0.4973, G_loss: 0.2535
# LS-GAN_training Epoch [130/200], D_loss: 0.5011, G_loss: 0.2165
# LS-GAN_training Epoch [131/200], D_loss: 0.4986, G_loss: 0.2676
# LS-GAN_training Epoch [132/200], D_loss: 0.4988, G_loss: 0.2299
# LS-GAN_training Epoch [133/200], D_loss: 0.4992, G_loss: 0.2672
# LS-GAN_training Epoch [134/200], D_loss: 0.4997, G_loss: 0.2309
# LS-GAN_training Epoch [135/200], D_loss: 0.4993, G_loss: 0.2502
# LS-GAN_training Epoch [136/200], D_loss: 0.4963, G_loss: 0.2446
# LS-GAN_training Epoch [137/200], D_loss: 0.4974, G_loss: 0.2435
# LS-GAN_training Epoch [138/200], D_loss: 0.4974, G_loss: 0.2366
# LS-GAN_training Epoch [139/200], D_loss: 0.4970, G_loss: 0.2456
# LS-GAN_training Epoch [140/200], D_loss: 0.5044, G_loss: 0.2065
# LS-GAN_training Epoch [141/200], D_loss: 0.5013, G_loss: 0.2546
# LS-GAN_training Epoch [142/200], D_loss: 0.5039, G_loss: 0.2745
# LS-GAN_training Epoch [143/200], D_loss: 0.4987, G_loss: 0.2494
# LS-GAN_training Epoch [144/200], D_loss: 0.4988, G_loss: 0.2715
# LS-GAN_training Epoch [145/200], D_loss: 0.4997, G_loss: 0.2616
# LS-GAN_training Epoch [146/200], D_loss: 0.5005, G_loss: 0.2388
# LS-GAN_training Epoch [147/200], D_loss: 0.5003, G_loss: 0.2730
# LS-GAN_training Epoch [148/200], D_loss: 0.4993, G_loss: 0.2310
# LS-GAN_training Epoch [149/200], D_loss: 0.4992, G_loss: 0.2415
# LS-GAN_training Epoch [150/200], D_loss: 0.4989, G_loss: 0.2532
# LS-GAN_training Epoch [151/200], D_loss: 0.4957, G_loss: 0.2475
# LS-GAN_training Epoch [152/200], D_loss: 0.4978, G_loss: 0.2272
# LS-GAN_training Epoch [153/200], D_loss: 0.5028, G_loss: 0.2360
# LS-GAN_training Epoch [154/200], D_loss: 0.5014, G_loss: 0.2516
# LS-GAN_training Epoch [155/200], D_loss: 0.5014, G_loss: 0.2651
# LS-GAN_training Epoch [156/200], D_loss: 0.5035, G_loss: 0.2562
# LS-GAN_training Epoch [157/200], D_loss: 0.4968, G_loss: 0.2467
# LS-GAN_training Epoch [158/200], D_loss: 0.4985, G_loss: 0.2607
# LS-GAN_training Epoch [159/200], D_loss: 0.5056, G_loss: 0.2165
# LS-GAN_training Epoch [160/200], D_loss: 0.5020, G_loss: 0.2543
# LS-GAN_training Epoch [161/200], D_loss: 0.4969, G_loss: 0.2523
# LS-GAN_training Epoch [162/200], D_loss: 0.4968, G_loss: 0.2462
# LS-GAN_training Epoch [163/200], D_loss: 0.4987, G_loss: 0.2650
# LS-GAN_training Epoch [164/200], D_loss: 0.5027, G_loss: 0.2227
# LS-GAN_training Epoch [165/200], D_loss: 0.5077, G_loss: 0.2688
# LS-GAN_training Epoch [166/200], D_loss: 0.5017, G_loss: 0.2599
# LS-GAN_training Epoch [167/200], D_loss: 0.4985, G_loss: 0.2406
# LS-GAN_training Epoch [168/200], D_loss: 0.5002, G_loss: 0.2688
# LS-GAN_training Epoch [169/200], D_loss: 0.4986, G_loss: 0.2539
# LS-GAN_training Epoch [170/200], D_loss: 0.4965, G_loss: 0.2530
# LS-GAN_training Epoch [171/200], D_loss: 0.4955, G_loss: 0.2603
# LS-GAN_training Epoch [172/200], D_loss: 0.4989, G_loss: 0.2606
# LS-GAN_training Epoch [173/200], D_loss: 0.5021, G_loss: 0.2656
# LS-GAN_training Epoch [174/200], D_loss: 0.5000, G_loss: 0.2454
# LS-GAN_training Epoch [175/200], D_loss: 0.4956, G_loss: 0.2570
# LS-GAN_training Epoch [176/200], D_loss: 0.5004, G_loss: 0.2455
# LS-GAN_training Epoch [177/200], D_loss: 0.5009, G_loss: 0.2239
# LS-GAN_training Epoch [178/200], D_loss: 0.4940, G_loss: 0.2666
# LS-GAN_training Epoch [179/200], D_loss: 0.4988, G_loss: 0.2346
# LS-GAN_training Epoch [180/200], D_loss: 0.5026, G_loss: 0.2606
# LS-GAN_training Epoch [181/200], D_loss: 0.5005, G_loss: 0.2501
# LS-GAN_training Epoch [182/200], D_loss: 0.4989, G_loss: 0.2886
# LS-GAN_training Epoch [183/200], D_loss: 0.5002, G_loss: 0.2489
# LS-GAN_training Epoch [184/200], D_loss: 0.5021, G_loss: 0.2591
# LS-GAN_training Epoch [185/200], D_loss: 0.4940, G_loss: 0.2597
# LS-GAN_training Epoch [186/200], D_loss: 0.5002, G_loss: 0.2415
# LS-GAN_training Epoch [187/200], D_loss: 0.5013, G_loss: 0.2290
# LS-GAN_training Epoch [188/200], D_loss: 0.5014, G_loss: 0.2274
# LS-GAN_training Epoch [189/200], D_loss: 0.4950, G_loss: 0.2438
# LS-GAN_training Epoch [190/200], D_loss: 0.4967, G_loss: 0.2748
# LS-GAN_training Epoch [191/200], D_loss: 0.5030, G_loss: 0.2433
# LS-GAN_training Epoch [192/200], D_loss: 0.5017, G_loss: 0.2513
# LS-GAN_training Epoch [193/200], D_loss: 0.4943, G_loss: 0.2610
# LS-GAN_training Epoch [194/200], D_loss: 0.5026, G_loss: 0.2379
# LS-GAN_training Epoch [195/200], D_loss: 0.4984, G_loss: 0.2471
# LS-GAN_training Epoch [196/200], D_loss: 0.4954, G_loss: 0.2507
# LS-GAN_training Epoch [197/200], D_loss: 0.5032, G_loss: 0.2402
# LS-GAN_training Epoch [198/200], D_loss: 0.4988, G_loss: 0.2541
# LS-GAN_training Epoch [199/200], D_loss: 0.4970, G_loss: 0.2632

# %%
# 保存模型参数
def save_model(generator, discriminator, output_dir, epoch):
    # 创建保存目录（如果不存在）
    os.makedirs(output_dir, exist_ok=True)

    # 定义文件名
    generator_filename = os.path.join(output_dir, f"lsgan_generator_epoch_{epoch}.pth")
    discriminator_filename = os.path.join(output_dir, f"lsgan_discriminator_epoch_{epoch}.pth")

    # 保存生成器的模型参数
    torch.save(generator.state_dict(), generator_filename)
    print(f"Generator model saved to {generator_filename}")

    # 保存判别器的模型参数
    torch.save(discriminator.state_dict(), discriminator_filename)
    print(f"Discriminator model saved to {discriminator_filename}")
save_model(lsgan_generator, lsgan_discriminator, 
        output_dir=r"data\model_params\lsgan_model_2", 
        epoch=num_epochs)

# save_model(lsgan_generator, lsgan_discriminator, 
#         output_dir=r"data\model_params\wgan_model", 
#         epoch=num_epochs)
# Out:
# Generator model saved to data\model_params\lsgan_model_2\lsgan_generator_epoch_200.pth
# Discriminator model saved to data\model_params\lsgan_model_2\lsgan_discriminator_epoch_200.pth

# %%
# 生成样本测试
z = torch.randn(test_sample_num, z_dim)
print(z.shape)

generated_data = lsgan_generator(z).detach().numpy()
print(generated_data.shape)

# 将生成的数据转换为 DataFrame
generated_df = pd.DataFrame(generated_data, columns=df_GAN.columns)

# 可视化生成的数据分布（你可以实现自己的可视化函数）
plot_scatter_matrix(df_GAN, generated_df, figsize=(10, 8), font=font)
# Out:
# torch.Size([7377, 4])
# (7377, 4)

# %%
# LSGAN的生成器   初始化   加载生成器参数  获取 PyTorch 模型参数  构建numpy版本  初始化numpy生成器

# 初始化生成器和判别器
lsgan_generator_item = LSGANGenerator(input_dim=z_dim, output_dim=data_dim)


# 加载生成器参数
generator_path = r"data\model_params\lsgan_model_2\lsgan_generator_epoch_200.pth"
lsgan_generator_item.load_state_dict(torch.load(generator_path))
lsgan_generator_item.eval()  # 切换到评估模式
print(f"Generator model loaded from {generator_path}")


# 假设 lsgan_generator_item 已经是训练好的模型
def extract_pytorch_params(model):
    params = {}
    for name, param in model.named_parameters():
        params[name] = param.data.numpy()
    return params
# 获取 PyTorch 模型参数
lsgan_generator_item_params = extract_pytorch_params(lsgan_generator_item)



# 构建numpy版本
class LSGANGeneratorNumpy:
    def __init__(self, input_dim, output_dim, params):
        self.input_dim = input_dim
        self.output_dim = output_dim
        
        # 使用从 PyTorch 模型中提取的参数初始化
        self.W1 = params['model.0.weight'].T  # 转置以匹配 numpy 矩阵乘法
        self.b1 = params['model.0.bias']
        
        self.W2 = params['model.2.weight'].T
        self.b2 = params['model.2.bias']
        
        self.W3 = params['model.4.weight'].T
        self.b3 = params['model.4.bias']
    
    def relu(self, x):
        return np.maximum(0, x)
    
    def tanh(self, x):
        return np.tanh(x)
    
    def forward(self, x):
        z1 = np.dot(x, self.W1) + self.b1
        a1 = self.relu(z1)
        
        z2 = np.dot(a1, self.W2) + self.b2
        a2 = self.relu(z2)
        
        z3 = np.dot(a2, self.W3) + self.b3
        output = self.tanh(z3)
        
        return output
    


# 初始化numpy生成器
lsgan_generator_numpy = LSGANGeneratorNumpy(z_dim, data_dim, lsgan_generator_item_params)



print('参数已迁移')
# Out:
# Generator model loaded from data\model_params\lsgan_model_2\lsgan_generator_epoch_200.pth
# 参数已迁移

# %%
# 验证环节
def series2U(z, M, scalers_X, input_term, isprint = True):
    if(isprint):print(z.shape)

    # 将 z 重新整理成 (M, z_dim) 的二维数组
    z_reshaped = z.reshape(M, z_dim)

    # 将 numpy 数组转换为 tensor，指定 dtype 为 float32
    z_tensor = torch.from_numpy(z_reshaped).float()
    if(isprint):print(z_tensor.shape)

    # z_tensor = torch.randn(2, z_dim)
    generated_data = lsgan_generator(z_tensor).detach().numpy()

    if(isprint):print(generated_data.shape)
    if(isprint):print(generated_data)

    # 分别提取 U1, U2, U3, U4
    U1 = generated_data[:, 0]
    U2 = generated_data[:, 1]
    U3 = generated_data[:, 2]
    U4 = generated_data[:, 3]

    # 将 U1, U2, U3, U4 连接成一个序列
    sequence = np.concatenate((U1, U2, U3, U4))

    if(isprint):print("U1:", U1)
    if(isprint):print("U2:", U2)
    if(isprint):print("U3:", U3)
    if(isprint):print("U4:", U4)
    if(isprint):print("Connected sequence:", sequence)


    U1_inverse = scalers_X[input_term[0]].inverse_transform(U1.reshape(-1, 1)).flatten()
    U2_inverse = scalers_X[input_term[1]].inverse_transform(U2.reshape(-1, 1)).flatten()
    U3_inverse = scalers_X[input_term[2]].inverse_transform(U3.reshape(-1, 1)).flatten()
    U4_inverse = scalers_X[input_term[3]].inverse_transform(U4.reshape(-1, 1)).flatten()

    if(isprint):print("U1_inverse:", U1_inverse)
    if(isprint):print("U2_inverse:", U2_inverse)
    if(isprint):print("U3_inverse:", U3_inverse)
    if(isprint):print("U4_inverse:", U4_inverse)

    return sequence


def series2U_numpy(z, M, scalers_X, input_term, isprint = True):

    if(isprint):print(z.shape)

    # 生成一些随机数据进行测试
    x =  z.reshape(M, z_dim)

    # 前向传播
    generated_data = lsgan_generator_numpy.forward(x)

    if(isprint):print("Generated data shape:", generated_data.shape)
    if(isprint):print("Generated data:\n", generated_data)


    # 分别提取 U1, U2, U3, U4
    U1 = generated_data[:, 0]
    U2 = generated_data[:, 1]
    U3 = generated_data[:, 2]
    U4 = generated_data[:, 3]

    # 将 U1, U2, U3, U4 连接成一个序列
    sequence = np.concatenate((U1, U2, U3, U4))

    if(isprint):print("U1:", U1)
    if(isprint):print("U2:", U2)
    if(isprint):print("U3:", U3)
    if(isprint):print("U4:", U4)
    if(isprint):print("Connected sequence:", sequence)

    U1_inverse = scalers_X[input_term[0]].inverse_transform(U1.reshape(-1, 1)).flatten()
    U2_inverse = scalers_X[input_term[1]].inverse_transform(U2.reshape(-1, 1)).flatten()
    U3_inverse = scalers_X[input_term[2]].inverse_transform(U3.reshape(-1, 1)).flatten()
    U4_inverse = scalers_X[input_term[3]].inverse_transform(U4.reshape(-1, 1)).flatten()

    if(isprint):print("U1_inverse:", U1_inverse)
    if(isprint):print("U2_inverse:", U2_inverse)
    if(isprint):print("U3_inverse:", U3_inverse)
    if(isprint):print("U4_inverse:", U4_inverse)

    return sequence


# 定义 M 和 z_dim
test_size_generated_data = 3      # 样本数量

# 使用 numpy 生成标准正态分布的随机数，形状为 (z_dim * M,)
z = np.random.randn(z_dim * test_size_generated_data)
generated_data          = series2U      (z,test_size_generated_data, scalers, input_term, isprint=False)
generated_data_numpy    = series2U_numpy(z,test_size_generated_data, scalers, input_term, isprint=False)

print("验证原模型与numpy模型的输出是否一致：")
result_d_state = np.fabs(generated_data-generated_data_numpy)<1e-6
# print(result_d_state)
print('总数量：',test_size_generated_data*4,',错误数量：',np.sum(result_d_state==False),'，正确数量：',np.sum(result_d_state==True))
# Out:
# 验证原模型与numpy模型的输出是否一致：
# 总数量： 12 ,错误数量： 0 ，正确数量： 12

# %%
def series2U_numpy_in_control(z, M, scalers_X, scalers, input_term, isprint = True):

    if(isprint):print(z.shape)

    # 生成一些随机数据进行测试
    x =  z.reshape(M, z_dim)

    # 前向传播
    generated_data = lsgan_generator_numpy.forward(x)

    if(isprint):print("Generated data shape:", generated_data.shape)
    if(isprint):print("Generated data:\n", generated_data)


    # 分别提取 U1, U2, U3, U4
    U1 = generated_data[:, 0]
    U2 = generated_data[:, 1]
    U3 = generated_data[:, 2]
    U4 = generated_data[:, 3]

    if(isprint):print("U1:", U1)
    if(isprint):print("U2:", U2)
    if(isprint):print("U3:", U3)
    if(isprint):print("U4:", U4)

    U1_inverse = scalers_X[input_term[0]].inverse_transform(U1.reshape(-1, 1)).flatten()
    U2_inverse = scalers_X[input_term[1]].inverse_transform(U2.reshape(-1, 1)).flatten()
    U3_inverse = scalers_X[input_term[2]].inverse_transform(U3.reshape(-1, 1)).flatten()
    U4_inverse = scalers_X[input_term[3]].inverse_transform(U4.reshape(-1, 1)).flatten()

    if(isprint):print("U1_inverse:", U1_inverse)
    if(isprint):print("U2_inverse:", U2_inverse)
    if(isprint):print("U3_inverse:", U3_inverse)
    if(isprint):print("U4_inverse:", U4_inverse)

    
    U1_inverse_trans = scalers[input_term[0]].transform(U1_inverse.reshape(-1, 1)).flatten()
    U2_inverse_trans = scalers[input_term[1]].transform(U2_inverse.reshape(-1, 1)).flatten()
    U3_inverse_trans = scalers[input_term[2]].transform(U3_inverse.reshape(-1, 1)).flatten()
    U4_inverse_trans = scalers[input_term[3]].transform(U4_inverse.reshape(-1, 1)).flatten()

    
    if(isprint):print("U1_inverse_trans:", U1_inverse_trans)
    if(isprint):print("U2_inverse_trans:", U2_inverse_trans)
    if(isprint):print("U3_inverse_trans:", U3_inverse_trans)
    if(isprint):print("U4_inverse_trans:", U4_inverse_trans)

    # 将 U1, U2, U3, U4 连接成一个序列
    sequence = np.concatenate((U1, U2, U3, U4))
    if(isprint):print("Connected sequence:", sequence)

    return sequence

# %%
# 测试series2U_numpy_in_control生成
z = np.random.randn(z_dim * test_size_generated_data)
generated_data = series2U_numpy_in_control(z,test_size_generated_data, scalers, scalers, input_term, isprint=True)
# Out:
# (12,)
# Generated data shape: (3, 4)
# Generated data:
#  [[0.48852621 0.66062686 0.93928111 0.80224457]
#  [0.15389441 0.31446021 0.76076071 0.20605016]
#  [0.04119085 0.38391659 0.82031692 0.23415921]]
# U1: [0.48852621 0.15389441 0.04119085]
# U2: [0.66062686 0.31446021 0.38391659]
# U3: [0.93928111 0.76076071 0.82031692]
# U4: [0.80224457 0.20605016 0.23415921]
# U1_inverse: [14940.10127923 11581.45512046 10450.26744029]
# U2_inverse: [44.42176884 35.1618113  37.01976928]
# U3_inverse: [0.41896107 0.380368   0.39324304]
# U4_inverse: [1156.29670415  964.15372642  973.21277909]
# U1_inverse_trans: [0.48852621 0.15389441 0.04119085]
# U2_inverse_trans: [0.66062686 0.31446021 0.38391659]
# U3_inverse_trans: [0.93928111 0.76076071 0.82031692]
# U4_inverse_trans: [0.80224457 0.20605016 0.23415921]
# Connected sequence: [0.48852621 0.15389441 0.04119085 0.66062686 0.31446021 0.38391659
#  0.93928111 0.76076071 0.82031692 0.80224457 0.20605016 0.23415921]

# %%
iscontrol = True
# iscontrol = False
Times = 200
# 过度系数  0.1 越小过度越快
rou = 0.1
if_add_noise = 0
if_gaolu_is_predict = 0
if_update_model = True
# if_update_model = False

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,rou,20)

# %%
# # 生成期望数据

def generate_y_aim_data(Times):
    if Times == 400:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        
    elif Times == 200:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10+75:410-125]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0+75:400-125]

    elif Times == 1000:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        set_y1 = np.repeat(np.arange(1457.5, 1562.5, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.35, 0.77, 0.02), 20)[0:400]

    else:
        set_y1 = np.full(Times,1500)
        set_y2 = np.full(Times,0.45)

    





    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)
print(set_y1.shape)
print(set_y1.shape)
# Out:
# (200,)
# (200,)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):

    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]

    
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    params = series2U_numpy_in_control(params,M, scalers, scalers, input_term, isprint=False)
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]
    
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = model_numpy.my_predict(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,rou,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,rou,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)

    # y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    # y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    # u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    # u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    # u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    # u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    # u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    # u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    # u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
# 生成高斯噪声,设置随机种子，以便结果可重现
np.random.seed(42)
gaussian_noise_SI = np.random.normal(0,d_yuansu*0.001,Times)
gaussian_noise_TEMP = np.random.normal(0,d_temp*0.1,Times)
plt.subplot(2, 1, 1)
plt.plot(gaussian_noise_SI)
plt.subplot(2, 1, 2)
plt.plot(gaussian_noise_TEMP)

# %%
def update_model(model_predict,model_gaolu,x,gaolu_data_past_x,gaolu_data_past_y,ifprint = False):
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    y_label = np.column_stack((y1_pred, y2_pred))
    gaolu_data_past_x.append(x)
    gaolu_data_past_y.append(y_label)

    
    X_modified = np.array(gaolu_data_past_x)
    y_modified = np.array(gaolu_data_past_y)
    if(ifprint):print(X_modified)
    if(ifprint):print(y_modified)
    X = X_modified.reshape(X_modified.shape[0],X_modified.shape[2])
    Y = y_modified.reshape(y_modified.shape[0],y_modified.shape[2])
    # print(X_modified.shape)
    # print(y_modified.shape)
    if y_modified.shape[0]% 1 == 0:
        model_predict.model_update(X, Y,
                                epochs=10, 
                                batch_size=64,
                                lr = 0.002,
                                ifprint = ifprint)
        # gaolu_data_past_x = []
        # gaolu_data_past_y = []

    return model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 3  # 预测时域长度  3
M = 3  # 4
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data,
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
gaolu_data_past_x = []
gaolu_data_past_y = []


# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.random.randn(z_dim * M)
    bounds = [(-max_control, max_control) for _ in range(z_dim * M)]
    
    # params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    # bounds = [(-max_control, max_control) for _ in range(4 * M)]

    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    result_u = series2U_numpy_in_control(result.x,M, scalers, scalers, input_term, isprint=False)

    U1, U2, U3, U4 =    result_u[0:M], result_u[M:2*M], \
                        result_u[2*M:3*M], result_u[3*M:4*M]
    
    
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                            y1[j+1],y2[j+1]))
    # x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model_predict.my_predict(x)
    if if_gaolu_is_predict:
        y1_pred, y2_pred = model_predict.my_predict(x)
        if if_add_noise:
            y1_pred = y1_pred+gaussian_noise_TEMP[k].item()
            y2_pred = y2_pred+gaussian_noise_SI[k].item()
    else:
        y1_pred, y2_pred = model_gaolu.my_predict(x)
        if if_update_model:
            model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y = update_model(model_predict,model_gaolu,
                                                                                        x,gaolu_data_past_x,gaolu_data_past_y,
                                                                                        ifprint = False)




    # 更新k_data
    params = result.x
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    k_data2[14] = y1_pred.item()
    k_data2[17] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 579
# (18,)
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [-0.1358] 高炉 [0.2036] 高炉与设定误差 [-0.4649] [-39.3314408] 模型误差 [-0.3394] 校正值 [-0.5228]
# 2设定 -0.6401 预测 [-0.4536] 高炉 [-0.3821] 高炉与设定误差 [-0.258] [-0.23959169] 模型误差 [-0.0715] 校正值 [0.0733]
# 这是对第1时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.6191] 高炉 [0.3659] 高炉与设定误差 [-0.6273] [-53.070799] 模型误差 [0.2531] 校正值 [0.0501]
# 2设定 -0.6401 预测 [-0.4479] 高炉 [-0.5914] 高炉与设定误差 [-0.0487] [-0.04522526] 模型误差 [0.1435] 校正值 [0.0087]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.3283] 高炉 [0.3742] 高炉与设定误差 [-0.6356] [-53.7729906] 模型误差 [-0.046] 校正值 [0.0056]
# 2设定 -0.6401 预测 [-0.6205] 高炉 [-0.6392] 高炉与设定误差 [-0.001] [-0.00092865] 模型误差 [0.0187] 校正值 [0.0123]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.3584] 高炉 [0.3555] 高炉与设定误差 [-0.6169] [-52.19093905] 模型误差 [0.0029] 校正值 [-0.0018]
# 2设定 -0.6401 预测 [-0.6499] 高炉 [-0.6716] 高炉与设定误差 [0.0314] [0.02915961] 模型误差 [0.0217] 校正值 [0.0146]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.4408] 高炉 [0.3588] 高炉与设定误差 [-0.6202] [-52.47012136] 模型误差 [0.0819] 校正值 [0.0107]
# 2设定 -0.6401 预测 [-0.4407] 高炉 [-0.4332] 高炉与设定误差 [-0.2069] [-0.19213769] 模型误差 [-0.0075] 校正值 [-0.0203]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.117] 高炉 [0.1775] 高炉与设定误差 [-0.4389] [-37.13179095] 模型误差 [-0.0605] 校正值 [-0.0178]
# 2设定 -0.6186 预测 [-0.4945] 高炉 [-0.5476] 高炉与设定误差 [-0.071] [-0.06593415] 模型误差 [0.0531] 校正值 [0.0129]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.2135] 高炉 [0.1621] 高炉与设定误差 [-0.4235] [-35.82892171] 模型误差 [0.0514] 校正值 [0.0295]
# 2设定 -0.6186 预测 [-0.6521] 高炉 [-0.6384] 高炉与设定误差 [0.0198] [0.01838727] 模型误差 [-0.0137] 校正值 [-0.0103]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.3524] 高炉 [0.3332] 高炉与设定误差 [-0.5945] [-50.29585377] 模型误差 [0.0192] 校正值 [-0.0193]
# 2设定 -0.6186 预测 [-0.4448] 高炉 [-0.4531] 高炉与设定误差 [-0.1654] [-0.15359871] 模型误差 [0.0083] 校正值 [0.0144]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.1472] 高炉 [0.1576] 高炉与设定误差 [-0.419] [-35.44821284] 模型误差 [-0.0104] 校正值 [0.0039]
# 2设定 -0.6186 预测 [-0.5365] 高炉 [-0.5345] 高炉与设定误差 [-0.0841] [-0.07809947] 模型误差 [-0.0021] 校正值 [-0.012]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.24] 高炉 [0.1874] 高炉与设定误差 [-0.4487] [-37.96089139] 模型误差 [0.0526] 校正值 [0.0001]
# 2设定 -0.6186 预测 [-0.5091] 高炉 [-0.5526] 高炉与设定误差 [-0.066] [-0.0612909] 模型误差 [0.0434] 校正值 [0.0093]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.1425] 高炉 [0.1451] 高炉与设定误差 [-0.4064] [-34.382228] 模型误差 [-0.0026] 校正值 [0.0073]
# 2设定 -0.6186 预测 [-0.5515] 高炉 [-0.5636] 高炉与设定误差 [-0.055] [-0.05107575] 模型误差 [0.0121] 校正值 [-0.0179]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.102] 高炉 [0.1276] 高炉与设定误差 [-0.3889] [-32.90169546] 模型误差 [-0.0255] 校正值 [0.0002]
# 2设定 -0.6186 预测 [-0.5494] 高炉 [-0.578] 高炉与设定误差 [-0.0406] [-0.03770319] 模型误差 [0.0286] 校正值 [0.001]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.0904] 高炉 [0.0903] 高炉与设定误差 [-0.3516] [-29.74604137] 模型误差 [1.e-04] 校正值 [0.0215]
# 2设定 -0.6186 预测 [-0.5497] 高炉 [-0.5624] 高炉与设定误差 [-0.0562] [-0.05219013] 模型误差 [0.0127] 校正值 [-0.0174]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.0664] 高炉 [0.0763] 高炉与设定误差 [-0.3376] [-28.56161433] 模型误差 [-0.0098] 校正值 [-0.0062]
# 2设定 -0.6186 预测 [-0.5098] 高炉 [-0.525] 高炉与设定误差 [-0.0936] [-0.08692164] 模型误差 [0.0151] 校正值 [-0.0033]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 -0.2613 预测 [0.0569] 高炉 [0.0451] 高炉与设定误差 [-0.3064] [-25.9220345] 模型误差 [0.0118] 校正值 [0.0088]
# 2设定 -0.6186 预测 [-0.5378] 高炉 [-0.5128] 高炉与设定误差 [-0.1057] [-0.09815831] 模型误差 [-0.025] 校正值 [-0.0139]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.0548] 高炉 [0.0629] 高炉与设定误差 [-0.2651] [-22.42797449] 模型误差 [-0.0081] 校正值 [-0.0129]
# 2设定 -0.6186 预测 [-0.5508] 高炉 [-0.5561] 高炉与设定误差 [-0.0625] [-0.05804062] 模型误差 [0.0053] 校正值 [0.0172]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.0797] 高炉 [0.084] 高炉与设定误差 [-0.2863] [-24.22153572] 模型误差 [-0.0043] 校正值 [0.0077]
# 2设定 -0.6186 预测 [-0.5582] 高炉 [-0.5378] 高炉与设定误差 [-0.0807] [-0.07494206] 模型误差 [-0.0204] 校正值 [-0.0098]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.0699] 高炉 [0.0693] 高炉与设定误差 [-0.2716] [-22.97788758] 模型误差 [0.0006] 校正值 [-0.0092]
# 2设定 -0.6186 预测 [-0.5416] 高炉 [-0.5535] 高炉与设定误差 [-0.0651] [-0.06045511] 模型误差 [0.0119] 校正值 [0.007]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.0835] 高炉 [0.1211] 高炉与设定误差 [-0.3234] [-27.36026662] 模型误差 [-0.0377] 校正值 [0.0019]
# 2设定 -0.6186 预测 [-0.6446] 高炉 [-0.5999] 高炉与设定误差 [-0.0186] [-0.01727289] 模型误差 [-0.0447] 校正值 [-0.0071]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.2274] 高炉 [0.2201] 高炉与设定误差 [-0.4223] [-35.72740019] 模型误差 [0.0073] 校正值 [0.0094]
# 2设定 -0.6186 预测 [-0.6801] 高炉 [-0.6979] 高炉与设定误差 [0.0793] [0.07364195] 模型误差 [0.0177] 校正值 [0.0252]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.3244] 高炉 [0.3061] 高炉与设定误差 [-0.5083] [-43.00316664] 模型误差 [0.0183] 校正值 [0.0015]
# 2设定 -0.6186 预测 [-0.5315] 高炉 [-0.5369] 高炉与设定误差 [-0.0817] [-0.0758707] 模型误差 [0.0054] 校正值 [-0.0154]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1829] 高炉 [0.1525] 高炉与设定误差 [-0.3547] [-30.00830804] 模型误差 [0.0304] 校正值 [-0.0092]
# 2设定 -0.6186 预测 [-0.6] 高炉 [-0.6207] 高炉与设定误差 [0.0022] [0.00204303] 模型误差 [0.0207] 校正值 [0.0009]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.2679] 高炉 [0.2357] 高炉与设定误差 [-0.4379] [-37.0471901] 模型误差 [0.0322] 校正值 [-0.0213]
# 2设定 -0.6186 预测 [-0.653] 高炉 [-0.6573] 高炉与设定误差 [0.0387] [0.03593875] 模型误差 [0.0044] 校正值 [-0.0167]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.2552] 高炉 [0.2269] 高炉与设定误差 [-0.4291] [-36.30269303] 模型误差 [0.0283] 校正值 [-0.0162]
# 2设定 -0.6186 预测 [-0.5967] 高炉 [-0.6191] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [0.0223] 校正值 [0.0023]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.2019] 高炉 [0.1792] 高炉与设定误差 [-0.3815] [-32.27564059] 模型误差 [0.0226] 校正值 [-0.0168]
# 2设定 -0.6186 预测 [-0.5861] 高炉 [-0.5731] 高炉与设定误差 [-0.0455] [-0.04225357] 模型误差 [-0.013] 校正值 [-0.0163]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1563] 高炉 [0.1609] 高炉与设定误差 [-0.3631] [-30.71896376] 模型误差 [-0.0046] 校正值 [-0.0232]
# 2设定 -0.597 预测 [-0.5625] 高炉 [-0.5686] 高炉与设定误差 [-0.0285] [-0.02646653] 模型误差 [0.0061] 校正值 [0.0131]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1359] 高炉 [0.1522] 高炉与设定误差 [-0.3545] [-29.99138737] 模型误差 [-0.0164] 校正值 [0.0008]
# 2设定 -0.597 预测 [-0.5749] 高炉 [-0.5625] 高炉与设定误差 [-0.0345] [-0.03203842] 模型误差 [-0.0124] 校正值 [-0.0079]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1256] 高炉 [0.1306] 高炉与设定误差 [-0.3328] [-28.15552571] 模型误差 [-0.005] 校正值 [0.0136]
# 2设定 -0.597 预测 [-0.6148] 高炉 [-0.6185] 高炉与设定误差 [0.0215] [0.01996598] 模型误差 [0.0037] 校正值 [0.0127]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.246] 高炉 [0.2319] 高炉与设定误差 [-0.4341] [-36.72570233] 模型误差 [0.0142] 校正值 [0.0048]
# 2设定 -0.597 预测 [-0.6542] 高炉 [-0.6461] 高炉与设定误差 [0.049] [0.04550385] 模型误差 [-0.0081] 校正值 [-0.0062]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.221] 高炉 [0.2183] 高炉与设定误差 [-0.4206] [-35.58357571] 模型误差 [0.0027] 校正值 [-0.0115]
# 2设定 -0.597 预测 [-0.6195] 高炉 [-0.6265] 高炉与设定误差 [0.0294] [0.02730231] 模型误差 [0.007] 校正值 [0.01]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.2133] 高炉 [0.1977] 高炉与设定误差 [-0.4] [-33.8407765] 模型误差 [0.0156] 校正值 [-0.]
# 2设定 -0.597 预测 [-0.5583] 高炉 [-0.5414] 高炉与设定误差 [-0.0556] [-0.05163294] 模型误差 [-0.0169] 校正值 [-0.0069]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1591] 高炉 [0.1694] 高炉与设定误差 [-0.3717] [-31.44654015] 模型误差 [-0.0103] 校正值 [-0.0126]
# 2设定 -0.597 预测 [-0.6446] 高炉 [-0.6479] 高炉与设定误差 [0.0509] [0.04726829] 模型误差 [0.0033] 校正值 [0.0165]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.3191] 高炉 [0.3124] 高炉与设定误差 [-0.5146] [-43.53615654] 模型误差 [0.0068] 校正值 [0.0082]
# 2设定 -0.597 预测 [-0.4366] 高炉 [-0.4148] 高炉与设定误差 [-0.1823] [-0.1692929] 模型误差 [-0.0219] 校正值 [-0.0047]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1114] 高炉 [0.1634] 高炉与设定误差 [-0.3657] [-30.93893001] 模型误差 [-0.052] 校正值 [-0.0056]
# 2设定 -0.597 预测 [-0.4687] 高炉 [-0.4462] 高炉与设定误差 [-0.1509] [-0.14013329] 模型误差 [-0.0226] 校正值 [0.0203]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 -0.2022 预测 [0.1174] 高炉 [0.1143] 高炉与设定误差 [-0.3165] [-26.7765147] 模型误差 [0.0031] 校正值 [0.0317]
# 2设定 -0.597 预测 [-0.5069] 高炉 [-0.4993] 高炉与设定误差 [-0.0977] [-0.0907291] 模型误差 [-0.0075] 校正值 [0.0146]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.0804] 高炉 [0.0814] 高炉与设定误差 [-0.2245] [-18.99313557] 模型误差 [-0.0009] 校正值 [-0.0051]
# 2设定 -0.597 预测 [-0.5428] 高炉 [-0.5577] 高炉与设定误差 [-0.0394] [-0.03658881] 模型误差 [0.0149] 校正值 [0.0072]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1009] 高炉 [0.0958] 高炉与设定误差 [-0.239] [-20.21986303] 模型误差 [0.0051] 校正值 [0.0022]
# 2设定 -0.597 预测 [-0.529] 高炉 [-0.5237] 高炉与设定误差 [-0.0734] [-0.06816291] 模型误差 [-0.0053] 校正值 [-0.013]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1243] 高炉 [0.1288] 高炉与设定误差 [-0.272] [-23.01172893] 模型误差 [-0.0045] 校正值 [-0.0044]
# 2设定 -0.597 预测 [-0.5892] 高炉 [-0.5978] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [0.0087] 校正值 [0.0067]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.2655] 高炉 [0.2545] 高炉与设定误差 [-0.3977] [-33.64619253] 模型误差 [0.011] 校正值 [0.0042]
# 2设定 -0.597 预测 [-0.6314] 高炉 [-0.6186] 高炉与设定误差 [0.0215] [0.01996598] 模型误差 [-0.0128] 校正值 [-0.0096]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.2053] 高炉 [0.198] 高炉与设定误差 [-0.3411] [-28.85772235] 模型误差 [0.0073] 校正值 [-0.0102]
# 2设定 -0.597 预测 [-0.679] 高炉 [-0.6942] 高炉与设定误差 [0.0971] [0.09017191] 模型误差 [0.0152] 校正值 [0.0123]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.2996] 高炉 [0.2925] 高炉与设定误差 [-0.4357] [-36.8610652] 模型误差 [0.0071] 校正值 [-0.0027]
# 2设定 -0.597 预测 [-0.5382] 高炉 [-0.5298] 高炉与设定误差 [-0.0672] [-0.06240528] 模型误差 [-0.0084] 校正值 [-0.0114]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1649] 高炉 [0.1793] 高炉与设定误差 [-0.3225] [-27.28412484] 模型误差 [-0.0145] 校正值 [-0.006]
# 2设定 -0.597 预测 [-0.4878] 高炉 [-0.4925] 高炉与设定误差 [-0.1046] [-0.09713679] 模型误差 [0.0047] 校正值 [0.0093]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1255] 高炉 [0.1189] 高炉与设定误差 [-0.2621] [-22.17416941] 模型误差 [0.0066] 校正值 [0.0131]
# 2设定 -0.597 预测 [-0.5295] 高炉 [-0.5218] 高炉与设定误差 [-0.0752] [-0.06983448] 模型误差 [-0.0076] 校正值 [-0.0047]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.0975] 高炉 [0.0798] 高炉与设定误差 [-0.223] [-18.86623303] 模型误差 [0.0177] 校正值 [-0.0074]
# 2设定 -0.597 预测 [-0.521] 高炉 [-0.5326] 高炉与设定误差 [-0.0644] [-0.05980506] 模型误差 [0.0116] 校正值 [0.0081]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1089] 高炉 [0.1095] 高炉与设定误差 [-0.2526] [-21.37045125] 模型误差 [-0.0005] 校正值 [-0.012]
# 2设定 -0.597 预测 [-0.5643] 高炉 [-0.5555] 高炉与设定误差 [-0.0415] [-0.03853897] 模型误差 [-0.0088] 校正值 [-0.0104]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.0553] 高炉 [0.0539] 高炉与设定误差 [-0.197] [-16.66658192] 模型误差 [0.0015] 校正值 [-0.0002]
# 2设定 -0.5755 预测 [-0.5312] 高炉 [-0.544] 高炉与设定误差 [-0.0315] [-0.02925248] 模型误差 [0.0128] 校正值 [0.008]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1389] 高炉 [0.1483] 高炉与设定误差 [-0.2914] [-24.65300409] 模型误差 [-0.0094] 校正值 [-0.0008]
# 2设定 -0.5755 预测 [-0.6494] 高炉 [-0.6302] 高炉与设定误差 [0.0547] [0.05079715] 模型误差 [-0.0193] 校正值 [-0.0111]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.2432] 高炉 [0.2436] 高炉与设定误差 [-0.3867] [-32.71557057] 模型误差 [-0.0003] 校正值 [0.0052]
# 2设定 -0.5755 预测 [-0.6169] 高炉 [-0.6304] 高炉与设定误差 [0.0549] [0.05098289] 模型误差 [0.0135] 校正值 [0.018]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.2217] 高炉 [0.2269] 高炉与设定误差 [-0.37] [-31.3027182] 模型误差 [-0.0052] 校正值 [-0.0002]
# 2设定 -0.5755 预测 [-0.6231] 高炉 [-0.6057] 高炉与设定误差 [0.0302] [0.02804523] 模型误差 [-0.0174] 校正值 [-0.013]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1898] 高炉 [0.1994] 高炉与设定误差 [-0.3425] [-28.97616455] 模型误差 [-0.0096] 校正值 [0.0033]
# 2设定 -0.5755 预测 [-0.5038] 高炉 [-0.5026] 高炉与设定误差 [-0.0729] [-0.06769858] 模型误差 [-0.0012] 校正值 [0.0166]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1541] 高炉 [0.1526] 高炉与设定误差 [-0.2957] [-25.01679481] 模型误差 [0.0015] 校正值 [0.0054]
# 2设定 -0.5755 预测 [-0.5393] 高炉 [-0.5316] 高炉与设定误差 [-0.0439] [-0.04076774] 模型误差 [-0.0077] 校正值 [-0.0005]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.089] 高炉 [0.0984] 高炉与设定误差 [-0.2415] [-20.43136894] 模型误差 [-0.0094] 校正值 [-0.0024]
# 2设定 -0.5755 预测 [-0.5675] 高炉 [-0.5734] 高炉与设定误差 [-0.0021] [-0.00195016] 模型误差 [0.0059] 校正值 [0.0079]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.1133] 高炉 [0.1196] 高炉与设定误差 [-0.2628] [-22.23339051] 模型误差 [-0.0063] 校正值 [0.0087]
# 2设定 -0.5755 预测 [-0.5498] 高炉 [-0.5362] 高炉与设定误差 [-0.0393] [-0.03649594] 模型误差 [-0.0135] 校正值 [-0.0061]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.063] 高炉 [0.0636] 高炉与设定误差 [-0.2067] [-17.48722076] 模型误差 [-0.0006] 校正值 [0.0048]
# 2设定 -0.5755 预测 [-0.5407] 高炉 [-0.5461] 高炉与设定误差 [-0.0294] [-0.02730231] 模型误差 [0.0054] 校正值 [0.0135]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 -0.1431 预测 [0.0832] 高炉 [0.0788] 高炉与设定误差 [-0.222] [-18.78163092] 模型误差 [0.0043] 校正值 [0.0016]
# 2设定 -0.5755 预测 [-0.5822] 高炉 [-0.5756] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [-0.0066] 校正值 [-0.005]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0745] 高炉 [0.0784] 高炉与设定误差 [-0.1625] [-13.74781475] 模型误差 [-0.004] 校正值 [-0.0045]
# 2设定 -0.5755 预测 [-0.5652] 高炉 [-0.5743] 高炉与设定误差 [-0.0012] [-0.00111438] 模型误差 [0.0091] 校正值 [0.007]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0795] 高炉 [0.0698] 高炉与设定误差 [-0.1538] [-13.01177801] 模型误差 [0.0097] 校正值 [0.004]
# 2设定 -0.5755 预测 [-0.5793] 高炉 [-0.5765] 高炉与设定误差 [0.001] [0.00092865] 模型误差 [-0.0028] 校正值 [-0.0086]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0815] 高炉 [0.0884] 高炉与设定误差 [-0.1725] [-14.5938346] 模型误差 [-0.0069] 校正值 [-0.0102]
# 2设定 -0.5755 预测 [-0.5508] 高炉 [-0.5529] 高炉与设定误差 [-0.0226] [-0.02098749] 模型误差 [0.002] 校正值 [0.003]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0456] 高炉 [0.0314] 高炉与设定误差 [-0.1154] [-9.763064] 模型误差 [0.0142] 校正值 [0.0065]
# 2设定 -0.5755 预测 [-0.5673] 高炉 [-0.5598] 高炉与设定误差 [-0.0157] [-0.0145798] 模型误差 [-0.0076] 校正值 [-0.0031]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0295] 高炉 [0.0403] 高炉与设定误差 [-0.1243] [-10.5160214] 模型误差 [-0.0107] 校正值 [-0.0134]
# 2设定 -0.5755 预测 [-0.558] 高炉 [-0.56] 高炉与设定误差 [-0.0155] [-0.01439407] 模型误差 [0.0019] 校正值 [0.008]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0725] 高炉 [0.0608] 高炉与设定误差 [-0.1448] [-12.25036153] 模型误差 [0.0117] 校正值 [0.0103]
# 2设定 -0.5755 预测 [-0.596] 高炉 [-0.5911] 高炉与设定误差 [0.0156] [0.01448694] 模型误差 [-0.0049] 校正值 [-0.0017]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0548] 高炉 [0.0471] 高炉与设定误差 [-0.1311] [-11.09131425] 模型误差 [0.0077] 校正值 [-0.0113]
# 2设定 -0.5755 预测 [-0.5817] 高炉 [-0.6072] 高炉与设定误差 [0.0317] [0.02943821] 模型误差 [0.0255] 校正值 [0.0055]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0811] 高炉 [0.078] 高炉与设定误差 [-0.1621] [-13.71397466] 模型误差 [0.0031] 校正值 [-0.002]
# 2设定 -0.5755 预测 [-0.5173] 高炉 [-0.4946] 高炉与设定误差 [-0.0809] [-0.07512778] 模型误差 [-0.0227] 校正值 [-0.0225]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0967] 高炉 [0.1157] 高炉与设定误差 [-0.1998] [-16.90346758] 模型误差 [-0.019] 校正值 [-0.0034]
# 2设定 -0.5755 预测 [-0.5643] 高炉 [-0.5839] 高炉与设定误差 [0.0084] [0.00780066] 模型误差 [0.0196] 校正值 [0.0219]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.1228] 高炉 [0.1397] 高炉与设定误差 [-0.2237] [-18.92545413] 模型误差 [-0.0169] 校正值 [0.024]
# 2设定 -0.5755 预测 [-0.5045] 高炉 [-0.4776] 高炉与设定误差 [-0.0979] [-0.09091484] 模型误差 [-0.0269] 校正值 [-0.0031]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0891] 高炉 [0.086] 高炉与设定误差 [-0.1701] [-14.39079029] 模型误差 [0.0031] 校正值 [-0.0031]
# 2设定 -0.554 预测 [-0.5035] 高炉 [-0.5024] 高炉与设定误差 [-0.0516] [-0.04791834] 模型误差 [-0.0011] 校正值 [0.0079]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0756] 高炉 [0.0669] 高炉与设定误差 [-0.1509] [-12.76643328] 模型误差 [0.0087] 校正值 [0.0098]
# 2设定 -0.554 预测 [-0.5274] 高炉 [-0.5312] 高炉与设定误差 [-0.0228] [-0.02117322] 模型误差 [0.0037] 校正值 [0.0095]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.0471] 高炉 [0.0526] 高炉与设定误差 [-0.1367] [-11.56508557] 模型误差 [-0.0056] 校正值 [-0.0118]
# 2设定 -0.554 预测 [-0.5368] 高炉 [-0.531] 高炉与设定误差 [-0.023] [-0.02135895] 模型误差 [-0.0058] 校正值 [-0.0106]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.1291] 高炉 [0.1211] 高炉与设定误差 [-0.2052] [-17.36031822] 模型误差 [0.008] 校正值 [0.0028]
# 2设定 -0.554 预测 [-0.5874] 高炉 [-0.592] 高炉与设定误差 [0.0381] [0.03538157] 模型误差 [0.0046] 校正值 [0.0046]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.2117] 高炉 [0.2206] 高炉与设定误差 [-0.3046] [-25.76975096] 模型误差 [-0.0089] 校正值 [-0.0061]
# 2设定 -0.554 预测 [-0.7037] 高炉 [-0.6963] 高炉与设定误差 [0.1423] [0.13214689] 模型误差 [-0.0074] 校正值 [-0.0119]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.298] 高炉 [0.2945] 高炉与设定误差 [-0.3786] [-32.0302946] 模型误差 [0.0035] 校正值 [0.0069]
# 2设定 -0.554 预测 [-0.5438] 高炉 [-0.5662] 高炉与设定误差 [0.0122] [0.01132953] 模型误差 [0.0223] 校正值 [0.0086]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.1729] 高炉 [0.1696] 高炉与设定误差 [-0.2536] [-21.4550521] 模型误差 [0.0033] 校正值 [-0.0057]
# 2设定 -0.554 预测 [-0.5506] 高炉 [-0.542] 高炉与设定误差 [-0.0119] [-0.01105094] 模型误差 [-0.0086] 校正值 [-0.0177]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.2081] 高炉 [0.1851] 高炉与设定误差 [-0.2692] [-22.77484201] 模型误差 [0.0229] 校正值 [0.0016]
# 2设定 -0.554 预测 [-0.4714] 高炉 [-0.4772] 高炉与设定误差 [-0.0767] [-0.07122746] 模型误差 [0.0059] 校正值 [0.0088]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.1298] 高炉 [0.1521] 高炉与设定误差 [-0.2361] [-19.9745183] 模型误差 [-0.0222] 校正值 [-0.017]
# 2设定 -0.554 预测 [-0.5714] 高炉 [-0.5558] 高炉与设定误差 [0.0018] [0.00167157] 模型误差 [-0.0156] 校正值 [-0.0071]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 -0.084 预测 [0.1315] 高炉 [0.1399] 高炉与设定误差 [-0.2239] [-18.94237481] 模型误差 [-0.0084] 校正值 [0.0188]
# 2设定 -0.554 预测 [-0.4852] 高炉 [-0.4917] 高炉与设定误差 [-0.0623] [-0.0578549] 模型误差 [0.0065] 校正值 [0.0158]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1081] 高炉 [0.1286] 高炉与设定误差 [-0.1536] [-12.9948586] 模型误差 [-0.0205] 校正值 [0.0076]
# 2设定 -0.554 预测 [-0.5368] 高炉 [-0.5163] 高炉与设定误差 [-0.0377] [-0.03501011] 模型误差 [-0.0205] 校正值 [-0.007]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.0728] 高炉 [0.0788] 高炉与设定误差 [-0.1037] [-8.77322093] 模型误差 [-0.0059] 校正值 [0.0194]
# 2设定 -0.554 预测 [-0.5133] 高炉 [-0.515] 高炉与设定误差 [-0.039] [-0.03621735] 模型误差 [0.0017] 校正值 [0.0188]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.088] 高炉 [0.1064] 高炉与设定误差 [-0.1313] [-11.10823492] 模型误差 [-0.0184] 校正值 [0.0042]
# 2设定 -0.554 预测 [-0.5489] 高炉 [-0.5324] 高炉与设定误差 [-0.0215] [-0.01996598] 模型误差 [-0.0165] 校正值 [-0.0049]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.0501] 高炉 [0.0608] 高炉与设定误差 [-0.0858] [-7.25884641] 模型误差 [-0.0107] 校正值 [0.0171]
# 2设定 -0.554 预测 [-0.531] 高炉 [-0.535] 高炉与设定误差 [-0.019] [-0.01764435] 模型误差 [0.0039] 校正值 [0.0146]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1367] 高炉 [0.1511] 高炉与设定误差 [-0.1761] [-14.8984017] 模型误差 [-0.0145] 校正值 [0.005]
# 2设定 -0.554 预测 [-0.6404] 高炉 [-0.6287] 高炉与设定误差 [0.0747] [0.06937015] 模型误差 [-0.0117] 校正值 [-0.0044]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.2283] 高炉 [0.2205] 高炉与设定误差 [-0.2455] [-20.76977613] 模型误差 [0.0078] 校正值 [0.0112]
# 2设定 -0.554 预测 [-0.6942] 高炉 [-0.7056] 高炉与设定误差 [0.1517] [0.14087621] 模型误差 [0.0114] 校正值 [0.015]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.2198] 高炉 [0.2232] 高炉与设定误差 [-0.2481] [-20.98974111] 模型误差 [-0.0034] 校正值 [-0.0045]
# 2设定 -0.554 预测 [-0.7239] 高炉 [-0.7235] 高炉与设定误差 [0.1695] [0.15740617] 模型误差 [-0.0005] 校正值 [-0.0111]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.3003] 高炉 [0.2979] 高炉与设定误差 [-0.3228] [-27.30950712] 模型误差 [0.0024] 校正值 [0.0059]
# 2设定 -0.554 预测 [-0.5126] 高炉 [-0.5216] 高炉与设定误差 [-0.0324] [-0.03008826] 模型误差 [0.0089] 校正值 [0.002]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1362] 高炉 [0.1472] 高炉与设定误差 [-0.1721] [-14.55999325] 模型误差 [-0.0109] 校正值 [-0.0015]
# 2设定 -0.554 预测 [-0.5124] 高炉 [-0.5085] 高炉与设定误差 [-0.0455] [-0.04225357] 模型误差 [-0.004] 校正值 [-0.0088]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.128] 高炉 [0.134] 高炉与设定误差 [-0.1589] [-13.44324765] 模型误差 [-0.006] 校正值 [0.0092]
# 2设定 -0.554 预测 [-0.5135] 高炉 [-0.5212] 高炉与设定误差 [-0.0328] [-0.03045972] 模型误差 [0.0076] 校正值 [0.0047]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.0885] 高炉 [0.0942] 高炉与设定误差 [-0.1191] [-10.0760908] 模型误差 [-0.0057] 校正值 [0.0047]
# 2设定 -0.5324 预测 [-0.5557] 高炉 [-0.5509] 高炉与设定误差 [0.0185] [0.01718003] 模型误差 [-0.0047] 校正值 [-0.007]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1086] 高炉 [0.1161] 高炉与设定误差 [-0.1411] [-11.9373341] 模型误差 [-0.0075] 校正值 [0.0048]
# 2设定 -0.5324 预测 [-0.6161] 高炉 [-0.6197] 高炉与设定误差 [0.0873] [0.08107115] 模型误差 [0.0036] 校正值 [0.0056]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.2864] 高炉 [0.2906] 高炉与设定误差 [-0.3156] [-26.70037292] 模型误差 [-0.0043] 校正值 [0.0036]
# 2设定 -0.5324 预测 [-0.5291] 高炉 [-0.5112] 高炉与设定误差 [-0.0212] [-0.01968738] 模型误差 [-0.0178] 校正值 [-0.0068]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1465] 高炉 [0.1442] 高炉与设定误差 [-0.1691] [-14.30618818] 模型误差 [0.0023] 校正值 [0.0051]
# 2设定 -0.5324 预测 [-0.5253] 高炉 [-0.531] 高炉与设定误差 [-0.0014] [-0.00130011] 模型误差 [0.0057] 校正值 [0.017]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1691] 高炉 [0.1955] 高炉与设定误差 [-0.2204] [-18.64626805] 模型误差 [-0.0264] 校正值 [-0.0002]
# 2设定 -0.5324 预测 [-0.4482] 高炉 [-0.4169] 高炉与设定误差 [-0.1155] [-0.10725908] 模型误差 [-0.0313] 校正值 [-0.0046]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.15] 高炉 [0.153] 高炉与设定误差 [-0.178] [-15.05914558] 模型误差 [-0.003] 校正值 [0.0189]
# 2设定 -0.5324 预测 [-0.5157] 高炉 [-0.5232] 高炉与设定误差 [-0.0093] [-0.00863645] 模型误差 [0.0075] 校正值 [0.0234]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1189] 高炉 [0.115] 高炉与设定误差 [-0.1399] [-11.83581131] 模型误差 [0.0039] 校正值 [0.0002]
# 2设定 -0.5324 预测 [-0.5006] 高炉 [-0.4854] 高炉与设定误差 [-0.047] [-0.04364655] 模型误差 [-0.0152] 校正值 [-0.0086]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.1122] 高炉 [0.1251] 高炉与设定误差 [-0.1501] [-12.69875058] 模型误差 [-0.0129] 校正值 [-0.0035]
# 2设定 -0.5324 预测 [-0.4726] 高炉 [-0.4758] 高炉与设定误差 [-0.0566] [-0.05256159] 模型误差 [0.0032] 校正值 [0.0155]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.0784] 高炉 [0.0931] 高炉与设定误差 [-0.118] [-9.98302898] 模型误差 [-0.0147] 校正值 [0.0119]
# 2设定 -0.5324 预测 [-0.5045] 高炉 [-0.488] 高炉与设定误差 [-0.0445] [-0.04132493] 模型误差 [-0.0166] 校正值 [-0.0039]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 -0.0249 预测 [0.053] 高炉 [0.059] 高炉与设定误差 [-0.0839] [-7.09810253] 模型误差 [-0.006] 校正值 [0.0142]
# 2设定 -0.5324 预测 [-0.5043] 高炉 [-0.507] 高炉与设定误差 [-0.0254] [-0.02358771] 模型误差 [0.0028] 校正值 [0.0156]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0779] 高炉 [0.0854] 高炉与设定误差 [-0.0513] [-4.34007956] 模型误差 [-0.0075] 校正值 [0.0059]
# 2设定 -0.5324 预测 [-0.5551] 高炉 [-0.5458] 高炉与设定误差 [0.0133] [0.01235104] 模型误差 [-0.0093] 校正值 [-0.0029]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0549] 高炉 [0.0516] 高炉与设定误差 [-0.0174] [-1.47207378] 模型误差 [0.0033] 校正值 [0.0076]
# 2设定 -0.5324 预测 [-0.5198] 高炉 [-0.5354] 高炉与设定误差 [0.003] [0.00278595] 模型误差 [0.0156] 校正值 [0.0095]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0697] 高炉 [0.0802] 高炉与设定误差 [-0.0461] [-3.90014958] 模型误差 [-0.0105] 校正值 [-0.0008]
# 2设定 -0.5324 预测 [-0.5494] 高炉 [-0.5354] 高炉与设定误差 [0.003] [0.00278595] 模型误差 [-0.014] 校正值 [-0.0126]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.057] 高炉 [0.0512] 高炉与设定误差 [-0.017] [-1.43823306] 模型误差 [0.0058] 校正值 [0.0108]
# 2设定 -0.5324 预测 [-0.5323] 高炉 [-0.5456] 高炉与设定误差 [0.0132] [0.01225818] 模型误差 [0.0133] 校正值 [0.0142]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0294] 高炉 [0.0491] 高炉与设定误差 [-0.0149] [-1.26056889] 模型误差 [-0.0197] 校正值 [-0.0054]
# 2设定 -0.5324 预测 [-0.5306] 高炉 [-0.5173] 高炉与设定误差 [-0.0151] [-0.01402262] 模型误差 [-0.0133] 校正值 [-0.013]
# 这是对第100时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0741] 高炉 [0.0738] 高炉与设定误差 [-0.0396] [-3.35023681] 模型误差 [0.0003] 校正值 [0.0187]
# 2设定 -0.5324 预测 [-0.5426] 高炉 [-0.5436] 高炉与设定误差 [0.0111] [0.01030801] 模型误差 [0.001] 校正值 [0.0129]
# 这是对第101时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0309] 高炉 [0.0324] 高炉与设定误差 [0.0017] [0.1438233] 模型误差 [-0.0015] 校正值 [-0.0001]
# 2设定 -0.5324 预测 [-0.5481] 高炉 [-0.5463] 高炉与设定误差 [0.0139] [0.01290823] 模型误差 [-0.0018] 校正值 [-0.0018]
# 这是对第102时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0418] 高炉 [0.0416] 高炉与设定误差 [-0.0074] [-0.62605436] 模型误差 [0.0002] 校正值 [0.0015]
# 2设定 -0.5324 预测 [-0.5198] 高炉 [-0.5301] 高炉与设定误差 [-0.0023] [-0.0021359] 模型误差 [0.0103] 校正值 [0.0023]
# 这是对第103时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0417] 高炉 [0.0464] 高炉与设定误差 [-0.0123] [-1.04060383] 模型误差 [-0.0047] 校正值 [-0.0001]
# 2设定 -0.5324 预测 [-0.5633] 高炉 [-0.5556] 高炉与设定误差 [0.0232] [0.02154468] 模型误差 [-0.0077] 校正值 [-0.0108]
# 这是对第104时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.0948] 高炉 [0.0955] 高炉与设定误差 [-0.0613] [-5.18609878] 模型误差 [-0.0006] 校正值 [0.0041]
# 2设定 -0.5324 预测 [-0.5759] 高炉 [-0.5806] 高炉与设定误差 [0.0481] [0.04466806] 模型误差 [0.0047] 校正值 [0.0075]
# 这是对第105时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.251] 高炉 [0.2523] 高炉与设定误差 [-0.2182] [-18.46014315] 模型误差 [-0.0013] 校正值 [0.0003]
# 2设定 -0.5109 预测 [-0.5946] 高炉 [-0.5813] 高炉与设定误差 [0.0704] [0.06537696] 模型误差 [-0.0134] 校正值 [-0.0064]
# 这是对第106时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.2016] 高炉 [0.22] 高炉与设定误差 [-0.1859] [-15.72750088] 模型误差 [-0.0184] 校正值 [0.0016]
# 2设定 -0.5109 预测 [-0.4975] 高炉 [-0.5001] 高炉与设定误差 [-0.0108] [-0.01002942] 模型误差 [0.0026] 校正值 [0.0135]
# 这是对第107时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.1319] 高炉 [0.155] 高炉与设定误差 [-0.1208] [-10.21991464] 模型误差 [-0.0231] 校正值 [0.0161]
# 2设定 -0.5109 预测 [-0.5223] 高炉 [-0.5146] 高炉与设定误差 [0.0037] [0.00343601] 模型误差 [-0.0077] 校正值 [-0.0033]
# 这是对第108时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.1209] 高炉 [0.1194] 高炉与设定误差 [-0.0852] [-7.20808502] 模型误差 [0.0015] 校正值 [0.0181]
# 2设定 -0.5109 预测 [-0.5746] 高炉 [-0.5884] 高炉与设定误差 [0.0775] [0.07197038] 模型误差 [0.0138] 校正值 [0.0073]
# 这是对第109时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.2693] 高炉 [0.2625] 高炉与设定误差 [-0.2283] [-19.31462334] 模型误差 [0.0069] 校正值 [-0.0039]
# 2设定 -0.5109 预测 [-0.5839] 高炉 [-0.5752] 高炉与设定误差 [0.0643] [0.0597122] 模型误差 [-0.0087] 校正值 [-0.0139]
# 这是对第110时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.208] 高炉 [0.2211] 高炉与设定误差 [-0.187] [-15.82056332] 模型误差 [-0.0131] 校正值 [-0.0044]
# 2设定 -0.5109 预测 [-0.4977] 高炉 [-0.5029] 高炉与设定误差 [-0.008] [-0.0074292] 模型误差 [0.0052] 校正值 [0.0106]
# 这是对第111时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.148] 高炉 [0.1556] 高炉与设定误差 [-0.1215] [-10.27913574] 模型误差 [-0.0077] 校正值 [0.0129]
# 2设定 -0.5109 预测 [-0.4774] 高炉 [-0.4653] 高炉与设定误差 [-0.0455] [-0.04225357] 模型误差 [-0.0121] 校正值 [-0.0052]
# 这是对第112时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.1332] 高炉 [0.1395] 高炉与设定误差 [-0.1054] [-8.91704477] 模型误差 [-0.0063] 校正值 [0.0084]
# 2设定 -0.5109 预测 [-0.5014] 高炉 [-0.4975] 高炉与设定误差 [-0.0134] [-0.01244391] 模型误差 [-0.0039] 校正值 [0.0116]
# 这是对第113时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.1026] 高炉 [0.1078] 高炉与设定误差 [-0.0736] [-6.22670292] 模型误差 [-0.0051] 校正值 [0.0073]
# 2设定 -0.5109 预测 [-0.5421] 高炉 [-0.5302] 高炉与设定误差 [0.0193] [0.01792295] 模型误差 [-0.0119] 校正值 [0.0036]
# 这是对第114时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.1145] 高炉 [0.116] 高炉与设定误差 [-0.0818] [-6.9204386] 模型误差 [-0.0015] 校正值 [0.0006]
# 2设定 -0.5109 预测 [-0.5306] 高炉 [-0.5367] 高炉与设定误差 [0.0258] [0.02395917] 模型误差 [0.0061] 校正值 [0.0105]
# 这是对第115时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1247] 高炉 [0.1266] 高炉与设定误差 [-0.0333] [-2.8172447] 模型误差 [-0.0019] 校正值 [0.006]
# 2设定 -0.5109 预测 [-0.6035] 高炉 [-0.5947] 高炉与设定误差 [0.0839] [0.07791373] 模型误差 [-0.0087] 校正值 [-0.0046]
# 这是对第116时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.2986] 高炉 [0.2959] 高炉与设定误差 [-0.2026] [-17.14035324] 模型误差 [0.0027] 校正值 [-0.0034]
# 2设定 -0.5109 预测 [-0.5126] 高炉 [-0.514] 高炉与设定误差 [0.0031] [0.00287882] 模型误差 [0.0014] 校正值 [0.0085]
# 这是对第117时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1733] 高炉 [0.1689] 高炉与设定误差 [-0.0756] [-6.39590651] 模型误差 [0.0044] 校正值 [-0.0008]
# 2设定 -0.5109 预测 [-0.5123] 高炉 [-0.5056] 高炉与设定误差 [-0.0053] [-0.00492184] 模型误差 [-0.0067] 校正值 [-0.0005]
# 这是对第118时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1419] 高炉 [0.1411] 高炉与设定误差 [-0.0478] [-4.0439728] 模型误差 [0.0008] 校正值 [-0.005]
# 2设定 -0.5109 预测 [-0.5074] 高炉 [-0.5131] 高炉与设定误差 [0.0022] [0.00204303] 模型误差 [0.0058] 校正值 [0.0067]
# 这是对第119时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1208] 高炉 [0.1071] 高炉与设定误差 [-0.0138] [-1.16750676] 模型误差 [0.0137] 校正值 [-0.0001]
# 2设定 -0.5109 预测 [-0.5078] 高炉 [-0.5062] 高炉与设定误差 [-0.0047] [-0.00436465] 模型误差 [-0.0016] 校正值 [-0.0049]
# 这是对第120时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1166] 高炉 [0.1329] 高炉与设定误差 [-0.0397] [-3.35869714] 模型误差 [-0.0164] 校正值 [-0.013]
# 2设定 -0.5109 预测 [-0.5081] 高炉 [-0.5033] 高炉与设定误差 [-0.0076] [-0.00705774] 模型误差 [-0.0049] 校正值 [0.0025]
# 这是对第121时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.105] 高炉 [0.1063] 高炉与设定误差 [-0.0131] [-1.10828542] 模型误差 [-0.0014] 校正值 [0.0107]
# 2设定 -0.5109 预测 [-0.5364] 高炉 [-0.5148] 高炉与设定误差 [0.0039] [0.00362173] 模型误差 [-0.0216] 校正值 [0.0009]
# 这是对第122时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1003] 高炉 [0.1099] 高炉与设定误差 [-0.0166] [-1.40439218] 模型误差 [-0.0095] 校正值 [-0.0017]
# 2设定 -0.5109 预测 [-0.5195] 高炉 [-0.5187] 高炉与设定误差 [0.0078] [0.00724347] 模型误差 [-0.0009] 校正值 [0.0182]
# 这是对第123时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1582] 高炉 [0.1554] 高炉与设定误差 [-0.0621] [-5.25378053] 模型误差 [0.0028] 校正值 [0.008]
# 2设定 -0.5109 预测 [-0.6244] 高炉 [-0.6124] 高炉与设定误差 [0.1015] [0.09425797] 模型误差 [-0.0121] 校正值 [-0.]
# 这是对第124时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.2765] 高炉 [0.2668] 高炉与设定误差 [-0.1735] [-14.67843671] 模型误差 [0.0098] 校正值 [-0.002]
# 2设定 -0.5109 预测 [-0.5789] 高炉 [-0.5884] 高炉与设定误差 [0.0775] [0.07197038] 模型误差 [0.0095] 校正值 [0.0121]
# 这是对第125时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.2127] 高炉 [0.234] 高炉与设定误差 [-0.1407] [-11.90349275] 模型误差 [-0.0212] 校正值 [-0.0067]
# 2设定 -0.4894 预测 [-0.5298] 高炉 [-0.5209] 高炉与设定误差 [0.0315] [0.02925248] 模型误差 [-0.0089] 校正值 [-0.0082]
# 这是对第126时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1466] 高炉 [0.1457] 高炉与设定误差 [-0.0524] [-4.43314169] 模型误差 [0.0009] 校正值 [0.0187]
# 2设定 -0.4894 预测 [-0.6001] 高炉 [-0.6129] 高炉与设定误差 [0.1235] [0.11468827] 模型误差 [0.0128] 校正值 [0.0083]
# 这是对第127时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.3037] 高炉 [0.3075] 高炉与设定误差 [-0.2142] [-18.12173597] 模型误差 [-0.0038] 校正值 [-0.0004]
# 2设定 -0.4894 预测 [-0.5031] 高炉 [-0.4842] 高炉与设定误差 [-0.0052] [-0.00482898] 模型误差 [-0.019] 校正值 [-0.0123]
# 这是对第128时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1627] 高炉 [0.1545] 高炉与设定误差 [-0.0613] [-5.18609878] 模型误差 [0.0082] 校正值 [0.0051]
# 2设定 -0.4894 预测 [-0.4738] 高炉 [-0.4772] 高炉与设定误差 [-0.0122] [-0.01132953] 模型误差 [0.0034] 校正值 [0.0101]
# 这是对第129时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1674] 高炉 [0.1738] 高炉与设定误差 [-0.0805] [-6.8104561] 模型误差 [-0.0064] 校正值 [-0.0008]
# 2设定 -0.4894 预测 [-0.5104] 高炉 [-0.5103] 高炉与设定误差 [0.0209] [0.01940878] 模型误差 [-1.e-04] 校正值 [-0.0021]
# 这是对第130时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1532] 高炉 [0.1502] 高炉与设定误差 [-0.0569] [-4.81385025] 模型误差 [0.003] 校正值 [0.0091]
# 2设定 -0.4894 预测 [-0.5152] 高炉 [-0.522] 高炉与设定误差 [0.0326] [0.03027399] 模型误差 [0.0067] 校正值 [-0.0004]
# 这是对第131时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1348] 高炉 [0.1404] 高炉与设定误差 [-0.0472] [-3.99321172] 模型误差 [-0.0056] 校正值 [-0.0032]
# 2设定 -0.4894 预测 [-0.5989] 高炉 [-0.6017] 高炉与设定误差 [0.1124] [0.10438026] 模型误差 [0.0028] 校正值 [-0.0038]
# 这是对第132时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.316] 高炉 [0.3118] 高炉与设定误差 [-0.2185] [-18.48552416] 模型误差 [0.0042] 校正值 [0.0046]
# 2设定 -0.4894 预测 [-0.4434] 高炉 [-0.4327] 高炉与设定误差 [-0.0566] [-0.05256159] 模型误差 [-0.0107] 校正值 [0.001]
# 这是对第133时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1845] 高炉 [0.1951] 高炉与设定误差 [-0.1018] [-8.61247767] 模型误差 [-0.0106] 校正值 [-0.0077]
# 2设定 -0.4894 预测 [-0.4744] 高炉 [-0.4735] 高炉与设定误差 [-0.0159] [-0.01476554] 模型误差 [-0.001] 校正值 [0.0018]
# 这是对第134时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.1427] 高炉 [0.1376] 高炉与设定误差 [-0.0443] [-3.74786604] 模型误差 [0.0051] 校正值 [0.0076]
# 2设定 -0.4894 预测 [-0.4749] 高炉 [-0.4628] 高炉与设定误差 [-0.0265] [-0.02460922] 模型误差 [-0.0121] 校正值 [0.0003]
# 这是对第135时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1252] 高炉 [0.1247] 高炉与设定误差 [0.0277] [2.3434737] 模型误差 [0.0005] 校正值 [-0.0035]
# 2设定 -0.4894 预测 [-0.4873] 高炉 [-0.4871] 高炉与设定误差 [-0.0023] [-0.0021359] 模型误差 [-0.0002] 校正值 [0.0072]
# 这是对第136时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1617] 高炉 [0.1733] 高炉与设定误差 [-0.0209] [-1.76818054] 模型误差 [-0.0116] 校正值 [0.0003]
# 2设定 -0.4894 预测 [-0.4886] 高炉 [-0.4825] 高炉与设定误差 [-0.0068] [-0.00631482] 模型误差 [-0.0061] 校正值 [-0.0012]
# 这是对第137时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1628] 高炉 [0.1663] 高炉与设定误差 [-0.0139] [-1.17596694] 模型误差 [-0.0035] 校正值 [0.0114]
# 2设定 -0.4894 预测 [-0.6022] 高炉 [-0.6023] 高炉与设定误差 [0.113] [0.10493745] 模型误差 [1.e-04] 校正值 [0.0079]
# 这是对第138时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.2981] 高炉 [0.2828] 高炉与设定误差 [-0.1304] [-11.03209315] 模型误差 [0.0154] 校正值 [-0.0002]
# 2设定 -0.4894 预测 [-0.5485] 高炉 [-0.5586] 高炉与设定误差 [0.0693] [0.06435545] 模型误差 [0.0102] 校正值 [0.0021]
# 这是对第139时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1962] 高炉 [0.1869] 高炉与设定误差 [-0.0345] [-2.91876686] 模型误差 [0.0093] 校正值 [-0.0015]
# 2设定 -0.4894 预测 [-0.6696] 高炉 [-0.6695] 高炉与设定误差 [0.1801] [0.16724986] 模型误差 [-1.e-04] 校正值 [-0.0089]
# 这是对第140时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.2824] 高炉 [0.2731] 高炉与设定误差 [-0.1208] [-10.21991464] 模型误差 [0.0093] 校正值 [-0.0088]
# 2设定 -0.4894 预测 [-0.5565] 高炉 [-0.568] 高炉与设定误差 [0.0786] [0.07299189] 模型误差 [0.0115] 校正值 [0.0041]
# 这是对第141时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1967] 高炉 [0.1946] 高炉与设定误差 [-0.0422] [-3.57020179] 模型误差 [0.0021] 校正值 [-0.0016]
# 2设定 -0.4894 预测 [-0.5121] 高炉 [-0.5144] 高炉与设定误差 [0.025] [0.02321625] 模型误差 [0.0023] 校正值 [-0.0072]
# 这是对第142时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1622] 高炉 [0.1618] 高炉与设定误差 [-0.0094] [-0.79525822] 模型误差 [0.0004] 校正值 [-0.0016]
# 2设定 -0.4894 预测 [-0.4877] 高炉 [-0.4964] 高炉与设定误差 [0.007] [0.00650055] 模型误差 [0.0087] 校正值 [-0.0009]
# 这是对第143时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1692] 高炉 [0.1648] 高炉与设定误差 [-0.0125] [-1.05752427] 模型误差 [0.0044] 校正值 [-0.0002]
# 2设定 -0.4894 预测 [-0.6177] 高炉 [-0.6144] 高炉与设定误差 [0.125] [0.11608125] 模型误差 [-0.0033] 校正值 [-0.0078]
# 这是对第144时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.3014] 高炉 [0.3034] 高炉与设定误差 [-0.1511] [-12.78335269] 模型误差 [-0.0021] 校正值 [-0.0048]
# 2设定 -0.4894 预测 [-0.5099] 高炉 [-0.5165] 高炉与设定误差 [0.0272] [0.02525928] 模型误差 [0.0066] 校正值 [0.0034]
# 这是对第145时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1873] 高炉 [0.1863] 高炉与设定误差 [-0.0339] [-2.86800578] 模型误差 [0.0011] 校正值 [0.0022]
# 2设定 -0.4678 预测 [-0.4741] 高炉 [-0.4701] 高炉与设定误差 [0.0023] [0.0021359] 模型误差 [-0.004] 校正值 [-0.0057]
# 这是对第146时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1824] 高炉 [0.1922] 高炉与设定误差 [-0.0398] [-3.36715717] 模型误差 [-0.0097] 校正值 [-0.0022]
# 2设定 -0.4678 预测 [-0.4819] 高炉 [-0.4852] 高炉与设定误差 [0.0174] [0.01615851] 模型误差 [0.0034] 校正值 [0.0038]
# 这是对第147时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1679] 高炉 [0.177] 高炉与设定误差 [-0.0247] [-2.08966799] 模型误差 [-0.0091] 校正值 [0.008]
# 2设定 -0.4678 预测 [-0.4895] 高炉 [-0.4751] 高炉与设定误差 [0.0073] [0.00677915] 模型误差 [-0.0144] 校正值 [-0.0045]
# 这是对第148时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1504] 高炉 [0.1547] 高炉与设定误差 [-0.0024] [-0.20304467] 模型误差 [-0.0044] 校正值 [0.0075]
# 2设定 -0.4678 预测 [-0.5793] 高炉 [-0.5869] 高炉与设定误差 [0.1191] [0.11060221] 模型误差 [0.0076] 校正值 [0.0133]
# 这是对第149时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.3074] 高炉 [0.3081] 高炉与设定误差 [-0.1557] [-13.1725219] 模型误差 [-0.0006] 校正值 [0.0048]
# 2设定 -0.4678 预测 [-0.4465] 高炉 [-0.4377] 高炉与设定误差 [-0.0301] [-0.02795236] 模型误差 [-0.0088] 校正值 [-0.0071]
# 这是对第150时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.2033] 高炉 [0.2035] 高炉与设定误差 [-0.0512] [-4.33161922] 模型误差 [-0.0002] 校正值 [-0.0001]
# 2设定 -0.4678 预测 [-0.474] 高炉 [-0.481] 高炉与设定误差 [0.0132] [0.01225818] 模型误差 [0.0071] 校正值 [0.0086]
# 这是对第151时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1952] 高炉 [0.1948] 高炉与设定误差 [-0.0424] [-3.58712215] 模型误差 [0.0004] 校正值 [0.0003]
# 2设定 -0.4678 预测 [-0.4916] 高炉 [-0.4832] 高炉与设定误差 [0.0153] [0.01420835] 模型误差 [-0.0085] 校正值 [-0.0067]
# 这是对第152时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1584] 高炉 [0.162] 高炉与设定误差 [-0.0096] [-0.81217866] 模型误差 [-0.0035] 校正值 [0.0002]
# 2设定 -0.4678 预测 [-0.5929] 高炉 [-0.6006] 高炉与设定误差 [0.1328] [0.12332472] 模型误差 [0.0077] 校正值 [0.0083]
# 这是对第153时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.3184] 高炉 [0.3189] 高炉与设定误差 [-0.1666] [-14.09468353] 模型误差 [-0.0005] 校正值 [0.0034]
# 2设定 -0.4678 预测 [-0.4896] 高炉 [-0.4809] 高炉与设定误差 [0.0131] [0.01216532] 模型误差 [-0.0087] 校正值 [-0.0085]
# 这是对第154时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1813] 高炉 [0.1821] 高炉与设定误差 [-0.0297] [-2.5126776] 模型误差 [-0.0008] 校正值 [-0.0003]
# 2设定 -0.4678 预测 [-0.4638] 高炉 [-0.4573] 高炉与设定误差 [-0.0105] [-0.00975082] 模型误差 [-0.0065] 校正值 [0.0086]
# 这是对第155时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.1768] 高炉 [0.1818] 高炉与设定误差 [0.0296] [2.50421742] 模型误差 [-0.005] 校正值 [-0.0002]
# 2设定 -0.4678 预测 [-0.4664] 高炉 [-0.4567] 高炉与设定误差 [-0.0112] [-0.01040088] 模型误差 [-0.0097] 校正值 [0.0052]
# 这是对第156时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2095] 高炉 [0.2293] 高炉与设定误差 [-0.0178] [-1.5059145] 模型误差 [-0.0198] 校正值 [0.004]
# 2设定 -0.4678 预测 [-0.4725] 高炉 [-0.4627] 高炉与设定误差 [-0.0051] [-0.00473612] 模型误差 [-0.0098] 校正值 [0.0086]
# 这是对第157时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2121] 高炉 [0.2121] 高炉与设定误差 [-0.0006] [-0.05076117] 模型误差 [0.] 校正值 [0.017]
# 2设定 -0.4678 预测 [-0.4932] 高炉 [-0.485] 高炉与设定误差 [0.0172] [0.01597278] 模型误差 [-0.0082] 校正值 [0.0081]
# 这是对第158时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2007] 高炉 [0.2122] 高炉与设定误差 [-0.0008] [-0.06768155] 模型误差 [-0.0115] 校正值 [-0.0022]
# 2设定 -0.4678 预测 [-0.4646] 高炉 [-0.4671] 高炉与设定误差 [-0.0008] [-0.00074292] 模型误差 [0.0024] 校正值 [0.007]
# 这是对第159时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2152] 高炉 [0.223] 高炉与设定误差 [-0.0116] [-0.98138249] 模型误差 [-0.0078] 校正值 [0.0087]
# 2设定 -0.4678 预测 [-0.4783] 高炉 [-0.4631] 高炉与设定误差 [-0.0047] [-0.00436465] 模型误差 [-0.0152] 校正值 [-0.0037]
# 这是对第160时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.175] 高炉 [0.173] 高炉与设定误差 [0.0384] [3.24871465] 模型误差 [0.0019] 校正值 [0.0066]
# 2设定 -0.4678 预测 [-0.5857] 高炉 [-0.5945] 高炉与设定误差 [0.1266] [0.11756709] 模型误差 [0.0088] 校正值 [0.0136]
# 这是对第161时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.3228] 高炉 [0.3339] 高炉与设定误差 [-0.1224] [-10.35527751] 模型误差 [-0.0111] 校正值 [-0.0026]
# 2设定 -0.4678 预测 [-0.4519] 高炉 [-0.4383] 高炉与设定误差 [-0.0296] [-0.02748804] 模型误差 [-0.0137] 校正值 [-0.0088]
# 这是对第162时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2086] 高炉 [0.2061] 高炉与设定误差 [0.0054] [0.45685049] 模型误差 [0.0025] 校正值 [0.0038]
# 2设定 -0.4678 预测 [-0.4559] 高炉 [-0.4594] 高炉与设定误差 [-0.0084] [-0.00780066] 模型误差 [0.0035] 校正值 [0.0091]
# 这是对第163时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2112] 高炉 [0.221] 高炉与设定误差 [-0.0096] [-0.81217866] 模型误差 [-0.0098] 校正值 [-0.0022]
# 2设定 -0.4678 预测 [-0.4687] 高炉 [-0.4614] 高炉与设定误差 [-0.0065] [-0.00603623] 模型误差 [-0.0073] 校正值 [-0.0036]
# 这是对第164时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.1745] 高炉 [0.1752] 高炉与设定误差 [0.0363] [3.07105041] 模型误差 [-0.0007] 校正值 [0.008]
# 2设定 -0.4678 预测 [-0.5897] 高炉 [-0.596] 高炉与设定误差 [0.1282] [0.11905292] 模型误差 [0.0063] 校正值 [0.0065]
# 这是对第165时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.3129] 高炉 [0.3148] 高炉与设定误差 [-0.1033] [-8.73938021] 模型误差 [-0.0018] 校正值 [0.]
# 2设定 -0.4463 预测 [-0.431] 高炉 [-0.426] 高炉与设定误差 [-0.0203] [-0.0188516] 模型误差 [-0.005] 校正值 [-0.0061]
# 这是对第166时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2143] 高炉 [0.211] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [0.0033] 校正值 [0.0021]
# 2设定 -0.4463 预测 [-0.4342] 高炉 [-0.4304] 高炉与设定误差 [-0.0159] [-0.01476554] 模型误差 [-0.0038] 校正值 [-0.005]
# 这是对第167时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2126] 高炉 [0.2251] 高炉与设定误差 [-0.0137] [-1.15904658] 模型误差 [-0.0126] 校正值 [-0.0053]
# 2设定 -0.4463 预测 [-0.4334] 高炉 [-0.4237] 高炉与设定误差 [-0.0226] [-0.02098749] 模型误差 [-0.0097] 校正值 [0.0092]
# 这是对第168时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.1596] 高炉 [0.1655] 高炉与设定误差 [0.0459] [3.88322891] 模型误差 [-0.0059] 校正值 [0.0092]
# 2设定 -0.4463 预测 [-0.5239] 高炉 [-0.5112] 高炉与设定误差 [0.065] [0.06036225] 模型误差 [-0.0127] 校正值 [0.0069]
# 这是对第169时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2364] 高炉 [0.2417] 高炉与设定误差 [-0.0302] [-2.55497866] 模型误差 [-0.0053] 校正值 [0.0066]
# 2设定 -0.4463 预测 [-0.4757] 高炉 [-0.4786] 高炉与设定误差 [0.0324] [0.03008826] 模型误差 [0.0029] 校正值 [0.0041]
# 这是对第170时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.1756] 高炉 [0.1752] 高炉与设定误差 [0.0363] [3.07105041] 模型误差 [0.0004] 校正值 [0.0032]
# 2设定 -0.4463 预测 [-0.6023] 高炉 [-0.609] 高炉与设定误差 [0.1627] [0.15109135] 模型误差 [0.0067] 校正值 [0.0027]
# 这是对第171时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2483] 高炉 [0.2428] 高炉与设定误差 [-0.0314] [-2.65650082] 模型误差 [0.0055] 校正值 [-0.0029]
# 2设定 -0.4463 预测 [-0.6979] 高炉 [-0.6948] 高炉与设定误差 [0.2485] [0.23076953] 模型误差 [-0.003] 校正值 [-0.0061]
# 这是对第172时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.3078] 高炉 [0.3093] 高炉与设定误差 [-0.0978] [-8.27406986] 模型误差 [-0.0015] 校正值 [0.0021]
# 2设定 -0.4463 预测 [-0.4612] 高炉 [-0.4621] 高炉与设定误差 [0.0159] [0.01476554] 模型误差 [0.0009] 校正值 [0.0016]
# 这是对第173时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2253] 高炉 [0.2222] 高炉与设定误差 [-0.0107] [-0.9052408] 模型误差 [0.0031] 校正值 [-0.0035]
# 2设定 -0.4463 预测 [-0.4506] 高炉 [-0.4525] 高炉与设定误差 [0.0063] [0.0058505] 模型误差 [0.0019] 校正值 [-0.0045]
# 这是对第174时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.22] 高炉 [0.2209] 高炉与设定误差 [-0.0095] [-0.8037184] 模型误差 [-0.0009] 校正值 [0.0002]
# 2设定 -0.4463 预测 [-0.4404] 高炉 [-0.4424] 高炉与设定误差 [-0.0039] [-0.00362173] 模型误差 [0.002] 校正值 [0.0014]
# 这是对第175时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.1744] 高炉 [0.169] 高炉与设定误差 [0.1016] [8.595557] 模型误差 [0.0054] 校正值 [0.0021]
# 2设定 -0.4463 预测 [-0.5394] 高炉 [-0.53] 高炉与设定误差 [0.0838] [0.07782087] 模型误差 [-0.0093] 校正值 [-0.0027]
# 这是对第176时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.304] 高炉 [0.3171] 高炉与设定误差 [-0.0466] [-3.94245033] 模型误差 [-0.0131] 校正值 [-0.0048]
# 2设定 -0.4463 预测 [-0.475] 高炉 [-0.4664] 高炉与设定误差 [0.0201] [0.01866586] 模型误差 [-0.0086] 校正值 [0.0072]
# 这是对第177时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2731] 高炉 [0.2716] 高炉与设定误差 [-0.0011] [-0.09306213] 模型误差 [0.0014] 校正值 [0.0113]
# 2设定 -0.4463 预测 [-0.4754] 高炉 [-0.4725] 高炉与设定误差 [0.0262] [0.02433063] 模型误差 [-0.0029] 校正值 [0.0084]
# 这是对第178时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2705] 高炉 [0.2761] 高炉与设定误差 [-0.0055] [-0.46531067] 模型误差 [-0.0056] 校正值 [-0.0019]
# 2设定 -0.4463 预测 [-0.4412] 高炉 [-0.4437] 高炉与设定误差 [-0.0026] [-0.00241449] 模型误差 [0.0025] 校正值 [0.0011]
# 这是对第179时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.1957] 高炉 [0.1875] 高炉与设定误差 [0.083] [7.02196075] 模型误差 [0.0082] 校正值 [0.0055]
# 2设定 -0.4463 预测 [-0.5956] 高炉 [-0.5914] 高炉与设定误差 [0.1451] [0.13474711] 模型误差 [-0.0042] 校正值 [-0.0015]
# 这是对第180时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.3248] 高炉 [0.328] 高炉与设定误差 [-0.0575] [-4.86461164] 模型误差 [-0.0033] 校正值 [-0.0043]
# 2设定 -0.4463 预测 [-0.4542] 高炉 [-0.4536] 高炉与设定误差 [0.0073] [0.00677915] 模型误差 [-0.0006] 校正值 [0.0063]
# 这是对第181时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2691] 高炉 [0.2711] 高炉与设定误差 [-0.0006] [-0.05076117] 模型误差 [-0.002] 校正值 [0.0008]
# 2设定 -0.4463 预测 [-0.4557] 高炉 [-0.4552] 高炉与设定误差 [0.009] [0.00835785] 模型误差 [-0.0005] 校正值 [-0.0014]
# 这是对第182时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.276] 高炉 [0.2768] 高炉与设定误差 [-0.0063] [-0.53299222] 模型误差 [-0.0008] 校正值 [0.0028]
# 2设定 -0.4463 预测 [-0.4414] 高炉 [-0.4418] 高炉与设定误差 [-0.0045] [-0.00417892] 模型误差 [0.0004] 校正值 [0.0005]
# 这是对第183时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2636] 高炉 [0.2742] 高炉与设定误差 [-0.0036] [-0.30456698] 模型误差 [-0.0106] 校正值 [-0.0003]
# 2设定 -0.4463 预测 [-0.4524] 高炉 [-0.4423] 高炉与设定误差 [-0.004] [-0.0037146] 模型误差 [-0.0101] 校正值 [-0.0015]
# 这是对第184时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.3035] 高炉 [0.3051] 高炉与设定误差 [-0.0345] [-2.91876686] 模型误差 [-0.0016] 校正值 [0.0102]
# 2设定 -0.4463 预测 [-0.4172] 高炉 [-0.4118] 高炉与设定误差 [-0.0345] [-0.03203842] 模型误差 [-0.0054] 校正值 [0.0089]
# 这是对第185时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.1738] 高炉 [0.1648] 高炉与设定误差 [0.1058] [8.95088549] 模型误差 [0.009] 校正值 [0.001]
# 2设定 -0.4247 预测 [-0.5356] 高炉 [-0.5319] 高炉与设定误差 [0.1072] [0.09955128] 模型误差 [-0.0037] 校正值 [0.0047]
# 这是对第186时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2774] 高炉 [0.2891] 高炉与设定误差 [-0.0186] [-1.57359609] 模型误差 [-0.0118] 校正值 [-0.0068]
# 2设定 -0.4247 预测 [-0.4571] 高炉 [-0.4478] 高炉与设定误差 [0.023] [0.02135895] 模型误差 [-0.0093] 校正值 [0.0001]
# 这是对第187时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2636] 高炉 [0.2716] 高炉与设定误差 [-0.001] [-0.08460194] 模型误差 [-0.008] 校正值 [0.0141]
# 2设定 -0.4247 预测 [-0.4472] 高炉 [-0.4382] 高炉与设定误差 [0.0135] [0.01253678] 模型误差 [-0.009] 校正值 [0.0099]
# 这是对第188时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2652] 高炉 [0.2677] 高炉与设定误差 [0.0028] [0.23688542] 模型误差 [-0.0025] 校正值 [0.0043]
# 2设定 -0.4247 预测 [-0.4297] 高炉 [-0.4337] 高炉与设定误差 [0.0089] [0.00826498] 模型误差 [0.0039] 校正值 [0.0089]
# 这是对第189时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2691] 高炉 [0.2775] 高炉与设定误差 [-0.0069] [-0.58375338] 模型误差 [-0.0084] 校正值 [-0.0018]
# 2设定 -0.4247 预测 [-0.4279] 高炉 [-0.4184] 高炉与设定误差 [-0.0064] [-0.00594336] 模型误差 [-0.0095] 校正值 [-0.0058]
# 这是对第190时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2701] 高炉 [0.2685] 高炉与设定误差 [0.0021] [0.17766407] 模型误差 [0.0017] 校正值 [0.0108]
# 2设定 -0.4247 预测 [-0.4282] 高炉 [-0.429] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [0.0008] 校正值 [0.0079]
# 这是对第191时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2624] 高炉 [0.272] 高炉与设定误差 [-0.0014] [-0.11844271] 模型误差 [-0.0096] 校正值 [0.0021]
# 2设定 -0.4247 预测 [-0.4285] 高炉 [-0.4265] 高炉与设定误差 [0.0018] [0.00167157] 模型误差 [-0.002] 校正值 [0.]
# 这是对第192时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2715] 高炉 [0.2749] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [-0.0034] 校正值 [-0.0012]
# 2设定 -0.4247 预测 [-0.4271] 高炉 [-0.4265] 高炉与设定误差 [0.0017] [0.00157871] 模型误差 [-0.0006] 校正值 [-0.0038]
# 这是对第193时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2736] 高炉 [0.2705] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [0.0031] 校正值 [0.0023]
# 2设定 -0.4247 预测 [-0.423] 高炉 [-0.4252] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [0.0022] 校正值 [-0.0016]
# 这是对第194时刻的最优U1、U2输入求解
# 1设定 0.2706 预测 [0.2683] 高炉 [0.271] 高炉与设定误差 [-0.0005] [-0.04230097] 模型误差 [-0.0027] 校正值 [-0.0004]
# 2设定 -0.4247 预测 [-0.4228] 高炉 [-0.4259] 高炉与设定误差 [0.0012] [0.00111438] 模型误差 [0.0031] 校正值 [-0.0005]
# 这是对第195时刻的最优U1、U2输入求解
# 1设定 0.3297 预测 [0.2728] 高炉 [0.2781] 高炉与设定误差 [0.0516] [4.36546025] 模型误差 [-0.0052] 校正值 [0.0021]
# 2设定 -0.4247 预测 [-0.4165] 高炉 [-0.416] 高炉与设定误差 [-0.0087] [-0.00807926] 模型误差 [-0.0005] 校正值 [-0.0023]
# 这是对第196时刻的最优U1、U2输入求解
# 1设定 0.3297 预测 [0.302] 高炉 [0.3133] 高炉与设定误差 [0.0164] [1.38747182] 模型误差 [-0.0113] 校正值 [0.0057]
# 2设定 -0.4247 预测 [-0.4156] 高炉 [-0.4094] 高炉与设定误差 [-0.0153] [-0.01420835] 模型误差 [-0.0062] 校正值 [-0.0006]
# 这是对第197时刻的最优U1、U2输入求解
# 1设定 0.3297 预测 [0.3208] 高炉 [0.3279] 高炉与设定误差 [0.0018] [0.15228349] 模型误差 [-0.0071] 校正值 [0.0047]
# 2设定 -0.4247 预测 [-0.4254] 高炉 [-0.4196] 高炉与设定误差 [-0.0051] [-0.00473612] 模型误差 [-0.0058] 校正值 [0.0011]
# 这是对第198时刻的最优U1、U2输入求解
# 1设定 0.3297 预测 [0.3272] 高炉 [0.328] 高炉与设定误差 [0.0017] [0.1438233] 模型误差 [-0.0008] 校正值 [0.0017]
# 2设定 -0.4247 预测 [-0.4274] 高炉 [-0.4266] 高炉与设定误差 [0.0019] [0.00176444] 模型误差 [-0.0008] 校正值 [0.0017]
# 这是对第199时刻的最优U1、U2输入求解
# 1设定 0.3297 预测 [0.3293] 高炉 [0.3285] 高炉与设定误差 [0.0011] [0.09306213] 模型误差 [0.0008] 校正值 [-0.0001]
# 2设定 -0.4247 预测 [-0.4245] 高炉 [-0.4255] 高炉与设定误差 [0.0007] [0.00065005] 模型误差 [0.0009] 校正值 [-0.0009]

# %%
if iscontrol:
    y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
    y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
    
    startt = 0
    endd = 400
    
    plt.figure(figsize=(7, 6))
    plt.subplot(2, 1, 1)
    plt.plot(set_y1[startt:endd],'r', label='设定值')
    plt.plot(y1_pred_inverse_transform[startt:endd],'b', label='实际值')
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')
    plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
    plt.legend(prop=font)
    plt.title(f"模型:MLP 训练次数:{epoch_sum_gaolu} 隐含层数:{3} 改进:{ischuangxin} 动态更新:{if_update_model} P:{P} M:{M} ", fontproperties=font)

    plt.subplot(2, 1, 2)
    plt.plot(set_y2[startt:endd],'r')
    plt.plot(y2_pred_inverse_transform[startt:endd],'b')
    plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')

# %%
startt = 50
endd = 150


font222 = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=10)  # 替换为你的中文字体文件路径

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()


a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))









# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(8, 13))

# 第一个维度的曲线
ax = plt.subplot(6, 1, 1)
plt.plot(set_y1[startt:endd], 'k.-', label='设定值')
plt.plot(y1_pred_inverse_transform, 'r', label='SC-MLP-U')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('铁水温度MIT/℃', fontproperties=font)  # 使用中文标签
plt.legend(prop=font222)
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边

input_term222 =        ['富氧流量/(m\u00b3/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
output_term222 = ['铁水温度MIT/℃', '铁水硅含量[Si]/%']
time_term= '时间戳h'
input_term333 =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term333 = ['铁水温度MIT', '铁水硅含量[Si]']
time_term= '时间戳h'
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
dtiem = -0.5




ax.text(0.5, dtiem, f'{subplot_labels[0]} {output_term333[0]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签




# 第二个维度的曲线
ax = plt.subplot(6, 1, 2)
plt.plot(set_y2[startt:endd], 'k.-')
plt.plot(y2_pred_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('铁水硅含量[Si]/%', fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.text(0.5, dtiem, f'{subplot_labels[1]} {output_term333[1]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签
# 第一个维度的u1曲线
ax = plt.subplot(6, 1, 3)
plt.plot(all_pred_u1_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[0], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[2]} {input_term333[0]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第二个维度的u2曲线
ax = plt.subplot(6, 1, 4)
plt.plot(all_pred_u2_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[1], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[3]} {input_term333[1]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第三个维度的u3曲线
ax = plt.subplot(6, 1, 5)
plt.plot(all_pred_u3_inverse_transform, 'r')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[2], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[4]} {input_term333[2]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第四个维度的u4曲线
ax = plt.subplot(6, 1, 6)
plt.plot(all_pred_u4_inverse_transform, 'r')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[3], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[5]} {input_term333[3]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签



# 调整子图布局
plt.tight_layout()
plt.show()
# Out:
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[5.35000000e+01 1.97641697e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 10.8066
# 平均误差 0.0365

# %%
startt = 50
endd = 150

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()

# # 将数据转换为DataFrame
# data = {
#     'set_y1': set_y1,
#     'set_y2': set_y2,
#     'RES_MLP_U_y1': y1_pred_inverse_transform,
#     'MLP_U_y2': y2_pred_inverse_transform,
#     'RES_MLP_U_u1': all_pred_u1_inverse_transform,
#     'RES_MLP_U_u2': all_pred_u2_inverse_transform,
#     'RES_MLP_U_u3': all_pred_u3_inverse_transform,
#     'RES_MLP_U_u4': all_pred_u4_inverse_transform
# }

# df = pd.DataFrame(data)

# # 保存DataFrame到Excel文件
# df.to_excel('pred_data_RES_MLP_U_'+str(cengshu)+'.xlsx', index=False)




a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))

# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(10, 6))

# 第一个维度的曲线
plt.subplot(2, 1, 1)
plt.plot(set_y1[startt:endd], 'ro-', label='设定值')
plt.plot(y1_pred_inverse_transform, 'bo-', label='RES_MLP_U 实际值')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend(prop=font)
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(2, 1, 2)
plt.plot(set_y2[startt:endd], 'ro-')
plt.plot(y2_pred_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 调整子图布局
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 8))
# 第一个维度的u1曲线
plt.subplot(4, 1, 1)
plt.plot(all_pred_u1_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(4, 1, 2)
plt.plot(all_pred_u2_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(4, 1, 3)
plt.plot(all_pred_u3_inverse_transform, 'bo-')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(4, 1, 4)
plt.plot(all_pred_u4_inverse_transform, 'bo-')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[5.35000000e+01 1.97641697e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 10.8066
# 平均误差 0.0365
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
