# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径

# %%
# 读取Excel文件
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\趋势变量+噪声变量\\趋势变量加随机噪声-专用数据1.xlsx'
df_sheet = pd.read_excel(excel_path, sheet_name='建模-分量-全部') 
print(df_sheet.info())
print(df_sheet.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7398 entries, 0 to 7397
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   时间戳          7398 non-null   float64
#  1   铁口1温度        7398 non-null   float64
#  2   时间戳.1        7398 non-null   float64
#  3   P            7398 non-null   float64
#  4   Unnamed: 4   0 non-null      float64
#  5   时间戳.2        7398 non-null   float64
#  6   SI           7398 non-null   float64
#  7   Unnamed: 7   0 non-null      float64
#  8   主参数时间戳       7398 non-null   float64
#  9   冷风压力         7398 non-null   float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  时间戳.3        7398 non-null   float64
#  13  冷风流量         7398 non-null   float64
#  14  Unnamed: 14  0 non-null      float64
#  15  时间戳.4        7398 non-null   float64
#  16  热风温度         7398 non-null   float64
#  17  Unnamed: 17  0 non-null      float64
#  18  时间戳.5        7398 non-null   float64
#  19  设定喷煤量        7398 non-null   float64
# dtypes: float64(20)
# memory usage: 1.1 MB
# None
# Index(['时间戳', '铁口1温度', '时间戳.1', 'P', 'Unnamed: 4', '时间戳.2', 'SI', 'Unnamed: 7',
#        '主参数时间戳', '冷风压力', 'Unnamed: 10', 'Unnamed: 11', '时间戳.3', '冷风流量',
#        'Unnamed: 14', '时间戳.4', '热风温度', 'Unnamed: 17', '时间戳.5', '设定喷煤量'],
#       dtype='object')

# %%
# 定义输入输出参数
input_term = ['冷风压力', '冷风流量', '热风温度', '设定喷煤量']
output_term = ['铁口1温度', 'SI']
time_term= '时间戳'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_process = df_sheet.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 2.25 * y.std()  # 使用标准差作为阈值
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value




# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[input_term[3]])
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[output_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process['主参数时间戳'], df_sheet_process[output_term[1]])

plt.figure(figsize=(15, 10))
for idx, column in enumerate(input_term+output_term):
    
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet[column].values,df_sheet_process[column].values,column)

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r*-', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 800
start1 = 0
length2 = 800
start2 = 4800


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 10))
for idx, column in enumerate(input_term+output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_process[input_term[0]].values,
    input_term[1]:   df_sheet_process[input_term[1]].values,
    input_term[2]:   df_sheet_process[input_term[2]].values,
    input_term[3]:   df_sheet_process[input_term[3]].values,
    output_term[0]:  df_sheet_process[output_term[0]].values,
    output_term[1]:  df_sheet_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
print('每摄氏度的输出差：',(data3-data1)/(data4-data2))



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [-0.16003665]
# [1500.]
# [0.05756924]
# [1510.]
# 每摄氏度的输出差： [0.02176059]
# [-0.50679494]
# [0.5]
# [-0.35920837]
# [0.6]
# 每0.01浓度的输出差： [0.14758657]

# %%
# 组合训练数据--拆分训练、测试集
train_size = 0.7
val_size = 0.15
test_size = 0.15
def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data):
    u1_data = u1_data
    u2_data = u2_data
    u3_data = u3_data
    u4_data = u4_data

    u1_data_1 = np.roll(u1_data, 1)
    u2_data_1 = np.roll(u2_data, 1)
    u3_data_1 = np.roll(u3_data, 1)
    u4_data_1 = np.roll(u4_data, 1)

    y1_data = y1_data
    y2_data = y2_data

    X = np.column_stack((   u1_data  [1:-1], u2_data  [1:-1], u3_data  [1:-1], u4_data  [1:-1],
                            u1_data_1[1:-1], u2_data_1[1:-1], u3_data_1[1:-1], u4_data_1[1:-1],
                            y1_data  [1:-1], y2_data  [1:-1])
                        )
    y = np.column_stack((y1_data[2:],y2_data[2:]))

    # 使用 reshape 转换形状(457, 10) (457, 2)--->(457, 1, 10) (457, 1, 2)
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))
    y_reshaped = y.reshape((y.shape[0], 1, y.shape[1]))
    print('总数据数量：',y.shape)


    isShuffle = True
    # isShuffle = False

    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_reshaped, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)




    y_train = y_train.reshape((y_train.shape[0],y_train.shape[2]))
    y_val = y_val.reshape((y_val.shape[0],y_val.shape[2]))
    y_test = y_test.reshape((y_test.shape[0],y_test.shape[2]))
    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test, X_reshaped, y_reshaped

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]][index_gaolu]
u2_data = normalized_data_dict[input_term[1]][index_gaolu]
u3_data = normalized_data_dict[input_term[2]][index_gaolu]
u4_data = normalized_data_dict[input_term[3]][index_gaolu]
y1_data = normalized_data_dict[output_term[0]][index_gaolu]
y2_data = normalized_data_dict[output_term[1]][index_gaolu]
num_samples = y1_data.shape[0]
print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test,\
X_gaolu_modified, y_gaolu_modified = make_data(u1_data,u2_data,u3_data,u4_data,y1_data, y2_data)

# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]][index_predict]
u2_data = normalized_data_dict[input_term[1]][index_predict]
u3_data = normalized_data_dict[input_term[2]][index_predict]
u4_data = normalized_data_dict[input_term[3]][index_predict]
y1_data = normalized_data_dict[output_term[0]][index_predict]
y2_data = normalized_data_dict[output_term[1]][index_predict]
num_samples = y1_data.shape[0]
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test,\
X_predict_modified, y_predict_modified = make_data(u1_data,u2_data,u3_data,u4_data,y1_data, y2_data)

all_data_X = np.concatenate((X_gaolu_modified,X_predict_modified),axis=0)  
all_data_y = np.concatenate((y_gaolu_modified,y_predict_modified),axis=0)  
print(all_data_X.shape)
print(all_data_X.shape)
# Out:
# 高炉模型数据
# 总数据数量： (799, 2)
# 训练数量： (559, 1, 10) (559, 2)
# 验证数量： (120, 1, 10) (120, 2)
# 测试数量： (120, 1, 10) (120, 2)
# 预测模型数据
# 总数据数量： (799, 2)
# 训练数量： (559, 1, 10) (559, 2)
# 验证数量： (120, 1, 10) (120, 2)
# 测试数量： (120, 1, 10) (120, 2)
# (1598, 1, 10)
# (1598, 1, 10)

# %%
all_data_X_tensor = torch.tensor(all_data_X)
all_data_X_tensor = all_data_X_tensor.to(torch.float32) 
all_data_X_tensor.shape




X_gaolu_train_tensor = torch.tensor(X_gaolu_train)
X_gaolu_train_tensor = X_gaolu_train_tensor.to(torch.float32) 
X_gaolu_train_tensor.shape

X_gaolu_val_tensor = torch.tensor(X_gaolu_val)
X_gaolu_val_tensor = X_gaolu_val_tensor.to(torch.float32) 
X_gaolu_val_tensor.shape

X_gaolu_test_tensor = torch.tensor(X_gaolu_test)
X_gaolu_test_tensor = X_gaolu_test_tensor.to(torch.float32) 
X_gaolu_test_tensor.shape



X_predict_train_tensor = torch.tensor(X_predict_train)
X_predict_train_tensor = X_predict_train_tensor.to(torch.float32) 
X_predict_train_tensor.shape

X_predict_val_tensor = torch.tensor(X_predict_val)
X_predict_val_tensor = X_predict_val_tensor.to(torch.float32) 
X_predict_val_tensor.shape

X_predict_test_tensor = torch.tensor(X_predict_test)
X_predict_test_tensor = X_predict_test_tensor.to(torch.float32) 
X_predict_test_tensor.shape
# Out:
# torch.Size([120, 1, 10])

# %%
# 自编码器
import torch
import torch.nn as nn

class Autoencoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(hidden_size, input_size),
            nn.Sigmoid()  # 将输出限制在 [0, 1] 的范围内
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded,decoded

# # 准备训练数据
# train_data = torch.randn(559, 5, 6)  # 训练数据集形状为 (样本数, 时间步, 特征数)
# train_labels = torch.randn(559, 2)   # 标签形状为 (样本数, 输出特征数)

# 定义输入维度、隐藏层维度和输出维度
input_size = 10  # 输入特征数
hidden_size = 128
output_size = 10

# %%
# 创建自编码器-高炉模型实例
Autoencoder_model_gaolu = Autoencoder(input_size, hidden_size)
# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(Autoencoder_model_gaolu.parameters(), lr=0.0015)

# 模型训练
epochs = 1000
loss_list = []
for epoch in range(epochs):
    optimizer.zero_grad()
    encoded,outputs = Autoencoder_model_gaolu(all_data_X_tensor)  # 前向传播
    loss = criterion(outputs, all_data_X_tensor)  # 计算损失
    loss.backward()  # 反向传播
    optimizer.step()  # 更新模型参数
    loss_list.append(loss.item())
    if epoch % 1 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.8f}", end='\r')

plt.plot(loss_list[:])
# Out:
# Epoch [1000/1000], Loss: 0.04164951

# %%
X_gaolu_train_encoded,outputs = Autoencoder_model_gaolu(X_gaolu_train_tensor)
X_gaolu_val_encoded,outputs = Autoencoder_model_gaolu(X_gaolu_val_tensor)
X_gaolu_test_encoded,outputs = Autoencoder_model_gaolu(X_gaolu_test_tensor)
X_gaolu_train_encoded.shape


X_predict_train_encoded,outputs = Autoencoder_model_gaolu(X_predict_train_tensor)
X_predict_val_encoded,outputs = Autoencoder_model_gaolu(X_predict_val_tensor)
X_predict_test_encoded,outputs = Autoencoder_model_gaolu(X_predict_test_tensor)
X_predict_train_encoded.shape
# Out:
# torch.Size([559, 1, 128])

# %%
# 定义LSTM模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyRNNModel(torch.nn.Module):
    def __init__(self,features_size,hidden_size,isbidirectional):
        super(MyRNNModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size=features_size,
            hidden_size=hidden_size,
            batch_first=True,
            bidirectional=isbidirectional
        )
        if isbidirectional:
            self.fc = nn.Linear(2 * hidden_size, 2)
        else:
            self.fc = nn.Linear(hidden_size, 2)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        
        last_lstm_output = lstm_out[:, -1, :]
        # print(last_lstm_output)
        output = self.fc(last_lstm_output)
        
        return output

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse



    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_train) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
epoch_once_time = 25

# %%
# 建立高炉模型实例
features_size = 128
hidden_size = 16
# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyRNNModel(features_size = features_size, 
                        hidden_size = hidden_size,
                        isbidirectional=True)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train_encoded, y_gaolu_train,
                                    X_gaolu_val_encoded, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 5/25 轮, 训练误差: 0.0385, 验证误差: 0.0106
# 第 25/25 轮, 训练误差: 0.0319, 验证误差: 0.0093
# epoch_sum: 25

# %%
# 高炉模型预测
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_gaolu_test_encoded)
# 计算 RMSE、MRE
y_test = y_gaolu_test
# y_test = y_test[:70]
# y_pred_0 = y_pred_0[:70]
# y_pred_1 = y_pred_1[:70]




y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

# 计算 
mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))


mape_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0)) * 100
mape_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1)) * 100

# 打印结果

print(f"RMSE:  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
print(f"MAPE:  {output_term[0]}: {mape_0:.4f}% , {output_term[1]}: {mape_1:.4f}%")
print(f"MRE :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)


output0 = y_test_0 - y_pred_0_inverse_transform
output1 = y_test_1 - y_pred_1_inverse_transform

# print(f"误差分析0:平均值:{output0.std():.4f},方差:{output0.mean():.4f}")
# print(f"误差分析1:平均值:{output1.std():.4f},方差:{output1.mean():.4f}")


plt.subplot(4, 1, 1)
plt.plot(y_test_0,'r')
plt.plot(y_pred_0_inverse_transform,'g')
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 2)
plt.plot(y_test_1,'r')
plt.plot(y_pred_1_inverse_transform,'g')
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
#

plt.subplot(4, 1, 3)
plt.plot(output0,'r-')
plt.ylabel(output_term[0]+'_err', fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 4)
plt.plot(output1,'g-')
plt.ylabel(output_term[1]+'_err', fontproperties=font)  # 使用中文标签


plt.tight_layout()
plt.show()
# Out:
# RMSE:  铁口1温度: 7.0265 , SI: 0.0714
# MAPE:  铁口1温度: 0.2886% , SI: 15.3638%
# MRE :  铁口1温度: 0.0029  , SI: 0.1536

# %%
# 创建预测模型实例
features_size = 128
hidden_size_predict = 16
# 设置随机种子
torch.manual_seed(0)
model = MyRNNModel(features_size = features_size, 
                    hidden_size = hidden_size_predict,
                    isbidirectional=True)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model.my_fit(X_predict_train_encoded, y_predict_train,
                                    X_predict_val_encoded, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 25/25 轮, 训练误差: 0.0394, 验证误差: 0.0098
# epoch_sum: 0

# %%
# 预测模型预测
y_pred_0,y_pred_1  = model.my_predict(X_predict_test_encoded)

# 计算 RMSE、MRE
y_test = y_predict_test







y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

# 计算 
mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))


mape_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0)) * 100
mape_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1)) * 100

# 打印结果

print(f"RMSE:  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
print(f"MAPE:  {output_term[0]}: {mape_0:.4f}% , {output_term[1]}: {mape_1:.4f}%")
print(f"MRE :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)


output0 = y_test_0 - y_pred_0_inverse_transform
output1 = y_test_1 - y_pred_1_inverse_transform

# print(f"误差分析0:平均值:{output0.std():.4f},方差:{output0.mean():.4f}")
# print(f"误差分析1:平均值:{output1.std():.4f},方差:{output1.mean():.4f}")


plt.subplot(4, 1, 1)
plt.plot(y_test_0,'r')
plt.plot(y_pred_0_inverse_transform,'g')
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 2)
plt.plot(y_test_1,'r')
plt.plot(y_pred_1_inverse_transform,'g')
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
#

plt.subplot(4, 1, 3)
plt.plot(output0,'r-')
plt.ylabel(output_term[0]+'_err', fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 4)
plt.plot(output1,'g-')
plt.ylabel(output_term[1]+'_err', fontproperties=font)  # 使用中文标签


plt.tight_layout()
plt.show()
# Out:
# RMSE:  铁口1温度: 8.7006 , SI: 0.0808
# MAPE:  铁口1温度: 0.3876% , SI: 11.5465%
# MRE :  铁口1温度: 0.0039  , SI: 0.1155

# %%
y_test = y_predict_test
y_test_0 = scalers[output_term[0]].inverse_transform(y_predict_test[:,0].reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform(y_predict_test[:,1].reshape(-1, 1)).flatten()
y_pred_0,y_pred_1  = model.my_predict(X_predict_test_encoded)
y_pred_0_predict = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_predict = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

y_pred_0,y_pred_1  = model_gaolu.my_predict(X_predict_test_encoded)
y_pred_0_gaolu = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_gaolu = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

plt.subplot(2, 1, 1)
plt.plot(y_test_0, 'r-', label='Actual')
plt.plot(y_pred_0_predict, 'g-', label='Predict')
plt.plot(y_pred_0_gaolu, 'b', label='Gaolu')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(y_test_1, 'r-', label='Actual')
plt.plot(y_pred_1_predict, 'g-', label='Predict')
plt.plot(y_pred_1_gaolu, 'b', label='Gaolu')
plt.legend()

# %%
# # 保存模型参数到文件
# torch.save(model.state_dict(), 'model_predict_params.pth')

# %%
# 自定义预测
model_predict = model
hidden_size = hidden_size_predict
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def lstm_forward(input, initial_states, w_ih, w_hh, b_ih, b_hh):
    h_0, c_0 = initial_states  # 初始状态  [b_size, hidden_size]
    b_size, seq_len, input_size = input.shape
    h_size = h_0.shape[-1]

    h_prev, c_prev = h_0, c_0

    # 使用 np.newaxis 在第一个维度上插入一个新的维度  # 使用 np.tile 在第一个维度上复制 b_size 次
    w_ih_expanded = w_ih[np.newaxis, :, :]    
    w_ih_batch = np.tile(w_ih_expanded, (b_size, 1, 1))
    w_hh_expanded = w_hh[np.newaxis, :, :]    
    w_hh_batch = np.tile(w_hh_expanded, (b_size, 1, 1))
    # print(w_ih_batch.shape)

    output_size = h_size
    output = np.zeros((b_size, seq_len, output_size))  # 初始化一个输出序列
    for t in range(seq_len):
        x = input[:, t, :]  # 当前时刻的输入向量 [b,in_size]->[b,in_size,1]
        w_times_x = np.matmul(w_ih_batch, x[:, :, np.newaxis]).squeeze(-1)   # bmm:含有批量大小的矩阵相乘
        # [b, 4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Wii*xt|Wif*xt|Wig*xt|Wio*xt
        w_times_h_prev = np.matmul(w_hh_batch, h_prev[:, :, np.newaxis]).squeeze(-1)
        # [b, 4*hidden_size, hidden_size]*[b, hidden_size, 1]->[b,4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Whi*ht-1|Whf*ht-1|Whg*ht-1|Who*ht-1

        # 分别计算输入门(i)、遗忘门(f)、cell门(g)、输出门(o)  维度均为 [b, h_size]
        i_t = sigmoid(w_times_x[:, :h_size] + w_times_h_prev[:, :h_size] + b_ih[:h_size] + b_hh[:h_size])  # 取前四分之一
        f_t = sigmoid(w_times_x[:, h_size:2*h_size] + w_times_h_prev[:, h_size:2*h_size]
                            + b_ih[h_size:2*h_size] + b_hh[h_size:2*h_size])
        g_t = np.tanh(w_times_x[:, 2*h_size:3*h_size] + w_times_h_prev[:, 2*h_size:3*h_size]
                            + b_ih[2*h_size:3*h_size] + b_hh[2*h_size:3*h_size])
        o_t = sigmoid(w_times_x[:, 3*h_size:] + w_times_h_prev[:, 3*h_size:]
                            + b_ih[3*h_size:] + b_hh[3*h_size:])
        c_prev = f_t * c_prev + i_t * g_t
        h_prev = o_t * np.tanh(c_prev)

        output[:, t, :] = h_prev

    return output, (np.expand_dims(h_prev, axis=0), np.expand_dims(c_prev, axis=0))  # 官方是三维，在第0维扩一维



def predict_my(data_input):

    input = data_input  # 随机初始化一个输入序列
    c_0 = np.zeros((data_input.shape[0], hidden_size))  # 初始值，不会参与训练
    h_0 = np.zeros((data_input.shape[0], hidden_size))

    output_forward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0.detach().numpy())

    last_lstm_output_forward = output_forward[:, -1, :]

    output_backward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0_reverse.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0_reverse.detach().numpy())

    last_lstm_output_backward = output_backward[:, -1, :]
    # print(last_lstm_output_forward.shape)
    # print(last_lstm_output_backward.shape)
    # 最终输出
    combined_hidden = np.concatenate((last_lstm_output_forward, last_lstm_output_backward), axis=1)
    # print(combined_hidden.shape)


    output = (np.dot(combined_hidden, np.transpose(model_predict.fc.weight.detach().numpy()))
                + model_predict.fc.bias.detach().numpy()
)
    y_pred_0, y_pred_1= output[:,0],output[:,1]

    # y_pred_0 = scalers[output_term[0]].inverse_transform(np.array(y_pred_0).reshape(-1, 1)).flatten()
    # y_pred_1 = scalers[output_term[1]].inverse_transform(np.array(y_pred_1).reshape(-1, 1)).flatten()




    return y_pred_0, y_pred_1


y_pred_0, y_pred_1= predict_my(X_predict_test_encoded.detach().numpy())


# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)
# plot_hit_rate_curve(y_test, y_pred_0.detach().numpy(), y_pred_1.detach().numpy())

# %%
# 生成期望数据
Times = 100

def generate_y_aim_data(Times):

    set_y1 = np.full(Times,1500)
    set_y1[30:] = 1505
    set_y1[60:] = 1510
    set_y1[90:] = 1515
    # set_y1[70:] = 1520
    # set_y1[90:] = 1525

    set_y2 = np.full(Times,0.40)
    set_y2[15:] = 0.44
    set_y2[45:] = 0.48
    set_y2[75:] = 0.52
    # 限制设定值在 -1 到 1 之间
    # set_y1 = np.clip(set_y1, -1, 1)
    # set_y2 = np.clip(set_y2, -1, 1)


    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# # 调用示例
# set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
# plt.plot(set_y1_trans)
# plt.plot(set_y2_trans)
# plt.title('y_sp')
# plt.show()

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+2  ]
    u2   = u2_data[randint  :randint+2  ]
    u3   = u3_data[randint  :randint+2  ]
    u4   = u4_data[randint  :randint+2  ]
    u1_1 = u1_data[randint-1:randint+2-1]
    u2_1 = u2_data[randint-1:randint+2-1]    
    u3_1 = u3_data[randint-1:randint+2-1]
    u4_1 = u4_data[randint-1:randint+2-1]

    y1   = y1_data[randint  :randint+2  ]
    y2   = y2_data[randint  :randint+2  ]
    k_data = np.concatenate((u1, u2, u3, u4, u1_1, u2_1, u3_1, u4_1, y1, y2), axis=0)
    # print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
import numpy as np

# 获取编码器线性层权重值和偏置
encoder_linear_weight = Autoencoder_model_gaolu.encoder[0].weight.detach().numpy()
encoder_linear_bias = Autoencoder_model_gaolu.encoder[0].bias.detach().numpy()

# 使用NumPy数组重建编码器部分
new_encoder_linear = np.matmul(encoder_linear_weight.T, np.diag(np.ones(features_size)))
new_encoder_bias = encoder_linear_bias

# 定义ReLU激活函数
def relu(x):
    return np.maximum(0, x)

# 重新构建编码器部分
def new_encoder_forward(x):
    encoded = np.matmul(x, new_encoder_linear) + new_encoder_bias
    return relu(encoded)

# %%
def data2encoder(x):


    x_encoded = new_encoder_forward(x)
    # print('x_encoded',x_encoded.shape)

    return x_encoded

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):
    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0
    # lamda1 = 0.001
    # y1_percent = 8.528
    # y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:2]
    u2   = k_data[2:4]
    u3   = k_data[4:6]
    u4   = k_data[6:8]
    u1_1 = k_data[8:10]
    u2_1 = k_data[10:12]
    u3_1 = k_data[12:14]
    u4_1 = k_data[14:16]

    y1   = k_data[16:18]
    y2   = k_data[18:20]
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]

    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1[:1],U1))
    u2   = np.concatenate((u2[:1],U2))
    u3   = np.concatenate((u3[:1],U3))
    u4   = np.concatenate((u4[:1],U4))

    u1_1 = np.concatenate((u1_1[:2],U1[:-1]))
    u2_1 = np.concatenate((u2_1[:2],U2[:-1]))
    u3_1 = np.concatenate((u3_1[:2],U3[:-1]))
    u4_1 = np.concatenate((u4_1[:2],U4[:-1]))

    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    y1_k = y1[1]
    y2_k = y2[1]
    # print(u1)
    # print(u2)
    # print(u1_1)
    # print(u2_1)
    # print(y1)
    # print(y2)
    # print(y1_k)    
    # print(y2_k)

    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        x = data2encoder(x)
        y1_m_k,y2_m_k = predict_my(x)
        # y1[j+1] = y1_m_k.item()###############################是否替换不知道有没有影响？
        # y2[j+1] = y2_m_k.item()###############################
        # 在k时刻，我要先通过k-1时刻来预测出当前k时刻下的预测值。
        # 实际上，这个时候我有k时刻的真实值。
        # 但是这么做是为了能够获取我的预测值和真实值之间的误差，
        # 然后基于这个误差，通过对控制器输入的调整来预测k+1时刻，
        # 然后依次往下。因此，在k时刻，我系统的值是固定的，
        # 也就是我的真实值，所以我要把它存储到我的整体的一个序列里面。
        # 在取出当前k时刻真实值的过程中，我不能将之前预测的时候的那个
        # 预测值覆盖掉真实值。后面新预测的数值要加上前面的那一个误差
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k

    # 对每个U对应的控制时刻进行预测-----M次
    for j in range(1,M+1):  
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        x = data2encoder(x)
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):
        x = np.column_stack((u1[-1],u2[-1],u3[-1],u4[-1],u1[-1],u2[-1],u3[-1],u4[-1],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        x = data2encoder(x)
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    k_data2 = np.concatenate((u1[1:3],u2[1:3],u3[1:3],u4[1:3],u1_1[1:3],u2_1[1:3],u3_1[1:3],u4_1[1:3],y1[1:3],y2[1:3]),axis=0)


    
    # y1_aim = scalers[output_term[0]].inverse_transform(np.array(y1_aim).reshape(-1, 1)).flatten()
    # y1 = scalers[output_term[0]].inverse_transform(np.array(y1).reshape(-1, 1)).flatten()
    # y1_k = scalers[output_term[0]].inverse_transform(np.array(y1_k).reshape(-1, 1)).flatten()
    # y2_aim = scalers[output_term[1]].inverse_transform(np.array(y2_aim).reshape(-1, 1)).flatten()
    # y2 = scalers[output_term[1]].inverse_transform(np.array(y2).reshape(-1, 1)).flatten()
    # y2_k = scalers[output_term[1]].inverse_transform(np.array(y2_k).reshape(-1, 1)).flatten()
    # E1_k = scalers[output_term[0]].inverse_transform(np.array(E1_k).reshape(-1, 1)).flatten()
    # E2_k = scalers[output_term[1]].inverse_transform(np.array(E2_k).reshape(-1, 1)).flatten()
    # u1 = scalers[input_term[0]].inverse_transform(np.array(u1).reshape(-1, 1)).flatten()
    # u2 = scalers[input_term[1]].inverse_transform(np.array(u2).reshape(-1, 1)).flatten()
    # u3 = scalers[input_term[2]].inverse_transform(np.array(u3).reshape(-1, 1)).flatten()
    # u4 = scalers[input_term[3]].inverse_transform(np.array(u4).reshape(-1, 1)).flatten()


    #和获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[2:]
    y2_M_k = y2[2:]
    if isprint==1:

        print('y1_k',y1_k)  
        print('y1_m_k',y1_m_k)    
        print('y2_k',y2_k)  
        print('y2_m_k',y2_m_k)    

        print('temp:')
        print('y1_aim',y1_aim)
        print('y1_r_aim',y1_r_aim)
        print('  ')
        print('y1_r',y1_r)
        print('y1_M_k+h1*E1_k',y1_M_k+h1*E1_k)
        print('  ')
        print('y1',y1)
        print('h*E1_k',h1*E1_k)

        print('Si_percent:')
        print('y2_aim',y2_aim)
        print('y2_r_aim',y2_r_aim)
        print('y2_r',y2_r)
        print('y2_M_k+h2*E2_k',y2_M_k+h2*E2_k)

        print('y2',y2)
        print('h*E2_k',h2*E2_k)

        print('u:')
        print(u1)
        print(u2)
        print(u3)
        print(u4)
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙
    
    # if np.abs(y1_aim-y1_k)<0.0001 and np.abs(y2_aim-y2_k)<0.0001:
    #     lamda1 = 1

    y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    u1_power = lamda1*np.sum(((np.diff(u1)**2)))
    u2_power = lamda2*np.sum(((np.diff(u2)**2)))
    u3_power = lamda3*np.sum(((np.diff(u3)**2)))
    u4_power = lamda4*np.sum(((np.diff(u3)**2)))

    mse = (0
            # +loss_function(y1_r, y1_M_k+h*E1_k, weights)
            # +loss_function(y2_r, y2_M_k+h*E2_k, weights)
            # +(np.abs(y1_aim-y1_k)**2+np.abs(y2_aim-y2_k)**2)*P*2000
            # +np.sum((y1_r-y1_M_k-h*E1_k)**2 + (y2_r-y2_M_k-h*E2_k)**2)
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power

            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1, E2_k*h2

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 4  # 预测时域长度  增大P能平稳些
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, 
                        y1_data, y2_data, num_samples, P)

# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
# MPC控制循环
for k in range(Times):
    print(f"这是对第{k}时刻的最优U1、U2输入求解")
    # print('y1_aim  y2_aim',set_y1[k],set_y2[k])
    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    # 定义参数的上下限  
    bounds = [(-max_control, max_control) for _ in range(4 * M)]
    # 设置退出条件
    exit_conditions = {'maxiter': 1000}  # 您可以根据需要调整容差

    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组
    
    # # 查看退出条件
    # if result.success:
    #     print("优化成功收敛!")
    # else:
    #     print("优化未成功收敛。")
    #     # 打印其他结果信息
    # print("最优参数:", result.x)
    # print("最优函数值:", result.fun)
    # print("迭代次数:", result.nit)
    # print("Gradient:", result.jac)
    optimized_U1, optimized_U2, optimized_U3, optimized_U4 = result.x[0:M], result.x[M:2*M], result.x[2*M:3*M], result.x[3*M:4*M]


    # 获取当前时刻下，在最优的U1、U2下的响应    
    u1_k = optimized_U1[0]
    u2_k = optimized_U2[0]
    u3_k = optimized_U3[0]
    u4_k = optimized_U4[0]
    u1_k_1 = k_data[9]
    u2_k_1 = k_data[11]
    u3_k_1 = k_data[13]
    u4_k_1 = k_data[15]
    y1_k = k_data[17] 
    y2_k = k_data[19] 
    

    
    x = np.column_stack((u1_k,u2_k,u3_k,u4_k,u1_k_1,u2_k_1,u3_k_1,u4_k_1,y1_k,y2_k))
    x = x.reshape((x.shape[0], 1, x.shape[1]))
    x = data2encoder(x)
    y1_pred0, y2_pred0 = model.my_predict(x)
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    

    # 获取当前时刻下，在最优的U1、U2下的响应
    params = np.concatenate((optimized_U1,optimized_U2,optimized_U3,optimized_U4),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 
    
    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))


    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(u1_k)
    all_pred_u2.append(u2_k)
    all_pred_u3.append(u3_k)
    all_pred_u4.append(u4_k)
    k_data2[17] = y1_pred
    k_data2[19] = y2_pred
    k_data = k_data2
# 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 301
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.0575] 高炉 [-0.2235] 高炉与设定误差 [0.0634] 模型误差 [0.166] 校正值 [0.0275]
# 2设定 -0.6544 预测 [-0.5062] 高炉 [-0.6195] 高炉与设定误差 [-0.0349] 模型误差 [0.1132] 校正值 [0.1547]
# 这是对第1时刻的最优U1、U2输入求解
# C:\Users\haokw\AppData\Local\Temp\ipykernel_27572\152659184.py:104: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[17] = y1_pred
# C:\Users\haokw\AppData\Local\Temp\ipykernel_27572\152659184.py:105: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[19] = y2_pred
# 1设定 -0.16 预测 [-0.072] 高炉 [-0.4088] 高炉与设定误差 [0.2487] 模型误差 [0.3368] 校正值 [-0.166]
# 2设定 -0.6544 预测 [-0.7094] 高炉 [-0.7485] 高炉与设定误差 [0.0941] 模型误差 [0.0391] 校正值 [-0.1132]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.0409] 高炉 [-0.069] 高炉与设定误差 [-0.0911] 模型误差 [0.0281] 校正值 [-0.3368]
# 2设定 -0.6544 预测 [-0.6247] 高炉 [-0.6355] 高炉与设定误差 [-0.0189] 模型误差 [0.0107] 校正值 [-0.0391]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.0783] 高炉 [0.0472] 高炉与设定误差 [-0.2072] 模型误差 [-0.1255] 校正值 [-0.0281]
# 2设定 -0.6544 预测 [-0.6142] 高炉 [-0.6066] 高炉与设定误差 [-0.0478] 模型误差 [-0.0076] 校正值 [-0.0107]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1635] 高炉 [0.0738] 高炉与设定误差 [-0.2338] 模型误差 [-0.2373] 校正值 [0.1255]
# 2设定 -0.6544 预测 [-0.6113] 高炉 [-0.5957] 高炉与设定误差 [-0.0587] 模型误差 [-0.0156] 校正值 [0.0076]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2986] 高炉 [-0.0938] 高炉与设定误差 [-0.0662] 模型误差 [-0.2049] 校正值 [0.2373]
# 2设定 -0.6544 预测 [-0.6134] 高炉 [-0.5483] 高炉与设定误差 [-0.1061] 模型误差 [-0.0651] 校正值 [0.0156]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3342] 高炉 [-0.3083] 高炉与设定误差 [0.1483] 模型误差 [-0.0258] 校正值 [0.2049]
# 2设定 -0.6544 预测 [-0.6968] 高炉 [-0.6574] 高炉与设定误差 [0.003] 模型误差 [-0.0394] 校正值 [0.0651]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2007] 高炉 [-0.4481] 高炉与设定误差 [0.2881] 模型误差 [0.2474] 校正值 [0.0258]
# 2设定 -0.6544 预测 [-0.7062] 高炉 [-0.6911] 高炉与设定误差 [0.0368] 模型误差 [-0.015] 校正值 [0.0394]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1285] 高炉 [-0.1753] 高炉与设定误差 [0.0153] 模型误差 [0.0469] 校正值 [-0.2474]
# 2设定 -0.6544 预测 [-0.6633] 高炉 [-0.6662] 高炉与设定误差 [0.0118] 模型误差 [0.0029] 校正值 [0.015]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1147] 高炉 [0.0249] 高炉与设定误差 [-0.1849] 模型误差 [-0.1396] 校正值 [-0.0469]
# 2设定 -0.6544 预测 [-0.6423] 高炉 [-0.6328] 高炉与设定误差 [-0.0216] 模型误差 [-0.0095] 校正值 [-0.0029]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1899] 高炉 [0.0317] 高炉与设定误差 [-0.1917] 模型误差 [-0.2216] 校正值 [0.1396]
# 2设定 -0.6544 预测 [-0.6094] 高炉 [-0.5864] 高炉与设定误差 [-0.068] 模型误差 [-0.023] 校正值 [0.0095]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3464] 高炉 [-0.0563] 高炉与设定误差 [-0.1038] 模型误差 [-0.2901] 校正值 [0.2216]
# 2设定 -0.6544 预测 [-0.6339] 高炉 [-0.4357] 高炉与设定误差 [-0.2186] 模型误差 [-0.1982] 校正值 [0.023]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3108] 高炉 [-0.3217] 高炉与设定误差 [0.1616] 模型误差 [0.0109] 校正值 [0.2901]
# 2设定 -0.6544 预测 [-0.6665] 高炉 [-0.467] 高炉与设定误差 [-0.1874] 模型误差 [-0.1995] 校正值 [0.1982]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2162] 高炉 [-0.5764] 高炉与设定误差 [0.4163] 模型误差 [0.3601] 校正值 [-0.0109]
# 2设定 -0.6544 预测 [-0.7177] 高炉 [-0.7256] 高炉与设定误差 [0.0713] 模型误差 [0.0079] 校正值 [0.1995]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1767] 高炉 [-0.494] 高炉与设定误差 [0.334] 模型误差 [0.3173] 校正值 [-0.3601]
# 2设定 -0.6544 预测 [-0.7674] 高炉 [-0.7605] 高炉与设定误差 [0.1061] 模型误差 [-0.0069] 校正值 [-0.0079]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.0828] 高炉 [-0.122] 高炉与设定误差 [-0.038] 模型误差 [0.0392] 校正值 [-0.3173]
# 2设定 -0.5953 预测 [-0.6187] 高炉 [-0.6168] 高炉与设定误差 [0.0215] 模型误差 [-0.0018] 校正值 [0.0069]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.1191] 高炉 [0.0356] 高炉与设定误差 [-0.1957] 模型误差 [-0.1547] 校正值 [-0.0392]
# 2设定 -0.5953 预测 [-0.5993] 高炉 [-0.5933] 高炉与设定误差 [-0.002] 模型误差 [-0.006] 校正值 [0.0018]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2402] 高炉 [-0.0005] 高炉与设定误差 [-0.1595] 模型误差 [-0.2397] 校正值 [0.1547]
# 2设定 -0.5953 预测 [-0.5894] 高炉 [-0.5522] 高炉与设定误差 [-0.0432] 模型误差 [-0.0373] 校正值 [0.006]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2678] 高炉 [-0.1015] 高炉与设定误差 [-0.0585] 模型误差 [-0.1663] 校正值 [0.2397]
# 2设定 -0.5953 预测 [-0.6287] 高炉 [-0.6593] 高炉与设定误差 [0.0639] 模型误差 [0.0305] 校正值 [0.0373]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.272] 高炉 [-0.1251] 高炉与设定误差 [-0.0349] 模型误差 [-0.1469] 校正值 [0.1663]
# 2设定 -0.5953 预测 [-0.5796] 高炉 [-0.5445] 高炉与设定误差 [-0.0508] 模型误差 [-0.0351] 校正值 [-0.0305]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2778] 高炉 [-0.05] 高炉与设定误差 [-0.11] 模型误差 [-0.2278] 校正值 [0.1469]
# 2设定 -0.5953 预测 [-0.599] 高炉 [-0.5983] 高炉与设定误差 [0.0029] 模型误差 [-0.0008] 校正值 [0.0351]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2873] 高炉 [-0.1002] 高炉与设定误差 [-0.0599] 模型误差 [-0.1871] 校正值 [0.2278]
# 2设定 -0.5953 预测 [-0.584] 高炉 [-0.5602] 高炉与设定误差 [-0.0351] 模型误差 [-0.0238] 校正值 [0.0008]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3378] 高炉 [-0.1261] 高炉与设定误差 [-0.0339] 模型误差 [-0.2117] 校正值 [0.1871]
# 2设定 -0.5953 预测 [-0.6158] 高炉 [-0.6042] 高炉与设定误差 [0.0088] 模型误差 [-0.0116] 校正值 [0.0238]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3494] 高炉 [-0.2561] 高炉与设定误差 [0.096] 模型误差 [-0.0933] 校正值 [0.2117]
# 2设定 -0.5953 预测 [-0.6088] 高炉 [-0.575] 高炉与设定误差 [-0.0203] 模型误差 [-0.0338] 校正值 [0.0116]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.275] 高炉 [-0.2198] 高炉与设定误差 [0.0598] 模型误差 [-0.0552] 校正值 [0.0933]
# 2设定 -0.5953 预测 [-0.6181] 高炉 [-0.6498] 高炉与设定误差 [0.0544] 模型误差 [0.0317] 校正值 [0.0338]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2114] 高炉 [-0.0545] 高炉与设定误差 [-0.1056] 模型误差 [-0.1569] 校正值 [0.0552]
# 2设定 -0.5953 预测 [-0.5897] 高炉 [-0.5874] 高炉与设定误差 [-0.008] 模型误差 [-0.0024] 校正值 [-0.0317]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2189] 高炉 [0.0366] 高炉与设定误差 [-0.1966] 模型误差 [-0.2555] 校正值 [0.1569]
# 2设定 -0.5953 预测 [-0.5759] 高炉 [-0.563] 高炉与设定误差 [-0.0323] 模型误差 [-0.0128] 校正值 [0.0024]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3048] 高炉 [-0.123] 高炉与设定误差 [-0.037] 模型误差 [-0.1818] 校正值 [0.2555]
# 2设定 -0.5953 预测 [-0.5792] 高炉 [-0.542] 高炉与设定误差 [-0.0533] 模型误差 [-0.0371] 校正值 [0.0128]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.3381] 高炉 [-0.2264] 高炉与设定误差 [0.0664] 模型误差 [-0.1117] 校正值 [0.1818]
# 2设定 -0.5953 预测 [-0.6256] 高炉 [-0.6506] 高炉与设定误差 [0.0553] 模型误差 [0.025] 校正值 [0.0371]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 -0.16 预测 [-0.2784] 高炉 [-0.1333] 高炉与设定误差 [-0.0268] 模型误差 [-0.1451] 校正值 [0.1117]
# 2设定 -0.5953 预测 [-0.6043] 高炉 [-0.593] 高炉与设定误差 [-0.0024] 模型误差 [-0.0113] 校正值 [-0.025]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2046] 高炉 [0.0108] 高炉与设定误差 [-0.0621] 模型误差 [-0.2154] 校正值 [0.1451]
# 2设定 -0.5953 预测 [-0.5909] 高炉 [-0.599] 高炉与设定误差 [0.0037] 模型误差 [0.0081] 校正值 [0.0113]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1899] 高炉 [0.0418] 高炉与设定误差 [-0.093] 模型误差 [-0.2316] 校正值 [0.2154]
# 2设定 -0.5953 预测 [-0.5782] 高炉 [-0.5652] 高炉与设定误差 [-0.0301] 模型误差 [-0.013] 校正值 [-0.0081]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.239] 高炉 [0.0177] 高炉与设定误差 [-0.069] 模型误差 [-0.2567] 校正值 [0.2316]
# 2设定 -0.5953 预测 [-0.6053] 高炉 [-0.5919] 高炉与设定误差 [-0.0035] 模型误差 [-0.0135] 校正值 [0.013]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2544] 高炉 [-0.0824] 高炉与设定误差 [0.0312] 模型误差 [-0.1719] 校正值 [0.2567]
# 2设定 -0.5953 预测 [-0.6087] 高炉 [-0.5875] 高炉与设定误差 [-0.0078] 模型误差 [-0.0212] 校正值 [0.0135]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2266] 高炉 [-0.0855] 高炉与设定误差 [0.0343] 模型误差 [-0.141] 校正值 [0.1719]
# 2设定 -0.5953 预测 [-0.6222] 高炉 [-0.6144] 高炉与设定误差 [0.019] 模型误差 [-0.0078] 校正值 [0.0212]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1638] 高炉 [0.0357] 高炉与设定误差 [-0.087] 模型误差 [-0.1995] 校正值 [0.141]
# 2设定 -0.5953 预测 [-0.5968] 高炉 [-0.6014] 高炉与设定误差 [0.006] 模型误差 [0.0046] 校正值 [0.0078]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1663] 高炉 [0.0838] 高炉与设定误差 [-0.135] 模型误差 [-0.2501] 校正值 [0.1995]
# 2设定 -0.5953 预测 [-0.5811] 高炉 [-0.5737] 高炉与设定误差 [-0.0217] 模型误差 [-0.0074] 校正值 [-0.0046]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2277] 高炉 [0.0459] 高炉与设定误差 [-0.0971] 模型误差 [-0.2736] 校正值 [0.2501]
# 2设定 -0.5953 预测 [-0.6002] 高炉 [-0.5726] 高炉与设定误差 [-0.0227] 模型误差 [-0.0276] 校正值 [0.0074]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2629] 高炉 [-0.1083] 高炉与设定误差 [0.0571] 模型误差 [-0.1546] 校正值 [0.2736]
# 2设定 -0.5953 预测 [-0.6137] 高炉 [-0.5935] 高炉与设定误差 [-0.0018] 模型误差 [-0.0201] 校正值 [0.0276]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2115] 高炉 [-0.1025] 高炉与设定误差 [0.0512] 模型误差 [-0.109] 校正值 [0.1546]
# 2设定 -0.5953 预测 [-0.6188] 高炉 [-0.6245] 高炉与设定误差 [0.0291] 模型误差 [0.0057] 校正值 [0.0201]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1497] 高炉 [0.0404] 高炉与设定误差 [-0.0916] 模型误差 [-0.1901] 校正值 [0.109]
# 2设定 -0.5953 预测 [-0.595] 高炉 [-0.6032] 高炉与设定误差 [0.0078] 模型误差 [0.0082] 校正值 [-0.0057]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1585] 高炉 [0.1026] 高炉与设定误差 [-0.1538] 模型误差 [-0.2611] 校正值 [0.1901]
# 2设定 -0.5953 预测 [-0.5513] 高炉 [-0.5505] 高炉与设定误差 [-0.0449] 模型误差 [-0.0008] 校正值 [-0.0082]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2072] 高炉 [0.0715] 高炉与设定误差 [-0.1227] 模型误差 [-0.2786] 校正值 [0.2611]
# 2设定 -0.5953 预测 [-0.5869] 高炉 [-0.5709] 高炉与设定误差 [-0.0244] 模型误差 [-0.0159] 校正值 [0.0008]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2332] 高炉 [0.0062] 高炉与设定误差 [-0.0574] 模型误差 [-0.2394] 校正值 [0.2786]
# 2设定 -0.5953 预测 [-0.6072] 高炉 [-0.5754] 高炉与设定误差 [-0.0199] 模型误差 [-0.0318] 校正值 [0.0159]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2747] 高炉 [-0.0657] 高炉与设定误差 [0.0145] 模型误差 [-0.2089] 校正值 [0.2394]
# 2设定 -0.5953 预测 [-0.6281] 高炉 [-0.5933] 高炉与设定误差 [-0.002] 模型误差 [-0.0347] 校正值 [0.0318]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2489] 高炉 [-0.044] 高炉与设定误差 [-0.0072] 模型误差 [-0.2049] 校正值 [0.2089]
# 2设定 -0.5363 预测 [-0.5954] 高炉 [-0.6135] 高炉与设定误差 [0.0772] 模型误差 [0.0181] 校正值 [0.0347]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1938] 高炉 [0.0687] 高炉与设定误差 [-0.1199] 模型误差 [-0.2625] 校正值 [0.2049]
# 2设定 -0.5363 预测 [-0.5259] 高炉 [-0.5137] 高炉与设定误差 [-0.0226] 模型误差 [-0.0122] 校正值 [-0.0181]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2066] 高炉 [0.0837] 高炉与设定误差 [-0.135] 模型误差 [-0.2903] 校正值 [0.2625]
# 2设定 -0.5363 预测 [-0.5261] 高炉 [-0.4998] 高炉与设定误差 [-0.0365] 模型误差 [-0.0263] 校正值 [0.0122]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.243] 高炉 [-0.0116] 高炉与设定误差 [-0.0397] 模型误差 [-0.2314] 校正值 [0.2903]
# 2设定 -0.5363 预测 [-0.5514] 高炉 [-0.5346] 高炉与设定误差 [-0.0017] 模型误差 [-0.0168] 校正值 [0.0263]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2462] 高炉 [-0.0771] 高炉与设定误差 [0.0258] 模型误差 [-0.1691] 校正值 [0.2314]
# 2设定 -0.5363 预测 [-0.545] 高炉 [-0.527] 高炉与设定误差 [-0.0093] 模型误差 [-0.018] 校正值 [0.0168]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2229] 高炉 [0.005] 高炉与设定误差 [-0.0563] 模型误差 [-0.228] 校正值 [0.1691]
# 2设定 -0.5363 预测 [-0.546] 高炉 [-0.5494] 高炉与设定误差 [0.0131] 模型误差 [0.0034] 校正值 [0.018]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1913] 高炉 [0.0714] 高炉与设定误差 [-0.1226] 模型误差 [-0.2626] 校正值 [0.228]
# 2设定 -0.5363 预测 [-0.5222] 高炉 [-0.5254] 高炉与设定误差 [-0.0109] 模型误差 [0.0032] 校正值 [-0.0034]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2166] 高炉 [0.0824] 高炉与设定误差 [-0.1336] 模型误差 [-0.2989] 校正值 [0.2626]
# 2设定 -0.5363 预测 [-0.5117] 高炉 [-0.4909] 高炉与设定误差 [-0.0454] 模型误差 [-0.0208] 校正值 [-0.0032]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.272] 高炉 [0.0068] 高炉与设定误差 [-0.058] 模型误差 [-0.2788] 校正值 [0.2989]
# 2设定 -0.5363 预测 [-0.5161] 高炉 [-0.4859] 高炉与设定误差 [-0.0504] 模型误差 [-0.0302] 校正值 [0.0208]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2791] 高炉 [-0.1092] 高炉与设定误差 [0.058] 模型误差 [-0.1699] 校正值 [0.2788]
# 2设定 -0.5363 预测 [-0.5507] 高炉 [-0.5544] 高炉与设定误差 [0.0181] 模型误差 [0.0038] 校正值 [0.0302]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2327] 高炉 [-0.0316] 高炉与设定误差 [-0.0196] 模型误差 [-0.2011] 校正值 [0.1699]
# 2设定 -0.5363 预测 [-0.5527] 高炉 [-0.5722] 高炉与设定误差 [0.0359] 模型误差 [0.0195] 校正值 [-0.0038]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.1747] 高炉 [0.0907] 高炉与设定误差 [-0.142] 模型误差 [-0.2655] 校正值 [0.2011]
# 2设定 -0.5363 预测 [-0.5204] 高炉 [-0.5221] 高炉与设定误差 [-0.0142] 模型误差 [0.0017] 校正值 [-0.0195]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2053] 高炉 [0.051] 高炉与设定误差 [-0.1022] 模型误差 [-0.2563] 校正值 [0.2655]
# 2设定 -0.5363 预测 [-0.505] 高炉 [-0.4623] 高炉与设定误差 [-0.074] 模型误差 [-0.0427] 校正值 [-0.0017]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2355] 高炉 [0.0108] 高炉与设定误差 [-0.062] 模型误差 [-0.2463] 校正值 [0.2563]
# 2设定 -0.5363 预测 [-0.5486] 高炉 [-0.5363] 高炉与设定误差 [-1.e-04] 模型误差 [-0.0123] 校正值 [0.0427]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 -0.0512 预测 [-0.2148] 高炉 [-0.0394] 高炉与设定误差 [-0.0119] 模型误差 [-0.1754] 校正值 [0.2463]
# 2设定 -0.5363 预测 [-0.5486] 高炉 [-0.5444] 高炉与设定误差 [0.0081] 模型误差 [-0.0042] 校正值 [0.0123]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1417] 高炉 [0.0167] 高炉与设定误差 [0.0408] 模型误差 [-0.1585] 校正值 [0.1754]
# 2设定 -0.5363 预测 [-0.5412] 高炉 [-0.5572] 高炉与设定误差 [0.0208] 模型误差 [0.016] 校正值 [0.0042]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0711] 高炉 [0.1513] 高炉与设定误差 [-0.0938] 模型误差 [-0.2225] 校正值 [0.1585]
# 2设定 -0.5363 预测 [-0.5352] 高炉 [-0.5711] 高炉与设定误差 [0.0348] 模型误差 [0.0358] 校正值 [-0.016]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0671] 高炉 [0.2124] 高炉与设定误差 [-0.1548] 模型误差 [-0.2795] 校正值 [0.2225]
# 2设定 -0.5363 预测 [-0.5016] 高炉 [-0.5264] 高炉与设定误差 [-0.0099] 模型误差 [0.0248] 校正值 [-0.0358]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1123] 高炉 [0.2115] 高炉与设定误差 [-0.1539] 模型误差 [-0.3238] 校正值 [0.2795]
# 2设定 -0.5363 预测 [-0.5114] 高炉 [-0.509] 高炉与设定误差 [-0.0273] 模型误差 [-0.0024] 校正值 [-0.0248]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1517] 高炉 [0.1233] 高炉与设定误差 [-0.0657] 模型误差 [-0.2749] 校正值 [0.3238]
# 2设定 -0.5363 预测 [-0.5236] 高炉 [-0.4751] 高炉与设定误差 [-0.0612] 模型误差 [-0.0485] 校正值 [0.0024]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1713] 高炉 [0.0656] 高炉与设定误差 [-0.008] 模型误差 [-0.2369] 校正值 [0.2749]
# 2设定 -0.5363 预测 [-0.555] 高炉 [-0.561] 高炉与设定误差 [0.0247] 模型误差 [0.006] 校正值 [0.0485]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1343] 高炉 [0.1104] 高炉与设定误差 [-0.0528] 模型误差 [-0.2447] 校正值 [0.2369]
# 2设定 -0.5363 预测 [-0.542] 高炉 [-0.563] 高炉与设定误差 [0.0266] 模型误差 [0.021] 校正值 [-0.006]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1013] 高炉 [0.1668] 高炉与设定误差 [-0.1093] 模型误差 [-0.2681] 校正值 [0.2447]
# 2设定 -0.5363 预测 [-0.5167] 高炉 [-0.5345] 高炉与设定误差 [-0.0018] 模型误差 [0.0177] 校正值 [-0.021]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1197] 高炉 [0.1851] 高炉与设定误差 [-0.1276] 模型误差 [-0.3048] 校正值 [0.2681]
# 2设定 -0.5363 预测 [-0.5184] 高炉 [-0.5241] 高炉与设定误差 [-0.0122] 模型误差 [0.0057] 校正值 [-0.0177]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1901] 高炉 [0.128] 高炉与设定误差 [-0.0705] 模型误差 [-0.3181] 校正值 [0.3048]
# 2设定 -0.5363 预测 [-0.5254] 高炉 [-0.476] 高炉与设定误差 [-0.0603] 模型误差 [-0.0494] 校正值 [-0.0057]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.2283] 高炉 [-0.0068] 高炉与设定误差 [0.0644] 模型误差 [-0.2215] 校正值 [0.3181]
# 2设定 -0.5363 预测 [-0.5797] 高炉 [-0.5767] 高炉与设定误差 [0.0404] 模型误差 [-0.003] 校正值 [0.0494]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1703] 高炉 [-0.0689] 高炉与设定误差 [0.1264] 模型误差 [-0.1014] 校正值 [0.2215]
# 2设定 -0.5363 预测 [-0.5821] 高炉 [-0.6095] 高炉与设定误差 [0.0732] 模型误差 [0.0274] 校正值 [0.003]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0789] 高炉 [0.0837] 高炉与设定误差 [-0.0261] 模型误差 [-0.1625] 校正值 [0.1014]
# 2设定 -0.5363 预测 [-0.5513] 高炉 [-0.5991] 高炉与设定误差 [0.0628] 模型误差 [0.0478] 校正值 [-0.0274]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0385] 高炉 [0.1955] 高炉与设定误差 [-0.138] 模型误差 [-0.234] 校正值 [0.1625]
# 2设定 -0.5363 预测 [-0.5096] 高炉 [-0.5598] 高炉与设定误差 [0.0235] 模型误差 [0.0501] 校正值 [-0.0478]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1609] 高炉 [0.1426] 高炉与设定误差 [-0.0851] 模型误差 [-0.3035] 校正值 [0.234]
# 2设定 -0.5363 预测 [-0.4878] 高炉 [-0.4249] 高炉与设定误差 [-0.1114] 模型误差 [-0.0629] 校正值 [-0.0501]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1553] 高炉 [-0.2333] 高炉与设定误差 [0.2909] 模型误差 [0.078] 校正值 [0.3035]
# 2设定 -0.4773 预测 [-0.5154] 高炉 [-0.5712] 高炉与设定误差 [0.0939] 模型误差 [0.0558] 校正值 [0.0629]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0514] 高炉 [-0.1202] 高炉与设定误差 [0.1778] 模型误差 [0.0689] 校正值 [-0.078]
# 2设定 -0.4773 预测 [-0.5837] 高炉 [-0.6612] 高炉与设定误差 [0.184] 模型误差 [0.0775] 校正值 [-0.0558]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [0.0361] 高炉 [0.0417] 高炉与设定误差 [0.0158] 模型误差 [-0.0057] 校正值 [-0.0689]
# 2设定 -0.4773 预测 [-0.4181] 高炉 [-0.476] 高炉与设定误差 [-0.0013] 模型误差 [0.0579] 校正值 [-0.0775]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [0.0488] 高炉 [0.2213] 高炉与设定误差 [-0.1637] 模型误差 [-0.1725] 校正值 [0.0057]
# 2设定 -0.4773 预测 [-0.4193] 高炉 [-0.4965] 高炉与设定误差 [0.0192] 模型误差 [0.0772] 校正值 [-0.0579]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0196] 高炉 [0.2713] 高炉与设定误差 [-0.2137] 模型误差 [-0.2909] 校正值 [0.1725]
# 2设定 -0.4773 预测 [-0.4005] 高炉 [-0.4323] 高炉与设定误差 [-0.045] 模型误差 [0.0318] 校正值 [-0.0772]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1182] 高炉 [0.2205] 高炉与设定误差 [-0.1629] 模型误差 [-0.3386] 校正值 [0.2909]
# 2设定 -0.4773 预测 [-0.4356] 高炉 [-0.4114] 高炉与设定误差 [-0.0658] 模型误差 [-0.0242] 校正值 [-0.0318]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1391] 高炉 [0.0509] 高炉与设定误差 [0.0066] 模型误差 [-0.19] 校正值 [0.3386]
# 2设定 -0.4773 预测 [-0.4854] 高炉 [-0.4488] 高炉与设定误差 [-0.0285] 模型误差 [-0.0366] 校正值 [0.0242]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1331] 高炉 [0.0536] 高炉与设定误差 [0.0039] 模型误差 [-0.1867] 校正值 [0.19]
# 2设定 -0.4773 预测 [-0.5272] 高炉 [-0.5941] 高炉与设定误差 [0.1168] 模型误差 [0.0669] 校正值 [0.0366]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0938] 高炉 [0.1762] 高炉与设定误差 [-0.1187] 模型误差 [-0.27] 校正值 [0.1867]
# 2设定 -0.4773 预测 [-0.4158] 高炉 [-0.4394] 高炉与设定误差 [-0.0379] 模型误差 [0.0236] 校正值 [-0.0669]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0747] 高炉 [0.1662] 高炉与设定误差 [-0.1087] 模型误差 [-0.241] 校正值 [0.27]
# 2设定 -0.4773 预测 [-0.408] 高炉 [-0.3878] 高炉与设定误差 [-0.0895] 模型误差 [-0.0202] 校正值 [-0.0236]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1151] 高炉 [-0.0043] 高炉与设定误差 [0.0618] 模型误差 [-0.1108] 校正值 [0.241]
# 2设定 -0.4773 预测 [-0.4885] 高炉 [-0.5518] 高炉与设定误差 [0.0745] 模型误差 [0.0633] 校正值 [0.0202]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0807] 高炉 [0.0841] 高炉与设定误差 [-0.0265] 模型误差 [-0.1648] 校正值 [0.1108]
# 2设定 -0.4773 预测 [-0.4692] 高炉 [-0.5559] 高炉与设定误差 [0.0787] 模型误差 [0.0868] 校正值 [-0.0633]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.033] 高炉 [0.2002] 高炉与设定误差 [-0.1427] 模型误差 [-0.2332] 校正值 [0.1648]
# 2设定 -0.4773 预测 [-0.4116] 高炉 [-0.4553] 高炉与设定误差 [-0.022] 模型误差 [0.0437] 校正值 [-0.0868]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.0684] 高炉 [0.2385] 高炉与设定误差 [-0.1809] 模型误差 [-0.3069] 校正值 [0.2332]
# 2设定 -0.4773 预测 [-0.4271] 高炉 [-0.4357] 高炉与设定误差 [-0.0415] 模型误差 [0.0086] 校正值 [-0.0437]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 0.0576 预测 [-0.1392] 高炉 [0.0393] 高炉与设定误差 [0.0183] 模型误差 [-0.1785] 校正值 [0.3069]
# 2设定 -0.4773 预测 [-0.4514] 高炉 [-0.3921] 高炉与设定误差 [-0.0852] 模型误差 [-0.0594] 校正值 [-0.0086]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [-0.0356] 高炉 [-0.0848] 高炉与设定误差 [0.2512] 模型误差 [0.0492] 校正值 [0.1785]
# 2设定 -0.4773 预测 [-0.5271] 高炉 [-0.6533] 高炉与设定误差 [0.1761] 模型误差 [0.1263] 校正值 [0.0594]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.1281] 高炉 [-0.0336] 高炉与设定误差 [0.1999] 模型误差 [0.1617] 校正值 [-0.0492]
# 2设定 -0.4773 预测 [-0.562] 高炉 [-0.5565] 高炉与设定误差 [0.0792] 模型误差 [-0.0055] 校正值 [-0.1263]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.1493] 高炉 [0.1059] 高炉与设定误差 [0.0605] 模型误差 [0.0434] 校正值 [-0.1617]
# 2设定 -0.4773 预测 [-0.49] 高炉 [-0.558] 高炉与设定误差 [0.0807] 模型误差 [0.068] 校正值 [0.0055]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.2037] 高炉 [0.1593] 高炉与设定误差 [0.0071] 模型误差 [0.0444] 校正值 [-0.0434]
# 2设定 -0.4773 预测 [-0.4173] 高炉 [-0.4412] 高炉与设定误差 [-0.0361] 模型误差 [0.0239] 校正值 [-0.068]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.2101] 高炉 [0.3096] 高炉与设定误差 [-0.1433] 模型误差 [-0.0995] 校正值 [-0.0444]
# 2设定 -0.4773 预测 [-0.4498] 高炉 [-0.5541] 高炉与设定误差 [0.0768] 模型误差 [0.1043] 校正值 [-0.0239]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.1614] 高炉 [0.3355] 高炉与设定误差 [-0.1692] 模型误差 [-0.1742] 校正值 [0.0995]
# 2设定 -0.4773 预测 [-0.4319] 高炉 [-0.4897] 高炉与设定误差 [0.0124] 模型误差 [0.0578] 校正值 [-0.1043]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.0806] 高炉 [0.4305] 高炉与设定误差 [-0.2641] 模型误差 [-0.3499] 校正值 [0.1742]
# 2设定 -0.4773 预测 [-0.4076] 高炉 [-0.4594] 高炉与设定误差 [-0.0179] 模型误差 [0.0518] 校正值 [-0.0578]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [-0.0685] 高炉 [0.2866] 高炉与设定误差 [-0.1202] 模型误差 [-0.3551] 校正值 [0.3499]
# 2设定 -0.4773 预测 [-0.4334] 高炉 [-0.4158] 高炉与设定误差 [-0.0615] 模型误差 [-0.0176] 校正值 [-0.0518]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [-0.0239] 高炉 [0.0133] 高炉与设定误差 [0.153] 模型误差 [-0.0372] 校正值 [0.3551]
# 2设定 -0.4773 预测 [-0.3571] 高炉 [-0.3515] 高炉与设定误差 [-0.1257] 模型误差 [-0.0056] 校正值 [0.0176]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.1664 预测 [0.0492] 高炉 [-0.0042] 高炉与设定误差 [0.1706] 模型误差 [0.0534] 校正值 [0.0372]
# 2设定 -0.4773 预测 [-0.4708] 高炉 [-0.6034] 高炉与设定误差 [0.1261] 模型误差 [0.1326] 校正值 [0.0056]

# %%
y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4).reshape(-1, 1)).flatten()
a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')
# Out:
# 上线分别是：[0.4344341  0.35020406]、[33.16828629 27.14167883]、[1263.5221402   841.53712915]、[53.10015501  6.3258078 ]

# %%
set_y1
# Out:
# array([1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500,
#        1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500,
#        1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1505, 1505, 1505,
#        1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505,
#        1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505, 1505,
#        1505, 1505, 1505, 1505, 1505, 1510, 1510, 1510, 1510, 1510, 1510,
#        1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510,
#        1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510, 1510,
#        1510, 1510, 1515, 1515, 1515, 1515, 1515, 1515, 1515, 1515, 1515,
#        1515])

# %%
rmse_1 = np.mean(np.fabs(set_y1-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))
# Out:
# 平均误差 4.9784
# 平均误差 0.031

# %%
# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(14, 10))
# 第一个维度的曲线
plt.subplot(6, 2, 1)
plt.plot(set_y1_trans, 'ro-', label='set_y1')
plt.plot(all_pred_y1, 'bo-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 2, 3)
plt.plot(set_y2_trans, 'ro-', label='set_y2')
plt.plot(all_pred_y2, 'bo-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 2, 5)
plt.plot(all_pred_u1, 'bo-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 2, 7)
plt.plot(all_pred_u2, 'bo-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 2, 9)
plt.plot(all_pred_u3, 'bo-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 2, 11)
plt.plot(all_pred_u4, 'bo-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')



######################################################

# 第一个维度的曲线
plt.subplot(6, 2, 2)
plt.plot(set_y1, 'ro-', label='set')
plt.plot(y1_pred_inverse_transform, 'bo-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 2, 4)
plt.plot(set_y2, 'ro-', label='set')
plt.plot(y2_pred_inverse_transform, 'bo-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 2, 6)
plt.plot(all_pred_u1, 'bo-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 2, 8)
plt.plot(all_pred_u2, 'bo-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 2, 10)
plt.plot(all_pred_u3, 'bo-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 2, 12)
plt.plot(all_pred_u4, 'bo-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')






# 调整子图布局
plt.tight_layout()
plt.show()
