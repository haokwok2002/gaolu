# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径

# %%
# 读取Excel文件
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\噪声变量\\随机噪声-专用数据1.xlsx'
df_sheet = pd.read_excel(excel_path, sheet_name='建模-分量-全部') 
print(df_sheet.info())
print(df_sheet.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7569 entries, 0 to 7568
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   时间戳         7398 non-null   float64
#  1   铁口1温度       7398 non-null   float64
#  2   SI          7398 non-null   float64
#  3   热风压力        7398 non-null   float64
#  4   设定喷煤量       7398 non-null   float64
#  5   热风温度        7398 non-null   float64
#  6   鼓风湿度        7398 non-null   float64
#  7   冷风流量        7398 non-null   float64
#  8   富氧流量        7398 non-null   float64
#  9   Unnamed: 9  0 non-null      float64
#  10  冷风压力        7569 non-null   float64
# dtypes: float64(11)
# memory usage: 650.6 KB
# None
# Index(['时间戳', '铁口1温度', 'SI', '热风压力', '设定喷煤量', '热风温度', '鼓风湿度', '冷风流量', '富氧流量',
#        'Unnamed: 9', '冷风压力'],
#       dtype='object')

# %%
# 定义输入输出参数
input_term = ['冷风压力', '冷风流量', '热风温度', '设定喷煤量']
output_term = ['铁口1温度', 'SI']
time_term= '时间戳'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_process = df_sheet.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 2.25 * y.std()  # 使用标准差作为阈值
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value




# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[input_term[3]])
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[output_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process[time_term], df_sheet_process[output_term[1]])

plt.figure(figsize=(15, 10))
for idx, column in enumerate(input_term+output_term):
    
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet[column].values,df_sheet_process[column].values,column)

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r*-', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 800
start1 = 0
length2 = 800
start2 = 4800


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 10))
for idx, column in enumerate(input_term+output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_process[input_term[0]].values,
    input_term[1]:   df_sheet_process[input_term[1]].values,
    input_term[2]:   df_sheet_process[input_term[2]].values,
    input_term[3]:   df_sheet_process[input_term[3]].values,
    output_term[0]:  df_sheet_process[output_term[0]].values,
    output_term[1]:  df_sheet_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
print('每摄氏度的输出差：',(data3-data1)/(data4-data2))



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [-0.06013143]
# [1500.]
# [0.0799695]
# [1510.]
# 每摄氏度的输出差： [0.01401009]
# [-0.50732222]
# [0.5]
# [-0.39408513]
# [0.6]
# 每0.01浓度的输出差： [0.11323709]

# %%
isShuffle = True
# isShuffle = False

# %%
# 组合训练数据--拆分训练、测试集
train_size = 0.7
val_size = 0.15
test_size = 0.15
def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data):
    u1_data = u1_data
    u2_data = u2_data
    u3_data = u3_data
    u4_data = u4_data

    u1_data_1 = np.roll(u1_data, 1)
    u2_data_1 = np.roll(u2_data, 1)
    u3_data_1 = np.roll(u3_data, 1)
    u4_data_1 = np.roll(u4_data, 1)

    y1_data = y1_data
    y2_data = y2_data

    X = np.column_stack((   u1_data  [1:-1], u2_data  [1:-1], u3_data  [1:-1], u4_data  [1:-1],
                            u1_data_1[1:-1], u2_data_1[1:-1], u3_data_1[1:-1], u4_data_1[1:-1],
                            y1_data  [1:-1], y2_data  [1:-1])
                        )
    y = np.column_stack((y1_data[2:],y2_data[2:]))

    # 使用 reshape 转换形状(457, 10) (457, 2)--->(457, 1, 10) (457, 1, 2)
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))
    y_reshaped = y.reshape((y.shape[0], 1, y.shape[1]))
    print('总数据数量：',y.shape)




    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_reshaped, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)




    y_train = y_train.reshape((y_train.shape[0],y_train.shape[2]))
    y_val = y_val.reshape((y_val.shape[0],y_val.shape[2]))
    y_test = y_test.reshape((y_test.shape[0],y_test.shape[2]))
    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]][index_gaolu]
u2_data = normalized_data_dict[input_term[1]][index_gaolu]
u3_data = normalized_data_dict[input_term[2]][index_gaolu]
u4_data = normalized_data_dict[input_term[3]][index_gaolu]
y1_data = normalized_data_dict[output_term[0]][index_gaolu]
y2_data = normalized_data_dict[output_term[1]][index_gaolu]
num_samples = y1_data.shape[0]
print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,y1_data, y2_data)

# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]][index_predict]
u2_data = normalized_data_dict[input_term[1]][index_predict]
u3_data = normalized_data_dict[input_term[2]][index_predict]
u4_data = normalized_data_dict[input_term[3]][index_predict]
y1_data = normalized_data_dict[output_term[0]][index_predict]
y2_data = normalized_data_dict[output_term[1]][index_predict]
num_samples = y1_data.shape[0]
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,y1_data, y2_data)
# Out:
# 高炉模型数据
# 总数据数量： (799, 2)
# 训练数量： (559, 1, 10) (559, 2)
# 验证数量： (120, 1, 10) (120, 2)
# 测试数量： (120, 1, 10) (120, 2)
# 预测模型数据
# 总数据数量： (799, 2)
# 训练数量： (559, 1, 10) (559, 2)
# 验证数量： (120, 1, 10) (120, 2)
# 测试数量： (120, 1, 10) (120, 2)

# %%
# 定义LSTM模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyRNNModel(torch.nn.Module):
    def __init__(self,features_size,hidden_size,isbidirectional):
        super(MyRNNModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size=features_size,
            hidden_size=hidden_size,
            batch_first=True,
            bidirectional=isbidirectional
        )
        if isbidirectional:
            self.fc = nn.Linear(2 * hidden_size, 2)
        else:
            self.fc = nn.Linear(hidden_size, 2)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        
        last_lstm_output = lstm_out[:, -1, :]
        # print(last_lstm_output)
        output = self.fc(last_lstm_output)
        
        return output

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse



    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_train) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
epoch_once_time = 25

# %%
# 建立高炉模型实例
features_size = 10
hidden_size = 16
# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyRNNModel(features_size = features_size, 
                        hidden_size = hidden_size,
                        isbidirectional=True)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 2/25 轮, 训练误差: 0.2526, 验证误差: 0.0317
# 第 25/25 轮, 训练误差: 0.0348, 验证误差: 0.0092
# epoch_sum: 25

# %%
# 高炉模型预测
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_gaolu_test)
# 计算 RMSE、MRE
y_test = y_gaolu_test
# y_test = y_test[:70]
# y_pred_0 = y_pred_0[:70]
# y_pred_1 = y_pred_1[:70]




y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

# 计算 
mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))


mape_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0)) * 100
mape_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1)) * 100

# 打印结果

print(f"RMSE:  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
print(f"MAPE:  {output_term[0]}: {mape_0:.4f}% , {output_term[1]}: {mape_1:.4f}%")
print(f"MRE :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)


output0 = y_test_0 - y_pred_0_inverse_transform
output1 = y_test_1 - y_pred_1_inverse_transform

# print(f"误差分析0:平均值:{output0.std():.4f},方差:{output0.mean():.4f}")
# print(f"误差分析1:平均值:{output1.std():.4f},方差:{output1.mean():.4f}")


plt.subplot(4, 1, 1)
plt.plot(y_test_0,'r')
plt.plot(y_pred_0_inverse_transform,'g')
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 2)
plt.plot(y_test_1,'r')
plt.plot(y_pred_1_inverse_transform,'g')
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
#

plt.subplot(4, 1, 3)
plt.plot(output0,'r-')
plt.ylabel(output_term[0]+'_err', fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 4)
plt.plot(output1,'g-')
plt.ylabel(output_term[1]+'_err', fontproperties=font)  # 使用中文标签


plt.tight_layout()
plt.show()
# Out:
# RMSE:  铁口1温度: 10.7255 , SI: 0.0942
# MAPE:  铁口1温度: 0.4725% , SI: 22.7960%
# MRE :  铁口1温度: 0.0047  , SI: 0.2280

# %%
# 创建预测模型实例
features_size = 10
hidden_size_predict = 16
# 设置随机种子
torch.manual_seed(0)
model = MyRNNModel(features_size = features_size, 
                    hidden_size = hidden_size_predict,
                    isbidirectional=True)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 25/25 轮, 训练误差: 0.0471, 验证误差: 0.0112
# epoch_sum: 0

# %%
# 预测模型预测
y_pred_0,y_pred_1  = model.my_predict(X_predict_test)

# 计算 RMSE、MRE
y_test = y_predict_test







y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

# 计算 
mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))


mape_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0)) * 100
mape_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1)) * 100

# 打印结果

print(f"RMSE:  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
print(f"MAPE:  {output_term[0]}: {mape_0:.4f}% , {output_term[1]}: {mape_1:.4f}%")
print(f"MRE :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")

# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)


output0 = y_test_0 - y_pred_0_inverse_transform
output1 = y_test_1 - y_pred_1_inverse_transform

# print(f"误差分析0:平均值:{output0.std():.4f},方差:{output0.mean():.4f}")
# print(f"误差分析1:平均值:{output1.std():.4f},方差:{output1.mean():.4f}")


plt.subplot(4, 1, 1)
plt.plot(y_test_0,'r')
plt.plot(y_pred_0_inverse_transform,'g')
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 2)
plt.plot(y_test_1,'r')
plt.plot(y_pred_1_inverse_transform,'g')
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
#

plt.subplot(4, 1, 3)
plt.plot(output0,'r-')
plt.ylabel(output_term[0]+'_err', fontproperties=font)  # 使用中文标签


plt.subplot(4, 1, 4)
plt.plot(output1,'g-')
plt.ylabel(output_term[1]+'_err', fontproperties=font)  # 使用中文标签


plt.tight_layout()
plt.show()
# Out:
# RMSE:  铁口1温度: 13.5467 , SI: 0.1282
# MAPE:  铁口1温度: 0.6021% , SI: 19.0745%
# MRE :  铁口1温度: 0.0060  , SI: 0.1907

# %%
y_test = y_predict_test
y_test_0 = scalers[output_term[0]].inverse_transform(y_predict_test[:,0].reshape(-1, 1)).flatten()
y_test_1 = scalers[output_term[1]].inverse_transform(y_predict_test[:,1].reshape(-1, 1)).flatten()
y_pred_0,y_pred_1  = model.my_predict(X_predict_test)
y_pred_0_predict = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_predict = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

y_pred_0,y_pred_1  = model_gaolu.my_predict(X_predict_test)
y_pred_0_gaolu = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
y_pred_1_gaolu = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

plt.subplot(2, 1, 1)
plt.plot(y_test_0, 'r-', label='Actual')
plt.plot(y_pred_0_predict, 'g-', label='Predict')
plt.plot(y_pred_0_gaolu, 'b', label='Gaolu')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(y_test_1, 'r-', label='Actual')
plt.plot(y_pred_1_predict, 'g-', label='Predict')
plt.plot(y_pred_1_gaolu, 'b', label='Gaolu')
plt.legend()

# %%
# # 保存模型参数到文件
# torch.save(model.state_dict(), 'model_predict_params.pth')

# %%
# 自定义预测
model_predict = model
hidden_size = hidden_size_predict
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def lstm_forward(input, initial_states, w_ih, w_hh, b_ih, b_hh):
    h_0, c_0 = initial_states  # 初始状态  [b_size, hidden_size]
    b_size, seq_len, input_size = input.shape
    h_size = h_0.shape[-1]

    h_prev, c_prev = h_0, c_0

    # 使用 np.newaxis 在第一个维度上插入一个新的维度  # 使用 np.tile 在第一个维度上复制 b_size 次
    w_ih_expanded = w_ih[np.newaxis, :, :]    
    w_ih_batch = np.tile(w_ih_expanded, (b_size, 1, 1))
    w_hh_expanded = w_hh[np.newaxis, :, :]    
    w_hh_batch = np.tile(w_hh_expanded, (b_size, 1, 1))
    # print(w_ih_batch.shape)

    output_size = h_size
    output = np.zeros((b_size, seq_len, output_size))  # 初始化一个输出序列
    for t in range(seq_len):
        x = input[:, t, :]  # 当前时刻的输入向量 [b,in_size]->[b,in_size,1]
        w_times_x = np.matmul(w_ih_batch, x[:, :, np.newaxis]).squeeze(-1)   # bmm:含有批量大小的矩阵相乘
        # [b, 4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Wii*xt|Wif*xt|Wig*xt|Wio*xt
        w_times_h_prev = np.matmul(w_hh_batch, h_prev[:, :, np.newaxis]).squeeze(-1)
        # [b, 4*hidden_size, hidden_size]*[b, hidden_size, 1]->[b,4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Whi*ht-1|Whf*ht-1|Whg*ht-1|Who*ht-1

        # 分别计算输入门(i)、遗忘门(f)、cell门(g)、输出门(o)  维度均为 [b, h_size]
        i_t = sigmoid(w_times_x[:, :h_size] + w_times_h_prev[:, :h_size] + b_ih[:h_size] + b_hh[:h_size])  # 取前四分之一
        f_t = sigmoid(w_times_x[:, h_size:2*h_size] + w_times_h_prev[:, h_size:2*h_size]
                            + b_ih[h_size:2*h_size] + b_hh[h_size:2*h_size])
        g_t = np.tanh(w_times_x[:, 2*h_size:3*h_size] + w_times_h_prev[:, 2*h_size:3*h_size]
                            + b_ih[2*h_size:3*h_size] + b_hh[2*h_size:3*h_size])
        o_t = sigmoid(w_times_x[:, 3*h_size:] + w_times_h_prev[:, 3*h_size:]
                            + b_ih[3*h_size:] + b_hh[3*h_size:])
        c_prev = f_t * c_prev + i_t * g_t
        h_prev = o_t * np.tanh(c_prev)

        output[:, t, :] = h_prev

    return output, (np.expand_dims(h_prev, axis=0), np.expand_dims(c_prev, axis=0))  # 官方是三维，在第0维扩一维



def predict_my(data_input):

    input = data_input  # 随机初始化一个输入序列
    c_0 = np.zeros((data_input.shape[0], hidden_size))  # 初始值，不会参与训练
    h_0 = np.zeros((data_input.shape[0], hidden_size))

    output_forward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0.detach().numpy())

    last_lstm_output_forward = output_forward[:, -1, :]

    output_backward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0_reverse.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0_reverse.detach().numpy())

    last_lstm_output_backward = output_backward[:, -1, :]
    # print(last_lstm_output_forward.shape)
    # print(last_lstm_output_backward.shape)
    # 最终输出
    combined_hidden = np.concatenate((last_lstm_output_forward, last_lstm_output_backward), axis=1)
    # print(combined_hidden.shape)


    output = (np.dot(combined_hidden, np.transpose(model_predict.fc.weight.detach().numpy()))
                + model_predict.fc.bias.detach().numpy()
)
    y_pred_0, y_pred_1= output[:,0],output[:,1]

    # y_pred_0 = scalers[output_term[0]].inverse_transform(np.array(y_pred_0).reshape(-1, 1)).flatten()
    # y_pred_1 = scalers[output_term[1]].inverse_transform(np.array(y_pred_1).reshape(-1, 1)).flatten()




    return y_pred_0, y_pred_1


y_pred_0, y_pred_1= predict_my(X_predict_test)


# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)
# plot_hit_rate_curve(y_test, y_pred_0.detach().numpy(), y_pred_1.detach().numpy())

# %%
# 生成期望数据
Times = 100

def generate_y_aim_data(Times):

    set_y1 = np.full(Times,1501)
    set_y1[30:] = 1505
    set_y1[60:] = 1510
    set_y1[90:] = 1515
    # set_y1[70:] = 1520
    # set_y1[90:] = 1525

    set_y2 = np.full(Times,0.40)
    set_y2[15:] = 0.44
    set_y2[45:] = 0.48
    set_y2[75:] = 0.52
    # 限制设定值在 -1 到 1 之间
    # set_y1 = np.clip(set_y1, -1, 1)
    # set_y2 = np.clip(set_y2, -1, 1)


    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# # 调用示例
# set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
# plt.plot(set_y1_trans)
# plt.plot(set_y2_trans)
# plt.title('y_sp')
# plt.show()

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+2  ]
    u2   = u2_data[randint  :randint+2  ]
    u3   = u3_data[randint  :randint+2  ]
    u4   = u4_data[randint  :randint+2  ]
    u1_1 = u1_data[randint-1:randint+2-1]
    u2_1 = u2_data[randint-1:randint+2-1]    
    u3_1 = u3_data[randint-1:randint+2-1]
    u4_1 = u4_data[randint-1:randint+2-1]

    y1   = y1_data[randint  :randint+2  ]
    y2   = y2_data[randint  :randint+2  ]
    k_data = np.concatenate((u1, u2, u3, u4, u1_1, u2_1, u3_1, u4_1, y1, y2), axis=0)
    # print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):
    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0
    # lamda1 = 0.001
    # y1_percent = 8.528
    # y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:2]
    u2   = k_data[2:4]
    u3   = k_data[4:6]
    u4   = k_data[6:8]
    u1_1 = k_data[8:10]
    u2_1 = k_data[10:12]
    u3_1 = k_data[12:14]
    u4_1 = k_data[14:16]

    y1   = k_data[16:18]
    y2   = k_data[18:20]
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]

    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1[:1],U1))
    u2   = np.concatenate((u2[:1],U2))
    u3   = np.concatenate((u3[:1],U3))
    u4   = np.concatenate((u4[:1],U4))

    u1_1 = np.concatenate((u1_1[:2],U1[:-1]))
    u2_1 = np.concatenate((u2_1[:2],U2[:-1]))
    u3_1 = np.concatenate((u3_1[:2],U3[:-1]))
    u4_1 = np.concatenate((u4_1[:2],U4[:-1]))

    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    y1_k = y1[1]
    y2_k = y2[1]
    # print(u1)
    # print(u2)
    # print(u1_1)
    # print(u2_1)
    # print(y1)
    # print(y2)
    # print(y1_k)    
    # print(y2_k)

    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k,y2_m_k = predict_my(x)
        # y1[j+1] = y1_m_k.item()###############################是否替换不知道有没有影响？
        # y2[j+1] = y2_m_k.item()###############################
        # 在k时刻，我要先通过k-1时刻来预测出当前k时刻下的预测值。
        # 实际上，这个时候我有k时刻的真实值。
        # 但是这么做是为了能够获取我的预测值和真实值之间的误差，
        # 然后基于这个误差，通过对控制器输入的调整来预测k+1时刻，
        # 然后依次往下。因此，在k时刻，我系统的值是固定的，
        # 也就是我的真实值，所以我要把它存储到我的整体的一个序列里面。
        # 在取出当前k时刻真实值的过程中，我不能将之前预测的时候的那个
        # 预测值覆盖掉真实值。后面新预测的数值要加上前面的那一个误差
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k

    # 对每个U对应的控制时刻进行预测-----M次
    for j in range(1,M+1):  
        x = np.column_stack((u1[j],u2[j],u3[j],u4[j],u1_1[j],u2_1[j],u3_1[j],u4_1[j],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):
        x = np.column_stack((u1[-1],u2[-1],u3[-1],u4[-1],u1[-1],u2[-1],u3[-1],u4[-1],y1[j],y2[j]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j,y2_k_j = predict_my(x)
        y1[j+1] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+1] = y2_k_j.item()

    k_data2 = np.concatenate((u1[1:3],u2[1:3],u3[1:3],u4[1:3],u1_1[1:3],u2_1[1:3],u3_1[1:3],u4_1[1:3],y1[1:3],y2[1:3]),axis=0)


    
    # y1_aim = scalers[output_term[0]].inverse_transform(np.array(y1_aim).reshape(-1, 1)).flatten()
    # y1 = scalers[output_term[0]].inverse_transform(np.array(y1).reshape(-1, 1)).flatten()
    # y1_k = scalers[output_term[0]].inverse_transform(np.array(y1_k).reshape(-1, 1)).flatten()
    # y2_aim = scalers[output_term[1]].inverse_transform(np.array(y2_aim).reshape(-1, 1)).flatten()
    # y2 = scalers[output_term[1]].inverse_transform(np.array(y2).reshape(-1, 1)).flatten()
    # y2_k = scalers[output_term[1]].inverse_transform(np.array(y2_k).reshape(-1, 1)).flatten()
    # E1_k = scalers[output_term[0]].inverse_transform(np.array(E1_k).reshape(-1, 1)).flatten()
    # E2_k = scalers[output_term[1]].inverse_transform(np.array(E2_k).reshape(-1, 1)).flatten()
    # u1 = scalers[input_term[0]].inverse_transform(np.array(u1).reshape(-1, 1)).flatten()
    # u2 = scalers[input_term[1]].inverse_transform(np.array(u2).reshape(-1, 1)).flatten()
    # u3 = scalers[input_term[2]].inverse_transform(np.array(u3).reshape(-1, 1)).flatten()
    # u4 = scalers[input_term[3]].inverse_transform(np.array(u4).reshape(-1, 1)).flatten()


    #和获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[2:]
    y2_M_k = y2[2:]
    if isprint==1:

        print('y1_k',y1_k)  
        print('y1_m_k',y1_m_k)    
        print('y2_k',y2_k)  
        print('y2_m_k',y2_m_k)    

        print('temp:')
        print('y1_aim',y1_aim)
        print('y1_r_aim',y1_r_aim)
        print('  ')
        print('y1_r',y1_r)
        print('y1_M_k+h1*E1_k',y1_M_k+h1*E1_k)
        print('  ')
        print('y1',y1)
        print('h*E1_k',h1*E1_k)

        print('Si_percent:')
        print('y2_aim',y2_aim)
        print('y2_r_aim',y2_r_aim)
        print('y2_r',y2_r)
        print('y2_M_k+h2*E2_k',y2_M_k+h2*E2_k)

        print('y2',y2)
        print('h*E2_k',h2*E2_k)

        print('u:')
        print(u1)
        print(u2)
        print(u3)
        print(u4)
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙
    
    # if np.abs(y1_aim-y1_k)<0.0001 and np.abs(y2_aim-y2_k)<0.0001:
    #     lamda1 = 1

    y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    u1_power = lamda1*np.sum(((np.diff(u1)**2)))
    u2_power = lamda2*np.sum(((np.diff(u2)**2)))
    u3_power = lamda3*np.sum(((np.diff(u3)**2)))
    u4_power = lamda4*np.sum(((np.diff(u3)**2)))

    mse = (0
            # +loss_function(y1_r, y1_M_k+h*E1_k, weights)
            # +loss_function(y2_r, y2_M_k+h*E2_k, weights)
            # +(np.abs(y1_aim-y1_k)**2+np.abs(y2_aim-y2_k)**2)*P*2000
            # +np.sum((y1_r-y1_M_k-h*E1_k)**2 + (y2_r-y2_M_k-h*E2_k)**2)
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power

            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1, E2_k*h2

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 4  # 预测时域长度  增大P能平稳些
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, 
                        y1_data, y2_data, num_samples, P)

# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
# MPC控制循环
for k in range(Times):
    print(f"这是对第{k}时刻的最优U1、U2输入求解")
    # print('y1_aim  y2_aim',set_y1[k],set_y2[k])
    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    # 定义参数的上下限  
    bounds = [(-max_control, max_control) for _ in range(4 * M)]
    # 设置退出条件
    exit_conditions = {'maxiter': 1000}  # 您可以根据需要调整容差

    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    optimized_U1, optimized_U2, optimized_U3, optimized_U4 = result.x[0:M], result.x[M:2*M], result.x[2*M:3*M], result.x[3*M:4*M]


    # 获取当前时刻下，在最优的U1、U2下的响应    
    u1_k = optimized_U1[0]
    u2_k = optimized_U2[0]
    u3_k = optimized_U3[0]
    u4_k = optimized_U4[0]
    u1_k_1 = k_data[9]
    u2_k_1 = k_data[11]
    u3_k_1 = k_data[13]
    u4_k_1 = k_data[15]
    y1_k = k_data[17] 
    y2_k = k_data[19] 
    

    
    x = np.column_stack((u1_k,u2_k,u3_k,u4_k,u1_k_1,u2_k_1,u3_k_1,u4_k_1,y1_k,y2_k))
    x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model.my_predict(x)
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    


    # 获取当前时刻下，在最优的U1、U2下的响应
    params = np.concatenate((optimized_U1,optimized_U2,optimized_U3,optimized_U4),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 
    
    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(u1_k)
    all_pred_u2.append(u2_k)
    all_pred_u3.append(u3_k)
    all_pred_u4.append(u4_k)
    k_data2[17] = y1_pred
    k_data2[19] = y2_pred
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 423
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0626] 高炉 [0.1167] 高炉与设定误差 [-0.1628] 模型误差 [-0.1793] 校正值 [0.0438]
# 2设定 -0.6206 预测 [-0.3595] 高炉 [-0.2863] 高炉与设定误差 [-0.3343] 模型误差 [-0.0732] 校正值 [0.1514]
# 这是对第1时刻的最优U1、U2输入求解
# C:\Users\haokw\AppData\Local\Temp\ipykernel_12424\3731276461.py:96: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[17] = y1_pred
# C:\Users\haokw\AppData\Local\Temp\ipykernel_12424\3731276461.py:97: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   k_data2[19] = y2_pred
# 1设定 -0.0461 预测 [-0.1416] 高炉 [0.0415] 高炉与设定误差 [-0.0877] 模型误差 [-0.1831] 校正值 [0.1793]
# 2设定 -0.6206 预测 [-0.506] 高炉 [-0.4631] 高炉与设定误差 [-0.1575] 模型误差 [-0.043] 校正值 [0.0732]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1687] 高炉 [-0.0273] 高炉与设定误差 [-0.0189] 模型误差 [-0.1415] 校正值 [0.1831]
# 2设定 -0.6206 预测 [-0.5735] 高炉 [-0.5426] 高炉与设定误差 [-0.078] 模型误差 [-0.031] 校正值 [0.043]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1806] 高炉 [-0.0851] 高炉与设定误差 [0.039] 模型误差 [-0.0955] 校正值 [0.1415]
# 2设定 -0.6206 预测 [-0.6203] 高炉 [-0.5997] 高炉与设定误差 [-0.0209] 模型误差 [-0.0206] 校正值 [0.031]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1455] 高炉 [-0.0941] 高炉与设定误差 [0.0479] 模型误差 [-0.0515] 校正值 [0.0955]
# 2设定 -0.6206 预测 [-0.6386] 高炉 [-0.6372] 高炉与设定误差 [0.0166] 模型误差 [-0.0014] 校正值 [0.0206]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1024] 高炉 [-0.0643] 高炉与设定误差 [0.0182] 模型误差 [-0.0381] 校正值 [0.0515]
# 2设定 -0.6206 预测 [-0.6313] 高炉 [-0.6409] 高炉与设定误差 [0.0204] 模型误差 [0.0096] 校正值 [0.0014]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.086] 高炉 [-0.0164] 高炉与设定误差 [-0.0297] 模型误差 [-0.0696] 校正值 [0.0381]
# 2设定 -0.6206 预测 [-0.613] 高炉 [-0.6116] 高炉与设定误差 [-0.009] 模型误差 [-0.0014] 校正值 [-0.0096]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1127] 高炉 [-0.0285] 高炉与设定误差 [-0.0177] 模型误差 [-0.0843] 校正值 [0.0696]
# 2设定 -0.6206 预测 [-0.6273] 高炉 [-0.6168] 高炉与设定误差 [-0.0038] 模型误差 [-0.0105] 校正值 [0.0014]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1286] 高炉 [-0.0757] 高炉与设定误差 [0.0295] 模型误差 [-0.0529] 校正值 [0.0843]
# 2设定 -0.6206 预测 [-0.633] 高炉 [-0.6277] 高炉与设定误差 [0.0071] 模型误差 [-0.0053] 校正值 [0.0105]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.102] 高炉 [-0.0603] 高炉与设定误差 [0.0142] 模型误差 [-0.0417] 校正值 [0.0529]
# 2设定 -0.6206 预测 [-0.6265] 高炉 [-0.6298] 高炉与设定误差 [0.0092] 模型误差 [0.0033] 校正值 [0.0053]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0893] 高炉 [-0.0317] 高炉与设定误差 [-0.0144] 模型误差 [-0.0575] 校正值 [0.0417]
# 2设定 -0.6206 预测 [-0.6227] 高炉 [-0.6256] 高炉与设定误差 [0.0051] 模型误差 [0.0029] 校正值 [-0.0033]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1022] 高炉 [-0.0256] 高炉与设定误差 [-0.0205] 模型误差 [-0.0766] 校正值 [0.0575]
# 2设定 -0.6206 预测 [-0.6209] 高炉 [-0.6147] 高炉与设定误差 [-0.0059] 模型误差 [-0.0062] 校正值 [-0.0029]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1207] 高炉 [-0.0586] 高炉与设定误差 [0.0125] 模型误差 [-0.0621] 校正值 [0.0766]
# 2设定 -0.6206 预测 [-0.6268] 高炉 [-0.6206] 高炉与设定误差 [-0.] 模型误差 [-0.0063] 校正值 [0.0062]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1095] 高炉 [-0.0684] 高炉与设定误差 [0.0223] 模型误差 [-0.041] 校正值 [0.0621]
# 2设定 -0.6206 预测 [-0.6271] 高炉 [-0.6286] 高炉与设定误差 [0.008] 模型误差 [0.0015] 校正值 [0.0063]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0894] 高炉 [-0.0407] 高炉与设定误差 [-0.0054] 模型误差 [-0.0487] 校正值 [0.041]
# 2设定 -0.6206 预测 [-0.621] 高炉 [-0.6246] 高炉与设定误差 [0.0041] 模型误差 [0.0036] 校正值 [-0.0015]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0943] 高炉 [-0.0342] 高炉与设定误差 [-0.0119] 模型误差 [-0.0601] 校正值 [0.0487]
# 2设定 -0.5753 预测 [-0.5873] 高炉 [-0.5894] 高炉与设定误差 [0.0141] 模型误差 [0.0021] 校正值 [-0.0036]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.105] 高炉 [-0.0272] 高炉与设定误差 [-0.0189] 模型误差 [-0.0778] 校正值 [0.0601]
# 2设定 -0.5753 预测 [-0.5746] 高炉 [-0.5627] 高炉与设定误差 [-0.0126] 模型误差 [-0.0119] 校正值 [-0.0021]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.122] 高炉 [-0.051] 高炉与设定误差 [0.0049] 模型误差 [-0.071] 校正值 [0.0778]
# 2设定 -0.5753 预测 [-0.5859] 高炉 [-0.5746] 高炉与设定误差 [-0.0007] 模型误差 [-0.0113] 校正值 [0.0119]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1176] 高炉 [-0.0674] 高炉与设定误差 [0.0213] 模型误差 [-0.0502] 校正值 [0.071]
# 2设定 -0.5753 预测 [-0.587] 高炉 [-0.5832] 高炉与设定误差 [0.0079] 模型误差 [-0.0038] 校正值 [0.0113]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0983] 高炉 [-0.0496] 高炉与设定误差 [0.0035] 模型误差 [-0.0487] 校正值 [0.0502]
# 2设定 -0.5753 预测 [-0.5799] 高炉 [-0.5788] 高炉与设定误差 [0.0036] 模型误差 [-0.001] 校正值 [0.0038]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0952] 高炉 [-0.0298] 高炉与设定误差 [-0.0163] 模型误差 [-0.0654] 校正值 [0.0487]
# 2设定 -0.5753 预测 [-0.5777] 高炉 [-0.5729] 高炉与设定误差 [-0.0024] 模型误差 [-0.0048] 校正值 [0.001]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.11] 高炉 [-0.0419] 高炉与设定误差 [-0.0042] 模型误差 [-0.0681] 校正值 [0.0654]
# 2设定 -0.5753 预测 [-0.5812] 高炉 [-0.5727] 高炉与设定误差 [-0.0025] 模型误差 [-0.0085] 校正值 [0.0048]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1138] 高炉 [-0.0561] 高炉与设定误差 [0.01] 模型误差 [-0.0577] 校正值 [0.0681]
# 2设定 -0.5753 预测 [-0.584] 高炉 [-0.5774] 高炉与设定误差 [0.0021] 模型误差 [-0.0066] 校正值 [0.0085]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1048] 高炉 [-0.0528] 高炉与设定误差 [0.0067] 模型误差 [-0.052] 校正值 [0.0577]
# 2设定 -0.5753 预测 [-0.5823] 高炉 [-0.579] 高炉与设定误差 [0.0038] 模型误差 [-0.0032] 校正值 [0.0066]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.0988] 高炉 [-0.039] 高炉与设定误差 [-0.0071] 模型误差 [-0.0598] 校正值 [0.052]
# 2设定 -0.5753 预测 [-0.5791] 高炉 [-0.5752] 高炉与设定误差 [-1.e-04] 模型误差 [-0.0039] 校正值 [0.0032]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1052] 高炉 [-0.0417] 高炉与设定误差 [-0.0044] 模型误差 [-0.0635] 校正值 [0.0598]
# 2设定 -0.5753 预测 [-0.581] 高炉 [-0.5749] 高炉与设定误差 [-0.0004] 模型误差 [-0.0061] 校正值 [0.0039]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1091] 高炉 [-0.051] 高炉与设定误差 [0.0049] 模型误差 [-0.0581] 校正值 [0.0635]
# 2设定 -0.5753 预测 [-0.5814] 高炉 [-0.5754] 高炉与设定误差 [0.0002] 模型误差 [-0.006] 校正值 [0.0061]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1047] 高炉 [-0.0492] 高炉与设定误差 [0.003] 模型误差 [-0.0555] 校正值 [0.0581]
# 2设定 -0.5753 预测 [-0.582] 高炉 [-0.5769] 高炉与设定误差 [0.0017] 模型误差 [-0.005] 校正值 [0.006]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1019] 高炉 [-0.0409] 高炉与设定误差 [-0.0052] 模型误差 [-0.061] 校正值 [0.0555]
# 2设定 -0.5753 预测 [-0.5817] 高炉 [-0.5769] 高炉与设定误差 [0.0016] 模型误差 [-0.0048] 校正值 [0.005]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 -0.0461 预测 [-0.1041] 高炉 [-0.0412] 高炉与设定误差 [-0.0049] 模型误差 [-0.0629] 校正值 [0.061]
# 2设定 -0.5753 预测 [-0.5835] 高炉 [-0.5781] 高炉与设定误差 [0.0028] 模型误差 [-0.0054] 校正值 [0.0048]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0581] 高炉 [-0.0086] 高炉与设定误差 [0.0185] 模型误差 [-0.0495] 校正值 [0.0629]
# 2设定 -0.5753 预测 [-0.5809] 高炉 [-0.5834] 高炉与设定误差 [0.0081] 模型误差 [0.0025] 校正值 [0.0054]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [0.024] 高炉 [0.0822] 高炉与设定误差 [-0.0723] 模型误差 [-0.0582] 校正值 [0.0495]
# 2设定 -0.5753 预测 [-0.6025] 高炉 [-0.6103] 高炉与设定误差 [0.035] 模型误差 [0.0078] 校正值 [-0.0025]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0411] 高炉 [0.0329] 高炉与设定误差 [-0.023] 模型误差 [-0.074] 校正值 [0.0582]
# 2设定 -0.5753 预测 [-0.6095] 高炉 [-0.6132] 高炉与设定误差 [0.038] 模型误差 [0.0038] 校正值 [-0.0078]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0618] 高炉 [-0.0134] 高炉与设定误差 [0.0233] 模型误差 [-0.0484] 校正值 [0.074]
# 2设定 -0.5753 预测 [-0.5804] 高炉 [-0.5811] 高炉与设定误差 [0.0058] 模型误差 [0.0007] 校正值 [-0.0038]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0408] 高炉 [0.0115] 高炉与设定误差 [-0.0016] 模型误差 [-0.0523] 校正值 [0.0484]
# 2设定 -0.5753 预测 [-0.5749] 高炉 [-0.5762] 高炉与设定误差 [0.001] 模型误差 [0.0013] 校正值 [-0.0007]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0422] 高炉 [0.0426] 高炉与设定误差 [-0.0327] 模型误差 [-0.0848] 校正值 [0.0523]
# 2设定 -0.5753 预测 [-0.5741] 高炉 [-0.5673] 高炉与设定误差 [-0.008] 模型误差 [-0.0068] 校正值 [-0.0013]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0716] 高炉 [0.0182] 高炉与设定误差 [-0.0082] 模型误差 [-0.0898] 校正值 [0.0848]
# 2设定 -0.5753 预测 [-0.5812] 高炉 [-0.5745] 高炉与设定误差 [-0.0008] 模型误差 [-0.0068] 校正值 [0.0068]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0791] 高炉 [-0.0263] 高炉与设定误差 [0.0363] 模型误差 [-0.0527] 校正值 [0.0898]
# 2设定 -0.5753 预测 [-0.5835] 高炉 [-0.5815] 高炉与设定误差 [0.0062] 模型误差 [-0.002] 校正值 [0.0068]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0464] 高炉 [-0.0037] 高炉与设定误差 [0.0137] 模型误差 [-0.0427] 校正值 [0.0527]
# 2设定 -0.5753 预测 [-0.5775] 高炉 [-0.5824] 高炉与设定误差 [0.0071] 模型误差 [0.0049] 校正值 [0.002]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0341] 高炉 [0.0279] 高炉与设定误差 [-0.018] 模型误差 [-0.062] 校正值 [0.0427]
# 2设定 -0.5753 预测 [-0.5801] 高炉 [-0.5828] 高炉与设定误差 [0.0076] 模型误差 [0.0027] 校正值 [-0.0049]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0503] 高炉 [0.0213] 高炉与设定误差 [-0.0114] 模型误差 [-0.0716] 校正值 [0.062]
# 2设定 -0.5753 预测 [-0.5788] 高炉 [-0.576] 高炉与设定误差 [0.0007] 模型误差 [-0.0028] 校正值 [-0.0027]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0606] 高炉 [-0.0029] 高炉与设定误差 [0.0128] 模型误差 [-0.0577] 校正值 [0.0716]
# 2设定 -0.5753 预测 [-0.5782] 高炉 [-0.5768] 高炉与设定误差 [0.0016] 模型误差 [-0.0013] 校正值 [0.0028]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0491] 高炉 [0.0041] 高炉与设定误差 [0.0058] 模型误差 [-0.0531] 校正值 [0.0577]
# 2设定 -0.5753 预测 [-0.5801] 高炉 [-0.5799] 高炉与设定误差 [0.0047] 模型误差 [-0.0002] 校正值 [0.0013]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0438] 高炉 [0.0342] 高炉与设定误差 [-0.0243] 模型误差 [-0.078] 校正值 [0.0531]
# 2设定 -0.5753 预测 [-0.576] 高炉 [-0.5708] 高炉与设定误差 [-0.0045] 模型误差 [-0.0051] 校正值 [0.0002]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0657] 高炉 [0.0253] 高炉与设定误差 [-0.0154] 模型误差 [-0.091] 校正值 [0.078]
# 2设定 -0.5753 预测 [-0.5801] 高炉 [-0.5735] 高炉与设定误差 [-0.0018] 模型误差 [-0.0066] 校正值 [0.0051]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0795] 高炉 [-0.0265] 高炉与设定误差 [0.0364] 模型误差 [-0.053] 校正值 [0.091]
# 2设定 -0.53 预测 [-0.5614] 高炉 [-0.5604] 高炉与设定误差 [0.0304] 模型误差 [-0.001] 校正值 [0.0066]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0467] 高炉 [0.0071] 高炉与设定误差 [0.0028] 模型误差 [-0.0538] 校正值 [0.053]
# 2设定 -0.53 预测 [-0.5335] 高炉 [-0.5331] 高炉与设定误差 [0.0031] 模型误差 [-0.0004] 校正值 [0.001]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0442] 高炉 [0.02] 高炉与设定误差 [-0.0101] 模型误差 [-0.0641] 校正值 [0.0538]
# 2设定 -0.53 预测 [-0.5307] 高炉 [-0.5282] 高炉与设定误差 [-0.0018] 模型误差 [-0.0025] 校正值 [0.0004]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0532] 高炉 [0.0148] 高炉与设定误差 [-0.0049] 模型误差 [-0.068] 校正值 [0.0641]
# 2设定 -0.53 预测 [-0.5329] 高炉 [-0.5251] 高炉与设定误差 [-0.0048] 模型误差 [-0.0077] 校正值 [0.0025]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0576] 高炉 [-0.0008] 高炉与设定误差 [0.0107] 模型误差 [-0.0567] 校正值 [0.068]
# 2设定 -0.53 预测 [-0.5376] 高炉 [-0.5337] 高炉与设定误差 [0.0038] 模型误差 [-0.0039] 校正值 [0.0077]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0479] 高炉 [0.0048] 高炉与设定误差 [0.0051] 模型误差 [-0.0527] 校正值 [0.0567]
# 2设定 -0.53 预测 [-0.5343] 高炉 [-0.5329] 高炉与设定误差 [0.0029] 模型误差 [-0.0014] 校正值 [0.0039]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0433] 高炉 [0.0178] 高炉与设定误差 [-0.0079] 模型误差 [-0.0611] 校正值 [0.0527]
# 2设定 -0.53 预测 [-0.5325] 高炉 [-0.5299] 高炉与设定误差 [-0.] 模型误差 [-0.0025] 校正值 [0.0014]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0504] 高炉 [0.017] 高炉与设定误差 [-0.0071] 模型误差 [-0.0674] 校正值 [0.0611]
# 2设定 -0.53 预测 [-0.5338] 高炉 [-0.5278] 高炉与设定误差 [-0.0022] 模型误差 [-0.006] 校正值 [0.0025]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0568] 高炉 [0.0074] 高炉与设定误差 [0.0025] 模型误差 [-0.0642] 校正值 [0.0674]
# 2设定 -0.53 预测 [-0.5414] 高炉 [-0.5354] 高炉与设定误差 [0.0054] 模型误差 [-0.006] 校正值 [0.006]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0546] 高炉 [0.0013] 高炉与设定误差 [0.0086] 模型误差 [-0.0558] 校正值 [0.0642]
# 2设定 -0.53 预测 [-0.5413] 高炉 [-0.5391] 高炉与设定误差 [0.0091] 模型误差 [-0.0022] 校正值 [0.006]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0453] 高炉 [0.0133] 高炉与设定误差 [-0.0034] 模型误差 [-0.0586] 校正值 [0.0558]
# 2设定 -0.53 预测 [-0.5331] 高炉 [-0.5313] 高炉与设定误差 [0.0013] 模型误差 [-0.0018] 校正值 [0.0022]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0484] 高炉 [0.0199] 高炉与设定误差 [-0.01] 模型误差 [-0.0683] 校正值 [0.0586]
# 2设定 -0.53 预测 [-0.5328] 高炉 [-0.5273] 高炉与设定误差 [-0.0027] 模型误差 [-0.0055] 校正值 [0.0018]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0856] 高炉 [-0.0163] 高炉与设定误差 [0.0262] 模型误差 [-0.0693] 校正值 [0.0683]
# 2设定 -0.53 预测 [-0.5635] 高炉 [-0.5516] 高炉与设定误差 [0.0216] 模型误差 [-0.0118] 校正值 [0.0055]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.062] 高炉 [-0.0273] 高炉与设定误差 [0.0372] 模型误差 [-0.0347] 校正值 [0.0693]
# 2设定 -0.53 预测 [-0.544] 高炉 [-0.5494] 高炉与设定误差 [0.0195] 模型误差 [0.0054] 校正值 [0.0118]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 0.0099 预测 [-0.0285] 高炉 [0.0453] 高炉与设定误差 [-0.0354] 模型误差 [-0.0739] 校正值 [0.0347]
# 2设定 -0.53 预测 [-0.5273] 高炉 [-0.5208] 高炉与设定误差 [-0.0092] 模型误差 [-0.0065] 校正值 [-0.0054]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0026] 高炉 [0.1029] 高炉与设定误差 [-0.0229] 模型误差 [-0.1003] 校正值 [0.0739]
# 2设定 -0.53 预测 [-0.5338] 高炉 [-0.5282] 高炉与设定误差 [-0.0018] 模型误差 [-0.0056] 校正值 [0.0065]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [-0.018] 高炉 [0.0578] 高炉与设定误差 [0.0221] 模型误差 [-0.0759] 校正值 [0.1003]
# 2设定 -0.53 预测 [-0.5535] 高炉 [-0.5512] 高炉与设定误差 [0.0212] 模型误差 [-0.0023] 校正值 [0.0056]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0019] 高炉 [0.0498] 高炉与设定误差 [0.0301] 模型误差 [-0.048] 校正值 [0.0759]
# 2设定 -0.53 预测 [-0.5346] 高炉 [-0.539] 高炉与设定误差 [0.009] 模型误差 [0.0044] 校正值 [0.0023]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.029] 高炉 [0.0775] 高炉与设定误差 [0.0025] 模型误差 [-0.0485] 校正值 [0.048]
# 2设定 -0.53 预测 [-0.5261] 高炉 [-0.5343] 高炉与设定误差 [0.0044] 模型误差 [0.0082] 校正值 [-0.0044]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0313] 高炉 [0.0996] 高炉与设定误差 [-0.0197] 模型误差 [-0.0684] 校正值 [0.0485]
# 2设定 -0.53 预测 [-0.5222] 高炉 [-0.5236] 高炉与设定误差 [-0.0064] 模型误差 [0.0014] 校正值 [-0.0082]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0137] 高炉 [0.094] 高炉与设定误差 [-0.014] 模型误差 [-0.0803] 校正值 [0.0684]
# 2设定 -0.53 预测 [-0.5277] 高炉 [-0.523] 高炉与设定误差 [-0.007] 模型误差 [-0.0047] 校正值 [-0.0014]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0011] 高炉 [0.0648] 高炉与设定误差 [0.0152] 模型误差 [-0.0637] 校正值 [0.0803]
# 2设定 -0.53 预测 [-0.5352] 高炉 [-0.5355] 高炉与设定误差 [0.0055] 模型误差 [0.0003] 校正值 [0.0047]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.018] 高炉 [0.0731] 高炉与设定误差 [0.0069] 模型误差 [-0.0551] 校正值 [0.0637]
# 2设定 -0.53 预测 [-0.5303] 高炉 [-0.5344] 高炉与设定误差 [0.0044] 模型误差 [0.0041] 校正值 [-0.0003]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0241] 高炉 [0.0902] 高炉与设定误差 [-0.0102] 模型误差 [-0.066] 校正值 [0.0551]
# 2设定 -0.53 预测 [-0.5263] 高炉 [-0.5284] 高炉与设定误差 [-0.0015] 模型误差 [0.0021] 校正值 [-0.0041]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.015] 高炉 [0.0949] 高炉与设定误差 [-0.0149] 模型误差 [-0.0799] 校正值 [0.066]
# 2设定 -0.53 预测 [-0.5356] 高炉 [-0.5314] 高炉与设定误差 [0.0014] 模型误差 [-0.0042] 校正值 [-0.0021]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0015] 高炉 [0.0645] 高炉与设定误差 [0.0154] 模型误差 [-0.063] 校正值 [0.0799]
# 2设定 -0.53 预测 [-0.5344] 高炉 [-0.537] 高炉与设定误差 [0.0071] 模型误差 [0.0027] 校正值 [0.0042]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0154] 高炉 [0.0721] 高炉与设定误差 [0.0079] 模型误差 [-0.0567] 校正值 [0.063]
# 2设定 -0.53 预测 [-0.5349] 高炉 [-0.536] 高炉与设定误差 [0.006] 模型误差 [0.0011] 校正值 [-0.0027]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0225] 高炉 [0.0899] 高炉与设定误差 [-0.0099] 模型误差 [-0.0674] 校正值 [0.0567]
# 2设定 -0.53 预测 [-0.5314] 高炉 [-0.5346] 高炉与设定误差 [0.0046] 模型误差 [0.0032] 校正值 [-0.0011]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0136] 高炉 [0.0906] 高炉与设定误差 [-0.0106] 模型误差 [-0.077] 校正值 [0.0674]
# 2设定 -0.53 预测 [-0.5379] 高炉 [-0.5352] 高炉与设定误差 [0.0053] 模型误差 [-0.0027] 校正值 [-0.0032]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.004] 高炉 [0.072] 高炉与设定误差 [0.008] 模型误差 [-0.0679] 校正值 [0.077]
# 2设定 -0.53 预测 [-0.5339] 高炉 [-0.535] 高炉与设定误差 [0.005] 模型误差 [0.0011] 校正值 [0.0027]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0112] 高炉 [0.0717] 高炉与设定误差 [0.0083] 模型误差 [-0.0604] 校正值 [0.0679]
# 2设定 -0.4847 预测 [-0.4939] 高炉 [-0.495] 高炉与设定误差 [0.0103] 模型误差 [0.0011] 校正值 [-0.0011]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0187] 高炉 [0.1076] 高炉与设定误差 [-0.0276] 模型误差 [-0.0889] 校正值 [0.0604]
# 2设定 -0.4847 预测 [-0.4846] 高炉 [-0.4751] 高炉与设定误差 [-0.0096] 模型误差 [-0.0096] 校正值 [-0.0011]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [-0.0061] 高炉 [0.0735] 高炉与设定误差 [0.0065] 模型误差 [-0.0796] 校正值 [0.0889]
# 2设定 -0.4847 预测 [-0.5063] 高炉 [-0.499] 高炉与设定误差 [0.0143] 模型误差 [-0.0073] 校正值 [0.0096]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [-0.0003] 高炉 [0.0475] 高炉与设定误差 [0.0324] 模型误差 [-0.0478] 校正值 [0.0796]
# 2设定 -0.4847 预测 [-0.5022] 高炉 [-0.5042] 高炉与设定误差 [0.0195] 模型误差 [0.002] 校正值 [0.0073]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0289] 高炉 [0.0607] 高炉与设定误差 [0.0192] 模型误差 [-0.0319] 校正值 [0.0478]
# 2设定 -0.4847 预测 [-0.4846] 高炉 [-0.4945] 高炉与设定误差 [0.0098] 模型误差 [0.0099] 校正值 [-0.002]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0462] 高炉 [0.0972] 高炉与设定误差 [-0.0173] 模型误差 [-0.0511] 校正值 [0.0319]
# 2设定 -0.4847 预测 [-0.4778] 高炉 [-0.4807] 高炉与设定误差 [-0.004] 模型误差 [0.0028] 校正值 [-0.0099]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0306] 高炉 [0.1054] 高炉与设定误差 [-0.0254] 模型误差 [-0.0748] 校正值 [0.0511]
# 2设定 -0.4847 预测 [-0.4814] 高炉 [-0.4746] 高炉与设定误差 [-0.0101] 模型误差 [-0.0068] 校正值 [-0.0028]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0076] 高炉 [0.0644] 高炉与设定误差 [0.0156] 模型误差 [-0.0568] 校正值 [0.0748]
# 2设定 -0.4847 预测 [-0.4905] 高炉 [-0.4873] 高炉与设定误差 [0.0026] 模型误差 [-0.0033] 校正值 [0.0068]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0216] 高炉 [0.0761] 高炉与设定误差 [0.0039] 模型误差 [-0.0545] 校正值 [0.0568]
# 2设定 -0.4847 预测 [-0.4999] 高炉 [-0.4991] 高炉与设定误差 [0.0144] 模型误差 [-0.0008] 校正值 [0.0033]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0251] 高炉 [0.093] 高炉与设定误差 [-0.013] 模型误差 [-0.0679] 校正值 [0.0545]
# 2设定 -0.4847 预测 [-0.4869] 高炉 [-0.4873] 高炉与设定误差 [0.0026] 模型误差 [0.0004] 校正值 [0.0008]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0134] 高炉 [0.1011] 高炉与设定误差 [-0.0212] 模型误差 [-0.0877] 校正值 [0.0679]
# 2设定 -0.4847 预测 [-0.4951] 高炉 [-0.4871] 高炉与设定误差 [0.0025] 模型误差 [-0.0079] 校正值 [-0.0004]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [-0.0057] 高炉 [0.0652] 高炉与设定误差 [0.0148] 模型误差 [-0.0709] 校正值 [0.0877]
# 2设定 -0.4847 预测 [-0.4965] 高炉 [-0.4906] 高炉与设定误差 [0.006] 模型误差 [-0.0059] 校正值 [0.0079]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0076] 高炉 [0.0734] 高炉与设定误差 [0.0066] 模型误差 [-0.0658] 校正值 [0.0709]
# 2设定 -0.4847 预测 [-0.4923] 高炉 [-0.4886] 高炉与设定误差 [0.0039] 模型误差 [-0.0037] 校正值 [0.0059]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0135] 高炉 [0.0826] 高炉与设定误差 [-0.0026] 模型误差 [-0.069] 校正值 [0.0658]
# 2设定 -0.4847 预测 [-0.4932] 高炉 [-0.4919] 高炉与设定误差 [0.0073] 模型误差 [-0.0013] 校正值 [0.0037]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 0.08 预测 [0.0112] 高炉 [0.0841] 高炉与设定误差 [-0.0041] 模型误差 [-0.0729] 校正值 [0.069]
# 2设定 -0.4847 预测 [-0.4975] 高炉 [-0.4934] 高炉与设定误差 [0.0087] 模型误差 [-0.0041] 校正值 [0.0013]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.0705] 高炉 [0.1212] 高炉与设定误差 [0.0288] 模型误差 [-0.0507] 校正值 [0.0729]
# 2设定 -0.4847 预测 [-0.4896] 高炉 [-0.4981] 高炉与设定误差 [0.0134] 模型误差 [0.0084] 校正值 [0.0041]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.0964] 高炉 [0.1436] 高炉与设定误差 [0.0064] 模型误差 [-0.0472] 校正值 [0.0507]
# 2设定 -0.4847 预测 [-0.4844] 高炉 [-0.4957] 高炉与设定误差 [0.011] 模型误差 [0.0113] 校正值 [-0.0084]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1022] 高炉 [0.1501] 高炉与设定误差 [-1.e-04] 模型误差 [-0.0479] 校正值 [0.0472]
# 2设定 -0.4847 预测 [-0.4801] 高炉 [-0.4877] 高炉与设定误差 [0.003] 模型误差 [0.0076] 校正值 [-0.0113]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1021] 高炉 [0.1197] 高炉与设定误差 [0.0303] 模型误差 [-0.0176] 校正值 [0.0479]
# 2设定 -0.4847 预测 [-0.4806] 高炉 [-0.4933] 高炉与设定误差 [0.0086] 模型误差 [0.0127] 校正值 [-0.0076]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1294] 高炉 [0.1473] 高炉与设定误差 [0.0028] 模型误差 [-0.0179] 校正值 [0.0176]
# 2设定 -0.4847 预测 [-0.4728] 高炉 [-0.4921] 高炉与设定误差 [0.0074] 模型误差 [0.0193] 校正值 [-0.0127]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1319] 高炉 [0.1636] 高炉与设定误差 [-0.0136] 模型误差 [-0.0318] 校正值 [0.0179]
# 2设定 -0.4847 预测 [-0.4722] 高炉 [-0.4865] 高炉与设定误差 [0.0018] 模型误差 [0.0143] 校正值 [-0.0193]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1196] 高炉 [0.162] 高炉与设定误差 [-0.012] 模型误差 [-0.0424] 校正值 [0.0318]
# 2设定 -0.4847 预测 [-0.4798] 高炉 [-0.4887] 高炉与设定误差 [0.004] 模型误差 [0.0089] 校正值 [-0.0143]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1088] 高炉 [0.1342] 高炉与设定误差 [0.0158] 模型误差 [-0.0254] 校正值 [0.0424]
# 2设定 -0.4847 预测 [-0.4817] 高炉 [-0.494] 高炉与设定误差 [0.0093] 模型误差 [0.0122] 校正值 [-0.0089]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1231] 高炉 [0.1438] 高炉与设定误差 [0.0062] 模型误差 [-0.0208] 校正值 [0.0254]
# 2设定 -0.4847 预测 [-0.4734] 高炉 [-0.4909] 高炉与设定误差 [0.0062] 模型误差 [0.0175] 校正值 [-0.0122]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.15 预测 [0.1287] 高炉 [0.1583] 高炉与设定误差 [-0.0082] 模型误差 [-0.0296] 校正值 [0.0208]
# 2设定 -0.4847 预测 [-0.4704] 高炉 [-0.4848] 高炉与设定误差 [1.e-04] 模型误差 [0.0144] 校正值 [-0.0175]

# %%
y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4).reshape(-1, 1)).flatten()
a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')
# Out:
# 上线分别是：[0.4368226  0.33269065]、[33.62543238 25.74344803]、[1267.49036067  834.92853733]、[ 5.34308431e+01 -1.70957554e-03]

# %%
rmse_1 = np.mean(np.fabs(set_y1-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))
# Out:
# 平均误差 1.2466
# 平均误差 0.0112

# %%
# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(14, 10))
# 第一个维度的曲线
plt.subplot(6, 2, 1)
plt.plot(set_y1_trans, 'ro-', label='set_y1')
plt.plot(all_pred_y1, 'bo-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 2, 3)
plt.plot(set_y2_trans, 'ro-', label='set_y2')
plt.plot(all_pred_y2, 'bo-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 2, 5)
plt.plot(all_pred_u1, 'bo-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 2, 7)
plt.plot(all_pred_u2, 'bo-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 2, 9)
plt.plot(all_pred_u3, 'bo-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 2, 11)
plt.plot(all_pred_u4, 'bo-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')



######################################################

# 第一个维度的曲线
plt.subplot(6, 2, 2)
plt.plot(set_y1, 'ro-', label='set')
plt.plot(y1_pred_inverse_transform, 'bo-', label='y1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(6, 2, 4)
plt.plot(set_y2, 'ro-', label='set')
plt.plot(y2_pred_inverse_transform, 'bo-', label='y2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第一个维度的u1曲线
plt.subplot(6, 2, 6)
plt.plot(all_pred_u1, 'bo-', label='u1')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(6, 2, 8)
plt.plot(all_pred_u2, 'bo-', label='u2')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(6, 2, 10)
plt.plot(all_pred_u3, 'bo-', label='u3')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(6, 2, 12)
plt.plot(all_pred_u4, 'bo-', label='u4')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,Times))
plt.ylim((-max_control,max_control))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')






# 调整子图布局
plt.tight_layout()
plt.show()
