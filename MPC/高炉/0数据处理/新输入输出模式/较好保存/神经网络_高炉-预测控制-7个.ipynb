# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")
from base import    double_control_predict_result,\
                    gaolu_predict_raw,\
                    data_tranform_plot,\
                    get_y_aim_data,\
                    generate_yr,\
                    replace_outliers_with_weighted_diff

from base import MyRNNModel,CustomPredictor_double

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='剔除直线输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='单SI_0.2_0.8') 
# print(df_sheet_yuansu.info())
# print(df_sheet_yuansu.columns)

excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_params = pd.read_excel(excel_path, sheet_name='1h_mean') 

# print(df_sheet_params.info())
# print(df_sheet_params.columns)

# %%
import pandas as pd

# 假设 df 是你的 DataFrame

# 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_yuansu.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
    # 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_params.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
# Out:
# 数据不包含 NaN 值
# 数据不包含 NaN 值

# %%
# 定义输入输出参数
input_term = ['富氧流量', '冷风流量', '热风压力', '冷风温度', '热风温度', '鼓风湿度', '设定喷煤量']
output_term = ['铁口1温度', 'SI']
time_term= '时间戳h'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_yuansu_process = df_sheet_yuansu.copy()
df_sheet_params_process = df_sheet_params.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 1.5 * y.std()  # 使用标准差作为阈值
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value

# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[4]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[5]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[6]])

# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[0]])
# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[1]])

plt.figure(figsize=(15, 4))
for idx, column in enumerate(input_term):
    plt.subplot(len(input_term), 1, idx+1)
    plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params[column].values,df_sheet_params_process[column].values,column)

plt.figure(figsize=(15, 2))
for idx, column in enumerate(output_term):
    plt.subplot(len(output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu[column].values,df_sheet_yuansu_process[column].values,column)
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_10224\3024773205.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r.', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 4800


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 6))
for idx, column in enumerate(output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_params_process[input_term[0]].values,
    input_term[1]:   df_sheet_params_process[input_term[1]].values,
    input_term[2]:   df_sheet_params_process[input_term[2]].values,
    input_term[3]:   df_sheet_params_process[input_term[3]].values,
    input_term[4]:   df_sheet_params_process[input_term[4]].values,
    input_term[5]:   df_sheet_params_process[input_term[5]].values,
    input_term[6]:   df_sheet_params_process[input_term[6]].values,
    output_term[0]:  df_sheet_yuansu_process[output_term[0]].values,
    output_term[1]:  df_sheet_yuansu_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [0.0341569]
# [1500.]
# [0.1523575]
# [1510.]
# 每摄氏度的输出差： [0.01182006]
# [-0.53242879]
# [0.5]
# [-0.4247456]
# [0.6]
# 每0.01浓度的输出差： [0.1076832]

# %%
isShuffle = True
# isShuffle = False
time_steps = 2

# %%
# 组合训练数据--拆分训练、测试集
test_size = 0.15
val_size = 0.15
train_size = 1-val_size-test_size
# 定义时间步数和特征数

# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,y1_data,y2_data,index_fanwei):
    X = np.column_stack((u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data))
    y = np.column_stack((y1_data, y2_data))

    X_modified = []
    y_modified = []
    
    for i in range(3,len(y1_data)):
        if i in index_fanwei:
            # print(i)
            # print(df_sheet_yuansu[time_term][i])
            yuansu_time = df_sheet_yuansu[time_term][i]
            closest_10 = df_sheet_params[df_sheet_params[time_term] <= yuansu_time].nlargest(time_steps, time_term)
            # print(closest_10)
            
            index = closest_10.index
            # print(index)
            # print(closest_10.iloc[-1][time_term])
            if closest_10.iloc[-1][time_term] < yuansu_time - time_steps + 1:
                print(i,yuansu_time,'errloss')
            else:

                # print(X[index, :])
                new_x_sample = np.concatenate([X[i, :] for i in index],axis=0)
                # print(new_x_sample)
                y_last = y[i-1, :]
                # print(y_last, 'y_last time : ',df_sheet_yuansu[time_term][i-1])
                new_x_sample = np.concatenate([new_x_sample,y_last],axis=0)
                # print(new_x_sample)
                y_sample = y[i, :]  
                X_modified.append(new_x_sample)
                y_modified.append(y_sample)
                print(i,yuansu_time,index[0],index[-1], end='\r')
                # break

    # 将列表转换为 NumPy 数组
    X_modified = np.array(X_modified)
    y_modified = np.array(y_modified)
    X_reshaped = X_modified.reshape((X_modified.shape[0], X_modified.shape[1]))

    # 打印新数据的形状
    print("Modified Input Shape:", X_reshaped.shape)
    print("Modified Output Shape:", y_modified.shape)


    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_modified, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
u5_data = normalized_data_dict[input_term[4]]
u6_data = normalized_data_dict[input_term[5]]
u7_data = normalized_data_dict[input_term[6]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]
print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_gaolu)



# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
u5_data = normalized_data_dict[input_term[4]]
u6_data = normalized_data_dict[input_term[5]]
u7_data = normalized_data_dict[input_term[6]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_predict)
# Out:
# 高炉模型数据
# Modified Input Shape: (398, 16)
# Modified Output Shape: (398, 2)
# 训练数量： (278, 16) (278, 2)
# 验证数量： (60, 16) (60, 2)
# 测试数量： (60, 16) (60, 2)
# 预测模型数据
# Modified Input Shape: (401, 16)
# Modified Output Shape: (401, 2)
# 训练数量： (279, 16) (279, 2)
# 验证数量： (61, 16) (61, 2)
# 测试数量： (61, 16) (61, 2)

# %%
# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyNeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MyNeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse



    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
epoch_once_time = 25

# %%
# 建立高炉模型实例
input_size = 16  # 输入特征大小
hidden_size = 20  # 隐藏层大小
output_size = 2  # 输出大小

# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyNeuralNetwork(input_size, hidden_size, output_size)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 25/25 轮, 训练误差: 0.0277, 验证误差: 0.0322
# epoch_sum: 25

# %%
# 高炉模型建模效果
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_gaolu_train)
# 计算 RMSE、MRE
y_test = y_gaolu_train
double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 11.8011 , SI: 0.0789
# MAPE:  铁口1温度: 0.5400% , SI: 14.8149%
# MRE :  铁口1温度: 0.0054  , SI: 0.1481
# per :  铁口1温度: 0.7086  , SI: 0.8309

# %%
# 高炉模型预测
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_gaolu_test)
# 计算 RMSE、MRE
y_test = y_gaolu_test
double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 11.0455 , SI: 0.0966
# MAPE:  铁口1温度: 0.5418% , SI: 14.5894%
# MRE :  铁口1温度: 0.0054  , SI: 0.1459
# per :  铁口1温度: 0.6667  , SI: 0.8167

# %%
# 创建预测模型实例
input_size = 16  # 输入特征大小
hidden_size = 20  # 隐藏层大小
output_size = 2  # 输出大小

# 设置随机种子
torch.manual_seed(0)
model_predict = MyNeuralNetwork(input_size, hidden_size, output_size)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model_predict.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 25/25 轮, 训练误差: 0.0612, 验证误差: 0.0565
# epoch_sum: 0

# %%
# 预测模型预测
y_pred_0,y_pred_1  = model_predict.my_predict(X_predict_test)
# 计算 RMSE、MRE
y_test = y_predict_test
double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 15.8501 , SI: 0.1436
# MAPE:  铁口1温度: 0.8425% , SI: 18.6355%
# MRE :  铁口1温度: 0.0084  , SI: 0.1864
# per :  铁口1温度: 0.4098  , SI: 0.6066

# %%
gaolu_predict_raw(scalers,output_term,model_predict,model_gaolu,X_predict_test,y_predict_test)

# %%
# 使用NumPy重新构建神经网络架构
class MyNeuralNetworkNumpy:
    def __init__(self, model, input_size, hidden_size, output_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        params = {name: param.detach().numpy() for name, param in model.state_dict().items()}
        self.weights_input_hidden = params['fc1.weight']
        self.bias_input_hidden = params['fc1.bias']
        self.weights_hidden_output = params['fc2.weight']
        self.bias_hidden_output = params['fc2.bias']
        
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    def relu(self, x):
        return np.maximum(0, x)

    def forward(self, x):
        hidden = np.dot(x, self.weights_input_hidden.T) + self.bias_input_hidden
        hidden_activation = self.relu(hidden)
        output = np.dot(hidden_activation, self.weights_hidden_output.T) + self.bias_hidden_output
        return output
    
    def my_predict(self, data_input):
        input = data_input  # 随机初始化一个输入序列
        output_prediction = model_numpy.forward(input)
        return output_prediction[:,0], output_prediction[:,1]

# 使用NumPy模型进行预测
model_numpy = MyNeuralNetworkNumpy(model_predict, input_size, hidden_size, output_size)


y_pred_0, y_pred_1 = model_numpy.my_predict(X_gaolu_test)

# 计算 RMSE、MRE
y_test = y_gaolu_test


double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 16.7340 , SI: 0.1732
# MAPE:  铁口1温度: 0.8150% , SI: 32.1404%
# MRE :  铁口1温度: 0.0082  , SI: 0.3214
# per :  铁口1温度: 0.5500  , SI: 0.3833

# %%
iscontrol = True
# iscontrol = False
Times = 100

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
# 生成期望数据
Times = 100

def generate_y_aim_data(Times):

    set_y1 = np.full(Times,1500)
    set_y1[30:] = 1510
    set_y1[60:] = 1505
    set_y1[90:] = 1515
    # set_y1[70:] = 1520
    # set_y1[90:] = 1525

    set_y2 = np.full(Times,0.44)
    set_y2[15:] = 0.48
    set_y2[45:] = 0.52
    set_y2[75:] = 0.44
    # 限制设定值在 -1 到 1 之间
    # set_y1 = np.clip(set_y1, -1, 1)
    # set_y2 = np.clip(set_y2, -1, 1)


    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# # 调用示例
# set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
# plt.plot(set_y1_trans)
# plt.plot(set_y2_trans)
# plt.title('y_sp')
# plt.show()

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]
    u5   = u2_data[randint  :randint+3  ]
    u6   = u3_data[randint  :randint+3  ]
    u7   = u4_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, u5, u6, u7, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):
    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]

    y1   = k_data[21:24]
    y2   = k_data[24:27]

    
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4, U5, U6, U7  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M], params[4*M:5*M],params[5*M:6*M], params[6*M:7*M]
    
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(u5.round(4))
        print(u6.round(4))
        print(u7.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = model_numpy.my_predict(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],u5[1:4],u6[1:4],u7[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    # y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    # y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    # u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    # u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    # u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    # u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)
    # u5_power = lamda2*np.sum((np.diff(u5[2:]))**2)
    # u6_power = lamda3*np.sum((np.diff(u6[2:]))**2)
    # u7_power = lamda4*np.sum((np.diff(u7[2:]))**2)

    y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            +u5_power
            +u6_power
            +u7_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
Times = 100
iscontrol = True
# iscontrol = False

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 4  # 预测时域长度  增大P能平稳些
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, 
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
all_pred_u5 = []
all_pred_u6 = []
all_pred_u7 = []
# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    bounds = [(-max_control, max_control) for _ in range(7 * M)]
    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    U1, U2, U3, U4, U5, U6, U7 =    result.x[0:M], result.x[M:2*M], \
                                    result.x[2*M:3*M], result.x[3*M:4*M], \
                                    result.x[4*M:5*M], result.x[5*M:6*M], \
                                    result.x[6*M:7*M]
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]

    y1   = k_data[21:24]
    y2   = k_data[24:27]
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                            y1[j+1],y2[j+1]))
    # x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model_predict.my_predict(x)
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    


    # 更新k_data
    params = np.concatenate((U1, U2, U3, U4, U5, U6, U7),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    all_pred_u5.append(U5[0])
    all_pred_u6.append(U6[0])
    all_pred_u7.append(U7[0])
    k_data2[23] = y1_pred.item()
    k_data2[26] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 579
# (27,)
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [0.131] 高炉 [0.2237] 高炉与设定误差 [-0.1895] [-16.03206797] 模型误差 [-0.0926] 校正值 [-0.0993]
# 2设定 -0.597 预测 [-0.3493] 高炉 [-0.294] 高炉与设定误差 [-0.3031] [-0.28147381] 模型误差 [-0.0554] 校正值 [0.1421]
# 这是对第1时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0389] 高炉 [0.064] 高炉与设定误差 [-0.0299] [-2.52959796] 模型误差 [-0.103] 校正值 [0.0926]
# 2设定 -0.597 预测 [-0.6221] 高炉 [-0.5017] 高炉与设定误差 [-0.0954] [-0.08859321] 模型误差 [-0.1204] 校正值 [0.0554]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0396] 高炉 [0.0456] 高炉与设定误差 [-0.0114] [-0.96446213] 模型误差 [-0.0852] 校正值 [0.103]
# 2设定 -0.597 预测 [-0.6481] 高炉 [-0.5584] 高炉与设定误差 [-0.0387] [-0.03593875] 模型误差 [-0.0897] 校正值 [0.1204]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0394] 高炉 [0.0592] 高炉与设定误差 [-0.025] [-2.11504853] 模型误差 [-0.0986] 校正值 [0.0852]
# 2设定 -0.597 预测 [-0.6829] 高炉 [-0.5996] 高炉与设定误差 [0.0026] [0.00241449] 模型误差 [-0.0833] 校正值 [0.0897]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0551] 高炉 [0.0428] 高炉与设定误差 [-0.0087] [-0.73603689] 模型误差 [-0.098] 校正值 [0.0986]
# 2设定 -0.597 预测 [-0.6782] 高炉 [-0.5971] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [-0.0811] 校正值 [0.0833]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0532] 高炉 [0.0464] 高炉与设定误差 [-0.0122] [-1.03214365] 模型误差 [-0.0996] 校正值 [0.098]
# 2设定 -0.597 预测 [-0.6704] 高炉 [-0.5914] 高炉与设定误差 [-0.0056] [-0.00520044] 模型误差 [-0.079] 校正值 [0.0811]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0543] 高炉 [0.0454] 高炉与设定误差 [-0.0113] [-0.95600195] 模型误差 [-0.0998] 校正值 [0.0996]
# 2设定 -0.597 预测 [-0.6744] 高炉 [-0.5811] 高炉与设定误差 [-0.0159] [-0.01476554] 模型误差 [-0.0934] 校正值 [0.079]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0356] 高炉 [0.0546] 高炉与设定误差 [-0.0205] [-1.73433982] 模型误差 [-0.0902] 校正值 [0.0998]
# 2设定 -0.597 预测 [-0.6805] 高炉 [-0.5891] 高炉与设定误差 [-0.0079] [-0.00733633] 模型误差 [-0.0914] 校正值 [0.0934]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0481] 高炉 [0.052] 高炉与设定误差 [-0.0178] [-1.5059145] 模型误差 [-0.1001] 校正值 [0.0902]
# 2设定 -0.597 预测 [-0.6826] 高炉 [-0.5901] 高炉与设定误差 [-0.0069] [-0.00640768] 模型误差 [-0.0925] 校正值 [0.0914]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.038] 高炉 [0.0519] 高炉与设定误差 [-0.0177] [-1.49745432] 模型误差 [-0.0898] 校正值 [0.1001]
# 2设定 -0.597 预测 [-0.6823] 高炉 [-0.5864] 高炉与设定误差 [-0.0106] [-0.00984369] 模型误差 [-0.0958] 校正值 [0.0925]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0344] 高炉 [0.0603] 高炉与设定误差 [-0.0262] [-2.21657084] 模型误差 [-0.0948] 校正值 [0.0898]
# 2设定 -0.597 预测 [-0.6918] 高炉 [-0.5981] 高炉与设定误差 [0.001] [0.00092865] 模型误差 [-0.0938] 校正值 [0.0958]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0398] 高炉 [0.0554] 高炉与设定误差 [-0.0213] [-1.80202125] 模型误差 [-0.0952] 校正值 [0.0948]
# 2设定 -0.597 预测 [-0.6906] 高炉 [-0.5962] 高炉与设定误差 [-0.0008] [-0.00074292] 模型误差 [-0.0944] 校正值 [0.0938]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0364] 高炉 [0.0563] 高炉与设定误差 [-0.0221] [-1.86970285] 模型误差 [-0.0927] 校正值 [0.0952]
# 2设定 -0.597 预测 [-0.6855] 高炉 [-0.5905] 高炉与设定误差 [-0.0065] [-0.00603623] 模型误差 [-0.095] 校正值 [0.0944]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0407] 高炉 [0.0557] 高炉与设定误差 [-0.0216] [-1.82740195] 模型误差 [-0.0964] 校正值 [0.0927]
# 2设定 -0.597 预测 [-0.6863] 高炉 [-0.5899] 高炉与设定误差 [-0.0071] [-0.00659342] 模型误差 [-0.0963] 校正值 [0.095]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0355] 高炉 [0.0562] 高炉与设定误差 [-0.0221] [-1.86970285] 模型误差 [-0.0917] 校正值 [0.0964]
# 2设定 -0.597 预测 [-0.6879] 高炉 [-0.5913] 高炉与设定误差 [-0.0057] [-0.00529331] 模型误差 [-0.0966] 校正值 [0.0963]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0554] 高炉 [0.0489] 高炉与设定误差 [-0.0147] [-1.24364853] 模型误差 [-0.1043] 校正值 [0.0917]
# 2设定 -0.554 预测 [-0.6543] 高炉 [-0.5622] 高炉与设定误差 [0.0082] [0.00761493] 模型误差 [-0.0921] 校正值 [0.0966]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0507] 高炉 [0.0504] 高炉与设定误差 [-0.0163] [-1.37901164] 模型误差 [-0.1011] 校正值 [0.1043]
# 2设定 -0.554 预测 [-0.6416] 高炉 [-0.5522] 高炉与设定误差 [-0.0018] [-0.00167157] 模型误差 [-0.0894] 校正值 [0.0921]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0619] 高炉 [0.038] 高炉与设定误差 [-0.0038] [-0.32148738] 模型误差 [-0.0998] 校正值 [0.1011]
# 2设定 -0.554 预测 [-0.6431] 高炉 [-0.5627] 高炉与设定误差 [0.0087] [0.00807926] 模型误差 [-0.0805] 校正值 [0.0894]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0475] 高炉 [0.0496] 高炉与设定误差 [-0.0154] [-1.30286987] 模型误差 [-0.0971] 校正值 [0.0998]
# 2设定 -0.554 预测 [-0.6353] 高炉 [-0.5658] 高炉与设定误差 [0.0118] [0.01095807] 模型误差 [-0.0695] 校正值 [0.0805]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0538] 高炉 [0.0521] 高炉与设定误差 [-0.0179] [-1.51437467] 模型误差 [-0.1059] 校正值 [0.0971]
# 2设定 -0.554 预测 [-0.6247] 高炉 [-0.5561] 高炉与设定误差 [0.0021] [0.00195016] 模型误差 [-0.0686] 校正值 [0.0695]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0688] 高炉 [0.0352] 高炉与设定误差 [-0.0011] [-0.09306213] 模型误差 [-0.104] 校正值 [0.1059]
# 2设定 -0.554 预测 [-0.6227] 高炉 [-0.5488] 高炉与设定误差 [-0.0051] [-0.00473612] 模型误差 [-0.0739] 校正值 [0.0686]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0654] 高炉 [0.0354] 高炉与设定误差 [-0.0013] [-0.10998252] 模型误差 [-0.1008] 校正值 [0.104]
# 2设定 -0.554 预测 [-0.6255] 高炉 [-0.5544] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [-0.0711] 校正值 [0.0739]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.059] 高炉 [0.0451] 高炉与设定误差 [-0.0109] [-0.92216116] 模型误差 [-0.1041] 校正值 [0.1008]
# 2设定 -0.554 预测 [-0.6251] 高炉 [-0.5586] 高炉与设定误差 [0.0047] [0.00436465] 模型误差 [-0.0664] 校正值 [0.0711]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0557] 高炉 [0.0452] 高炉与设定误差 [-0.011] [-0.93062133] 模型误差 [-0.1009] 校正值 [0.1041]
# 2设定 -0.554 预测 [-0.6209] 高炉 [-0.5517] 高炉与设定误差 [-0.0022] [-0.00204303] 模型误差 [-0.0691] 校正值 [0.0664]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0656] 高炉 [0.0376] 高炉与设定误差 [-0.0035] [-0.2961068] 模型误差 [-0.1032] 校正值 [0.1009]
# 2设定 -0.554 预测 [-0.6229] 高炉 [-0.5568] 高炉与设定误差 [0.0028] [0.00260022] 模型误差 [-0.0661] 校正值 [0.0691]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.048] 高炉 [0.0501] 高炉与设定误差 [-0.016] [-1.3536311] 模型误差 [-0.0982] 校正值 [0.1032]
# 2设定 -0.554 预测 [-0.6203] 高炉 [-0.555] 高炉与设定误差 [0.0011] [0.00102151] 模型误差 [-0.0653] 校正值 [0.0661]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0474] 高炉 [0.0596] 高炉与设定误差 [-0.0254] [-2.14888925] 模型误差 [-0.107] 校正值 [0.0982]
# 2设定 -0.554 预测 [-0.6161] 高炉 [-0.5439] 高炉与设定误差 [-0.01] [-0.0092865] 模型误差 [-0.0722] 校正值 [0.0653]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0436] 高炉 [0.0542] 高炉与设定误差 [-0.02] [-1.69203876] 模型误差 [-0.0978] 校正值 [0.107]
# 2设定 -0.554 预测 [-0.6251] 高炉 [-0.5432] 高炉与设定误差 [-0.0108] [-0.01002942] 模型误差 [-0.0819] 校正值 [0.0722]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0616] 高炉 [0.0381] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [-0.0997] 校正值 [0.0978]
# 2设定 -0.554 预测 [-0.6348] 高炉 [-0.5592] 高炉与设定误差 [0.0052] [0.00482898] 模型误差 [-0.0756] 校正值 [0.0819]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 0.0342 预测 [-0.0601] 高炉 [0.0393] 高炉与设定误差 [-0.0051] [-0.43146991] 模型误差 [-0.0994] 校正值 [0.0997]
# 2设定 -0.554 预测 [-0.6301] 高炉 [-0.5657] 高炉与设定误差 [0.0117] [0.0108652] 模型误差 [-0.0645] 校正值 [0.0756]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.0416] 高炉 [0.1079] 高炉与设定误差 [0.0445] [3.7647864] 模型误差 [-0.0662] 校正值 [0.0994]
# 2设定 -0.554 预测 [-0.6196] 高炉 [-0.5362] 高炉与设定误差 [-0.0178] [-0.01652997] 模型误差 [-0.0834] 校正值 [0.0645]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.0817] 高炉 [0.125] 高炉与设定误差 [0.0274] [2.31809316] 模型误差 [-0.0433] 校正值 [0.0662]
# 2设定 -0.554 预测 [-0.6356] 高炉 [-0.5656] 高炉与设定误差 [0.0116] [0.01077234] 模型误差 [-0.07] 校正值 [0.0834]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1063] 高炉 [0.1332] 高炉与设定误差 [0.0192] [1.62435733] 模型误差 [-0.0269] 校正值 [0.0433]
# 2设定 -0.554 预测 [-0.6252] 高炉 [-0.5996] 高炉与设定误差 [0.0457] [0.0424393] 模型误差 [-0.0255] 校正值 [0.07]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1226] 高炉 [0.133] 高炉与设定误差 [0.0194] [1.64127768] 模型误差 [-0.0104] 校正值 [0.0269]
# 2设定 -0.554 预测 [-0.6253] 高炉 [-0.6148] 高炉与设定误差 [0.0608] [0.05646192] 模型误差 [-0.0105] 校正值 [0.0255]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.14] 高炉 [0.1347] 高炉与设定误差 [0.0176] [1.48899414] 模型误差 [0.0053] 校正值 [0.0104]
# 2设定 -0.554 预测 [-0.5705] 高炉 [-0.5843] 高炉与设定误差 [0.0303] [0.0281381] 模型误差 [0.0137] 校正值 [0.0105]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1557] 高炉 [0.143] 高炉与设定误差 [0.0093] [0.78679804] 模型误差 [0.0126] 校正值 [-0.0053]
# 2设定 -0.554 预测 [-0.5437] 高炉 [-0.5682] 高炉与设定误差 [0.0142] [0.01318683] 模型误差 [0.0245] 校正值 [-0.0137]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1613] 高炉 [0.153] 高炉与设定误差 [-0.0006] [-0.05076117] 模型误差 [0.0084] 校正值 [-0.0126]
# 2设定 -0.554 预测 [-0.5679] 高炉 [-0.6006] 高炉与设定误差 [0.0466] [0.04327509] 模型误差 [0.0326] 校正值 [-0.0245]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1608] 高炉 [0.1483] 高炉与设定误差 [0.0041] [0.34686796] 模型误差 [0.0126] 校正值 [-0.0084]
# 2设定 -0.554 预测 [-0.526] 高炉 [-0.564] 高炉与设定误差 [0.01] [0.0092865] 模型误差 [0.038] 校正值 [-0.0326]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1645] 高炉 [0.1449] 高炉与设定误差 [0.0075] [0.63451454] 模型误差 [0.0196] 校正值 [-0.0126]
# 2设定 -0.554 预测 [-0.517] 高炉 [-0.5599] 高炉与设定误差 [0.0059] [0.00547904] 模型误差 [0.0429] 校正值 [-0.038]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1712] 高炉 [0.1597] 高炉与设定误差 [-0.0073] [-0.61759418] 模型误差 [0.0115] 校正值 [-0.0196]
# 2设定 -0.554 预测 [-0.5117] 高炉 [-0.5753] 高炉与设定误差 [0.0213] [0.01978024] 模型误差 [0.0636] 校正值 [-0.0429]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1646] 高炉 [0.1602] 高炉与设定误差 [-0.0079] [-0.66835529] 模型误差 [0.0044] 校正值 [-0.0115]
# 2设定 -0.554 预测 [-0.4925] 高炉 [-0.5616] 高炉与设定误差 [0.0076] [0.00705774] 模型误差 [0.0691] 校正值 [-0.0636]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1575] 高炉 [0.1551] 高炉与设定误差 [-0.0027] [-0.22842524] 模型误差 [0.0024] 校正值 [-0.0044]
# 2设定 -0.554 预测 [-0.4856] 高炉 [-0.5395] 高炉与设定误差 [-0.0145] [-0.01346542] 模型误差 [0.0539] 校正值 [-0.0691]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1551] 高炉 [0.1531] 高炉与设定误差 [-0.0007] [-0.05922136] 模型误差 [0.002] 校正值 [-0.0024]
# 2设定 -0.554 预测 [-0.4986] 高炉 [-0.5588] 高炉与设定误差 [0.0048] [0.00445752] 模型误差 [0.0601] 校正值 [-0.0539]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1544] 高炉 [0.1531] 高炉与设定误差 [-0.0007] [-0.05922136] 模型误差 [0.0014] 校正值 [-0.002]
# 2设定 -0.554 预测 [-0.4943] 高炉 [-0.5546] 高炉与设定误差 [0.0006] [0.00055719] 模型误差 [0.0602] 校正值 [-0.0601]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1538] 高炉 [0.1551] 高炉与设定误差 [-0.0027] [-0.22842524] 模型误差 [-0.0013] 校正值 [-0.0014]
# 2设定 -0.554 预测 [-0.4938] 高炉 [-0.5629] 高炉与设定误差 [0.009] [0.00835785] 模型误差 [0.0691] 校正值 [-0.0602]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1513] 高炉 [0.1589] 高炉与设定误差 [-0.0065] [-0.54991262] 模型误差 [-0.0075] 校正值 [0.0013]
# 2设定 -0.5109 预测 [-0.447] 高炉 [-0.5036] 高炉与设定误差 [-0.0073] [-0.00677915] 模型误差 [0.0566] 校正值 [-0.0691]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1455] 高炉 [0.1454] 高炉与设定误差 [0.0069] [0.58375338] 模型误差 [0.] 校正值 [0.0075]
# 2设定 -0.5109 预测 [-0.4533] 高炉 [-0.4691] 高炉与设定误差 [-0.0418] [-0.03881757] 模型误差 [0.0158] 校正值 [-0.0566]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1519] 高炉 [0.1292] 高炉与设定误差 [0.0231] [1.9543048] 模型误差 [0.0226] 校正值 [-0.]
# 2设定 -0.5109 预测 [-0.491] 高炉 [-0.5155] 高炉与设定误差 [0.0046] [0.00427179] 模型误差 [0.0245] 校正值 [-0.0158]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1727] 高炉 [0.1585] 高炉与设定误差 [-0.0061] [-0.51607182] 模型误差 [0.0142] 校正值 [-0.0226]
# 2设定 -0.5109 预测 [-0.4868] 高炉 [-0.5744] 高炉与设定误差 [0.0635] [0.05896928] 模型误差 [0.0876] 校正值 [-0.0245]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1672] 高炉 [0.1831] 高炉与设定误差 [-0.0307] [-2.59727956] 模型误差 [-0.0159] 校正值 [-0.0142]
# 2设定 -0.5109 预测 [-0.4296] 高炉 [-0.5288] 高炉与设定误差 [0.0179] [0.01662283] 模型误差 [0.0991] 校正值 [-0.0876]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1395] 高炉 [0.1685] 高炉与设定误差 [-0.0162] [-1.37055146] 模型误差 [-0.029] 校正值 [0.0159]
# 2设定 -0.5109 预测 [-0.4135] 高炉 [-0.4679] 高炉与设定误差 [-0.043] [-0.03993195] 模型误差 [0.0544] 校正值 [-0.0991]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1284] 高炉 [0.1496] 高炉与设定误差 [0.0028] [0.23688542] 模型误差 [-0.0212] 校正值 [0.029]
# 2设定 -0.5109 预测 [-0.4521] 高炉 [-0.4971] 高炉与设定误差 [-0.0138] [-0.01281537] 模型误差 [0.0449] 校正值 [-0.0544]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1309] 高炉 [0.1571] 高炉与设定误差 [-0.0048] [-0.40608933] 模型误差 [-0.0262] 校正值 [0.0212]
# 2设定 -0.5109 预测 [-0.4646] 高炉 [-0.5128] 高炉与设定误差 [0.0019] [0.00176444] 模型误差 [0.0482] 校正值 [-0.0449]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1266] 高炉 [0.1497] 高炉与设定误差 [0.0027] [0.22842524] 模型误差 [-0.0231] 校正值 [0.0262]
# 2设定 -0.5109 预测 [-0.4629] 高炉 [-0.5014] 高炉与设定误差 [-0.0095] [-0.00882217] 模型误差 [0.0385] 校正值 [-0.0482]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.129] 高炉 [0.1574] 高炉与设定误差 [-0.005] [-0.42300969] 模型误差 [-0.0284] 校正值 [0.0231]
# 2设定 -0.5109 预测 [-0.4714] 高炉 [-0.4852] 高炉与设定误差 [-0.0257] [-0.0238663] 模型误差 [0.0138] 校正值 [-0.0385]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1245] 高炉 [0.1351] 高炉与设定误差 [0.0172] [1.45515342] 模型误差 [-0.0107] 校正值 [0.0284]
# 2设定 -0.5109 预测 [-0.4945] 高炉 [-0.5131] 高炉与设定误差 [0.0023] [0.0021359] 模型误差 [0.0186] 校正值 [-0.0138]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1399] 高炉 [0.1414] 高炉与设定误差 [0.011] [0.93062133] 模型误差 [-0.0014] 校正值 [0.0107]
# 2设定 -0.5109 预测 [-0.4925] 高炉 [-0.5374] 高炉与设定误差 [0.0265] [0.02460922] 模型误差 [0.0449] 校正值 [-0.0186]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1498] 高炉 [0.15] 高炉与设定误差 [0.0023] [0.19458447] 模型误差 [-0.0002] 校正值 [0.0014]
# 2设定 -0.5109 预测 [-0.4686] 高炉 [-0.4874] 高炉与设定误差 [-0.0235] [-0.02182327] 模型误差 [0.0188] 校正值 [-0.0449]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1519] 高炉 [0.1326] 高炉与设定误差 [0.0197] [1.66665822] 模型误差 [0.0193] 校正值 [0.0002]
# 2设定 -0.5109 预测 [-0.4897] 高炉 [-0.5424] 高炉与设定误差 [0.0315] [0.02925248] 模型误差 [0.0527] 校正值 [-0.0188]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 0.1524 预测 [0.1743] 高炉 [0.1602] 高炉与设定误差 [-0.0079] [-0.66835529] 模型误差 [0.014] 校正值 [-0.0193]
# 2设定 -0.5109 预测 [-0.4613] 高炉 [-0.5391] 高炉与设定误差 [0.0282] [0.02618793] 模型误差 [0.0777] 校正值 [-0.0527]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.114] 高炉 [0.1357] 高炉与设定误差 [-0.0425] [-3.59558249] 模型误差 [-0.0218] 校正值 [-0.014]
# 2设定 -0.5109 预测 [-0.436] 高炉 [-0.4632] 高炉与设定误差 [-0.0477] [-0.0442966] 模型误差 [0.0272] 校正值 [-0.0777]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0757] 高炉 [0.1272] 高炉与设定误差 [-0.034] [-2.87646612] 模型误差 [-0.0515] 校正值 [0.0218]
# 2设定 -0.5109 预测 [-0.4789] 高炉 [-0.4405] 高炉与设定误差 [-0.0704] [-0.06537696] 模型误差 [-0.0384] 校正值 [-0.0272]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0452] 高炉 [0.0993] 高炉与设定误差 [-0.0061] [-0.51607182] 模型误差 [-0.0542] 校正值 [0.0515]
# 2设定 -0.5109 预测 [-0.5423] 高炉 [-0.4976] 高炉与设定误差 [-0.0133] [-0.01235104] 模型误差 [-0.0447] 校正值 [0.0384]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0397] 高炉 [0.1058] 高炉与设定误差 [-0.0126] [-1.06598445] 模型误差 [-0.0661] 校正值 [0.0542]
# 2设定 -0.5109 预测 [-0.5543] 高炉 [-0.4975] 高炉与设定误差 [-0.0134] [-0.01244391] 模型误差 [-0.0568] 校正值 [0.0447]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0295] 高炉 [0.1047] 高炉与设定误差 [-0.0115] [-0.97292231] 模型误差 [-0.0752] 校正值 [0.0661]
# 2设定 -0.5109 预测 [-0.5663] 高炉 [-0.504] 高炉与设定误差 [-0.0069] [-0.00640768] 模型误差 [-0.0623] 校正值 [0.0568]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0192] 高炉 [0.0923] 高炉与设定误差 [0.001] [0.08460194] 模型误差 [-0.0731] 校正值 [0.0752]
# 2设定 -0.5109 预测 [-0.5725] 高炉 [-0.5043] 高炉与设定误差 [-0.0066] [-0.00612909] 模型误差 [-0.0683] 校正值 [0.0623]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0201] 高炉 [0.0936] 高炉与设定误差 [-0.0003] [-0.02538058] 模型误差 [-0.0735] 校正值 [0.0731]
# 2设定 -0.5109 预测 [-0.5785] 高炉 [-0.5093] 高炉与设定误差 [-0.0016] [-0.00148584] 模型误差 [-0.0692] 校正值 [0.0683]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0198] 高炉 [0.0942] 高炉与设定误差 [-0.0009] [-0.07614174] 模型误差 [-0.0744] 校正值 [0.0735]
# 2设定 -0.5109 预测 [-0.5799] 高炉 [-0.5079] 高炉与设定误差 [-0.003] [-0.00278595] 模型误差 [-0.0721] 校正值 [0.0692]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.019] 高炉 [0.0952] 高炉与设定误差 [-0.002] [-0.16920389] 模型误差 [-0.0763] 校正值 [0.0744]
# 2设定 -0.5109 预测 [-0.5827] 高炉 [-0.5069] 高炉与设定误差 [-0.004] [-0.0037146] 模型误差 [-0.0758] 校正值 [0.0721]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0172] 高炉 [0.0925] 高炉与设定误差 [0.0007] [0.05922136] 模型误差 [-0.0754] 校正值 [0.0763]
# 2设定 -0.5109 预测 [-0.5863] 高炉 [-0.5029] 高炉与设定误差 [-0.008] [-0.0074292] 模型误差 [-0.0834] 校正值 [0.0758]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0178] 高炉 [0.0898] 高炉与设定误差 [0.0035] [0.2961068] 模型误差 [-0.072] 校正值 [0.0754]
# 2设定 -0.5109 预测 [-0.5935] 高炉 [-0.5108] 高炉与设定误差 [-1.e-04] [-9.28649977e-05] 模型误差 [-0.0827] 校正值 [0.0834]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0209] 高炉 [0.0934] 高炉与设定误差 [-1.e-04] [-0.00846019] 模型误差 [-0.0725] 校正值 [0.072]
# 2设定 -0.5109 预测 [-0.5936] 高炉 [-0.5128] 高炉与设定误差 [0.0019] [0.00176444] 模型误差 [-0.0808] 校正值 [0.0827]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0208] 高炉 [0.0975] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [-0.0767] 校正值 [0.0725]
# 2设定 -0.5109 预测 [-0.5919] 高炉 [-0.5102] 高炉与设定误差 [-0.0007] [-0.00065005] 模型误差 [-0.0817] 校正值 [0.0808]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.017] 高炉 [0.0922] 高炉与设定误差 [0.0011] [0.09306213] 模型误差 [-0.0751] 校正值 [0.0767]
# 2设定 -0.5109 预测 [-0.592] 高炉 [-0.5093] 高炉与设定误差 [-0.0016] [-0.00148584] 模型误差 [-0.0827] 校正值 [0.0817]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0175] 高炉 [0.0918] 高炉与设定误差 [0.0015] [0.12690291] 模型误差 [-0.0743] 校正值 [0.0751]
# 2设定 -0.5109 预测 [-0.5935] 高炉 [-0.511] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [-0.0825] 校正值 [0.0827]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0364] 高炉 [0.0963] 高炉与设定误差 [-0.003] [-0.25380582] 模型误差 [-0.0599] 校正值 [0.0743]
# 2设定 -0.597 预测 [-0.671] 高炉 [-0.5906] 高炉与设定误差 [-0.0065] [-0.00603623] 模型误差 [-0.0804] 校正值 [0.0825]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0337] 高炉 [0.0917] 高炉与设定误差 [0.0016] [0.1353631] 模型误差 [-0.058] 校正值 [0.0599]
# 2设定 -0.597 预测 [-0.6768] 高炉 [-0.5794] 高炉与设定误差 [-0.0176] [-0.01634424] 模型误差 [-0.0973] 校正值 [0.0804]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0351] 高炉 [0.0975] 高炉与设定误差 [-0.0042] [-0.35532814] 模型误差 [-0.0624] 校正值 [0.058]
# 2设定 -0.597 预测 [-0.6926] 高炉 [-0.5949] 高炉与设定误差 [-0.0022] [-0.00204303] 模型误差 [-0.0977] 校正值 [0.0973]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0313] 高炉 [0.092] 高炉与设定误差 [0.0012] [0.10152233] 模型误差 [-0.0607] 校正值 [0.0624]
# 2设定 -0.597 预测 [-0.6946] 高炉 [-0.5908] 高炉与设定误差 [-0.0063] [-0.0058505] 模型误差 [-0.1038] 校正值 [0.0977]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0324] 高炉 [0.0924] 高炉与设定误差 [0.0009] [0.07614174] 模型误差 [-0.0599] 校正值 [0.0607]
# 2设定 -0.597 预测 [-0.7002] 高炉 [-0.595] 高炉与设定误差 [-0.002] [-0.0018573] 模型误差 [-0.1051] 校正值 [0.1038]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0332] 高炉 [0.0927] 高炉与设定误差 [0.0005] [0.04230097] 模型误差 [-0.0595] 校正值 [0.0599]
# 2设定 -0.597 预测 [-0.702] 高炉 [-0.5966] 高炉与设定误差 [-0.0005] [-0.00046433] 模型误差 [-0.1054] 校正值 [0.1051]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0337] 高炉 [0.0932] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [-0.0595] 校正值 [0.0595]
# 2设定 -0.597 预测 [-0.7024] 高炉 [-0.5963] 高炉与设定误差 [-0.0007] [-0.00065005] 模型误差 [-0.1061] 校正值 [0.1054]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0337] 高炉 [0.0933] 高炉与设定误差 [-0.] [-0.] 模型误差 [-0.0596] 校正值 [0.0595]
# 2设定 -0.597 预测 [-0.703] 高炉 [-0.5965] 高炉与设定误差 [-0.0005] [-0.00046433] 模型误差 [-0.1065] 校正值 [0.1061]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0337] 高炉 [0.0929] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [-0.0592] 校正值 [0.0596]
# 2设定 -0.597 预测 [-0.7035] 高炉 [-0.5967] 高炉与设定误差 [-0.0004] [-0.00037146] 模型误差 [-0.1068] 校正值 [0.1065]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.034] 高炉 [0.0934] 高炉与设定误差 [-1.e-04] [-0.00846019] 模型误差 [-0.0594] 校正值 [0.0592]
# 2设定 -0.597 预测 [-0.7038] 高炉 [-0.5961] 高炉与设定误差 [-0.0009] [-0.00083578] 模型误差 [-0.1077] 校正值 [0.1068]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0339] 高炉 [0.0937] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [-0.0598] 校正值 [0.0594]
# 2设定 -0.597 预测 [-0.7047] 高炉 [-0.5969] 高炉与设定误差 [-1.e-04] [-9.28649977e-05] 模型误差 [-0.1077] 校正值 [0.1077]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0335] 高炉 [0.0934] 高炉与设定误差 [-1.e-04] [-0.00846019] 模型误差 [-0.0599] 校正值 [0.0598]
# 2设定 -0.597 预测 [-0.7048] 高炉 [-0.5967] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [-0.108] 校正值 [0.1077]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0332] 高炉 [0.0932] 高炉与设定误差 [0.] [0.] 模型误差 [-0.06] 校正值 [0.0599]
# 2设定 -0.597 预测 [-0.705] 高炉 [-0.5967] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [-0.1083] 校正值 [0.108]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0333] 高炉 [0.0929] 高炉与设定误差 [0.0003] [0.02538058] 模型误差 [-0.0597] 校正值 [0.06]
# 2设定 -0.597 预测 [-0.7053] 高炉 [-0.5966] 高炉与设定误差 [-0.0005] [-0.00046433] 模型误差 [-0.1087] 校正值 [0.1083]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 0.0933 预测 [0.0336] 高炉 [0.0932] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [-0.0596] 校正值 [0.0597]
# 2设定 -0.597 预测 [-0.7057] 高炉 [-0.5972] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [-0.1085] 校正值 [0.1087]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.14] 高炉 [0.1212] 高炉与设定误差 [0.0903] [7.63955528] 模型误差 [0.0188] 校正值 [0.0596]
# 2设定 -0.597 预测 [-0.7056] 高炉 [-0.6499] 高炉与设定误差 [0.0528] [0.04903272] 模型误差 [-0.0557] 校正值 [0.1085]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2132] 高炉 [0.1647] 高炉与设定误差 [0.0468] [3.95937068] 模型误差 [0.0485] 校正值 [-0.0188]
# 2设定 -0.597 预测 [-0.658] 高炉 [-0.676] 高炉与设定误差 [0.0789] [0.07327049] 模型误差 [0.0179] 校正值 [0.0557]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2553] 高炉 [0.2118] 高炉与设定误差 [-0.0003] [-0.02538058] 模型误差 [0.0435] 校正值 [-0.0485]
# 2设定 -0.597 预测 [-0.587] 高炉 [-0.6517] 高炉与设定误差 [0.0547] [0.05079715] 模型误差 [0.0647] 校正值 [-0.0179]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.255] 高炉 [0.2373] 高炉与设定误差 [-0.0259] [-2.19119031] 模型误差 [0.0177] 校正值 [-0.0435]
# 2设定 -0.597 预测 [-0.5637] 高炉 [-0.6515] 高炉与设定误差 [0.0545] [0.05061142] 模型误差 [0.0878] 校正值 [-0.0647]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2317] 高炉 [0.2234] 高炉与设定误差 [-0.012] [-1.01522329] 模型误差 [0.0083] 校正值 [-0.0177]
# 2设定 -0.597 预测 [-0.5147] 高炉 [-0.6183] 高炉与设定误差 [0.0212] [0.01968738] 模型误差 [0.1036] 校正值 [-0.0878]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.221] 高炉 [0.2181] 高炉与设定误差 [-0.0067] [-0.56683298] 模型误差 [0.0029] 校正值 [-0.0083]
# 2设定 -0.597 预测 [-0.4956] 高炉 [-0.5968] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [0.1012] 校正值 [-0.1036]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.215] 高炉 [0.2159] 高炉与设定误差 [-0.0044] [-0.37224853] 模型误差 [-0.0009] 校正值 [-0.0029]
# 2设定 -0.597 预测 [-0.4958] 高炉 [-0.5901] 高炉与设定误差 [-0.007] [-0.00650055] 模型误差 [0.0942] 校正值 [-0.1012]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.211] 高炉 [0.2006] 高炉与设定误差 [0.0109] [0.92216116] 模型误差 [0.0105] 校正值 [0.0009]
# 2设定 -0.597 预测 [-0.5021] 高炉 [-0.5915] 高炉与设定误差 [-0.0055] [-0.00510757] 模型误差 [0.0894] 校正值 [-0.0942]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2268] 高炉 [0.2137] 高炉与设定误差 [-0.0022] [-0.18612427] 模型误差 [0.0131] 校正值 [-0.0105]
# 2设定 -0.597 预测 [-0.5072] 高炉 [-0.5698] 高炉与设定误差 [-0.0272] [-0.02525928] 模型误差 [0.0626] 校正值 [-0.0894]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.2115 预测 [0.2248] 高炉 [0.214] 高炉与设定误差 [-0.0026] [-0.21996504] 模型误差 [0.0107] 校正值 [-0.0131]
# 2设定 -0.597 预测 [-0.5317] 高炉 [-0.5954] 高炉与设定误差 [-0.0017] [-0.00157871] 模型误差 [0.0637] 校正值 [-0.0626]

# %%
# 数据转换、
data_tranform_plot(scalers,Times ,max_control,
                        output_term,input_term,
                        set_y1,set_y2,set_y1_trans,set_y2_trans,
                        all_pred_y1, all_pred_y2,
                        all_pred_u1,
                        all_pred_u2,
                        all_pred_u3,
                        all_pred_u4)
# Out:
# 上线分别是：[2.00736825e+04 2.48731508e-04]、[3.37254652e+01 3.41094835e-06]、[ 4.32087465e-01 -2.78527280e-04]、[236.915       36.54472222]
# 平均误差 1.0955
# 平均误差 0.0163
