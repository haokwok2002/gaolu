# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")
from base import    double_control_predict_result,\
                    gaolu_predict_raw,\
                    data_tranform_plot,\
                    get_y_aim_data,\
                    generate_yr,\
                    replace_outliers_with_weighted_diff

from base import MyRNNModel,CustomPredictor_double

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\简单插值数据-时间戳.xlsx'
df_sheet = pd.read_excel(excel_path, sheet_name='Sheet2') 
print(df_sheet.info())
print(df_sheet.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7398 entries, 0 to 7397
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   时间戳         7398 non-null   int64
#  1   Unnamed: 1  7398 non-null   int64
#  2   SI          7398 non-null   float64
#  3   铁口1温度       7398 non-null   float64
#  4   富氧流量        7398 non-null   float64
#  5   冷风流量        7398 non-null   float64
#  6   热风压力        7398 non-null   float64
#  7   热风温度        7398 non-null   float64
#  8   鼓风湿度        7398 non-null   float64
#  9   设定喷煤量       7398 non-null   float64
#  10  上小时喷煤量      7398 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 635.9 KB
# None
# Index(['时间戳', 'Unnamed: 1', 'SI', '铁口1温度', '富氧流量', '冷风流量', '热风压力', '热风温度',
#        '鼓风湿度', '设定喷煤量', '上小时喷煤量'],
#       dtype='object')

# %%
# 定义输入输出参数
input_term = ['富氧流量', '冷风流量', '热风压力', '热风温度', '鼓风湿度', '设定喷煤量', '上小时喷煤量']
output_term = ['铁口1温度', 'SI']
time_term= '时间戳'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_process = df_sheet.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 1.5 * y.std()  # 使用标准差作为阈值
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value




# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[4]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[5]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[input_term[6]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[output_term[0]])
replace_outliers_with_weighted_diff(df_sheet_process['时间戳'], df_sheet_process[output_term[1]])

plt.figure(figsize=(15, 6))
for idx, column in enumerate(input_term+output_term):
    
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet[column].values,df_sheet_process[column].values,column)
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_18580\3007301193.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r*-', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 400


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 4))
for idx, column in enumerate(input_term+output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_process[time_term].values,df_sheet_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_process[input_term[0]].values,
    input_term[1]:   df_sheet_process[input_term[1]].values,
    input_term[2]:   df_sheet_process[input_term[2]].values,
    input_term[3]:   df_sheet_process[input_term[3]].values,
    input_term[4]:   df_sheet_process[input_term[4]].values,
    input_term[5]:   df_sheet_process[input_term[5]].values,
    input_term[6]:   df_sheet_process[input_term[6]].values,
    output_term[0]:  df_sheet_process[output_term[0]].values,
    output_term[1]:  df_sheet_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [0.05471948]
# [1500.]
# [0.18042565]
# [1510.]
# 每摄氏度的输出差： [0.01257062]
# [-0.52854026]
# [0.5]
# [-0.40998065]
# [0.6]
# 每0.01浓度的输出差： [0.11855962]

# %%
isShuffle = True
# isShuffle = False

# %%
# 组合训练数据--拆分训练、测试集
train_size = 0.7
val_size = 0.15
test_size = 0.15
# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,y1_data,y2_data):
    u1_data = u1_data
    u2_data = u2_data
    u3_data = u3_data
    u4_data = u4_data
    u5_data = u5_data
    u6_data = u6_data
    u7_data = u7_data

    y1_data = y1_data
    y2_data = y2_data

    X = np.column_stack((   u1_data  [1:-1], u2_data  [1:-1], u3_data  [1:-1], u4_data  [1:-1], u5_data  [1:-1], u6_data  [1:-1], u7_data  [1:-1],
                            u1_data  [0:-2], u2_data  [0:-2], u3_data  [0:-2], u4_data  [0:-2], u5_data  [0:-2], u6_data  [0:-2], u7_data  [0:-2],
                            y1_data  [0:-2], y2_data  [0:-2])
                        )
    y = np.column_stack((y1_data[1:-1],y2_data[1:-1]))

    # 使用 reshape 转换形状(457, 10) (457, 2)--->(457, 1, 10) (457, 1, 2)
    X_reshaped = X.reshape((X.shape[0], 1, X.shape[1]))
    y_reshaped = y.reshape((y.shape[0], 1, y.shape[1]))
    print('总数据数量：',y.shape)

    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_reshaped, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    y_train = y_train.reshape((y_train.shape[0],y_train.shape[2]))
    y_val = y_val.reshape((y_val.shape[0],y_val.shape[2]))
    y_test = y_test.reshape((y_test.shape[0],y_test.shape[2]))
    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]][index_gaolu]
u2_data = normalized_data_dict[input_term[1]][index_gaolu]
u3_data = normalized_data_dict[input_term[2]][index_gaolu]
u4_data = normalized_data_dict[input_term[3]][index_gaolu]
u5_data = normalized_data_dict[input_term[4]][index_gaolu]
u6_data = normalized_data_dict[input_term[5]][index_gaolu]
u7_data = normalized_data_dict[input_term[6]][index_gaolu]
y1_data = normalized_data_dict[output_term[0]][index_gaolu]
y2_data = normalized_data_dict[output_term[1]][index_gaolu]
num_samples = y1_data.shape[0]
print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,y1_data,y2_data)

# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]][index_predict]
u2_data = normalized_data_dict[input_term[1]][index_predict]
u3_data = normalized_data_dict[input_term[2]][index_predict]
u4_data = normalized_data_dict[input_term[3]][index_predict]
u5_data = normalized_data_dict[input_term[4]][index_predict]
u6_data = normalized_data_dict[input_term[5]][index_predict]
u7_data = normalized_data_dict[input_term[6]][index_predict]
y1_data = normalized_data_dict[output_term[0]][index_predict]
y2_data = normalized_data_dict[output_term[1]][index_predict]
num_samples = y1_data.shape[0]
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,y1_data,y2_data)
# Out:
# 高炉模型数据
# 总数据数量： (399, 2)
# 训练数量： (279, 1, 16) (279, 2)
# 验证数量： (60, 1, 16) (60, 2)
# 测试数量： (60, 1, 16) (60, 2)
# 预测模型数据
# 总数据数量： (399, 2)
# 训练数量： (279, 1, 16) (279, 2)
# 验证数量： (60, 1, 16) (60, 2)
# 测试数量： (60, 1, 16) (60, 2)

# %%
# 定义LSTM模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyRNNModel(torch.nn.Module):
    def __init__(self,features_size,hidden_size,isbidirectional):
        super(MyRNNModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size=features_size,
            hidden_size=hidden_size,
            batch_first=True,
            bidirectional=isbidirectional
        )
        if isbidirectional:
            self.fc = nn.Linear(2 * hidden_size, 2)
        else:
            self.fc = nn.Linear(hidden_size, 2)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        
        last_lstm_output = lstm_out[:, -1, :]
        # print(last_lstm_output)
        output = self.fc(last_lstm_output)
        
        return output

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse



    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
epoch_once_time = 25

# %%
# 建立高炉模型实例
features_size = 16
hidden_size = 16
# 设置随机种子
# torch.manual_seed(0)
model_gaolu = MyRNNModel(features_size = features_size, 
                        hidden_size = hidden_size,
                        isbidirectional=True)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 2/25 轮, 训练误差: 0.0940, 验证误差: 0.0623
# 第 25/25 轮, 训练误差: 0.0173, 验证误差: 0.0269
# epoch_sum: 25

# %%
# 高炉模型预测
y_pred_0,y_pred_1  = model_gaolu.my_predict(X_gaolu_test)
# 计算 RMSE、MRE
y_test = y_gaolu_test
# y_test = y_test[:70]
# y_pred_0 = y_pred_0[:70]
# y_pred_1 = y_pred_1[:70]

double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 9.6638 , SI: 0.0929
# MAPE:  铁口1温度: 0.5084% , SI: 17.2743%
# MRE :  铁口1温度: 0.0051  , SI: 0.1727
# per :  铁口1温度: 0.7167  , SI: 0.7500

# %%
# 创建预测模型实例
features_size = 16
hidden_size_predict = 16
# 设置随机种子
torch.manual_seed(0)
model = MyRNNModel(features_size = features_size, 
                    hidden_size = hidden_size_predict,
                    isbidirectional=True)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 25/25 轮, 训练误差: 0.0305, 验证误差: 0.0226
# epoch_sum: 0

# %%
# 预测模型预测
y_pred_0,y_pred_1  = model.my_predict(X_predict_test)

# 计算 RMSE、MRE
y_test = y_predict_test

double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁口1温度: 10.4126 , SI: 0.0675
# MAPE:  铁口1温度: 0.5589% , SI: 14.7104%
# MRE :  铁口1温度: 0.0056  , SI: 0.1471
# per :  铁口1温度: 0.6833  , SI: 0.8167

# %%
# 高炉、预测、原始对比
gaolu_predict_raw(scalers,output_term,model,model_gaolu,X_predict_test,y_predict_test)

# %%
iscontrol = True
# iscontrol = False

# %%
# 自定义预测
model_predict = model
hidden_size = hidden_size_predict
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def lstm_forward(input, initial_states, w_ih, w_hh, b_ih, b_hh):
    h_0, c_0 = initial_states  # 初始状态  [b_size, hidden_size]
    b_size, seq_len, input_size = input.shape
    h_size = h_0.shape[-1]

    h_prev, c_prev = h_0, c_0

    # 使用 np.newaxis 在第一个维度上插入一个新的维度  # 使用 np.tile 在第一个维度上复制 b_size 次
    w_ih_expanded = w_ih[np.newaxis, :, :]    
    w_ih_batch = np.tile(w_ih_expanded, (b_size, 1, 1))
    w_hh_expanded = w_hh[np.newaxis, :, :]    
    w_hh_batch = np.tile(w_hh_expanded, (b_size, 1, 1))
    # print(w_ih_batch.shape)

    output_size = h_size
    output = np.zeros((b_size, seq_len, output_size))  # 初始化一个输出序列
    for t in range(seq_len):
        x = input[:, t, :]  # 当前时刻的输入向量 [b,in_size]->[b,in_size,1]
        w_times_x = np.matmul(w_ih_batch, x[:, :, np.newaxis]).squeeze(-1)   # bmm:含有批量大小的矩阵相乘
        # [b, 4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Wii*xt|Wif*xt|Wig*xt|Wio*xt
        w_times_h_prev = np.matmul(w_hh_batch, h_prev[:, :, np.newaxis]).squeeze(-1)
        # [b, 4*hidden_size, hidden_size]*[b, hidden_size, 1]->[b,4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Whi*ht-1|Whf*ht-1|Whg*ht-1|Who*ht-1

        # 分别计算输入门(i)、遗忘门(f)、cell门(g)、输出门(o)  维度均为 [b, h_size]
        i_t = sigmoid(w_times_x[:, :h_size] + w_times_h_prev[:, :h_size] + b_ih[:h_size] + b_hh[:h_size])  # 取前四分之一
        f_t = sigmoid(w_times_x[:, h_size:2*h_size] + w_times_h_prev[:, h_size:2*h_size]
                            + b_ih[h_size:2*h_size] + b_hh[h_size:2*h_size])
        g_t = np.tanh(w_times_x[:, 2*h_size:3*h_size] + w_times_h_prev[:, 2*h_size:3*h_size]
                            + b_ih[2*h_size:3*h_size] + b_hh[2*h_size:3*h_size])
        o_t = sigmoid(w_times_x[:, 3*h_size:] + w_times_h_prev[:, 3*h_size:]
                            + b_ih[3*h_size:] + b_hh[3*h_size:])
        c_prev = f_t * c_prev + i_t * g_t
        h_prev = o_t * np.tanh(c_prev)

        output[:, t, :] = h_prev

    return output, (np.expand_dims(h_prev, axis=0), np.expand_dims(c_prev, axis=0))  # 官方是三维，在第0维扩一维



def predict_my(data_input):

    input = data_input  # 随机初始化一个输入序列
    c_0 = np.zeros((data_input.shape[0], hidden_size))  # 初始值，不会参与训练
    h_0 = np.zeros((data_input.shape[0], hidden_size))

    output_forward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0.detach().numpy())

    last_lstm_output_forward = output_forward[:, -1, :]

    output_backward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0_reverse.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0_reverse.detach().numpy())

    last_lstm_output_backward = output_backward[:, -1, :]
    # print(last_lstm_output_forward.shape)
    # print(last_lstm_output_backward.shape)
    # 最终输出
    combined_hidden = np.concatenate((last_lstm_output_forward, last_lstm_output_backward), axis=1)
    # print(combined_hidden.shape)


    output = (np.dot(combined_hidden, np.transpose(model_predict.fc.weight.detach().numpy()))
                + model_predict.fc.bias.detach().numpy()
)
    y_pred_0, y_pred_1= output[:,0],output[:,1]

    # y_pred_0 = scalers[output_term[0]].inverse_transform(np.array(y_pred_0).reshape(-1, 1)).flatten()
    # y_pred_1 = scalers[output_term[1]].inverse_transform(np.array(y_pred_1).reshape(-1, 1)).flatten()




    return y_pred_0, y_pred_1


y_pred_0, y_pred_1= predict_my(X_predict_test)


# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)
# plot_hit_rate_curve(y_test, y_pred_0.detach().numpy(), y_pred_1.detach().numpy())

# %%
# 生成期望数据
Times = 100

def generate_y_aim_data(Times):

    set_y1 = np.full(Times,1500)
    set_y1[30:] = 1510
    set_y1[60:] = 1505
    set_y1[90:] = 1515
    # set_y1[70:] = 1520
    # set_y1[90:] = 1525

    set_y2 = np.full(Times,0.44)
    set_y2[15:] = 0.48
    set_y2[45:] = 0.52
    set_y2[75:] = 0.44
    # 限制设定值在 -1 到 1 之间
    # set_y1 = np.clip(set_y1, -1, 1)
    # set_y2 = np.clip(set_y2, -1, 1)


    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# # 调用示例
# set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
# plt.plot(set_y1_trans)
# plt.plot(set_y2_trans)
# plt.title('y_sp')
# plt.show()

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]
    u5   = u2_data[randint  :randint+3  ]
    u6   = u3_data[randint  :randint+3  ]
    u7   = u4_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, u5, u6, u7, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):
    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]

    y1   = k_data[21:24]
    y2   = k_data[24:27]

    
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4, U5, U6, U7  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M], params[4*M:5*M],params[5*M:6*M], params[6*M:7*M]
    
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(u5.round(4))
        print(u6.round(4))
        print(u7.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = predict_my(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = predict_my(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = predict_my(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],u5[1:4],u6[1:4],u7[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    # y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    # y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    # u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    # u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    # u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    # u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)
    # u5_power = lamda2*np.sum((np.diff(u5[2:]))**2)
    # u6_power = lamda3*np.sum((np.diff(u6[2:]))**2)
    # u7_power = lamda4*np.sum((np.diff(u7[2:]))**2)

    y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            +u5_power
            +u6_power
            +u7_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
Times = 100

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 4  # 预测时域长度  增大P能平稳些
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, 
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
all_pred_u5 = []
all_pred_u6 = []
all_pred_u7 = []
# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    bounds = [(-max_control, max_control) for _ in range(7 * M)]
    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    U1, U2, U3, U4, U5, U6, U7 =    result.x[0:M], result.x[M:2*M], \
                                    result.x[2*M:3*M], result.x[3*M:4*M], \
                                    result.x[4*M:5*M], result.x[5*M:6*M], \
                                    result.x[6*M:7*M]
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]

    y1   = k_data[21:24]
    y2   = k_data[24:27]
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],u5[j+2],u6[j+2],u7[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],u5[j+1],u6[j+1],u7[j+1],
                            y1[j+1],y2[j+1]))
    x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model.my_predict(x)
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    


    # 更新k_data
    params = np.concatenate((U1, U2, U3, U4, U5, U6, U7),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    all_pred_u5.append(U5[0])
    all_pred_u6.append(U6[0])
    all_pred_u7.append(U7[0])
    k_data2[23] = y1_pred.item()
    k_data2[26] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 353
# (27,)
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [0.1364] 高炉 [0.2307] 高炉与设定误差 [-0.176] [-14.00090277] 模型误差 [-0.0943] 校正值 [-0.0917]
# 2设定 -0.5997 预测 [-0.3979] 高炉 [-0.3946] 高炉与设定误差 [-0.2051] [-0.17299313] 模型误差 [-0.0033] 校正值 [0.0354]
# 这是对第1时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0219] 高炉 [0.0478] 高炉与设定误差 [0.0069] [0.54889903] 模型误差 [-0.0697] 校正值 [0.0943]
# 2设定 -0.5997 预测 [-0.5824] 高炉 [-0.7778] 高炉与设定误差 [0.1781] [0.15021978] 模型误差 [0.1954] 校正值 [0.0033]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0157] 高炉 [0.1133] 高炉与设定误差 [-0.0586] [-4.66166433] 模型误差 [-0.129] 校正值 [0.0697]
# 2设定 -0.5997 预测 [-0.4221] 高炉 [-0.659] 高炉与设定误差 [0.0594] [0.05010138] 模型误差 [0.2369] 校正值 [-0.1954]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0337] 高炉 [0.1166] 高炉与设定误差 [-0.0619] [-4.92418125] 模型误差 [-0.1503] 校正值 [0.129]
# 2设定 -0.5997 预测 [-0.3687] 高炉 [-0.591] 高炉与设定误差 [-0.0086] [-0.00725373] 模型误差 [0.2223] 校正值 [-0.2369]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.089] 高炉 [0.1018] 高炉与设定误差 [-0.0471] [-3.74683253] 模型误差 [-0.1908] 校正值 [0.1503]
# 2设定 -0.5997 预测 [-0.3763] 高炉 [-0.5782] 高炉与设定误差 [-0.0215] [-0.01813434] 模型误差 [0.2018] 校正值 [-0.2223]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1311] 高炉 [0.0539] 高炉与设定误差 [0.0008] [0.06364047] 模型误差 [-0.185] 校正值 [0.1908]
# 2设定 -0.5997 预测 [-0.3957] 高炉 [-0.5813] 高炉与设定误差 [-0.0184] [-0.01551962] 模型误差 [0.1856] 校正值 [-0.2018]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1088] 高炉 [0.1016] 高炉与设定误差 [-0.0469] [-3.73092244] 模型误差 [-0.2104] 校正值 [0.185]
# 2设定 -0.5997 预测 [-0.4122] 高炉 [-0.5784] 高炉与设定误差 [-0.0213] [-0.01796564] 模型误差 [0.1662] 校正值 [-0.1856]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1013] 高炉 [0.097] 高炉与设定误差 [-0.0423] [-3.36498978] 模型误差 [-0.1983] 校正值 [0.2104]
# 2设定 -0.5997 预测 [-0.432] 高炉 [-0.6053] 高炉与设定误差 [0.0056] [0.00472336] 模型误差 [0.1733] 校正值 [-0.1662]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1379] 高炉 [0.0709] 高炉与设定误差 [-0.0161] [-1.28076446] 模型误差 [-0.2088] 校正值 [0.1983]
# 2设定 -0.5997 预测 [-0.4267] 高炉 [-0.6143] 高炉与设定误差 [0.0146] [0.01231448] 模型误差 [0.1876] 校正值 [-0.1733]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1525] 高炉 [0.0556] 高炉与设定误差 [-0.0009] [-0.07159552] 模型误差 [-0.2081] 校正值 [0.2088]
# 2设定 -0.5997 预测 [-0.4135] 高炉 [-0.601] 高炉与设定误差 [0.0013] [0.00109649] 模型误差 [0.1874] 校正值 [-0.1876]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1246] 高炉 [0.0789] 高炉与设定误差 [-0.0242] [-1.92512413] 模型误差 [-0.2036] 校正值 [0.2081]
# 2设定 -0.5997 预测 [-0.4124] 高炉 [-0.5905] 高炉与设定误差 [-0.0091] [-0.00767546] 模型误差 [0.1781] 校正值 [-0.1874]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1464] 高炉 [0.0669] 高炉与设定误差 [-0.0121] [-0.96256207] 模型误差 [-0.2133] 校正值 [0.2036]
# 2设定 -0.5997 预测 [-0.4206] 高炉 [-0.5954] 高炉与设定误差 [-0.0042] [-0.00354252] 模型误差 [0.1748] 校正值 [-0.1781]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1465] 高炉 [0.0568] 高炉与设定误差 [-0.0021] [-0.16705622] 模型误差 [-0.2033] 校正值 [0.2133]
# 2设定 -0.5997 预测 [-0.4223] 高炉 [-0.6041] 高炉与设定误差 [0.0044] [0.00371121] 模型误差 [0.1817] 校正值 [-0.1748]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1484] 高炉 [0.0458] 高炉与设定误差 [0.0089] [0.70800018] 模型误差 [-0.1943] 校正值 [0.2033]
# 2设定 -0.5997 预测 [-0.4184] 高炉 [-0.6063] 高炉与设定误差 [0.0067] [0.00565117] 模型误差 [0.1879] 校正值 [-0.1817]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1405] 高炉 [0.0593] 高炉与设定误差 [-0.0046] [-0.3659327] 模型误差 [-0.1998] 校正值 [0.1943]
# 2设定 -0.5997 预测 [-0.4138] 高炉 [-0.5932] 高炉与设定误差 [-0.0065] [-0.00548247] 模型误差 [0.1794] 校正值 [-0.1879]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1446] 高炉 [0.0365] 高炉与设定误差 [0.0183] [1.45577574] 模型误差 [-0.1811] 校正值 [0.1998]
# 2设定 -0.5523 预测 [-0.3769] 高炉 [-0.5997] 高炉与设定误差 [0.0474] [0.03997989] 模型误差 [0.2228] 校正值 [-0.1794]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1297] 高炉 [0.056] 高炉与设定误差 [-0.0013] [-0.10341576] 模型误差 [-0.1857] 校正值 [0.1811]
# 2设定 -0.5523 预测 [-0.3342] 高炉 [-0.5776] 高炉与设定误差 [0.0253] [0.02133947] 模型误差 [0.2433] 校正值 [-0.2228]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1311] 高炉 [0.0483] 高炉与设定误差 [0.0064] [0.50912373] 模型误差 [-0.1794] 校正值 [0.1857]
# 2设定 -0.5523 预测 [-0.3102] 高炉 [-0.5462] 高炉与设定误差 [-0.006] [-0.00506075] 模型误差 [0.236] 校正值 [-0.2433]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1253] 高炉 [0.0583] 高炉与设定误差 [-0.0036] [-0.2863821] 模型误差 [-0.1837] 校正值 [0.1794]
# 2设定 -0.5523 预测 [-0.3156] 高炉 [-0.5372] 高炉与设定误差 [-0.015] [-0.01265186] 模型误差 [0.2216] 校正值 [-0.236]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1286] 高炉 [0.0552] 高炉与设定误差 [-0.0005] [-0.03977529] 模型误差 [-0.1838] 校正值 [0.1837]
# 2设定 -0.5523 预测 [-0.3291] 高炉 [-0.5441] 高炉与设定误差 [-0.0081] [-0.00683201] 模型误差 [0.215] 校正值 [-0.2216]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.129] 高炉 [0.0588] 高炉与设定误差 [-0.0041] [-0.3261574] 模型误差 [-0.1879] 校正值 [0.1838]
# 2设定 -0.5523 预测 [-0.3364] 高炉 [-0.5483] 高炉与设定误差 [-0.0039] [-0.00328948] 模型误差 [0.2119] 校正值 [-0.215]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1327] 高炉 [0.0503] 高炉与设定误差 [0.0045] [0.35797761] 模型误差 [-0.183] 校正值 [0.1879]
# 2设定 -0.5523 预测 [-0.332] 高炉 [-0.5486] 高炉与设定误差 [-0.0036] [-0.00303645] 模型误差 [0.2166] 校正值 [-0.2119]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1237] 高炉 [0.0662] 高炉与设定误差 [-0.0115] [-0.91483172] 模型误差 [-0.1899] 校正值 [0.183]
# 2设定 -0.5523 预测 [-0.3354] 高炉 [-0.5458] 高炉与设定误差 [-0.0065] [-0.00548247] 模型误差 [0.2104] 校正值 [-0.2166]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.134] 高炉 [0.0519] 高炉与设定误差 [0.0028] [0.22274163] 模型误差 [-0.1859] 校正值 [0.1899]
# 2设定 -0.5523 预测 [-0.3412] 高炉 [-0.5521] 高炉与设定误差 [-1.e-04] [-8.43457479e-05] 模型误差 [0.2109] 校正值 [-0.2104]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1208] 高炉 [0.0703] 高炉与设定误差 [-0.0156] [-1.24098908] 模型误差 [-0.1911] 校正值 [0.1859]
# 2设定 -0.5523 预测 [-0.3408] 高炉 [-0.5507] 高炉与设定误差 [-0.0016] [-0.00134953] 模型误差 [0.2098] 校正值 [-0.2109]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1159] 高炉 [0.0697] 高炉与设定误差 [-0.015] [-1.19325874] 模型误差 [-0.1857] 校正值 [0.1911]
# 2设定 -0.5523 预测 [-0.3423] 高炉 [-0.5571] 高炉与设定误差 [0.0048] [0.0040486] 模型误差 [0.2148] 校正值 [-0.2098]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1295] 高炉 [0.0578] 高炉与设定误差 [-0.0031] [-0.24660682] 模型误差 [-0.1873] 校正值 [0.1857]
# 2设定 -0.5523 预测 [-0.338] 高炉 [-0.5557] 高炉与设定误差 [0.0035] [0.0029521] 模型误差 [0.2177] 校正值 [-0.2148]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1322] 高炉 [0.0535] 高炉与设定误差 [0.0012] [0.09546071] 模型误差 [-0.1858] 校正值 [0.1873]
# 2设定 -0.5523 预测 [-0.3349] 高炉 [-0.5492] 高炉与设定误差 [-0.0031] [-0.00261472] 模型误差 [0.2143] 校正值 [-0.2177]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1312] 高炉 [0.0578] 高炉与设定误差 [-0.0031] [-0.24660682] 模型误差 [-0.189] 校正值 [0.1858]
# 2设定 -0.5523 预测 [-0.3405] 高炉 [-0.5481] 高炉与设定误差 [-0.0042] [-0.00354252] 模型误差 [0.2076] 校正值 [-0.2143]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1351] 高炉 [0.0524] 高炉与设定误差 [0.0023] [0.18296635] 模型误差 [-0.1876] 校正值 [0.189]
# 2设定 -0.5523 预测 [-0.3446] 高炉 [-0.5502] 高炉与设定误差 [-0.002] [-0.00168692] 模型误差 [0.2056] 校正值 [-0.2076]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [-0.028] 高炉 [0.1696] 高炉与设定误差 [0.0108] [0.85914633] 模型误差 [-0.1976] 校正值 [0.1876]
# 2设定 -0.5523 预测 [-0.3465] 高炉 [-0.5332] 高炉与设定误差 [-0.019] [-0.01602569] 模型误差 [0.1868] 校正值 [-0.2056]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [-0.0183] 高炉 [0.1451] 高炉与设定误差 [0.0353] [2.80813575] 模型误差 [-0.1634] 校正值 [0.1976]
# 2设定 -0.5523 预测 [-0.3636] 高炉 [-0.5618] 高炉与设定误差 [0.0095] [0.00801285] 模型误差 [0.1982] 校正值 [-0.1868]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0135] 高炉 [0.183] 高炉与设定误差 [-0.0026] [-0.20683152] 模型误差 [-0.1695] 校正值 [0.1634]
# 2设定 -0.5523 预测 [-0.355] 高炉 [-0.5487] 高炉与设定误差 [-0.0036] [-0.00303645] 模型误差 [0.1937] 校正值 [-0.1982]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0112] 高炉 [0.1716] 高炉与设定误差 [0.0089] [0.70800018] 模型误差 [-0.1604] 校正值 [0.1695]
# 2设定 -0.5523 预测 [-0.3582] 高炉 [-0.5566] 高炉与设定误差 [0.0044] [0.00371121] 模型误差 [0.1984] 校正值 [-0.1937]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0076] 高炉 [0.1664] 高炉与设定误差 [0.014] [1.11370822] 模型误差 [-0.1589] 校正值 [0.1604]
# 2设定 -0.5523 预测 [-0.3543] 高炉 [-0.5538] 高炉与设定误差 [0.0016] [0.00134953] 模型误差 [0.1995] 校正值 [-0.1984]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0205] 高炉 [0.1842] 高炉与设定误差 [-0.0038] [-0.30229223] 模型误差 [-0.1637] 校正值 [0.1589]
# 2设定 -0.5523 预测 [-0.3517] 高炉 [-0.5427] 高炉与设定误差 [-0.0096] [-0.00809719] 模型误差 [0.191] 校正值 [-0.1995]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0177] 高炉 [0.1682] 高炉与设定误差 [0.0122] [0.97051711] 模型误差 [-0.1505] 校正值 [0.1637]
# 2设定 -0.5523 预测 [-0.3567] 高炉 [-0.5488] 高炉与设定误差 [-0.0034] [-0.00286776] 模型误差 [0.1921] 校正值 [-0.191]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0223] 高炉 [0.191] 高炉与设定误差 [-0.0105] [-0.83528112] 模型误差 [-0.1687] 校正值 [0.1505]
# 2设定 -0.5523 预测 [-0.3595] 高炉 [-0.5466] 高炉与设定误差 [-0.0056] [-0.00472336] 模型误差 [0.1871] 校正值 [-0.1921]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0212] 高炉 [0.1793] 高炉与设定误差 [0.0011] [0.08750564] 模型误差 [-0.1581] 校正值 [0.1687]
# 2设定 -0.5523 预测 [-0.3646] 高炉 [-0.5568] 高炉与设定误差 [0.0046] [0.0038799] 模型误差 [0.1922] 校正值 [-0.1871]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0221] 高炉 [0.1843] 高炉与设定误差 [-0.0038] [-0.30229223] 模型误差 [-0.1622] 校正值 [0.1581]
# 2设定 -0.5523 预测 [-0.3594] 高炉 [-0.5534] 高炉与设定误差 [0.0011] [0.0009278] 模型误差 [0.194] 校正值 [-0.1922]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0187] 高炉 [0.1686] 高炉与设定误差 [0.0118] [0.93869693] 模型误差 [-0.15] 校正值 [0.1622]
# 2设定 -0.5523 预测 [-0.3584] 高炉 [-0.5558] 高炉与设定误差 [0.0035] [0.0029521] 模型误差 [0.1974] 校正值 [-0.194]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0293] 高炉 [0.1924] 高炉与设定误差 [-0.0119] [-0.94665198] 模型误差 [-0.1631] 校正值 [0.15]
# 2设定 -0.5523 预测 [-0.356] 高炉 [-0.5454] 高炉与设定误差 [-0.0068] [-0.00573551] 模型误差 [0.1894] 校正值 [-0.1974]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0185] 高炉 [0.1782] 高炉与设定误差 [0.0022] [0.17501128] 模型误差 [-0.1597] 校正值 [0.1631]
# 2设定 -0.5523 预测 [-0.3622] 高炉 [-0.5553] 高炉与设定误差 [0.0031] [0.00261472] 模型误差 [0.1932] 校正值 [-0.1894]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0205] 高炉 [0.1774] 高炉与设定误差 [0.003] [0.23865176] 模型误差 [-0.1569] 校正值 [0.1597]
# 2设定 -0.5523 预测 [-0.3594] 高炉 [-0.5653] 高炉与设定误差 [0.0131] [0.01104929] 模型误差 [0.2059] 校正值 [-0.1932]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0159] 高炉 [0.1726] 高炉与设定误差 [0.0078] [0.62049454] 模型误差 [-0.1567] 校正值 [0.1569]
# 2设定 -0.5523 预测 [-0.3943] 高炉 [-0.5651] 高炉与设定误差 [0.0128] [0.01079626] 模型误差 [0.1708] 校正值 [-0.2059]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.023] 高炉 [0.1865] 高炉与设定误差 [-0.006] [-0.47730351] 模型误差 [-0.1635] 校正值 [0.1567]
# 2设定 -0.5048 预测 [-0.34] 高炉 [-0.5736] 高炉与设定误差 [0.0688] [0.05802988] 模型误差 [0.2336] 校正值 [-0.1708]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0175] 高炉 [0.167] 高炉与设定误差 [0.0134] [1.0659778] 模型误差 [-0.1495] 校正值 [0.1635]
# 2设定 -0.5048 预测 [-0.2809] 高炉 [-0.532] 高炉与设定误差 [0.0272] [0.02294204] 模型误差 [0.251] 校正值 [-0.2336]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.019] 高炉 [0.1901] 高炉与设定误差 [-0.0097] [-0.77164069] 模型误差 [-0.1711] 校正值 [0.1495]
# 2设定 -0.5048 预测 [-0.2568] 高炉 [-0.4952] 高炉与设定误差 [-0.0096] [-0.00809719] 模型误差 [0.2385] 校正值 [-0.251]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0103] 高炉 [0.1772] 高炉与设定误差 [0.0032] [0.25456186] 模型误差 [-0.167] 校正值 [0.1711]
# 2设定 -0.5048 预测 [-0.2654] 高炉 [-0.5023] 高炉与设定误差 [-0.0026] [-0.00219299] 模型误差 [0.2368] 校正值 [-0.2385]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0124] 高炉 [0.1641] 高炉与设定误差 [0.0163] [1.29667455] 模型误差 [-0.1517] 校正值 [0.167]
# 2设定 -0.5048 预测 [-0.2677] 高炉 [-0.5128] 高炉与设定误差 [0.008] [0.00674766] 模型误差 [0.2451] 校正值 [-0.2368]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0271] 高炉 [0.1868] 高炉与设定误差 [-0.0063] [-0.50116868] 模型误差 [-0.1597] 校正值 [0.1517]
# 2设定 -0.5048 预测 [-0.2605] 高炉 [-0.5016] 高炉与设定误差 [-0.0032] [-0.00269906] 模型误差 [0.2411] 校正值 [-0.2451]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0214] 高炉 [0.1903] 高炉与设定误差 [-0.0099] [-0.78755078] 模型误差 [-0.1689] 校正值 [0.1597]
# 2设定 -0.5048 预测 [-0.2634] 高炉 [-0.4991] 高炉与设定误差 [-0.0057] [-0.00480771] 模型误差 [0.2357] 校正值 [-0.2411]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0125] 高炉 [0.1632] 高炉与设定误差 [0.0173] [1.37622514] 模型误差 [-0.1507] 校正值 [0.1689]
# 2设定 -0.5048 预测 [-0.2686] 高炉 [-0.5108] 高炉与设定误差 [0.006] [0.00506075] 模型误差 [0.2423] 校正值 [-0.2357]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0288] 高炉 [0.185] 高炉与设定误差 [-0.0046] [-0.3659327] 模型误差 [-0.1562] 校正值 [0.1507]
# 2设定 -0.5048 预测 [-0.2632] 高炉 [-0.5035] 高炉与设定误差 [-0.0013] [-0.00109649] 模型误差 [0.2403] 校正值 [-0.2423]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0246] 高炉 [0.1972] 高炉与设定误差 [-0.0168] [-1.33644977] 模型误差 [-0.1725] 校正值 [0.1562]
# 2设定 -0.5048 预测 [-0.2643] 高炉 [-0.4971] 高炉与设定误差 [-0.0077] [-0.00649462] 模型误差 [0.2328] 校正值 [-0.2403]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0096] 高炉 [0.1748] 高炉与设定误差 [0.0056] [0.44548326] 模型误差 [-0.1652] 校正值 [0.1725]
# 2设定 -0.5048 预测 [-0.2713] 高炉 [-0.5098] 高炉与设定误差 [0.0049] [0.00413294] 模型误差 [0.2385] 校正值 [-0.2328]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0146] 高炉 [0.1691] 高炉与设定误差 [0.0114] [0.90687668] 模型误差 [-0.1544] 校正值 [0.1652]
# 2设定 -0.5048 预测 [-0.2668] 高炉 [-0.5164] 高炉与设定误差 [0.0115] [0.00969976] 模型误差 [0.2495] 校正值 [-0.2385]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0248] 高炉 [0.2008] 高炉与设定误差 [-0.0204] [-1.62283198] 模型误差 [-0.176] 校正值 [0.1544]
# 2设定 -0.5048 预测 [-0.2565] 高炉 [-0.4954] 高炉与设定误差 [-0.0094] [-0.0079285] 模型误差 [0.239] 校正值 [-0.2495]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0065] 高炉 [0.1718] 高炉与设定误差 [0.0087] [0.69209009] 模型误差 [-0.1653] 校正值 [0.176]
# 2设定 -0.5048 预测 [-0.2649] 高炉 [-0.5132] 高炉与设定误差 [0.0084] [0.00708504] 模型误差 [0.2483] 校正值 [-0.239]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0143] 高炉 [0.1707] 高炉与设定误差 [0.0097] [0.77164069] 模型误差 [-0.1564] 校正值 [0.1653]
# 2设定 -0.5048 预测 [-0.2573] 高炉 [-0.5102] 高炉与设定误差 [0.0054] [0.00455467] 模型误差 [0.2529] 校正值 [-0.2483]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0335] 高炉 [0.1224] 高炉与设定误差 [-0.0048] [-0.38184282] 模型误差 [-0.1559] 校正值 [0.1564]
# 2设定 -0.5048 预测 [-0.2525] 高炉 [-0.5055] 高炉与设定误差 [0.0006] [0.00050607] 模型误差 [0.253] 校正值 [-0.2529]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0378] 高炉 [0.1129] 高炉与设定误差 [0.0047] [0.37388774] 模型误差 [-0.1507] 校正值 [0.1559]
# 2设定 -0.5048 预测 [-0.2519] 高炉 [-0.5001] 高炉与设定误差 [-0.0047] [-0.00396425] 模型误差 [0.2482] 校正值 [-0.253]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0243] 高炉 [0.1243] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1486] 校正值 [0.1507]
# 2设定 -0.5048 预测 [-0.2562] 高炉 [-0.4969] 高炉与设定误差 [-0.0079] [-0.00666331] 模型误差 [0.2408] 校正值 [-0.2482]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0236] 高炉 [0.1254] 高炉与设定误差 [-0.0078] [-0.62049454] 模型误差 [-0.149] 校正值 [0.1486]
# 2设定 -0.5048 预测 [-0.263] 高炉 [-0.5012] 高炉与设定误差 [-0.0036] [-0.00303645] 模型误差 [0.2382] 校正值 [-0.2408]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0306] 高炉 [0.1202] 高炉与设定误差 [-0.0026] [-0.20683152] 模型误差 [-0.1508] 校正值 [0.149]
# 2设定 -0.5048 预测 [-0.2663] 高炉 [-0.5062] 高炉与设定误差 [0.0014] [0.00118084] 模型误差 [0.2399] 校正值 [-0.2382]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.033] 高炉 [0.1144] 高炉与设定误差 [0.0031] [0.24660682] 模型误差 [-0.1474] 校正值 [0.1508]
# 2设定 -0.5048 预测 [-0.265] 高炉 [-0.5063] 高炉与设定误差 [0.0015] [0.00126519] 模型误差 [0.2413] 校正值 [-0.2399]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0302] 高炉 [0.1163] 高炉与设定误差 [0.0012] [0.09546071] 模型误差 [-0.1465] 校正值 [0.1474]
# 2设定 -0.5048 预测 [-0.2637] 高炉 [-0.5025] 高炉与设定误差 [-0.0023] [-0.00193995] 模型误差 [0.2388] 校正值 [-0.2413]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0291] 高炉 [0.1186] 高炉与设定误差 [-0.001] [-0.07955059] 模型误差 [-0.1477] 校正值 [0.1465]
# 2设定 -0.5048 预测 [-0.2658] 高炉 [-0.5044] 高炉与设定误差 [-0.0004] [-0.00033738] 模型误差 [0.2386] 校正值 [-0.2388]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.03] 高炉 [0.117] 高炉与设定误差 [0.0005] [0.03977529] 模型误差 [-0.147] 校正值 [0.1477]
# 2设定 -0.5048 预测 [-0.2662] 高炉 [-0.5055] 高炉与设定误差 [0.0007] [0.00059042] 模型误差 [0.2393] 校正值 [-0.2386]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0295] 高炉 [0.1161] 高炉与设定误差 [0.0015] [0.11932588] 模型误差 [-0.1456] 校正值 [0.147]
# 2设定 -0.5048 预测 [-0.2656] 高炉 [-0.5024] 高炉与设定误差 [-0.0024] [-0.0020243] 模型误差 [0.2368] 校正值 [-0.2393]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0282] 高炉 [0.1211] 高炉与设定误差 [-0.0035] [-0.27842705] 模型误差 [-0.1493] 校正值 [0.1456]
# 2设定 -0.5048 预测 [-0.2672] 高炉 [-0.508] 高炉与设定误差 [0.0031] [0.00261472] 模型误差 [0.2408] 校正值 [-0.2368]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0313] 高炉 [0.1111] 高炉与设定误差 [0.0065] [0.51707881] 模型误差 [-0.1424] 校正值 [0.1493]
# 2设定 -0.5048 预测 [-0.2643] 高炉 [-0.5053] 高炉与设定误差 [0.0004] [0.00033738] 模型误差 [0.2409] 校正值 [-0.2408]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0255] 高炉 [0.1222] 高炉与设定误差 [-0.0046] [-0.3659327] 模型误差 [-0.1476] 校正值 [0.1424]
# 2设定 -0.5048 预测 [-0.264] 高炉 [-0.5073] 高炉与设定误差 [0.0025] [0.00210864] 模型误差 [0.2433] 校正值 [-0.2409]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0288] 高炉 [0.1217] 高炉与设定误差 [-0.0042] [-0.33411244] 模型误差 [-0.1506] 校正值 [0.1476]
# 2设定 -0.5048 预测 [-0.2617] 高炉 [-0.5068] 高炉与设定误差 [0.002] [0.00168692] 模型误差 [0.2451] 校正值 [-0.2433]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0326] 高炉 [0.1135] 高炉与设定误差 [0.004] [0.31820235] 模型误差 [-0.1461] 校正值 [0.1506]
# 2设定 -0.5048 预测 [-0.2599] 高炉 [-0.5054] 高炉与设定误差 [0.0006] [0.00050607] 模型误差 [0.2455] 校正值 [-0.2451]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.029] 高炉 [0.1431] 高炉与设定误差 [-0.0255] [-2.02853986] 模型误差 [-0.1721] 校正值 [0.1461]
# 2设定 -0.5997 预测 [-0.3448] 高炉 [-0.5108] 高炉与设定误差 [-0.0889] [-0.07498337] 模型误差 [0.166] 校正值 [-0.2455]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0519] 高炉 [0.1261] 高炉与设定误差 [-0.0086] [-0.68413505] 模型误差 [-0.1781] 校正值 [0.1721]
# 2设定 -0.5997 预测 [-0.4248] 高炉 [-0.5631] 高炉与设定误差 [-0.0366] [-0.03087055] 模型误差 [0.1383] 校正值 [-0.166]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0596] 高炉 [0.1188] 高炉与设定误差 [-0.0012] [-0.09546071] 模型误差 [-0.1785] 校正值 [0.1781]
# 2设定 -0.5997 预测 [-0.4577] 高炉 [-0.5883] 高炉与设定误差 [-0.0114] [-0.00961542] 模型误差 [0.1306] 校正值 [-0.1383]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0602] 高炉 [0.1149] 高炉与设定误差 [0.0027] [0.21478658] 模型误差 [-0.1751] 校正值 [0.1785]
# 2设定 -0.5997 预测 [-0.4607] 高炉 [-0.6071] 高炉与设定误差 [0.0074] [0.00624159] 模型误差 [0.1464] 校正值 [-0.1306]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0578] 高炉 [0.1232] 高炉与设定误差 [-0.0056] [-0.44548326] 模型误差 [-0.181] 校正值 [0.1751]
# 2设定 -0.5997 预测 [-0.454] 高炉 [-0.6082] 高炉与设定误差 [0.0085] [0.00716939] 模型误差 [0.1542] 校正值 [-0.1464]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0628] 高炉 [0.1014] 高炉与设定误差 [0.0162] [1.2887195] 模型误差 [-0.1642] 校正值 [0.181]
# 2设定 -0.5997 预测 [-0.4463] 高炉 [-0.5992] 高炉与设定误差 [-0.0005] [-0.00042173] 模型误差 [0.1529] 校正值 [-0.1542]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0483] 高炉 [0.1291] 高炉与设定误差 [-0.0115] [-0.91483172] 模型误差 [-0.1774] 校正值 [0.1642]
# 2设定 -0.5997 预测 [-0.4468] 高炉 [-0.5829] 高炉与设定误差 [-0.0168] [-0.01417009] 模型误差 [0.1361] 校正值 [-0.1529]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0587] 高炉 [0.1297] 高炉与设定误差 [-0.0121] [-0.96256207] 模型误差 [-0.1883] 校正值 [0.1774]
# 2设定 -0.5997 预测 [-0.4619] 高炉 [-0.5894] 高炉与设定误差 [-0.0103] [-0.00868761] 模型误差 [0.1275] 校正值 [-0.1361]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0695] 高炉 [0.0965] 高炉与设定误差 [0.0211] [1.67851729] 模型误差 [-0.166] 校正值 [0.1883]
# 2设定 -0.5997 预测 [-0.4712] 高炉 [-0.5978] 高炉与设定误差 [-0.0019] [-0.00160257] 模型误差 [0.1266] 校正值 [-0.1275]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0505] 高炉 [0.1413] 高炉与设定误差 [-0.0237] [-1.88534891] 模型误差 [-0.1918] 校正值 [0.166]
# 2设定 -0.5997 预测 [-0.4729] 高炉 [-0.6092] 高炉与设定误差 [0.0095] [0.00801285] 模型误差 [0.1363] 校正值 [-0.1266]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0719] 高炉 [0.0988] 高炉与设定误差 [0.0188] [1.49555096] 模型误差 [-0.1707] 校正值 [0.1918]
# 2设定 -0.5997 预测 [-0.4643] 高炉 [-0.6378] 高炉与设定误差 [0.0382] [0.03222008] 模型误差 [0.1735] 校正值 [-0.1363]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.055] 高炉 [0.1328] 高炉与设定误差 [-0.0153] [-1.21712395] 模型误差 [-0.1878] 校正值 [0.1707]
# 2设定 -0.5997 预测 [-0.43] 高炉 [-0.5981] 高炉与设定误差 [-0.0016] [-0.00134953] 模型误差 [0.1681] 校正值 [-0.1735]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0687] 高炉 [0.109] 高炉与设定误差 [0.0085] [0.67618] 模型误差 [-0.1777] 校正值 [0.1878]
# 2设定 -0.5997 预测 [-0.4314] 高炉 [-0.6013] 高炉与设定误差 [0.0016] [0.00134953] 模型误差 [0.1699] 校正值 [-0.1681]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.061] 高炉 [0.1246] 高炉与设定误差 [-0.007] [-0.55685411] 模型误差 [-0.1855] 校正值 [0.1777]
# 2设定 -0.5997 预测 [-0.4299] 高炉 [-0.5896] 高炉与设定误差 [-0.01] [-0.00843457] 模型误差 [0.1597] 校正值 [-0.1699]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0673] 高炉 [0.1103] 高炉与设定误差 [0.0072] [0.5727642] 模型误差 [-0.1776] 校正值 [0.1855]
# 2设定 -0.5997 预测 [-0.439] 高炉 [-0.5818] 高炉与设定误差 [-0.0179] [-0.01509789] 模型误差 [0.1428] 校正值 [-0.1597]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0524] 高炉 [0.2529] 高炉与设定误差 [-0.0096] [-0.76368565] 模型误差 [-0.2005] 校正值 [0.1776]
# 2设定 -0.5997 预测 [-0.4551] 高炉 [-0.5692] 高炉与设定误差 [-0.0305] [-0.02572545] 模型误差 [0.1141] 校正值 [-0.1428]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0438] 高炉 [0.1953] 高炉与设定误差 [0.048] [3.81842808] 模型误差 [-0.1515] 校正值 [0.2005]
# 2设定 -0.5997 预测 [-0.4861] 高炉 [-0.6237] 高炉与设定误差 [0.024] [0.02024298] 模型误差 [0.1376] 校正值 [-0.1141]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0821] 高炉 [0.2529] 高炉与设定误差 [-0.0096] [-0.76368565] 模型误差 [-0.1708] 校正值 [0.1515]
# 2设定 -0.5997 预测 [-0.4658] 高炉 [-0.5904] 高炉与设定误差 [-0.0093] [-0.00784415] 模型误差 [0.1246] 校正值 [-0.1376]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0734] 高炉 [0.2204] 高炉与设定误差 [0.0229] [1.8217084] 模型误差 [-0.1469] 校正值 [0.1708]
# 2设定 -0.5997 预测 [-0.4741] 高炉 [-0.604] 高炉与设定误差 [0.0043] [0.00362687] 模型误差 [0.1299] 校正值 [-0.1246]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0941] 高炉 [0.2522] 高炉与设定误差 [-0.0089] [-0.70800018] 模型误差 [-0.1581] 校正值 [0.1469]
# 2设定 -0.5997 预测 [-0.4704] 高炉 [-0.5907] 高炉与设定误差 [-0.009] [-0.00759112] 模型误差 [0.1203] 校正值 [-0.1299]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0861] 高炉 [0.2348] 高炉与设定误差 [0.0085] [0.67618] 模型误差 [-0.1487] 校正值 [0.1581]
# 2设定 -0.5997 预测 [-0.4785] 高炉 [-0.6042] 高炉与设定误差 [0.0045] [0.00379556] 模型误差 [0.1257] 校正值 [-0.1203]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0937] 高炉 [0.2477] 高炉与设定误差 [-0.0044] [-0.35002257] 模型误差 [-0.154] 校正值 [0.1487]
# 2设定 -0.5997 预测 [-0.4744] 高炉 [-0.5975] 高炉与设定误差 [-0.0022] [-0.00185561] 模型误差 [0.123] 校正值 [-0.1257]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0897] 高炉 [0.2395] 高炉与设定误差 [0.0038] [0.30229223] 模型误差 [-0.1498] 校正值 [0.154]
# 2设定 -0.5997 预测 [-0.4764] 高炉 [-0.6065] 高炉与设定误差 [0.0068] [0.00573551] 模型误差 [0.1301] 校正值 [-0.123]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0931] 高炉 [0.2428] 高炉与设定误差 [0.0005] [0.03977529] 模型误差 [-0.1497] 校正值 [0.1498]
# 2设定 -0.5997 预测 [-0.4703] 高炉 [-0.6003] 高炉与设定误差 [0.0006] [0.00050607] 模型误差 [0.13] 校正值 [-0.1301]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.2433 预测 [0.0935] 高炉 [0.2445] 高炉与设定误差 [-0.0012] [-0.09546071] 模型误差 [-0.151] 校正值 [0.1497]
# 2设定 -0.5997 预测 [-0.4705] 高炉 [-0.5984] 高炉与设定误差 [-0.0013] [-0.00109649] 模型误差 [0.1279] 校正值 [-0.13]

# %%
# 数据转换、
data_tranform_plot(scalers,Times ,max_control,
                        output_term,input_term,
                        set_y1,set_y2,set_y1_trans,set_y2_trans,
                        all_pred_y1, all_pred_y2,
                        all_pred_u1,
                        all_pred_u2,
                        all_pred_u3,
                        all_pred_u4)
# Out:
# 上线分别是：[2.00440000e+04 8.47377777e-02]、[33.63755615 25.45833375]、[0.42875    0.33949271]、[1268.  798.]
# 平均误差 1.0031
# 平均误差 0.0115
