# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")


import base

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\Admin\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='剔除直线输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='单SI_0.2_0.8') 
# print(df_sheet_yuansu.info())
# print(df_sheet_yuansu.columns)

excel_path = f'C:\\Users\\Admin\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_params = pd.read_excel(excel_path, sheet_name='1h_mean_all') 

# print(df_sheet_params.info())
# print(df_sheet_params.columns)

# %%
import pandas as pd

# 假设 df 是你的 DataFrame

# 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_yuansu.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
    # 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_params.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
# Out:
# 数据不包含 NaN 值
# 数据不包含 NaN 值

# %%
input_term =        ['富氧流量', '冷风流量', '热风压力', '热风温度']

output_term = ['铁水温度[MIT]', '铁水硅含量[SI]']
time_term= '时间戳h'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_yuansu_process = df_sheet_yuansu.copy()
df_sheet_params_process = df_sheet_params.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 2.5 * y.std()
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value

# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[3]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[4]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[5]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[6]])

# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[0]])
# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[1]])

plt.figure(figsize=(15, 4))
for idx, column in enumerate(input_term):
    plt.subplot(len(input_term), 1, idx+1)
    plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params[column].values,df_sheet_params_process[column].values,column)

plt.figure(figsize=(15, 2))
for idx, column in enumerate(output_term):
    plt.subplot(len(output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu[column].values,df_sheet_yuansu_process[column].values,column)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\Admin\AppData\Local\Temp\ipykernel_40236\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r.', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 400


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 6))
for idx, column in enumerate(output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_params_process[input_term[0]].values,
    input_term[1]:   df_sheet_params_process[input_term[1]].values,
    input_term[2]:   df_sheet_params_process[input_term[2]].values,
    input_term[3]:   df_sheet_params_process[input_term[3]].values,
    # input_term[4]:   df_sheet_params_process[input_term[4]].values,
    # input_term[5]:   df_sheet_params_process[input_term[5]].values,
    # input_term[6]:   df_sheet_params_process[input_term[6]].values,
    output_term[0]:  df_sheet_yuansu_process[output_term[0]].values,
    output_term[1]:  df_sheet_yuansu_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每浓度的输出差：',(data3-data1))
# Out:
# [0.0341569]
# [1500.]
# [0.1523575]
# [1510.]
# 每摄氏度的输出差： [0.01182006]
# [-0.53242879]
# [0.5]
# [-0.4247456]
# [0.6]
# 每浓度的输出差： [0.1076832]

# %%
isShuffle = True
isShuffle = False
time_steps = 2
test_size = 0.15
val_size = 0.15
train_size = 1-val_size-test_size

# %%
# 组合训练数据--拆分训练、测试集

# 定义时间步数和特征数

# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data,index_fanwei):
    X = np.column_stack((u1_data,u2_data,u3_data,u4_data))
    y = np.column_stack((y1_data, y2_data))

    X_modified = []
    y_modified = []
    
    for i in range(3,len(y1_data)):
        if i in index_fanwei:
            # print(i)
            # print(df_sheet_yuansu[time_term][i])
            yuansu_time = df_sheet_yuansu[time_term][i]
            closest_10 = df_sheet_params[df_sheet_params[time_term] <= yuansu_time].nlargest(time_steps, time_term)
            # print(closest_10)
            
            index = closest_10.index
            # print(index)
            # print(closest_10.iloc[-1][time_term])
            if closest_10.iloc[-1][time_term] < yuansu_time - time_steps + 1:
                print(i,yuansu_time,'errloss')
            else:

                # print(X[index, :])
                new_x_sample = np.concatenate([X[i, :] for i in index],axis=0)
                # print(new_x_sample)
                y_last = y[i-1, :]
                # print(y_last, 'y_last time : ',df_sheet_yuansu[time_term][i-1])
                new_x_sample = np.concatenate([new_x_sample,y_last],axis=0)
                # print(new_x_sample)
                y_sample = y[i, :]  
                X_modified.append(new_x_sample)
                y_modified.append(y_sample)
                print(i,yuansu_time,index[0],index[-1], end='\r')
                # break

    # 将列表转换为 NumPy 数组
    X_modified = np.array(X_modified)
    y_modified = np.array(y_modified)
    X_reshaped = X_modified.reshape((X_modified.shape[0], X_modified.shape[1]))

    # 打印新数据的形状
    print("Modified Input Shape:", X_reshaped.shape)
    print("Modified Output Shape:", y_modified.shape)


    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_modified, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def symmetrical_moving_average(data, N):
    """
    使用对称的移动平均滤波，当前值由其自身及其前后的值决定。
    
    :param data: 输入的数据序列，一般为列表或者NumPy数组。
    :return: 经过滤波处理的数据序列。
    """
    filtered_data = []
    N = 9
    percent = 0.8
    # 遍历数据，从索引1开始到倒数第二个元素结束
    for i in range(1, len(data) - 1):
        # 计算当前值及其前后值的平均
        average = (data[i - 1]*(1-percent)/2 + data[i]*percent + data[i + 1]*(1-percent)/2)
        filtered_data.append(average)
    
    # 对于序列的第一个和最后一个元素，直接使用原始值
    # 或者可以使用其他边界处理策略
    filtered_data.insert(0, data[0])
    filtered_data.append(data[-1])
    
    return np.array(filtered_data)

# 示例数据
data = [2, 4, 6, 8, 10, 12, 14]
filtered_data = symmetrical_moving_average(data,9)
print(filtered_data)
# Out:
# [ 2.  4.  6.  8. 10. 12. 14.]

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)

print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_gaolu)



# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_predict)
# Out:
# 高炉模型数据
# Modified Input Shape: (398, 10)
# Modified Output Shape: (398, 2)
# 训练数量： (278, 10) (278, 2)
# 验证数量： (60, 10) (60, 2)
# 测试数量： (60, 10) (60, 2)
# 预测模型数据
# Modified Input Shape: (401, 10)
# Modified Output Shape: (401, 2)
# 训练数量： (279, 10) (279, 2)
# 验证数量： (61, 10) (61, 2)
# 测试数量： (61, 10) (61, 2)

# %%
epoch_once_time = 50
ischuangxin = True
# ischuangxin = False
cengshu = 3

# %%
# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyNeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, if_chuangxin = False,gamma = 0.1):
        self.if_chuangxin = if_chuangxin
        super(MyNeuralNetwork, self).__init__()
        if cengshu == 3:    
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()
        elif cengshu == 2:  
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()


    def forward(self, x0):
        if cengshu == 3:    
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                x4 = x + x2 + x3
                output = self.fc4(x4)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                output = self.fc4(x3)
        elif cengshu == 2:  
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = x + x2
                output = self.fc3(x3)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                output = self.fc3(x2)
        return output
        
        return output
    
    

    
    def custom_loss(self, y_true, y_pred):

        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse
    

    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    def model_update(self, 
                X_train, y_train, 
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)
        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}')
            
            
        return 0
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
# 建立高炉模型实例
input_size = 10  # 输入特征大小
hidden_size = 16  # 32
output_size = 2  # 输出大小
# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyNeuralNetwork(input_size, 
                            hidden_size,
                            output_size,
                            ischuangxin,
                            gamma = 0.1)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 8/50 轮, 训练误差: 0.0377, 验证误差: 0.0171
# 第 50/50 轮, 训练误差: 0.0290, 验证误差: 0.0140
# epoch_sum: 50

# %%
input_term333_ENGLISH = ['Oxygen Flow', 'Pulverized Coal Injection', 'Hot Blast Pressure', 'Hot Blast Temperature']
output_term333_ENGLISH = ['Hot Metal Temperature', 'Hot Metal Silicon Content']
time_term = 'Timestamp'
print(input_term333_ENGLISH)
print(output_term333_ENGLISH)
# Out:
# ['Oxygen Flow', 'Pulverized Coal Injection', 'Hot Blast Pressure', 'Hot Blast Temperature']
# ['Hot Metal Temperature', 'Hot Metal Silicon Content']

# %%
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
input_term333 =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term333 = ['MIT', '[Si]']
time_term= '时间戳h'
print(input_term333)
print(output_term333)








input_term222 =        ['富氧流量/(m\u00b3/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
output_term222 = ['MIT/℃', '[Si]/%']
time_term= '时间戳h'
print(input_term222)
print(output_term222)
# Out:
# ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
# ['MIT', '[Si]']
# ['富氧流量/(m³/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
# ['MIT/℃', '[Si]/%']

# %%
ditem = -0.65

# %%
def double_control_train_test_result(scalers, output_term, y_test, y_pred_0, y_pred_1, y_test_2, y_pred_0_2, y_pred_1_2,ditem,a,b):
    y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    plt.figure(figsize=(9, 8))
    
    
    ax = plt.subplot(4, 1, 1)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    ax.legend(prop=font, loc='upper right', bbox_to_anchor=(a, b), ncol=4) 
    
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[0]} {output_term333[0]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('训练样本', fontproperties=font)  




    ax = plt.subplot(4, 1, 2)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font) 

    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[1]} {output_term333[1]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    
    ax.set_xlabel('训练样本', fontproperties=font)  




    y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1_2).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    ax = plt.subplot(4, 1, 3)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[2]} {output_term333[0]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  



    ax = plt.subplot(4, 1, 4)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[3]} {output_term333[1]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  




    plt.subplots_adjust(hspace=0.6)  # 调整子图之间的垂直间距
    plt.tight_layout()  # 自动调整子图布局
    plt.show()

# %%
# 高炉模型建模效果
y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_gaolu_train)
y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_gaolu_test)

double_control_train_test_result(scalers,  output_term,
                                        y_gaolu_train,  y_train_pred_0, y_train_pred_1,
                                        y_gaolu_test ,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.63, b = 0.38 )

# %% [markdown]
# 英文版

# %%
    # y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
    # y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
    # y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
    # y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1_2).reshape(-1, 1)).flatten()

    # rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
    # rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

    # mae_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform)))
    # mae_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform)))


    # mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
    # mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))

    # percent0 = np.sum(np.fabs(y_test_0 - y_pred_0_inverse_transform) < 10)/len(y_test_0)
    # percent1 = np.sum(np.fabs(y_test_1 - y_pred_1_inverse_transform) < 0.1)/len(y_test_1)


    # R2_0 = r2_score(y_pred_0_inverse_transform, y_test_0)
    # R2_1 = r2_score(y_pred_1_inverse_transform, y_test_1)

    # # 打印结果
    # print('测试集')
    # print(f"RMSE   :  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
    # print(f"MAE   :  {output_term[0]}: {mae_0:.4f} , {output_term[1]}: {mae_1:.4f}")
    # print(f"MRE    :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")
    # print(f"percent:  {output_term[0]}: { percent0:.4f}  , {output_term[1]}: { percent1:.4f} ")
    # # print(f"R2     :  {output_term[0]}: { R2_0:.4f}  , {output_term[1]}: { R2_1:.4f} ")


    
    # print('测试集')
    # print(f"{rmse_0:.4f} {rmse_1:.4f} ")
    # print(f"{mae_0:.4f} {mae_1:.4f}")
    # print(f"{ mre_0:.4f} { mre_1:.4f} ")
    # print(f"{ percent0:.4f} { percent1:.4f} ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
#       2 y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
#       3 y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
#
# NameError: name 'y_test_2' is not defined

# %%
def double_control_train_test_result_English(scalers, output_term, y_test, y_pred_0, y_pred_1, y_test_2, y_pred_0_2, y_pred_1_2, ditem, a, b):
    def plot_subplot(y_true, y_pred, subplot_index, title, ylabel):
        ax = plt.subplot(4, 1, subplot_index)
        if subplot_index == 2:            
            plt.plot(y_true, 'k', label="True Value")
            plt.plot(y_pred, 'r--', label="Predicted Value")
            ax.legend(prop=font, loc='upper right', bbox_to_anchor=(a, b), ncol=4)
        else :            
            plt.plot(y_true, 'k')
            plt.plot(y_pred, 'r--')
        
        plt.ylabel(ylabel, fontproperties=font)
        ax.yaxis.set_label_coords(-0.07, 0.5)
        ax.text(0.5, ditem, title, transform=ax.transAxes, ha='center', fontproperties=font)
        ax.set_xlabel('Samples', fontproperties=font)

    y_test_0 = scalers[output_term[0]].inverse_transform(y_test[:, 0].reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform(y_test[:, 1].reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform(y_pred_0.reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform(y_pred_1.reshape(-1, 1)).flatten()



    rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
    rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

    mae_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform)))
    mae_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform)))


    mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
    mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))

    percent0 = np.sum(np.fabs(y_test_0 - y_pred_0_inverse_transform) < 10)/len(y_test_0)
    percent1 = np.sum(np.fabs(y_test_1 - y_pred_1_inverse_transform) < 0.1)/len(y_test_1)


    # 打印结果
    print('测试集')
    print(f"RMSE   :  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
    print(f"MAE   :  {output_term[0]}: {mae_0:.4f} , {output_term[1]}: {mae_1:.4f}")
    print(f"MRE    :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")
    print(f"percent:  {output_term[0]}: { percent0:.4f}  , {output_term[1]}: { percent1:.4f} ")
    # print(f"R2     :  {output_term[0]}: { R2_0:.4f}  , {output_term[1]}: { R2_1:.4f} ")


    
    print('测试集')
    print(f"{rmse_0:.4f} {rmse_1:.4f} ")
    print(f"{mae_0:.4f} {mae_1:.4f}")
    print(f"{ mre_0:.4f} { mre_1:.4f} ")
    print(f"{ percent0:.4f} { percent1:.4f} ")




    plt.figure(figsize=(9, 8))
    plot_subplot(y_test_0, y_pred_0_inverse_transform, 1, f'{subplot_labels[0]} {output_term333[0]} Modeling Effect', output_term222[0])
    plot_subplot(y_test_1, y_pred_1_inverse_transform, 2, f'{subplot_labels[1]} {output_term333[1]} Modeling Effect', output_term222[1])

    y_test_0 = scalers[output_term[0]].inverse_transform(y_test_2[:, 0].reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform(y_test_2[:, 1].reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform(y_pred_0_2.reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform(y_pred_1_2.reshape(-1, 1)).flatten()





    rmse_0 = np.sqrt(mean_squared_error(y_test_0, y_pred_0_inverse_transform))
    rmse_1 = np.sqrt(mean_squared_error(y_test_1, y_pred_1_inverse_transform))

    mae_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform)))
    mae_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform)))


    mre_0 = np.mean(np.abs((y_test_0 - y_pred_0_inverse_transform) / y_test_0))
    mre_1 = np.mean(np.abs((y_test_1 - y_pred_1_inverse_transform) / y_test_1))

    percent0 = np.sum(np.fabs(y_test_0 - y_pred_0_inverse_transform) < 10)/len(y_test_0)
    percent1 = np.sum(np.fabs(y_test_1 - y_pred_1_inverse_transform) < 0.1)/len(y_test_1)



    # 打印结果
    print('测试集')
    print(f"RMSE   :  {output_term[0]}: {rmse_0:.4f} , {output_term[1]}: {rmse_1:.4f} ")
    print(f"MAE   :  {output_term[0]}: {mae_0:.4f} , {output_term[1]}: {mae_1:.4f}")
    print(f"MRE    :  {output_term[0]}: { mre_0:.4f}  , {output_term[1]}: { mre_1:.4f} ")
    print(f"percent:  {output_term[0]}: { percent0:.4f}  , {output_term[1]}: { percent1:.4f} ")
    # print(f"R2     :  {output_term[0]}: { R2_0:.4f}  , {output_term[1]}: { R2_1:.4f} ")


    
    print('测试集')
    print(f"{rmse_0:.4f} {rmse_1:.4f} ")
    print(f"{mae_0:.4f} {mae_1:.4f}")
    print(f"{ mre_0:.4f} { mre_1:.4f} ")
    print(f"{ percent0:.4f} { percent1:.4f} ")






    plot_subplot(y_test_0, y_pred_0_inverse_transform, 3, f'{subplot_labels[2]} {output_term333[0]} Prediction Effect', output_term222[0])
    plot_subplot(y_test_1, y_pred_1_inverse_transform, 4, f'{subplot_labels[3]} {output_term333[1]} Prediction Effect', output_term222[1])

    plt.subplots_adjust(hspace=0.6)  # Adjust vertical spacing between subplots
    plt.tight_layout()  # Automatically adjust subplot layout
    plt.show()

# %%
# 高炉模型建模效果

y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_gaolu_train)
y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_gaolu_test)

double_control_train_test_result_English(scalers,  output_term,
                                        y_gaolu_train,  y_train_pred_0, y_train_pred_1,
                                        y_gaolu_test ,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 1.0, b = 1 )

# base.double_control_train_test_result(scalers,  output_term,
#                                         y_gaolu_train[:-1],  y_train_pred_0[1:], y_train_pred_1[1:],
#                                         y_gaolu_test[:-1] ,   y_test_pred_0[1:],  y_test_pred_1[1:])
# Out:
# 测试集
# RMSE   :  铁水温度[MIT]: 12.0296 , 铁水硅含量[SI]: 0.0823
# MAE   :  铁水温度[MIT]: 8.6729 , 铁水硅含量[SI]: 0.0604
# MRE    :  铁水温度[MIT]: 0.0057  , 铁水硅含量[SI]: 0.1256
# percent:  铁水温度[MIT]: 0.6655  , 铁水硅含量[SI]: 0.8165
# 测试集
# 12.0296 0.0823
# 8.6729 0.0604
# 0.0057 0.1256
# 0.6655 0.8165
# 测试集
# RMSE   :  铁水温度[MIT]: 7.6254 , 铁水硅含量[SI]: 0.0492
# MAE   :  铁水温度[MIT]: 5.7594 , 铁水硅含量[SI]: 0.0391
# MRE    :  铁水温度[MIT]: 0.0038  , 铁水硅含量[SI]: 0.1104
# percent:  铁水温度[MIT]: 0.8333  , 铁水硅含量[SI]: 0.9333
# 测试集
# 7.6254 0.0492
# 5.7594 0.0391
# 0.0038 0.1104
# 0.8333 0.9333

# %%
def double_control_train_test_result(scalers, output_term, y_test, y_pred_0, y_pred_1, y_test_2, y_pred_0_2, y_pred_1_2,ditem,a,b):
    y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    plt.figure(figsize=(9, 8))
    
    
    ax = plt.subplot(4, 1, 1)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    ax.legend(prop=font, loc='upper right', bbox_to_anchor=(a, b), ncol=4) 
    
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[0]} {output_term333[0]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('训练样本', fontproperties=font)  




    ax = plt.subplot(4, 1, 2)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font) 

    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[1]} {output_term333[1]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    
    ax.set_xlabel('训练样本', fontproperties=font)  




    y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1_2).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    ax = plt.subplot(4, 1, 3)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[2]} {output_term333[0]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  



    ax = plt.subplot(4, 1, 4)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[3]} {output_term333[1]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  




    plt.subplots_adjust(hspace=0.6)  # 调整子图之间的垂直间距
    plt.tight_layout()  # 自动调整子图布局
    plt.show()

# %%
# 创建预测模型实例
# 设置随机种子
torch.manual_seed(0)
model_predict = MyNeuralNetwork(input_size, hidden_size, output_size,ischuangxin)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model_predict.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0286, 验证误差: 0.0349
# epoch_sum: 0

# %%
# 预测模型建模效果
y_train_pred_0,y_train_pred_1 = model_predict.my_predict(X_predict_train)


y_test_pred_0,y_test_pred_1 = model_predict.my_predict(X_predict_test)

double_control_train_test_result(scalers,  output_term,
                                        y_predict_train,  y_train_pred_0, y_train_pred_1,
                                        y_predict_test,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.31, b = 0.38 )

# %%
# 高炉模型建模效果

# 预测模型建模效果
y_train_pred_0,y_train_pred_1 = model_predict.my_predict(X_predict_train)


y_test_pred_0,y_test_pred_1 = model_predict.my_predict(X_predict_test)

double_control_train_test_result_English(scalers,  output_term,
                                        y_predict_train,  y_train_pred_0, y_train_pred_1,
                                        y_predict_test,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.31, b = 0.38 )
# Out:
# 测试集
# RMSE   :  铁水温度[MIT]: 10.9456 , 铁水硅含量[SI]: 0.0848
# MAE   :  铁水温度[MIT]: 8.6317 , 铁水硅含量[SI]: 0.0689
# MRE    :  铁水温度[MIT]: 0.0057  , 铁水硅含量[SI]: 0.1918
# percent:  铁水温度[MIT]: 0.6631  , 铁水硅含量[SI]: 0.7814
# 测试集
# 10.9456 0.0848
# 8.6317 0.0689
# 0.0057 0.1918
# 0.6631 0.7814
# 测试集
# RMSE   :  铁水温度[MIT]: 14.4519 , 铁水硅含量[SI]: 0.1299
# MAE   :  铁水温度[MIT]: 11.9172 , 铁水硅含量[SI]: 0.0951
# MRE    :  铁水温度[MIT]: 0.0080  , 铁水硅含量[SI]: 0.2930
# percent:  铁水温度[MIT]: 0.4754  , 铁水硅含量[SI]: 0.6885
# 测试集
# 14.4519 0.1299
# 11.9172 0.0951
# 0.0080 0.2930
# 0.4754 0.6885

# %%
base.gaolu_predict_raw(scalers,output_term,model_predict,model_gaolu,X_predict_test,y_predict_test)

# %%
# 使用NumPy重新构建神经网络架构
class MyNeuralNetworkNumpy:
    def __init__(self, model, input_size, hidden_size, output_size,ifchuangxin):
        self.ifchuangxin = ifchuangxin
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        params = {name: param.detach().numpy() for name, param in model.state_dict().items()}
        if cengshu == 3:    
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
            self.weights_fc4 = params['fc4.weight']
            self.bias_fc4 = params['fc4.bias']
        elif cengshu == 2:  
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
        
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    def relu(self, x):
        return np.maximum(0, x)

    def forward(self, x):
        if cengshu == 3:    
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                hidden4 = hidden1 + hidden2 + hidden3
                output = np.dot(hidden4, self.weights_fc4.T) + self.bias_fc4

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                output = np.dot(hidden3, self.weights_fc4.T) + self.bias_fc4
        elif cengshu == 2:  
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = hidden1 + hidden2
                output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3
                # hidden2 = self.relu(hidden2)

                # hidden3 = np.concatenate([x, hidden1, hidden2], axis=1)  # 按列连接
                # output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                output = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3


            
        return output
    
    
    def my_predict(self, data_input):
        input = data_input  # 随机初始化一个输入序列
        output_prediction = model_numpy.forward(input)
        return output_prediction[:,0], output_prediction[:,1]

# 使用NumPy模型进行预测
model_numpy = MyNeuralNetworkNumpy(model_predict, input_size, hidden_size, output_size,ischuangxin)


y_pred_0, y_pred_1 = model_numpy.my_predict(X_predict_test)

# 计算 RMSE、MRE
y_test = y_predict_test


base.double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁水温度[MIT]: 14.4519 , 铁水硅含量[SI]: 0.1299
# MAPE:  铁水温度[MIT]: 0.7988% , 铁水硅含量[SI]: 29.2975%
# MRE :  铁水温度[MIT]: 0.0080  , 铁水硅含量[SI]: 0.2930
# per :  铁水温度[MIT]: 0.4754  , 铁水硅含量[SI]: 0.6885

# %%
iscontrol = True
# iscontrol = False
Times = 200
# 过度系数  0.1 越小过度越快
rou = 0.1
if_add_noise = 0
if_gaolu_is_predict = 0
if_update_model = True
# if_update_model = False

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,rou,20)

# %%
# # 生成期望数据

def generate_y_aim_data(Times):
    if Times == 400:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        
    elif Times == 200:
        # set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10+75:410-125]
        # set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0+75:400-125]
        set_y1 = np.repeat(np.arange(1450, 1555, 5), 20)[10+75:410-125]
        set_y2 = np.repeat(np.arange(0.30, 0.72, 0.02), 20)[0+75:400-125]

    elif Times == 1000:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        set_y1 = np.repeat(np.arange(1457.5, 1562.5, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.35, 0.77, 0.02), 20)[0:400]

    else:
        set_y1 = np.full(Times,1500)
        set_y2 = np.full(Times,0.45)

    





    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)
print(set_y1.shape)
print(set_y1.shape)
# Out:
# (200,)
# (200,)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):

    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]

    
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]
    
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = model_numpy.my_predict(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,rou,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,rou,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)

    # y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    # y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    # u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    # u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    # u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    # u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    # u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    # u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    # u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
# 生成高斯噪声,设置随机种子，以便结果可重现
np.random.seed(42)
gaussian_noise_SI = np.random.normal(0,d_yuansu*0.001,Times)
gaussian_noise_TEMP = np.random.normal(0,d_temp*0.1,Times)
plt.subplot(2, 1, 1)
plt.plot(gaussian_noise_SI)
plt.subplot(2, 1, 2)
plt.plot(gaussian_noise_TEMP)

# %%
def update_model(model_predict,model_gaolu,x,gaolu_data_past_x,gaolu_data_past_y):
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    y_label = np.column_stack((y1_pred, y2_pred))
    gaolu_data_past_x.append(x)
    gaolu_data_past_y.append(y_label)

    
    X_modified = np.array(gaolu_data_past_x)
    y_modified = np.array(gaolu_data_past_y)
    # print(X_modified)
    # print(y_modified)
    X = X_modified.reshape(X_modified.shape[0],X_modified.shape[2])
    Y = y_modified.reshape(y_modified.shape[0],y_modified.shape[2])
    print(X_modified.shape)
    print(y_modified.shape)
    if y_modified.shape[0]% 1 == 0:
        model_predict.model_update(X, Y,
                                epochs=10, 
                                batch_size=64,
                                lr = 0.002)
        # gaolu_data_past_x = []
        # gaolu_data_past_y = []

    return model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 3  # 预测时域长度  3
M = 3  # 4
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data,
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
gaolu_data_past_x = []
gaolu_data_past_y = []


# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    bounds = [(-max_control, max_control) for _ in range(4 * M)]
    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='COBYLA', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    U1, U2, U3, U4 =    result.x[0:M], result.x[M:2*M], \
                        result.x[2*M:3*M], result.x[3*M:4*M]
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                            y1[j+1],y2[j+1]))
    # x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model_predict.my_predict(x)
    if if_gaolu_is_predict:
        y1_pred, y2_pred = model_predict.my_predict(x)
        if if_add_noise:
            y1_pred = y1_pred+gaussian_noise_TEMP[k].item()
            y2_pred = y2_pred+gaussian_noise_SI[k].item()
    else:
        y1_pred, y2_pred = model_gaolu.my_predict(x)
        if if_update_model:
            model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y = update_model(model_predict,model_gaolu,x,gaolu_data_past_x,gaolu_data_past_y)




    # 更新k_data
    params = np.concatenate((U1, U2, U3, U4),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    k_data2[14] = y1_pred.item()
    k_data2[17] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 579
# (18,)
# 这是对第0时刻的最优U1、U2输入求解
# (1, 1, 10)
# (1, 1, 2)
# 第 1/10 轮, 训练误差: 6.8290
# 第 2/10 轮, 训练误差: 4.9289
# 第 3/10 轮, 训练误差: 3.3777
# 第 4/10 轮, 训练误差: 2.1580
# 第 5/10 轮, 训练误差: 1.2500
# 第 6/10 轮, 训练误差: 0.6284
# 第 7/10 轮, 训练误差: 0.2580
# 第 8/10 轮, 训练误差: 0.0945
# 第 9/10 轮, 训练误差: 0.0872
# 第 10/10 轮, 训练误差: 0.1839
# 1设定 -0.3204 预测 [-0.1311] 高炉 [0.1732] 高炉与设定误差 [-0.4937] [-41.76797758] 模型误差 [-0.3043] 校正值 [-0.5037]
# 2设定 -0.6832 预测 [-0.4649] 高炉 [-0.3462] 高炉与设定误差 [-0.337] [-0.31295506] 模型误差 [-0.1187] 校正值 [0.0375]
# 这是对第1时刻的最优U1、U2输入求解
# (2, 1, 10)
# (2, 1, 2)
# 第 1/10 轮, 训练误差: 1.4709
# 第 2/10 轮, 训练误差: 0.8788
# 第 3/10 轮, 训练误差: 0.4842
# 第 4/10 轮, 训练误差: 0.2591
# 第 5/10 轮, 训练误差: 0.1504
# 第 6/10 轮, 训练误差: 0.1130
# 第 7/10 轮, 训练误差: 0.1133
# 第 8/10 轮, 训练误差: 0.1265
# 第 9/10 轮, 训练误差: 0.1374
# 第 10/10 轮, 训练误差: 0.1400
# 1设定 -0.3204 预测 [0.6476] 高炉 [0.3831] 高炉与设定误差 [-0.7035] [-59.51746249] 模型误差 [0.2645] 校正值 [0.0237]
# 2设定 -0.6832 预测 [-0.3095] 高炉 [-0.4389] 高炉与设定误差 [-0.2443] [-0.22686919] 模型误差 [0.1294] 校正值 [0.0008]
# 这是对第2时刻的最优U1、U2输入求解
# (3, 1, 10)
# (3, 1, 2)
# 第 1/10 轮, 训练误差: 0.3152
# 第 2/10 轮, 训练误差: 0.1117
# 第 3/10 轮, 训练误差: 0.0424
# 第 4/10 轮, 训练误差: 0.0559
# 第 5/10 轮, 训练误差: 0.0795
# 第 6/10 轮, 训练误差: 0.0783
# 第 7/10 轮, 训练误差: 0.0558
# 第 8/10 轮, 训练误差: 0.0286
# 第 9/10 轮, 训练误差: 0.0110
# 第 10/10 轮, 训练误差: 0.0087
# 1设定 -0.3204 预测 [-0.1169] 高炉 [0.0674] 高炉与设定误差 [-0.3878] [-32.80863301] 模型误差 [-0.1843] 校正值 [0.0261]
# 2设定 -0.6832 预测 [-0.4922] 高炉 [-0.5357] 高炉与设定误差 [-0.1474] [-0.13688302] 模型误差 [0.0435] 校正值 [-0.0256]
# 这是对第3时刻的最优U1、U2输入求解
# (4, 1, 10)
# (4, 1, 2)
# 第 1/10 轮, 训练误差: 0.0280
# 第 2/10 轮, 训练误差: 0.0179
# 第 3/10 轮, 训练误差: 0.0100
# 第 4/10 轮, 训练误差: 0.0038
# 第 5/10 轮, 训练误差: 0.0058
# 第 6/10 轮, 训练误差: 0.0065
# 第 7/10 轮, 训练误差: 0.0041
# 第 8/10 轮, 训练误差: 0.0026
# 第 9/10 轮, 训练误差: 0.0032
# 第 10/10 轮, 训练误差: 0.0032
# 1设定 -0.3204 预测 [-0.1508] 高炉 [-0.1623] 高炉与设定误差 [-0.1581] [-13.37556621] 模型误差 [0.0115] 校正值 [-0.0085]
# 2设定 -0.6832 预测 [-0.4729] 高炉 [-0.5389] 高炉与设定误差 [-0.1443] [-0.13400419] 模型误差 [0.066] 校正值 [-0.0028]
# 这是对第4时刻的最优U1、U2输入求解
# (5, 1, 10)
# (5, 1, 2)
# 第 1/10 轮, 训练误差: 0.0122
# 第 2/10 轮, 训练误差: 0.0162
# 第 3/10 轮, 训练误差: 0.0083
# 第 4/10 轮, 训练误差: 0.0056
# 第 5/10 轮, 训练误差: 0.0044
# 第 6/10 轮, 训练误差: 0.0050
# 第 7/10 轮, 训练误差: 0.0041
# 第 8/10 轮, 训练误差: 0.0018
# 第 9/10 轮, 训练误差: 0.0012
# 第 10/10 轮, 训练误差: 0.0030
# 1设定 -0.3204 预测 [-0.2595] 高炉 [-0.2322] 高炉与设定误差 [-0.0883] [-7.47035106] 模型误差 [-0.0273] 校正值 [0.0148]
# 2设定 -0.6832 预测 [-0.629] 高炉 [-0.5697] 高炉与设定误差 [-0.1135] [-0.10540177] 模型误差 [-0.0593] 校正值 [-0.0186]
# 这是对第5时刻的最优U1、U2输入求解
# (6, 1, 10)
# (6, 1, 2)
# 第 1/10 轮, 训练误差: 0.0052
# 第 2/10 轮, 训练误差: 0.0116
# 第 3/10 轮, 训练误差: 0.0073
# 第 4/10 轮, 训练误差: 0.0027
# 第 5/10 轮, 训练误差: 0.0026
# 第 6/10 轮, 训练误差: 0.0054
# 第 7/10 轮, 训练误差: 0.0042
# 第 8/10 轮, 训练误差: 0.0013
# 第 9/10 轮, 训练误差: 0.0011
# 第 10/10 轮, 训练误差: 0.0031
# 1设定 -0.3204 预测 [-0.2856] 高炉 [-0.2557] 高炉与设定误差 [-0.0647] [-5.47374552] 模型误差 [-0.0299] 校正值 [-0.0084]
# 2设定 -0.6616 预测 [-0.59] 高炉 [-0.6136] 高炉与设定误差 [-0.048] [-0.0445752] 模型误差 [0.0236] 校正值 [0.0302]
# 这是对第6时刻的最优U1、U2输入求解
# (7, 1, 10)
# (7, 1, 2)
# 第 1/10 轮, 训练误差: 0.0027
# 第 2/10 轮, 训练误差: 0.0106
# 第 3/10 轮, 训练误差: 0.0024
# 第 4/10 轮, 训练误差: 0.0012
# 第 5/10 轮, 训练误差: 0.0051
# 第 6/10 轮, 训练误差: 0.0036
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0009
# 第 9/10 轮, 训练误差: 0.0028
# 第 10/10 轮, 训练误差: 0.0027
# 1设定 -0.3204 预测 [-0.2741] 高炉 [-0.2776] 高炉与设定误差 [-0.0429] [-3.62942321] 模型误差 [0.0034] 校正值 [0.0062]
# 2设定 -0.6616 预测 [-0.6438] 高炉 [-0.6305] 高炉与设定误差 [-0.0312] [-0.02897388] 模型误差 [-0.0133] 校正值 [-0.014]
# 这是对第7时刻的最优U1、U2输入求解
# (8, 1, 10)
# (8, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0124
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0025
# 第 5/10 轮, 训练误差: 0.0065
# 第 6/10 轮, 训练误差: 0.0044
# 第 7/10 轮, 训练误差: 0.0008
# 第 8/10 轮, 训练误差: 0.0006
# 第 9/10 轮, 训练误差: 0.0029
# 第 10/10 轮, 训练误差: 0.0035
# 1设定 -0.3204 预测 [-0.2921] 高炉 [-0.2902] 高炉与设定误差 [-0.0302] [-2.55497866] 模型误差 [-0.0019] 校正值 [-0.0065]
# 2设定 -0.6616 预测 [-0.6228] 高炉 [-0.6423] 高炉与设定误差 [-0.0193] [-0.01792295] 模型误差 [0.0195] 校正值 [0.0134]
# 这是对第8时刻的最优U1、U2输入求解
# (9, 1, 10)
# (9, 1, 2)
# 第 1/10 轮, 训练误差: 0.0017
# 第 2/10 轮, 训练误差: 0.0088
# 第 3/10 轮, 训练误差: 0.0017
# 第 4/10 轮, 训练误差: 0.0012
# 第 5/10 轮, 训练误差: 0.0045
# 第 6/10 轮, 训练误差: 0.0029
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0007
# 第 9/10 轮, 训练误差: 0.0023
# 第 10/10 轮, 训练误差: 0.0023
# 1设定 -0.3204 预测 [-0.292] 高炉 [-0.3009] 高炉与设定误差 [-0.0195] [-1.64973786] 模型误差 [0.009] 校正值 [0.002]
# 2设定 -0.6616 预测 [-0.6557] 高炉 [-0.6469] 高炉与设定误差 [-0.0147] [-0.01365116] 模型误差 [-0.0088] 校正值 [-0.0154]
# 这是对第9时刻的最优U1、U2输入求解
# (10, 1, 10)
# (10, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0097
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0019
# 第 5/10 轮, 训练误差: 0.0051
# 第 6/10 轮, 训练误差: 0.0034
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0023
# 第 10/10 轮, 训练误差: 0.0028
# 1设定 -0.3204 预测 [-0.305] 高炉 [-0.3024] 高炉与设定误差 [-0.018] [-1.52283485] 模型误差 [-0.0026] 校正值 [-0.008]
# 2设定 -0.6616 预测 [-0.6348] 高炉 [-0.6518] 高炉与设定误差 [-0.0099] [-0.00919363] 模型误差 [0.017] 校正值 [0.0103]
# 这是对第10时刻的最优U1、U2输入求解
# (11, 1, 10)
# (11, 1, 2)
# 第 1/10 轮, 训练误差: 0.0013
# 第 2/10 轮, 训练误差: 0.0072
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0036
# 第 6/10 轮, 训练误差: 0.0024
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0006
# 第 9/10 轮, 训练误差: 0.0019
# 第 10/10 轮, 训练误差: 0.0019
# 1设定 -0.3204 预测 [-0.3001] 高炉 [-0.3058] 高炉与设定误差 [-0.0146] [-1.23518835] 模型误差 [0.0058] 校正值 [0.0026]
# 2设定 -0.6616 预测 [-0.6613] 高炉 [-0.6498] 高炉与设定误差 [-0.0118] [-0.01095807] 模型误差 [-0.0115] 校正值 [-0.0151]
# 这是对第11时刻的最优U1、U2输入求解
# (12, 1, 10)
# (12, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0086
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0017
# 第 5/10 轮, 训练误差: 0.0045
# 第 6/10 轮, 训练误差: 0.0030
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0019
# 第 10/10 轮, 训练误差: 0.0025
# 1设定 -0.3204 预测 [-0.3067] 高炉 [-0.3031] 高炉与设定误差 [-0.0173] [-1.4636136] 模型误差 [-0.0035] 校正值 [-0.0068]
# 2设定 -0.6616 预测 [-0.6393] 高炉 [-0.6553] 高炉与设定误差 [-0.0064] [-0.00594336] 模型误差 [0.016] 校正值 [0.0136]
# 这是对第12时刻的最优U1、U2输入求解
# (13, 1, 10)
# (13, 1, 2)
# 第 1/10 轮, 训练误差: 0.0014
# 第 2/10 轮, 训练误差: 0.0056
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0027
# 第 6/10 轮, 训练误差: 0.0021
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0013
# 第 10/10 轮, 训练误差: 0.0016
# 1设定 -0.3204 预测 [-0.3007] 高炉 [-0.3074] 高炉与设定误差 [-0.013] [-1.09982524] 模型误差 [0.0067] 校正值 [0.0046]
# 2设定 -0.6616 预测 [-0.6633] 高炉 [-0.6482] 高炉与设定误差 [-0.0134] [-0.01244391] 模型误差 [-0.0151] 校正值 [-0.0157]
# 这是对第13时刻的最优U1、U2输入求解
# (14, 1, 10)
# (14, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0066
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0012
# 第 5/10 轮, 训练误差: 0.0034
# 第 6/10 轮, 训练误差: 0.0025
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0014
# 第 10/10 轮, 训练误差: 0.0019
# 1设定 -0.3204 预测 [-0.3124] 高炉 [-0.304] 高炉与设定误差 [-0.0164] [-1.38747182] 模型误差 [-0.0083] 校正值 [-0.0062]
# 2设定 -0.6616 预测 [-0.6352] 高炉 [-0.6464] 高炉与设定误差 [-0.0153] [-0.01420835] 模型误差 [0.0111] 校正值 [0.0144]
# 这是对第14时刻的最优U1、U2输入求解
# (15, 1, 10)
# (15, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0049
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0024
# 第 6/10 轮, 训练误差: 0.0017
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0012
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.3204 预测 [-0.3025] 高炉 [-0.3044] 高炉与设定误差 [-0.016] [-1.3536311] 模型误差 [0.002] 校正值 [0.0068]
# 2设定 -0.6616 预测 [-0.6583] 高炉 [-0.6423] 高炉与设定误差 [-0.0194] [-0.01801581] 模型误差 [-0.016] 校正值 [-0.0105]
# 这是对第15时刻的最优U1、U2输入求解
# (16, 1, 10)
# (16, 1, 2)
# 第 1/10 轮, 训练误差: 0.0015
# 第 2/10 轮, 训练误差: 0.0056
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0015
# 第 5/10 轮, 训练误差: 0.0031
# 第 6/10 轮, 训练误差: 0.0020
# 第 7/10 轮, 训练误差: 0.0008
# 第 8/10 轮, 训练误差: 0.0006
# 第 9/10 轮, 训练误差: 0.0015
# 第 10/10 轮, 训练误差: 0.0016
# 1设定 -0.2613 预测 [-0.2901] 高炉 [-0.2388] 高炉与设定误差 [-0.0225] [-1.90354373] 模型误差 [-0.0512] 校正值 [-0.0148]
# 2设定 -0.6616 预测 [-0.6355] 高炉 [-0.5992] 高炉与设定误差 [-0.0625] [-0.05804062] 模型误差 [-0.0364] 校正值 [0.0076]
# 这是对第16时刻的最优U1、U2输入求解
# (17, 1, 10)
# (17, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0043
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0023
# 第 6/10 轮, 训练误差: 0.0016
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0011
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2613 预测 [-0.2328] 高炉 [-0.2344] 高炉与设定误差 [-0.0269] [-2.27579226] 模型误差 [0.0017] 校正值 [0.0181]
# 2设定 -0.6616 预测 [-0.6416] 高炉 [-0.6317] 高炉与设定误差 [-0.0299] [-0.02776663] 模型误差 [-0.0099] 校正值 [0.0133]
# 这是对第17时刻的最优U1、U2输入求解
# (18, 1, 10)
# (18, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0047
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0020
# 第 6/10 轮, 训练误差: 0.0022
# 第 7/10 轮, 训练误差: 0.0009
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0008
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2613 预测 [-0.2713] 高炉 [-0.2571] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [-0.0143] 校正值 [-0.0065]
# 2设定 -0.6616 预测 [-0.6389] 高炉 [-0.6454] 高炉与设定误差 [-0.0162] [-0.01504413] 模型误差 [0.0065] 校正值 [0.009]
# 这是对第18时刻的最优U1、U2输入求解
# (19, 1, 10)
# (19, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0029
# 第 3/10 轮, 训练误差: 0.0015
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0015
# 第 6/10 轮, 训练误差: 0.0014
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0010
# 1设定 -0.2613 预测 [-0.2471] 高炉 [-0.2634] 高炉与设定误差 [0.002] [0.16920389] 模型误差 [0.0163] 校正值 [0.0135]
# 2设定 -0.6616 预测 [-0.665] 高炉 [-0.6583] 高炉与设定误差 [-0.0034] [-0.00315741] 模型误差 [-0.0067] 校正值 [-0.0042]
# 这是对第19时刻的最优U1、U2输入求解
# (20, 1, 10)
# (20, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0042
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0017
# 第 6/10 轮, 训练误差: 0.0019
# 第 7/10 轮, 训练误差: 0.0008
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0011
# 1设定 -0.2613 预测 [-0.2719] 高炉 [-0.2632] 高炉与设定误差 [0.0019] [0.16074369] 模型误差 [-0.0087] 校正值 [-0.0093]
# 2设定 -0.6616 预测 [-0.6506] 高炉 [-0.6629] 高炉与设定误差 [0.0013] [0.00120725] 模型误差 [0.0123] 校正值 [0.0106]
# 这是对第20时刻的最优U1、U2输入求解
# (21, 1, 10)
# (21, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0030
# 第 3/10 轮, 训练误差: 0.0017
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0016
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2613 预测 [-0.251] 高炉 [-0.2617] 高炉与设定误差 [0.0003] [0.02538058] 模型误差 [0.0107] 校正值 [0.0108]
# 2设定 -0.6616 预测 [-0.671] 高炉 [-0.6633] 高炉与设定误差 [0.0016] [0.00148584] 模型误差 [-0.0078] 校正值 [-0.0153]
# 这是对第21时刻的最优U1、U2输入求解
# (22, 1, 10)
# (22, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0035
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0015
# 第 6/10 轮, 训练误差: 0.0017
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0010
# 1设定 -0.2613 预测 [-0.2698] 高炉 [-0.2663] 高炉与设定误差 [0.005] [0.42300969] 模型误差 [-0.0034] 校正值 [-0.0056]
# 2设定 -0.6616 预测 [-0.6452] 高炉 [-0.667] 高炉与设定误差 [0.0053] [0.00492184] 模型误差 [0.0218] 校正值 [0.0108]
# 这是对第22时刻的最优U1、U2输入求解
# (23, 1, 10)
# (23, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0032
# 第 3/10 轮, 训练误差: 0.0018
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0018
# 第 7/10 轮, 训练误差: 0.0011
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2613 预测 [-0.2516] 高炉 [-0.2586] 高炉与设定误差 [-0.0028] [-0.23688542] 模型误差 [0.007] 校正值 [0.0099]
# 2设定 -0.6616 预测 [-0.6678] 高炉 [-0.6582] 高炉与设定误差 [-0.0035] [-0.00325028] 模型误差 [-0.0096] 校正值 [-0.0186]
# 这是对第23时刻的最优U1、U2输入求解
# (24, 1, 10)
# (24, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0023
# 第 3/10 轮, 训练误差: 0.0018
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0015
# 第 7/10 轮, 训练误差: 0.0008
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2613 预测 [-0.2743] 高炉 [-0.2658] 高炉与设定误差 [0.0044] [0.37224853] 模型误差 [-0.0085] 校正值 [-0.006]
# 2设定 -0.6616 预测 [-0.6468] 高炉 [-0.6684] 高炉与设定误差 [0.0067] [0.00622195] 模型误差 [0.0215] 校正值 [0.009]
# 这是对第24时刻的最优U1、U2输入求解
# (25, 1, 10)
# (25, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0027
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0013
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2613 预测 [-0.2507] 高炉 [-0.26] 高炉与设定误差 [-0.0013] [-0.10998252] 模型误差 [0.0093] 校正值 [0.0028]
# 2设定 -0.6616 预测 [-0.6648] 高炉 [-0.6586] 高炉与设定误差 [-0.0031] [-0.00287882] 模型误差 [-0.0062] 校正值 [-0.0225]
# 这是对第25时刻的最优U1、U2输入求解
# (26, 1, 10)
# (26, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0029
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0014
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2613 预测 [-0.2646] 高炉 [-0.2649] 高炉与设定误差 [0.0035] [0.2961068] 模型误差 [0.0002] 校正值 [-0.0084]
# 2设定 -0.6401 预测 [-0.6247] 高炉 [-0.6444] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [0.0197] 校正值 [0.009]
# 这是对第26时刻的最优U1、U2输入求解
# (27, 1, 10)
# (27, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0027
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0014
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2613 预测 [-0.2497] 高炉 [-0.2546] 高炉与设定误差 [-0.0067] [-0.56683298] 模型误差 [0.005] 校正值 [0.0038]
# 2设定 -0.6401 预测 [-0.6472] 高炉 [-0.6369] 高炉与设定误差 [-0.0033] [-0.00306454] 模型误差 [-0.0104] 校正值 [-0.0183]
# 这是对第27时刻的最优U1、U2输入求解
# (28, 1, 10)
# (28, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0022
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0012
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2613 预测 [-0.2715] 高炉 [-0.2642] 高炉与设定误差 [0.0028] [0.23688542] 模型误差 [-0.0073] 校正值 [-0.0047]
# 2设定 -0.6401 预测 [-0.625] 高炉 [-0.6439] 高炉与设定误差 [0.0038] [0.00352887] 模型误差 [0.0189] 校正值 [0.0101]
# 这是对第28时刻的最优U1、U2输入求解
# (29, 1, 10)
# (29, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0025
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0012
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2613 预测 [-0.2531] 高炉 [-0.2657] 高炉与设定误差 [0.0044] [0.37224853] 模型误差 [0.0127] 校正值 [0.0059]
# 2设定 -0.6401 预测 [-0.6468] 高炉 [-0.6425] 高炉与设定误差 [0.0023] [0.0021359] 模型误差 [-0.0043] 校正值 [-0.0186]
# 这是对第29时刻的最优U1、U2输入求解
# (30, 1, 10)
# (30, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0024
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0013
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2613 预测 [-0.2647] 高炉 [-0.2604] 高炉与设定误差 [-0.0009] [-0.07614174] 模型误差 [-0.0042] 校正值 [-0.0154]
# 2设定 -0.6401 预测 [-0.6194] 高炉 [-0.6392] 高炉与设定误差 [-0.0009] [-0.00083578] 模型误差 [0.0198] 校正值 [0.0044]
# 这是对第30时刻的最优U1、U2输入求解
# (31, 1, 10)
# (31, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0012
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.2613 预测 [-0.2475] 高炉 [-0.2595] 高炉与设定误差 [-0.0018] [-0.15228349] 模型误差 [0.0121] 校正值 [0.0061]
# 2设定 -0.6401 预测 [-0.6456] 高炉 [-0.6402] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [-0.0054] 校正值 [-0.0178]
# 这是对第31时刻的最优U1、U2输入求解
# (32, 1, 10)
# (32, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0011
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.2613 预测 [-0.2688] 高炉 [-0.2603] 高炉与设定误差 [-0.001] [-0.08460194] 模型误差 [-0.0085] 校正值 [-0.0092]
# 2设定 -0.6401 预测 [-0.6223] 高炉 [-0.6398] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [0.0175] 校正值 [0.006]
# 这是对第32时刻的最优U1、U2输入求解
# (33, 1, 10)
# (33, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0022
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0012
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2613 预测 [-0.2526] 高炉 [-0.2633] 高炉与设定误差 [0.0019] [0.16074369] 模型误差 [0.0107] 校正值 [0.0108]
# 2设定 -0.6401 预测 [-0.6466] 高炉 [-0.6411] 高炉与设定误差 [0.001] [0.00092865] 模型误差 [-0.0055] 校正值 [-0.0168]
# 这是对第33时刻的最优U1、U2输入求解
# (34, 1, 10)
# (34, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2613 预测 [-0.2702] 高炉 [-0.2652] 高炉与设定误差 [0.0038] [0.32148738] 模型误差 [-0.0051] 校正值 [-0.0118]
# 2设定 -0.6401 预测 [-0.6225] 高炉 [-0.6425] 高炉与设定误差 [0.0024] [0.00222876] 模型误差 [0.02] 校正值 [-0.0011]
# 这是对第34时刻的最优U1、U2输入求解
# (35, 1, 10)
# (35, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0032
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0013
# 第 7/10 轮, 训练误差: 0.0015
# 第 8/10 轮, 训练误差: 0.0009
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.2613 预测 [-0.2468] 高炉 [-0.2527] 高炉与设定误差 [-0.0086] [-0.72757671] 模型误差 [0.0059] 校正值 [-0.0025]
# 2设定 -0.6401 预测 [-0.6369] 高炉 [-0.6318] 高炉与设定误差 [-0.0084] [-0.00780066] 模型误差 [-0.0051] 校正值 [-0.0256]
# 这是对第35时刻的最优U1、U2输入求解
# (36, 1, 10)
# (36, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0018
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.2022 预测 [-0.2209] 高炉 [-0.1779] 高炉与设定误差 [-0.0243] [-2.05582712] 模型误差 [-0.043] 校正值 [-0.0052]
# 2设定 -0.6401 预测 [-0.6158] 高炉 [-0.6156] 高炉与设定误差 [-0.0245] [-0.02275192] 模型误差 [-0.0002] 校正值 [0.0076]
# 这是对第36时刻的最优U1、U2输入求解
# (37, 1, 10)
# (37, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0026
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0014
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2022 预测 [-0.2148] 高炉 [-0.2] 高炉与设定误差 [-0.0022] [-0.18612427] 模型误差 [-0.0148] 校正值 [0.0309]
# 2设定 -0.6401 预测 [-0.6609] 高炉 [-0.6637] 高炉与设定误差 [0.0235] [0.02182327] 模型误差 [0.0028] 校正值 [0.0021]
# 这是对第37时刻的最优U1、U2输入求解
# (38, 1, 10)
# (38, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.2162] 高炉 [-0.2299] 高炉与设定误差 [0.0276] [2.33501352] 模型误差 [0.0137] 校正值 [0.0073]
# 2设定 -0.6401 预测 [-0.6196] 高炉 [-0.6549] 高炉与设定误差 [0.0148] [0.01374402] 模型误差 [0.0353] 校正值 [0.0029]
# 这是对第38时刻的最优U1、U2输入求解
# (39, 1, 10)
# (39, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0019
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.201] 高炉 [-0.1979] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [-0.0031] 校正值 [-0.0097]
# 2设定 -0.6401 预测 [-0.6078] 高炉 [-0.5874] 高炉与设定误差 [-0.0528] [-0.04903272] 模型误差 [-0.0205] 校正值 [-0.032]
# 这是对第39时刻的最优U1、U2输入求解
# (40, 1, 10)
# (40, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.213] 高炉 [-0.1944] 高炉与设定误差 [-0.0079] [-0.66835529] 模型误差 [-0.0186] 校正值 [-0.0076]
# 2设定 -0.6401 预测 [-0.6145] 高炉 [-0.6393] 高炉与设定误差 [-0.0008] [-0.00074292] 模型误差 [0.0247] 校正值 [0.0172]
# 这是对第40时刻的最优U1、U2输入求解
# (41, 1, 10)
# (41, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.1917] 高炉 [-0.2104] 高炉与设定误差 [0.0082] [0.69373591] 模型误差 [0.0188] 校正值 [0.0198]
# 2设定 -0.6401 预测 [-0.6452] 高炉 [-0.6543] 高炉与设定误差 [0.0142] [0.01318683] 模型误差 [0.0091] 校正值 [-0.0231]
# 这是对第41时刻的最优U1、U2输入求解
# (42, 1, 10)
# (42, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0019
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.2019] 高炉 [-0.2087] 高炉与设定误差 [0.0064] [0.5414524] 模型误差 [0.0068] 校正值 [-0.0157]
# 2设定 -0.6401 预测 [-0.6117] 高炉 [-0.6444] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [0.0327] 校正值 [-0.0026]
# 这是对第42时刻的最优U1、U2输入求解
# (43, 1, 10)
# (43, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.186] 高炉 [-0.1935] 高炉与设定误差 [-0.0087] [-0.73603689] 模型误差 [0.0075] 校正值 [-0.0045]
# 2设定 -0.6401 预测 [-0.6351] 高炉 [-0.6347] 高炉与设定误差 [-0.0054] [-0.00501471] 模型误差 [-0.0004] 校正值 [-0.0333]
# 这是对第43时刻的最优U1、U2输入求解
# (44, 1, 10)
# (44, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.2061] 高炉 [-0.1906] 高炉与设定误差 [-0.0116] [-0.98138249] 模型误差 [-0.0155] 校正值 [-0.0062]
# 2设定 -0.6401 预测 [-0.6131] 高炉 [-0.6379] 高炉与设定误差 [-0.0022] [-0.00204303] 模型误差 [0.0248] 校正值 [0.0025]
# 这是对第44时刻的最优U1、U2输入求解
# (45, 1, 10)
# (45, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.2009] 高炉 [-0.1944] 高炉与设定误差 [-0.0078] [-0.65989511] 模型误差 [-0.0065] 校正值 [0.0152]
# 2设定 -0.6401 预测 [-0.6474] 高炉 [-0.6444] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [-0.003] 校正值 [-0.0229]
# 这是对第45时刻的最优U1、U2输入求解
# (46, 1, 10)
# (46, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.2102] 高炉 [-0.203] 高炉与设定误差 [0.0007] [0.05922136] 模型误差 [-0.0072] 校正值 [0.0058]
# 2设定 -0.6186 预测 [-0.6033] 高炉 [-0.629] 高炉与设定误差 [0.0104] [0.00965796] 模型误差 [0.0257] 校正值 [0.0044]
# 这是对第46时刻的最优U1、U2输入求解
# (47, 1, 10)
# (47, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0015
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.1994] 高炉 [-0.2018] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0025] 校正值 [0.0084]
# 2设定 -0.6186 预测 [-0.6186] 高炉 [-0.6107] 高炉与设定误差 [-0.0079] [-0.00733633] 模型误差 [-0.0079] 校正值 [-0.0238]
# 这是对第47时刻的最优U1、U2输入求解
# (48, 1, 10)
# (48, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0005
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.2022 预测 [-0.2134] 高炉 [-0.2004] 高炉与设定误差 [-0.0018] [-0.15228349] 模型误差 [-0.013] 校正值 [-0.0058]
# 2设定 -0.6186 预测 [-0.5988] 高炉 [-0.6191] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [0.0203] 校正值 [0.0074]
# 这是对第48时刻的最优U1、U2输入求解
# (49, 1, 10)
# (49, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.2022 预测 [-0.1934] 高炉 [-0.1988] 高炉与设定误差 [-0.0035] [-0.2961068] 模型误差 [0.0054] 校正值 [0.0122]
# 2设定 -0.6186 预测 [-0.6282] 高炉 [-0.6242] 高炉与设定误差 [0.0056] [0.00520044] 模型误差 [-0.004] 校正值 [-0.0182]
# 这是对第49时刻的最优U1、U2输入求解
# (50, 1, 10)
# (50, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.2139] 高炉 [-0.198] 高炉与设定误差 [-0.0042] [-0.35532814] 模型误差 [-0.0159] 校正值 [-0.0069]
# 2设定 -0.6186 预测 [-0.5998] 高炉 [-0.6169] 高炉与设定误差 [-0.0017] [-0.00157871] 模型误差 [0.0171] 校正值 [0.0061]
# 这是对第50时刻的最优U1、U2输入求解
# (51, 1, 10)
# (51, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.1973] 高炉 [-0.2015] 高炉与设定误差 [-0.0008] [-0.06768155] 模型误差 [0.0042] 校正值 [0.015]
# 2设定 -0.6186 预测 [-0.6291] 高炉 [-0.6228] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [-0.0063] 校正值 [-0.0166]
# 这是对第51时刻的最优U1、U2输入求解
# (52, 1, 10)
# (52, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.2022 预测 [-0.2121] 高炉 [-0.2065] 高炉与设定误差 [0.0043] [0.36378835] 模型误差 [-0.0056] 校正值 [-0.0021]
# 2设定 -0.6186 预测 [-0.6] 高炉 [-0.6206] 高炉与设定误差 [0.002] [0.0018573] 模型误差 [0.0206] 校正值 [0.0079]
# 这是对第52时刻的最优U1、U2输入求解
# (53, 1, 10)
# (53, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.2022 预测 [-0.1968] 高炉 [-0.201] 高炉与设定误差 [-0.0012] [-0.10152233] 模型误差 [0.0042] 校正值 [0.0114]
# 2设定 -0.6186 预测 [-0.6249] 高炉 [-0.618] 高炉与设定误差 [-0.0005] [-0.00046433] 模型误差 [-0.0069] 校正值 [-0.0164]
# 这是对第53时刻的最优U1、U2输入求解
# (54, 1, 10)
# (54, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.2022 预测 [-0.2154] 高炉 [-0.1939] 高炉与设定误差 [-0.0083] [-0.70219609] 模型误差 [-0.0215] 校正值 [-0.0014]
# 2设定 -0.6186 预测 [-0.603] 高炉 [-0.6153] 高炉与设定误差 [-0.0033] [-0.00306454] 模型误差 [0.0123] 校正值 [0.0093]
# 这是对第54时刻的最优U1、U2输入求解
# (55, 1, 10)
# (55, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.2022 预测 [-0.2032] 高炉 [-0.1973] 高炉与设定误差 [-0.005] [-0.42300969] 模型误差 [-0.0059] 校正值 [0.0119]
# 2设定 -0.6186 预测 [-0.6311] 高炉 [-0.616] 高炉与设定误差 [-0.0025] [-0.00232162] 模型误差 [-0.0151] 校正值 [-0.0106]
# 这是对第55时刻的最优U1、U2输入求解
# (56, 1, 10)
# (56, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0017
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1599] 高炉 [-0.159] 高炉与设定误差 [0.0159] [1.34517092] 模型误差 [-0.0009] 校正值 [0.0011]
# 2设定 -0.6186 预测 [-0.6044] 高炉 [-0.6189] 高炉与设定误差 [0.0004] [0.00037146] 模型误差 [0.0146] 校正值 [0.0132]
# 这是对第56时刻的最优U1、U2输入求解
# (57, 1, 10)
# (57, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0012
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1405] 高炉 [-0.1467] 高炉与设定误差 [0.0036] [0.30456698] 模型误差 [0.0062] 校正值 [0.0008]
# 2设定 -0.6186 预测 [-0.6327] 高炉 [-0.6279] 高炉与设定误差 [0.0093] [0.00863645] 模型误差 [-0.0049] 校正值 [-0.0132]
# 这是对第57时刻的最优U1、U2输入求解
# (58, 1, 10)
# (58, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1432] 高炉 [-0.1338] 高炉与设定误差 [-0.0093] [-0.78679804] 模型误差 [-0.0093] 校正值 [-0.007]
# 2设定 -0.6186 预测 [-0.6028] 高炉 [-0.6172] 高炉与设定误差 [-0.0013] [-0.00120725] 模型误差 [0.0144] 校正值 [0.0057]
# 这是对第58时刻的最优U1、U2输入求解
# (59, 1, 10)
# (59, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1427] 高炉 [-0.1371] 高炉与设定误差 [-0.0061] [-0.51607182] 模型误差 [-0.0056] 校正值 [0.0078]
# 2设定 -0.6186 预测 [-0.6271] 高炉 [-0.6193] 高炉与设定误差 [0.0007] [0.00065005] 模型误差 [-0.0078] 校正值 [-0.0141]
# 这是对第59时刻的最优U1、U2输入求解
# (60, 1, 10)
# (60, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0015
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1524] 高炉 [-0.1373] 高炉与设定误差 [-0.0059] [-0.49915146] 模型误差 [-0.0151] 校正值 [0.002]
# 2设定 -0.6186 预测 [-0.6054] 高炉 [-0.6171] 高炉与设定误差 [-0.0015] [-0.00139298] 模型误差 [0.0117] 校正值 [0.0075]
# 这是对第60时刻的最优U1、U2输入求解
# (61, 1, 10)
# (61, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1485] 高炉 [-0.1474] 高炉与设定误差 [0.0043] [0.36378835] 模型误差 [-0.0011] 校正值 [0.0136]
# 2设定 -0.6186 预测 [-0.6299] 高炉 [-0.6251] 高炉与设定误差 [0.0066] [0.00612909] 模型误差 [-0.0048] 校正值 [-0.0109]
# 这是对第61时刻的最优U1、U2输入求解
# (62, 1, 10)
# (62, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0015
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.1431 预测 [-0.1496] 高炉 [-0.1442] 高炉与设定误差 [0.0011] [0.09306213] 模型误差 [-0.0054] 校正值 [-0.0001]
# 2设定 -0.6186 预测 [-0.6035] 高炉 [-0.6193] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [0.0158] 校正值 [0.0057]
# 这是对第62时刻的最优U1、U2输入求解
# (63, 1, 10)
# (63, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0010
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1428] 高炉 [-0.1418] 高炉与设定误差 [-0.0013] [-0.10998252] 模型误差 [-0.001] 校正值 [0.0046]
# 2设定 -0.6186 预测 [-0.6243] 高炉 [-0.619] 高炉与设定误差 [0.0004] [0.00037146] 模型误差 [-0.0053] 校正值 [-0.0148]
# 这是对第63时刻的最优U1、U2输入求解
# (64, 1, 10)
# (64, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.1431 预测 [-0.1477] 高炉 [-0.1411] 高炉与设定误差 [-0.0021] [-0.17766407] 模型误差 [-0.0066] 校正值 [0.]
# 2设定 -0.6186 预测 [-0.6039] 高炉 [-0.6188] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [0.0149] 校正值 [0.0064]
# 这是对第64时刻的最优U1、U2输入求解
# (65, 1, 10)
# (65, 1, 2)
# 第 1/10 轮, 训练误差: 0.0016
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.144] 高炉 [-0.1433] 高炉与设定误差 [0.0002] [0.01692039] 模型误差 [-0.0007] 校正值 [0.0041]
# 2设定 -0.6186 预测 [-0.6248] 高炉 [-0.6191] 高炉与设定误差 [0.0006] [0.00055719] 模型误差 [-0.0057] 校正值 [-0.01]
# 这是对第65时刻的最优U1、U2输入求解
# (66, 1, 10)
# (66, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.1431 预测 [-0.1441] 高炉 [-0.142] 高炉与设定误差 [-0.0011] [-0.09306213] 模型误差 [-0.0021] 校正值 [-0.0021]
# 2设定 -0.597 预测 [-0.5909] 高炉 [-0.5995] 高炉与设定误差 [0.0024] [0.00222876] 模型误差 [0.0086] 校正值 [0.0065]
# 这是对第66时刻的最优U1、U2输入求解
# (67, 1, 10)
# (67, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.1431 预测 [-0.1381] 高炉 [-0.1371] 高炉与设定误差 [-0.006] [-0.50761164] 模型误差 [-0.001] 校正值 [0.0058]
# 2设定 -0.597 预测 [-0.6042] 高炉 [-0.5956] 高炉与设定误差 [-0.0014] [-0.00130011] 模型误差 [-0.0086] 校正值 [-0.0069]
# 这是对第67时刻的最优U1、U2输入求解
# (68, 1, 10)
# (68, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.1431 预测 [-0.1416] 高炉 [-0.1392] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [-0.0024] 校正值 [-0.0026]
# 2设定 -0.597 预测 [-0.594] 高炉 [-0.6011] 高炉与设定误差 [0.0041] [0.00380747] 模型误差 [0.0071] 校正值 [0.0084]
# 这是对第68时刻的最优U1、U2输入求解
# (69, 1, 10)
# (69, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1401] 高炉 [-0.1436] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [0.0034] 校正值 [0.0081]
# 2设定 -0.597 预测 [-0.6067] 高炉 [-0.5985] 高炉与设定误差 [0.0015] [0.00139298] 模型误差 [-0.0082] 校正值 [-0.0048]
# 这是对第69时刻的最优U1、U2输入求解
# (70, 1, 10)
# (70, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1499] 高炉 [-0.1452] 高炉与设定误差 [0.0021] [0.17766407] 模型误差 [-0.0047] 校正值 [-0.0044]
# 2设定 -0.597 预测 [-0.5915] 高炉 [-0.5987] 高炉与设定误差 [0.0017] [0.00157871] 模型误差 [0.0072] 校正值 [0.0059]
# 这是对第70时刻的最优U1、U2输入求解
# (71, 1, 10)
# (71, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1374] 高炉 [-0.1406] 高炉与设定误差 [-0.0025] [-0.21150485] 模型误差 [0.0032] 校正值 [0.001]
# 2设定 -0.597 预测 [-0.6017] 高炉 [-0.5956] 高炉与设定误差 [-0.0014] [-0.00130011] 模型误差 [-0.0061] 校正值 [-0.0095]
# 这是对第71时刻的最优U1、U2输入求解
# (72, 1, 10)
# (72, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1471] 高炉 [-0.1377] 高炉与设定误差 [-0.0055] [-0.46531067] 模型误差 [-0.0095] 校正值 [-0.0036]
# 2设定 -0.597 预测 [-0.5892] 高炉 [-0.5928] 高炉与设定误差 [-0.0042] [-0.00390033] 模型误差 [0.0037] 校正值 [0.0067]
# 这是对第72时刻的最优U1、U2输入求解
# (73, 1, 10)
# (73, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1409] 高炉 [-0.1464] 高炉与设定误差 [0.0032] [0.2707262] 模型误差 [0.0055] 校正值 [0.0117]
# 2设定 -0.597 预测 [-0.6083] 高炉 [-0.6008] 高炉与设定误差 [0.0037] [0.00343601] 模型误差 [-0.0076] 校正值 [-0.0016]
# 这是对第73时刻的最优U1、U2输入求解
# (74, 1, 10)
# (74, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.1489] 高炉 [-0.1546] 高炉与设定误差 [0.0115] [0.97292231] 模型误差 [0.0058] 校正值 [-0.006]
# 2设定 -0.597 预测 [-0.5929] 高炉 [-0.6046] 高炉与设定误差 [0.0076] [0.00705774] 模型误差 [0.0117] 校正值 [0.0053]
# 这是对第74时刻的最优U1、U2输入求解
# (75, 1, 10)
# (75, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.1431 预测 [-0.129] 高炉 [-0.1388] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [0.0098] 校正值 [-0.0052]
# 2设定 -0.597 预测 [-0.5953] 高炉 [-0.5929] 高炉与设定误差 [-0.0041] [-0.00380747] 模型误差 [-0.0024] 校正值 [-0.0116]
# 这是对第75时刻的最优U1、U2输入求解
# (76, 1, 10)
# (76, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0989] 高炉 [-0.0972] 高炉与设定误差 [0.0131] [1.10828542] 模型误差 [-0.0018] 校正值 [-0.0073]
# 2设定 -0.597 预测 [-0.5843] 高炉 [-0.5889] 高炉与设定误差 [-0.0081] [-0.00752207] 模型误差 [0.0046] 校正值 [0.0049]
# 这是对第76时刻的最优U1、U2输入求解
# (77, 1, 10)
# (77, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0774] 高炉 [-0.0802] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [0.0027] 校正值 [0.0037]
# 2设定 -0.597 预测 [-0.6052] 高炉 [-0.5982] 高炉与设定误差 [0.0012] [0.00111438] 模型误差 [-0.0071] 校正值 [-0.0038]
# 这是对第77时刻的最优U1、U2输入求解
# (78, 1, 10)
# (78, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0858] 高炉 [-0.07] 高炉与设定误差 [-0.014] [-1.1844272] 模型误差 [-0.0157] 校正值 [-0.0075]
# 2设定 -0.597 预测 [-0.5927] 高炉 [-0.595] 高炉与设定误差 [-0.0021] [-0.00195016] 模型误差 [0.0023] 校正值 [0.0057]
# 这是对第78时刻的最优U1、U2输入求解
# (79, 1, 10)
# (79, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0818] 高炉 [-0.0797] 高炉与设定误差 [-0.0043] [-0.36378835] 模型误差 [-0.002] 校正值 [0.0105]
# 2设定 -0.597 预测 [-0.6089] 高炉 [-0.6005] 高炉与设定误差 [0.0035] [0.00325028] 模型误差 [-0.0084] 校正值 [-0.0035]
# 这是对第79时刻的最优U1、U2输入求解
# (80, 1, 10)
# (80, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0926] 高炉 [-0.0914] 高炉与设定误差 [0.0073] [0.61759418] 模型误差 [-0.0012] 校正值 [-0.0012]
# 2设定 -0.597 预测 [-0.594] 高炉 [-0.6024] 高炉与设定误差 [0.0054] [0.00501471] 模型误差 [0.0084] 校正值 [0.0064]
# 这是对第80时刻的最优U1、U2输入求解
# (81, 1, 10)
# (81, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0759] 高炉 [-0.0884] 高炉与设定误差 [0.0043] [0.36378835] 模型误差 [0.0124] 校正值 [0.0051]
# 2设定 -0.597 预测 [-0.5973] 高炉 [-0.5956] 高炉与设定误差 [-0.0015] [-0.00139298] 模型误差 [-0.0018] 校正值 [-0.0046]
# 这是对第81时刻的最优U1、U2输入求解
# (82, 1, 10)
# (82, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0010
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0884] 高炉 [-0.0801] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [-0.0083] 校正值 [0.0037]
# 2设定 -0.597 预测 [-0.5927] 高炉 [-0.5956] 高炉与设定误差 [-0.0014] [-0.00130011] 模型误差 [0.0029] 校正值 [-0.004]
# 这是对第82时刻的最优U1、U2输入求解
# (83, 1, 10)
# (83, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0899] 高炉 [-0.0759] 高炉与设定误差 [-0.0081] [-0.68527573] 模型误差 [-0.014] 校正值 [-0.0025]
# 2设定 -0.597 预测 [-0.5954] 高炉 [-0.5952] 高炉与设定误差 [-0.0018] [-0.00167157] 模型误差 [-0.0002] 校正值 [-0.0027]
# 这是对第83时刻的最优U1、U2输入求解
# (84, 1, 10)
# (84, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0841] 高炉 [-0.0839] 高炉与设定误差 [-1.e-04] [-0.00846019] 模型误差 [-0.0002] 校正值 [0.0095]
# 2设定 -0.597 预测 [-0.5988] 高炉 [-0.6004] 高炉与设定误差 [0.0033] [0.00306454] 模型误差 [0.0015] 校正值 [-0.0028]
# 这是对第84时刻的最优U1、U2输入求解
# (85, 1, 10)
# (85, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0908] 高炉 [-0.0916] 高炉与设定误差 [0.0076] [0.64297475] 模型误差 [0.0009] 校正值 [-0.0057]
# 2设定 -0.597 预测 [-0.5926] 高炉 [-0.6005] 高炉与设定误差 [0.0034] [0.00315741] 模型误差 [0.0079] 校正值 [0.0056]
# 这是对第85时刻的最优U1、U2输入求解
# (86, 1, 10)
# (86, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0621] 高炉 [-0.0869] 高炉与设定误差 [0.0029] [0.24534562] 模型误差 [0.0249] 校正值 [-0.0047]
# 2设定 -0.5755 预测 [-0.5882] 高炉 [-0.5815] 高炉与设定误差 [0.006] [0.0055719] 模型误差 [-0.0067] 校正值 [-0.0076]
# 这是对第86时刻的最优U1、U2输入求解
# (87, 1, 10)
# (87, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0784] 高炉 [-0.0854] 高炉与设定误差 [0.0014] [0.11844271] 模型误差 [0.0071] 校正值 [-0.0194]
# 2设定 -0.5755 预测 [-0.5669] 高炉 [-0.5719] 高炉与设定误差 [-0.0036] [-0.00334314] 模型误差 [0.005] 校正值 [0.008]
# 这是对第87时刻的最优U1、U2输入求解
# (88, 1, 10)
# (88, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0712] 高炉 [-0.0643] 高炉与设定误差 [-0.0198] [-1.6751184] 模型误差 [-0.007] 校正值 [-0.0042]
# 2设定 -0.5755 预测 [-0.5831] 高炉 [-0.5677] 高炉与设定误差 [-0.0078] [-0.00724347] 模型误差 [-0.0154] 校正值 [-0.0076]
# 这是对第88时刻的最优U1、U2输入求解
# (89, 1, 10)
# (89, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0929] 高炉 [-0.072] 高炉与设定误差 [-0.0121] [-1.02368347] 模型误差 [-0.021] 校正值 [-0.0023]
# 2设定 -0.5755 预测 [-0.5778] 高炉 [-0.5757] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [-0.0021] 校正值 [0.0132]
# 这是对第89时刻的最优U1、U2输入求解
# (90, 1, 10)
# (90, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0846] 高炉 [-0.0871] 高炉与设定误差 [0.003] [0.25380582] 模型误差 [0.0025] 校正值 [0.0128]
# 2设定 -0.5755 预测 [-0.5893] 高炉 [-0.5821] 高炉与设定误差 [0.0066] [0.00612909] 模型误差 [-0.0072] 校正值 [-0.0005]
# 这是对第90时刻的最优U1、U2输入求解
# (91, 1, 10)
# (91, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0902] 高炉 [-0.0871] 高炉与设定误差 [0.003] [0.25380582] 模型误差 [-0.0032] 校正值 [-0.0008]
# 2设定 -0.5755 预测 [-0.5698] 高炉 [-0.5764] 高炉与设定误差 [0.0009] [0.00083578] 模型误差 [0.0067] 校正值 [0.007]
# 这是对第91时刻的最优U1、U2输入求解
# (92, 1, 10)
# (92, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0809] 高炉 [-0.0843] 高炉与设定误差 [0.0002] [0.01692039] 模型误差 [0.0034] 校正值 [0.0044]
# 2设定 -0.5755 预测 [-0.5825] 高炉 [-0.5765] 高炉与设定误差 [0.001] [0.00092865] 模型误差 [-0.006] 校正值 [-0.0069]
# 这是对第92时刻的最优U1、U2输入求解
# (93, 1, 10)
# (93, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0882] 高炉 [-0.0785] 高炉与设定误差 [-0.0056] [-0.47377085] 模型误差 [-0.0097] 校正值 [-0.0044]
# 2设定 -0.5755 预测 [-0.5681] 高炉 [-0.5721] 高炉与设定误差 [-0.0034] [-0.00315741] 模型误差 [0.004] 校正值 [0.0059]
# 这是对第93时刻的最优U1、U2输入求解
# (94, 1, 10)
# (94, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0826] 高炉 [-0.083] 高炉与设定误差 [-0.001] [-0.08460194] 模型误差 [0.0004] 校正值 [0.0101]
# 2设定 -0.5755 预测 [-0.5856] 高炉 [-0.5754] 高炉与设定误差 [-1.e-04] [-9.28649977e-05] 模型误差 [-0.0102] 校正值 [-0.0031]
# 这是对第94时刻的最优U1、U2输入求解
# (95, 1, 10)
# (95, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0935] 高炉 [-0.0885] 高炉与设定误差 [0.0045] [0.38070871] 模型误差 [-0.005] 校正值 [-0.0018]
# 2设定 -0.5755 预测 [-0.5731] 高炉 [-0.5787] 高炉与设定误差 [0.0032] [0.00297168] 模型误差 [0.0056] 校正值 [0.0063]
# 这是对第95时刻的最优U1、U2输入求解
# (96, 1, 10)
# (96, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0002
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0386] 高炉 [-0.0455] 高炉与设定误差 [0.0206] [1.7428] 模型误差 [0.0069] 校正值 [0.0065]
# 2设定 -0.5755 预测 [-0.5726] 高炉 [-0.5672] 高炉与设定误差 [-0.0083] [-0.00770779] 模型误差 [-0.0055] 校正值 [-0.0043]
# 这是对第96时刻的最优U1、U2输入求解
# (97, 1, 10)
# (97, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0009
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0255] 高炉 [-0.029] 高炉与设定误差 [0.004] [0.33840778] 模型误差 [0.0035] 校正值 [0.0045]
# 2设定 -0.5755 预测 [-0.5767] 高炉 [-0.5839] 高炉与设定误差 [0.0084] [0.00780066] 模型误差 [0.0071] 校正值 [-0.0026]
# 这是对第97时刻的最优U1、U2输入求解
# (98, 1, 10)
# (98, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0009
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0273] 高炉 [-0.0208] 高炉与设定误差 [-0.0041] [-0.34686796] 模型误差 [-0.0065] 校正值 [-0.0039]
# 2设定 -0.5755 预测 [-0.5651] 高炉 [-0.5652] 高炉与设定误差 [-0.0103] [-0.0095651] 模型误差 [1.e-04] 校正值 [-0.0084]
# 这是对第98时刻的最优U1、U2输入求解
# (99, 1, 10)
# (99, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0291] 高炉 [-0.0251] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [-0.004] 校正值 [0.0089]
# 2设定 -0.5755 预测 [-0.5751] 高炉 [-0.5772] 高炉与设定误差 [0.0017] [0.00157871] 模型误差 [0.0021] 校正值 [-0.0013]
# 这是对第99时刻的最优U1、U2输入求解
# (100, 1, 10)
# (100, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0009
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0314] 高炉 [-0.0311] 高炉与设定误差 [0.0061] [0.51607182] 模型误差 [-0.0004] 校正值 [0.0025]
# 2设定 -0.5755 预测 [-0.573] 高炉 [-0.5818] 高炉与设定误差 [0.0063] [0.0058505] 模型误差 [0.0088] 校正值 [-0.0033]
# 这是对第100时刻的最优U1、U2输入求解
# (101, 1, 10)
# (101, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0265] 高炉 [-0.0315] 高炉与设定误差 [0.0066] [0.5583728] 模型误差 [0.0051] 校正值 [0.0021]
# 2设定 -0.5755 预测 [-0.567] 高炉 [-0.5788] 高炉与设定误差 [0.0033] [0.00306454] 模型误差 [0.0118] 校正值 [-0.0085]
# 这是对第101时刻的最优U1、U2输入求解
# (102, 1, 10)
# (102, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0251] 高炉 [-0.0234] 高炉与设定误差 [-0.0015] [-0.12690291] 模型误差 [-0.0017] 校正值 [-0.0053]
# 2设定 -0.5755 预测 [-0.5632] 高炉 [-0.5707] 高炉与设定误差 [-0.0048] [-0.00445752] 模型误差 [0.0075] 校正值 [-0.0115]
# 这是对第102时刻的最优U1、U2输入求解
# (103, 1, 10)
# (103, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0009
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# ...
# 2设定 -0.4894 预测 [-0.4912] 高炉 [-0.4905] 高炉与设定误差 [0.0011] [0.00102151] 模型误差 [-0.0007] 校正值 [0.0027]
# 这是对第166时刻的最优U1、U2输入求解
# (167, 1, 10)
# (167, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.1524 预测 [0.1493] 高炉 [0.1544] 高炉与设定误差 [-0.0021] [-0.17766407] 模型误差 [-0.0051] 校正值 [0.0024]
# 2设定 -0.4894 预测 [-0.4948] 高炉 [-0.4859] 高炉与设定误差 [-0.0035] [-0.00325028] 模型误差 [-0.0089] 校正值 [0.0004]
# 这是对第167时刻的最优U1、U2输入求解
# (168, 1, 10)
# (168, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.1524 预测 [0.1504] 高炉 [0.155] 高炉与设定误差 [-0.0026] [-0.21996504] 模型误差 [-0.0046] 校正值 [0.0043]
# 2设定 -0.4894 预测 [-0.4932] 高炉 [-0.4851] 高炉与设定误差 [-0.0042] [-0.00390033] 模型误差 [-0.0081] 校正值 [0.0079]
# 这是对第168时刻的最优U1、U2输入求解
# (169, 1, 10)
# (169, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.1524 预测 [0.1495] 高炉 [0.1521] 高炉与设定误差 [0.0002] [0.01692039] 模型误差 [-0.0027] 校正值 [0.0041]
# 2设定 -0.4894 预测 [-0.502] 高炉 [-0.4946] 高炉与设定误差 [0.0053] [0.00492184] 模型误差 [-0.0074] 校正值 [0.0072]
# 这是对第169时刻的最优U1、U2输入求解
# (170, 1, 10)
# (170, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.1524 预测 [0.1513] 高炉 [0.154] 高炉与设定误差 [-0.0016] [-0.1353631] 模型误差 [-0.0026] 校正值 [0.0024]
# 2设定 -0.4894 预测 [-0.4924] 高炉 [-0.4891] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [-0.0033] 校正值 [0.0061]
# 这是对第170时刻的最优U1、U2输入求解
# (171, 1, 10)
# (171, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.1524 预测 [0.1501] 高炉 [0.1546] 高炉与设定误差 [-0.0022] [-0.18612427] 模型误差 [-0.0044] 校正值 [0.0028]
# 2设定 -0.4894 预测 [-0.497] 高炉 [-0.4873] 高炉与设定误差 [-0.0021] [-0.00195016] 模型误差 [-0.0098] 校正值 [0.0032]
# 这是对第171时刻的最优U1、U2输入求解
# (172, 1, 10)
# (172, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.1524 预测 [0.1501] 高炉 [0.1519] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [-0.0018] 校正值 [0.0038]
# 2设定 -0.4894 预测 [-0.4959] 高炉 [-0.4935] 高炉与设定误差 [0.0042] [0.00390033] 模型误差 [-0.0023] 校正值 [0.0096]
# 这是对第172时刻的最优U1、U2输入求解
# (173, 1, 10)
# (173, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0000
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.1524 预测 [0.1515] 高炉 [0.1537] 高炉与设定误差 [-0.0013] [-0.10998252] 模型误差 [-0.0022] 校正值 [0.0007]
# 2设定 -0.4894 预测 [-0.4971] 高炉 [-0.4919] 高炉与设定误差 [0.0025] [0.00232162] 模型误差 [-0.0052] 校正值 [0.0011]
# 这是对第173时刻的最优U1、U2输入求解
# (174, 1, 10)
# (174, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.1524 预测 [0.152] 高炉 [0.1542] 高炉与设定误差 [-0.0018] [-0.15228349] 模型误差 [-0.0022] 校正值 [0.0019]
# 2设定 -0.4894 预测 [-0.4906] 高炉 [-0.4873] 高炉与设定误差 [-0.0021] [-0.00195016] 模型误差 [-0.0033] 校正值 [0.0042]
# 这是对第174时刻的最优U1、U2输入求解
# (175, 1, 10)
# (175, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.1524 预测 [0.1531] 高炉 [0.1565] 高炉与设定误差 [-0.0042] [-0.35532814] 模型误差 [-0.0034] 校正值 [0.0024]
# 2设定 -0.4894 预测 [-0.4976] 高炉 [-0.4905] 高炉与设定误差 [0.0011] [0.00102151] 模型误差 [-0.0072] 校正值 [0.0033]
# 这是对第175时刻的最优U1、U2输入求解
# (176, 1, 10)
# (176, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.1937] 高炉 [0.2095] 高炉与设定误差 [0.0019] [0.16074369] 模型误差 [-0.0158] 校正值 [0.0029]
# 2设定 -0.4894 预测 [-0.4918] 高炉 [-0.4725] 高炉与设定误差 [-0.0168] [-0.01560132] 模型误差 [-0.0193] 校正值 [0.0063]
# 这是对第176时刻的最优U1、U2输入求解
# (177, 1, 10)
# (177, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.196] 高炉 [0.2117] 高炉与设定误差 [-0.0002] [-0.01692039] 模型误差 [-0.0157] 校正值 [0.0135]
# 2设定 -0.4894 预测 [-0.4994] 高炉 [-0.5163] 高炉与设定误差 [0.0269] [0.02498069] 模型误差 [0.0169] 校正值 [0.0156]
# 这是对第177时刻的最优U1、U2输入求解
# (178, 1, 10)
# (178, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2025] 高炉 [0.2088] 高炉与设定误差 [0.0027] [0.22842524] 模型误差 [-0.0062] 校正值 [0.0054]
# 2设定 -0.4894 预测 [-0.496] 高炉 [-0.4966] 高炉与设定误差 [0.0072] [0.00668628] 模型误差 [0.0006] 校正值 [0.0065]
# 这是对第178时刻的最优U1、U2输入求解
# (179, 1, 10)
# (179, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0000
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2125] 高炉 [0.2195] 高炉与设定误差 [-0.0081] [-0.68527573] 模型误差 [-0.0071] 校正值 [0.]
# 2设定 -0.4894 预测 [-0.49] 高炉 [-0.4922] 高炉与设定误差 [0.0029] [0.00269308] 模型误差 [0.0023] 校正值 [-0.0017]
# 这是对第179时刻的最优U1、U2输入求解
# (180, 1, 10)
# (180, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2102] 高炉 [0.2156] 高炉与设定误差 [-0.0041] [-0.34686796] 模型误差 [-0.0054] 校正值 [0.0035]
# 2设定 -0.4894 预测 [-0.4879] 高炉 [-0.4876] 高炉与设定误差 [-0.0018] [-0.00167157] 模型误差 [-0.0003] 校正值 [-0.0044]
# 这是对第180时刻的最优U1、U2输入求解
# (181, 1, 10)
# (181, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2094] 高炉 [0.2004] 高炉与设定误差 [0.011] [0.93062133] 模型误差 [0.009] 校正值 [0.0081]
# 2设定 -0.4894 预测 [-0.4874] 高炉 [-0.4907] 高炉与设定误差 [0.0014] [0.00130011] 模型误差 [0.0033] 校正值 [0.0028]
# 这是对第181时刻的最优U1、U2输入求解
# (182, 1, 10)
# (182, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2092] 高炉 [0.2141] 高炉与设定误差 [-0.0027] [-0.22842524] 模型误差 [-0.0049] 校正值 [-0.0024]
# 2设定 -0.4894 预测 [-0.4883] 高炉 [-0.4859] 高炉与设定误差 [-0.0034] [-0.00315741] 模型误差 [-0.0023] 校正值 [-0.0007]
# 这是对第182时刻的最优U1、U2输入求解
# (183, 1, 10)
# (183, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2109] 高炉 [0.2175] 高炉与设定误差 [-0.006] [-0.50761164] 模型误差 [-0.0066] 校正值 [0.0051]
# 2设定 -0.4894 预测 [-0.4929] 高炉 [-0.4876] 高炉与设定误差 [-0.0018] [-0.00167157] 模型误差 [-0.0053] 校正值 [0.0021]
# 这是对第183时刻的最优U1、U2输入求解
# (184, 1, 10)
# (184, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2026] 高炉 [0.2123] 高炉与设定误差 [-0.0008] [-0.06768155] 模型误差 [-0.0097] 校正值 [0.0028]
# 2设定 -0.4894 预测 [-0.4931] 高炉 [-0.4938] 高炉与设定误差 [0.0044] [0.00408606] 模型误差 [0.0007] 校正值 [0.0049]
# 这是对第184时刻的最优U1、U2输入求解
# (185, 1, 10)
# (185, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.214] 高炉 [0.2164] 高炉与设定误差 [-0.0049] [-0.41454951] 模型误差 [-0.0024] 校正值 [0.006]
# 2设定 -0.4894 预测 [-0.4888] 高炉 [-0.4878] 高炉与设定误差 [-0.0016] [-0.00148584] 模型误差 [-0.001] 校正值 [0.003]
# 这是对第185时刻的最优U1、U2输入求解
# (186, 1, 10)
# (186, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2068] 高炉 [0.2263] 高炉与设定误差 [-0.0149] [-1.26056889] 模型误差 [-0.0195] 校正值 [0.0033]
# 2设定 -0.4678 预测 [-0.473] 高炉 [-0.4536] 高炉与设定误差 [-0.0142] [-0.01318683] 模型误差 [-0.0193] 校正值 [-0.0036]
# 这是对第186时刻的最优U1、U2输入求解
# (187, 1, 10)
# (187, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.202] 高炉 [0.2052] 高炉与设定误差 [0.0062] [0.52453204] 模型误差 [-0.0032] 校正值 [0.0116]
# 2设定 -0.4678 预测 [-0.4814] 高炉 [-0.482] 高炉与设定误差 [0.0141] [0.01309397] 模型误差 [0.0006] 校正值 [0.0156]
# 这是对第187时刻的最优U1、U2输入求解
# (188, 1, 10)
# (188, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2078] 高炉 [0.2046] 高炉与设定误差 [0.0068] [0.5752932] 模型误差 [0.0032] 校正值 [0.0032]
# 2设定 -0.4678 预测 [-0.4742] 高炉 [-0.4735] 高炉与设定误差 [0.0057] [0.00529331] 模型误差 [-0.0007] 校正值 [0.0002]
# 这是对第188时刻的最优U1、U2输入求解
# (189, 1, 10)
# (189, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2108] 高炉 [0.2183] 高炉与设定误差 [-0.0069] [-0.58375338] 模型误差 [-0.0075] 校正值 [0.0009]
# 2设定 -0.4678 预测 [-0.4641] 高炉 [-0.4568] 高炉与设定误差 [-0.011] [-0.01021515] 模型误差 [-0.0073] 校正值 [-0.002]
# 这是对第189时刻的最优U1、U2输入求解
# (190, 1, 10)
# (190, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.207] 高炉 [0.2114] 高炉与设定误差 [0.] [0.] 模型误差 [-0.0044] 校正值 [0.0091]
# 2设定 -0.4678 预测 [-0.4759] 高炉 [-0.4704] 高炉与设定误差 [0.0026] [0.00241449] 模型误差 [-0.0055] 校正值 [0.0086]
# 这是对第190时刻的最优U1、U2输入求解
# (191, 1, 10)
# (191, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2054] 高炉 [0.2064] 高炉与设定误差 [0.0051] [0.43146991] 模型误差 [-0.001] 校正值 [0.0041]
# 2设定 -0.4678 预测 [-0.4733] 高炉 [-0.4684] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [-0.0049] 校正值 [0.0076]
# 这是对第191时刻的最优U1、U2输入求解
# (192, 1, 10)
# (192, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2114] 高炉 [0.2103] 高炉与设定误差 [0.0011] [0.09306213] 模型误差 [0.001] 校正值 [-0.0011]
# 2设定 -0.4678 预测 [-0.4751] 高炉 [-0.4675] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [-0.0075] 校正值 [0.0057]
# 这是对第192时刻的最优U1、U2输入求解
# (193, 1, 10)
# (193, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2128] 高炉 [0.2115] 高炉与设定误差 [-0.] [-0.] 模型误差 [0.0013] 校正值 [0.0024]
# 2设定 -0.4678 预测 [-0.4735] 高炉 [-0.4625] 高炉与设定误差 [-0.0053] [-0.00492184] 模型误差 [-0.0111] 校正值 [-0.0004]
# 这是对第193时刻的最优U1、U2输入求解
# (194, 1, 10)
# (194, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0000
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2106] 高炉 [0.2145] 高炉与设定误差 [-0.0031] [-0.26226602] 模型误差 [-0.0039] 校正值 [-0.0017]
# 2设定 -0.4678 预测 [-0.472] 高炉 [-0.4718] 高炉与设定误差 [0.0039] [0.00362173] 模型误差 [-0.0003] 校正值 [0.0034]
# 这是对第194时刻的最优U1、U2输入求解
# (195, 1, 10)
# (195, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2117] 高炉 [0.2114] 高炉与设定误差 [0.] [0.] 模型误差 [0.0002] 校正值 [-0.0018]
# 2设定 -0.4678 预测 [-0.4676] 高炉 [-0.4631] 高炉与设定误差 [-0.0048] [-0.00445752] 模型误差 [-0.0046] 校正值 [0.0013]
# 这是对第195时刻的最优U1、U2输入求解
# (196, 1, 10)
# (196, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2581] 高炉 [0.2877] 高炉与设定误差 [-0.0171] [-1.44669324] 模型误差 [-0.0296] 校正值 [-0.0026]
# 2设定 -0.4678 预测 [-0.474] 高炉 [-0.433] 高炉与设定误差 [-0.0348] [-0.03231702] 模型误差 [-0.041] 校正值 [0.0021]
# 这是对第196时刻的最优U1、U2输入求解
# (197, 1, 10)
# (197, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2759] 高炉 [0.2722] 高炉与设定误差 [-0.0017] [-0.1438233] 模型误差 [0.0037] 校正值 [0.0034]
# 2设定 -0.4678 预测 [-0.4712] 高炉 [-0.5224] 高炉与设定误差 [0.0546] [0.05070429] 模型误差 [0.0512] 校正值 [0.0146]
# 这是对第197时刻的最优U1、U2输入求解
# (198, 1, 10)
# (198, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2727] 高炉 [0.287] 高炉与设定误差 [-0.0164] [-1.38747182] 模型误差 [-0.0144] 校正值 [-0.0062]
# 2设定 -0.4678 预测 [-0.4625] 高炉 [-0.461] 高炉与设定误差 [-0.0069] [-0.00640768] 模型误差 [-0.0015] 校正值 [-0.0094]
# 这是对第198时刻的最优U1、U2输入求解
# (199, 1, 10)
# (199, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2727] 高炉 [0.3051] 高炉与设定误差 [-0.0345] [-2.91876686] 模型误差 [-0.0324] 校正值 [-0.0014]
# 2设定 -0.4678 预测 [-0.466] 高炉 [-0.4605] 高炉与设定误差 [-0.0074] [-0.00687201] 模型误差 [-0.0055] 校正值 [0.0012]
# 这是对第199时刻的最优U1、U2输入求解
# (200, 1, 10)
# (200, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2658] 高炉 [0.2587] 高炉与设定误差 [0.0118] [0.99830293] 模型误差 [0.0071] 校正值 [0.0203]
# 2设定 -0.4678 预测 [-0.4758] 高炉 [-0.4749] 高炉与设定误差 [0.0071] [0.00659342] 模型误差 [-0.0008] 校正值 [0.0052]

# %%
if iscontrol:
    y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
    y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
    
    startt = 0
    endd = 400
    
    plt.figure(figsize=(7, 6))
    plt.subplot(2, 1, 1)
    plt.plot(set_y1[startt:endd],'r', label='设定值')
    plt.plot(y1_pred_inverse_transform[startt:endd],'b', label='实际值')
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')
    plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
    plt.legend(prop=font)
    plt.title(f"模型:MLP 训练次数:{epoch_sum_gaolu} 隐含层数:{3} 改进:{ischuangxin} 动态更新:{if_update_model} P:{P} M:{M} ", fontproperties=font)

    plt.subplot(2, 1, 2)
    plt.plot(set_y2[startt:endd],'r')
    plt.plot(y2_pred_inverse_transform[startt:endd],'b')
    plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')

# %%
startt = 50
endd = 150


font222 = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=10)  # 替换为你的中文字体文件路径

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()


a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))









# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(8, 13))

# 第一个维度的曲线
ax = plt.subplot(6, 1, 1)
plt.plot(set_y1[startt:endd], 'k.-', label='Set Value')
plt.plot(y1_pred_inverse_transform, 'r', label='SC-MLP-U')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('MIT/℃', fontproperties=font)  # 使用中文标签
plt.legend(prop=font222)
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边





input_term222 =        ['Oxygen Flow/(m\u00b3/h)', 'Cold Air Flow/(m\u00b3/h)', 'Hot Air Pressure/kPa', 'Hot Air Temperature/℃']

# input_term =        ['Oxygen Flow', 'Cold Air Flow', 'Hot Air Pressure', 'Hot Air Temperature']
output_term222 = ['MIT/℃', '[Si]/%']
time_term= '时间戳h'
input_term333 =        ['Oxygen Flow', 'Cold Air Flow', 'Hot Air Pressure', 'Hot Air Temperature']
output_term333 = ['MIT', '[Si]']
time_term= '时间戳h'
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
dtiem = -0.5




ax.text(0.5, dtiem, f'{subplot_labels[0]} {output_term333[0]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签




# 第二个维度的曲线
ax = plt.subplot(6, 1, 2)
plt.plot(set_y2[startt:endd], 'k.-')
plt.plot(y2_pred_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('[Si]/%', fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[1]} {output_term333[1]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签





# 第一个维度的u1曲线
ax = plt.subplot(6, 1, 3)
plt.plot(all_pred_u1_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[0], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[2]} {input_term333[0]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第二个维度的u2曲线
ax = plt.subplot(6, 1, 4)
plt.plot(all_pred_u2_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[1], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[3]} {input_term333[1]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第三个维度的u3曲线
ax = plt.subplot(6, 1, 5)
plt.plot(all_pred_u3_inverse_transform, 'r')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[2], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[4]} {input_term333[2]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第四个维度的u4曲线
ax = plt.subplot(6, 1, 6)
plt.plot(all_pred_u4_inverse_transform, 'r')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[3], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.08, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[5]} {input_term333[3]}', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('Control cycles', fontproperties=font)  # 只给最下面的子图添加横坐标标签



# 调整子图布局
plt.tight_layout()
plt.show()
# Out:
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[3.37254652e+01 3.41094835e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 0.6255
# 平均误差 0.0046

# %%
startt = 50
endd = 150

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()

# # 将数据转换为DataFrame
# data = {
#     'set_y1': set_y1,
#     'set_y2': set_y2,
#     'RES_MLP_U_y1': y1_pred_inverse_transform,
#     'MLP_U_y2': y2_pred_inverse_transform,
#     'RES_MLP_U_u1': all_pred_u1_inverse_transform,
#     'RES_MLP_U_u2': all_pred_u2_inverse_transform,
#     'RES_MLP_U_u3': all_pred_u3_inverse_transform,
#     'RES_MLP_U_u4': all_pred_u4_inverse_transform
# }

# df = pd.DataFrame(data)

# # 保存DataFrame到Excel文件
# df.to_excel('pred_data_RES_MLP_U_'+str(cengshu)+'.xlsx', index=False)




a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))

# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(10, 6))

# 第一个维度的曲线
plt.subplot(2, 1, 1)
plt.plot(set_y1[startt:endd], 'ro-', label='设定值')
plt.plot(y1_pred_inverse_transform, 'bo-', label='RES_MLP_U 实际值')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend(prop=font)
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(2, 1, 2)
plt.plot(set_y2[startt:endd], 'ro-')
plt.plot(y2_pred_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 调整子图布局
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 8))
# 第一个维度的u1曲线
plt.subplot(4, 1, 1)
plt.plot(all_pred_u1_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(4, 1, 2)
plt.plot(all_pred_u2_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(4, 1, 3)
plt.plot(all_pred_u3_inverse_transform, 'bo-')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(4, 1, 4)
plt.plot(all_pred_u4_inverse_transform, 'bo-')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[3.37254652e+01 3.41094835e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 0.6255
# 平均误差 0.0046
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
