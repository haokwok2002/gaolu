# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import scipy.linalg as la
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")
import base

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出 (2)') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='剔除直线输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='单SI_0.2_0.8') 
# print(df_sheet_yuansu.info())
# print(df_sheet_yuansu.columns)

excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_params = pd.read_excel(excel_path, sheet_name='1h_mean') 

# print(df_sheet_params.info())
# print(df_sheet_params.columns)

# %%
# 定义输入输出参数
input_term = ['富氧流量', '冷风流量', '热风压力', '冷风温度', '热风温度', '鼓风湿度', '设定喷煤量']
output_term = ['铁口1温度', 'SI']
time_term= '时间戳h'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_yuansu_process = df_sheet_yuansu.copy()
df_sheet_params_process = df_sheet_params.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 1.5 * y.std()  # 使用标准差作为阈值
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value

# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[3]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[4]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[5]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[6]])

replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[0]])
replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[1]])

# plt.figure(figsize=(15, 10))
# for idx, column in enumerate(input_term):
#     plt.subplot(len(input_term), 1, idx+1)
#     plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params[column].values,df_sheet_params_process[column].values,column)

# plt.figure(figsize=(15, 10))
# for idx, column in enumerate(output_term):
#     plt.subplot(len(output_term), 1, idx+1)
#     plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu[column].values,df_sheet_yuansu_process[column].values,column)
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_28588\3167423026.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r.', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 400


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 10))
for idx, column in enumerate(output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu_process[column].values,column,index_predict,index_gaolu)

plt.figure(figsize=(15, 6))
for idx, column in enumerate(input_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_params_process[input_term[0]].values,
    input_term[1]:   df_sheet_params_process[input_term[1]].values,
    input_term[2]:   df_sheet_params_process[input_term[2]].values,
    input_term[3]:   df_sheet_params_process[input_term[3]].values,
    input_term[4]:   df_sheet_params_process[input_term[4]].values,
    input_term[5]:   df_sheet_params_process[input_term[5]].values,
    input_term[6]:   df_sheet_params_process[input_term[6]].values,
    output_term[0]:  df_sheet_yuansu_process[output_term[0]].values,
    output_term[1]:  df_sheet_yuansu_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
plt.plot(normalized_data_dict['SI'],'r')
plt.plot(normalized_data_dict['铁口1温度'],'b')

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每0.01浓度的输出差：',(data3-data1))
# Out:
# [0.05471948]
# [1500.]
# [0.18042565]
# [1510.]
# 每摄氏度的输出差： [0.01257062]
# [-0.52854026]
# [0.5]
# [-0.40998065]
# [0.6]
# 每0.01浓度的输出差： [0.11855962]

# %%
isShuffle = True
# isShuffle = False
time_steps = 2


test_size = 0.15
val_size = 0.15
train_size = 1-val_size-test_size

# %%
# 组合训练数据--拆分训练、测试集
# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,y1_data,y2_data,index_fanwei):
# def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data,index_fanwei):
    X = np.column_stack((u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data))
    y = np.column_stack((y1_data, y2_data))

    X_modified = []
    y_modified = []
    
    for i in range(11,len(y1_data)):
        if i in index_fanwei:
            # print(i)
            # print(df_sheet_yuansu[time_term][i])
            yuansu_time = df_sheet_yuansu[time_term][i]
            closest_10 = df_sheet_params[df_sheet_params[time_term] <= yuansu_time].nlargest(time_steps, time_term)
            # print(closest_10)
            
            index = closest_10.index
            # print(index)
            # print(closest_10.iloc[-1][time_term])
            if closest_10.iloc[-1][time_term] < yuansu_time - time_steps + 1:
                print(i,yuansu_time,'errloss')
            else:

                # print(X[index, :])
                new_x_sample = np.concatenate([X[i, :] for i in index],axis=0)
                # print(new_x_sample)
                y_last = y[i-1, :]
                # print(y_last, 'y_last time : ',df_sheet_yuansu[time_term][i-1])
                new_x_sample = np.concatenate([new_x_sample,y_last],axis=0)
                # print(new_x_sample)
                y_sample = y[i, :]  
                X_modified.append(new_x_sample)
                y_modified.append(y_sample)
                print(i,yuansu_time,index[0],index[-1], end='\r')
                # break

    # 将列表转换为 NumPy 数组
    X_modified = np.array(X_modified)
    y_modified = np.array(y_modified)
    X_reshaped = X_modified.reshape((X_modified.shape[0],1, X_modified.shape[1]))

    # 打印新数据的形状
    print("Modified Input Shape:", X_reshaped.shape)
    print("Modified Output Shape:", y_modified.shape)


    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_modified, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def symmetrical_moving_average(data, N):
    """
    使用对称的移动平均滤波，当前值由其自身及其前后的值决定。
    
    :param data: 输入的数据序列，一般为列表或者NumPy数组。
    :return: 经过滤波处理的数据序列。
    """
    filtered_data = []
    N = 9
    percent = 0.8
    # 遍历数据，从索引1开始到倒数第二个元素结束
    for i in range(1, len(data) - 1):
        # 计算当前值及其前后值的平均
        average = (data[i - 1]*(1-percent)/2 + data[i]*percent + data[i + 1]*(1-percent)/2)
        filtered_data.append(average)
    
    # 对于序列的第一个和最后一个元素，直接使用原始值
    # 或者可以使用其他边界处理策略
    filtered_data.insert(0, data[0])
    filtered_data.append(data[-1])
    
    return np.array(filtered_data)

# 示例数据
data = [2, 4, 6, 8, 10, 12, 14]
filtered_data = symmetrical_moving_average(data,9)
print(filtered_data)
# Out:
# [ 2.  4.  6.  8. 10. 12. 14.]

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
u5_data = normalized_data_dict[input_term[4]]
u6_data = normalized_data_dict[input_term[5]]
u7_data = normalized_data_dict[input_term[6]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]
# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)
print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_gaolu)



# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
u5_data = normalized_data_dict[input_term[4]]
u6_data = normalized_data_dict[input_term[5]]
u7_data = normalized_data_dict[input_term[6]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,u5_data,u6_data,u7_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_predict)
# Out:
# 高炉模型数据
# 273 288 272 271
# Modified Input Shape: (390, 1, 16)
# Modified Output Shape: (390, 2)
# 训练数量： (272, 1, 16) (272, 2)
# 验证数量： (59, 1, 16) (59, 2)
# 测试数量： (59, 1, 16) (59, 2)
# 预测模型数据
# Modified Input Shape: (401, 1, 16)
# Modified Output Shape: (401, 2)
# 训练数量： (279, 1, 16) (279, 2)
# 验证数量： (61, 1, 16) (61, 2)
# 测试数量： (61, 1, 16) (61, 2)

# %%
# 定义LSTM模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyRNNModel(torch.nn.Module):
    def __init__(self,features_size,hidden_size,isbidirectional):
        super(MyRNNModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size=features_size,
            hidden_size=hidden_size,
            batch_first=True,
            bidirectional=isbidirectional
        )
        if isbidirectional:
            self.fc = nn.Linear(2 * hidden_size, 2)
        else:
            self.fc = nn.Linear(hidden_size, 2)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        
        last_lstm_output = lstm_out[:, -1, :]
        # print(last_lstm_output)
        output = self.fc(last_lstm_output)
        
        return output

    def custom_loss(self, y_true, y_pred):
        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse



    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
epoch_once_time = 50

# %%
# 建立高炉模型实例
features_size = 16
hidden_size = 16
# 设置随机种子
# torch.manual_seed(0)
model_gaolu = MyRNNModel(features_size = features_size, 
                        hidden_size = hidden_size,
                        isbidirectional=True)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.figure(figsize=(6, 2))
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 3/50 轮, 训练误差: 0.0578, 验证误差: 0.0567
# 第 50/50 轮, 训练误差: 0.0187, 验证误差: 0.0182
# epoch_sum: 50

# %%
# 高炉模型建模效果
y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_gaolu_train)
y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_gaolu_test)

base.double_control_train_test_result(scalers,  output_term,
                                        y_gaolu_train,  y_train_pred_0, y_train_pred_1,
                                        y_gaolu_test,   y_test_pred_0,  y_test_pred_1)

# y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_predict_train)
# y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_predict_test)

# base.double_control_train_test_result(scalers,  output_term,
#                                         y_predict_train,  y_train_pred_0, y_train_pred_1,
#                                         y_predict_test ,   y_test_pred_0,  y_test_pred_1)
# Out:
# 训练集
# RMSE:  铁口1温度: 8.4144 , SI: 0.0686
# MAPE:  铁口1温度: 0.4173% , SI: 12.9800%
# MRE :  铁口1温度: 0.0042  , SI: 0.1298
# per :  铁口1温度: 0.8015  , SI: 0.8493
# 测试集
# RMSE:  铁口1温度: 8.1703 , SI: 0.0698
# MAPE:  铁口1温度: 0.4294% , SI: 11.9055%
# MRE :  铁口1温度: 0.0043  , SI: 0.1191
# per :  铁口1温度: 0.7458  , SI: 0.8136

# %%
# 创建预测模型实例
features_size = 16
hidden_size_predict = 16
# 设置随机种子
torch.manual_seed(0)
model = MyRNNModel(features_size = features_size, 
                    hidden_size = hidden_size_predict,
                    isbidirectional=True)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.figure(figsize=(6, 2))
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0270, 验证误差: 0.0213
# epoch_sum: 0

# %%
# 预测模型建模效果

y_train_pred_0,y_train_pred_1 = model.my_predict(X_predict_train)


y_test_pred_0,y_test_pred_1 = model.my_predict(X_predict_test)

base.double_control_train_test_result(scalers,  output_term,
                                        y_predict_train,  y_train_pred_0, y_train_pred_1,
                                        y_predict_test,   y_test_pred_0,  y_test_pred_1)
# Out:
# 训练集
# RMSE:  铁口1温度: 9.6556 , SI: 0.0785
# MAPE:  铁口1温度: 0.5046% , SI: 17.4532%
# MRE :  铁口1温度: 0.0050  , SI: 0.1745
# per :  铁口1温度: 0.7168  , SI: 0.7814
# 测试集
# RMSE:  铁口1温度: 9.3826 , SI: 0.0815
# MAPE:  铁口1温度: 0.4930% , SI: 19.7115%
# MRE :  铁口1温度: 0.0049  , SI: 0.1971
# per :  铁口1温度: 0.7213  , SI: 0.7541

# %%
# 高炉、预测、原始对比
base.gaolu_predict_raw(scalers,output_term,model,model_gaolu,X_predict_test,y_predict_test)

# %%
iscontrol = True
# iscontrol = False

Times = 100

# %%
# 自定义预测
model_predict = model
hidden_size = hidden_size_predict
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def lstm_forward(input, initial_states, w_ih, w_hh, b_ih, b_hh):
    h_0, c_0 = initial_states  # 初始状态  [b_size, hidden_size]
    b_size, seq_len, input_size = input.shape
    h_size = h_0.shape[-1]

    h_prev, c_prev = h_0, c_0

    # 使用 np.newaxis 在第一个维度上插入一个新的维度  # 使用 np.tile 在第一个维度上复制 b_size 次
    w_ih_expanded = w_ih[np.newaxis, :, :]    
    w_ih_batch = np.tile(w_ih_expanded, (b_size, 1, 1))
    w_hh_expanded = w_hh[np.newaxis, :, :]    
    w_hh_batch = np.tile(w_hh_expanded, (b_size, 1, 1))
    # print(w_ih_batch.shape)

    output_size = h_size
    output = np.zeros((b_size, seq_len, output_size))  # 初始化一个输出序列
    for t in range(seq_len):
        x = input[:, t, :]  # 当前时刻的输入向量 [b,in_size]->[b,in_size,1]
        w_times_x = np.matmul(w_ih_batch, x[:, :, np.newaxis]).squeeze(-1)   # bmm:含有批量大小的矩阵相乘
        # [b, 4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Wii*xt|Wif*xt|Wig*xt|Wio*xt
        w_times_h_prev = np.matmul(w_hh_batch, h_prev[:, :, np.newaxis]).squeeze(-1)
        # [b, 4*hidden_size, hidden_size]*[b, hidden_size, 1]->[b,4*hidden_size, 1]->[b, 4*hidden_size]
        # 这一步就是计算了 Whi*ht-1|Whf*ht-1|Whg*ht-1|Who*ht-1

        # 分别计算输入门(i)、遗忘门(f)、cell门(g)、输出门(o)  维度均为 [b, h_size]
        i_t = sigmoid(w_times_x[:, :h_size] + w_times_h_prev[:, :h_size] + b_ih[:h_size] + b_hh[:h_size])  # 取前四分之一
        f_t = sigmoid(w_times_x[:, h_size:2*h_size] + w_times_h_prev[:, h_size:2*h_size]
                            + b_ih[h_size:2*h_size] + b_hh[h_size:2*h_size])
        g_t = np.tanh(w_times_x[:, 2*h_size:3*h_size] + w_times_h_prev[:, 2*h_size:3*h_size]
                            + b_ih[2*h_size:3*h_size] + b_hh[2*h_size:3*h_size])
        o_t = sigmoid(w_times_x[:, 3*h_size:] + w_times_h_prev[:, 3*h_size:]
                            + b_ih[3*h_size:] + b_hh[3*h_size:])
        c_prev = f_t * c_prev + i_t * g_t
        h_prev = o_t * np.tanh(c_prev)

        output[:, t, :] = h_prev

    return output, (np.expand_dims(h_prev, axis=0), np.expand_dims(c_prev, axis=0))  # 官方是三维，在第0维扩一维



def predict_my(data_input):

    input = data_input  # 随机初始化一个输入序列
    c_0 = np.zeros((data_input.shape[0], hidden_size))  # 初始值，不会参与训练
    h_0 = np.zeros((data_input.shape[0], hidden_size))

    output_forward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0.detach().numpy())

    last_lstm_output_forward = output_forward[:, -1, :]

    output_backward, (h_n_me, c_n_me) = lstm_forward(input, (h_0, c_0), 
                                                model_predict.lstm.weight_ih_l0_reverse.detach().numpy(),
                                                model_predict.lstm.weight_hh_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_ih_l0_reverse.detach().numpy(), 
                                                model_predict.lstm.bias_hh_l0_reverse.detach().numpy())

    last_lstm_output_backward = output_backward[:, -1, :]
    # print(last_lstm_output_forward.shape)
    # print(last_lstm_output_backward.shape)
    # 最终输出
    combined_hidden = np.concatenate((last_lstm_output_forward, last_lstm_output_backward), axis=1)
    # print(combined_hidden.shape)


    output = (np.dot(combined_hidden, np.transpose(model_predict.fc.weight.detach().numpy()))
                + model_predict.fc.bias.detach().numpy()
)
    y_pred_0, y_pred_1= output[:,0],output[:,1]

    # y_pred_0 = scalers[output_term[0]].inverse_transform(np.array(y_pred_0).reshape(-1, 1)).flatten()
    # y_pred_1 = scalers[output_term[1]].inverse_transform(np.array(y_pred_1).reshape(-1, 1)).flatten()




    return y_pred_0, y_pred_1


y_pred_0, y_pred_1= predict_my(X_predict_test)


# plot_hit_rate_curve(y_test, y_pred_0, y_pred_1)
# plot_hit_rate_curve(y_test, y_pred_0.detach().numpy(), y_pred_1.detach().numpy())

# %%
# # 生成期望数据
# Times = 100

# def generate_y_aim_data(Times):

#     set_y1 = np.full(Times,1500)
#     set_y1[30:] = 1510
#     set_y1[60:] = 1505
#     set_y1[90:] = 1515
#     # set_y1[70:] = 1520
#     # set_y1[90:] = 1525

#     set_y2 = np.full(Times,0.44)
#     set_y2[15:] = 0.48
#     set_y2[45:] = 0.52
#     set_y2[75:] = 0.44
#     # 限制设定值在 -1 到 1 之间
#     # set_y1 = np.clip(set_y1, -1, 1)
#     # set_y2 = np.clip(set_y2, -1, 1)


#     set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
#     set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

#     return set_y1, set_y2, set_y1_trans, set_y2_trans

# # # 调用示例
# # set_y1, set_y2, set_y1_trans, set_y2_trans= generate_y_aim_data(Times)
# # plt.plot(set_y1_trans)
# # plt.plot(set_y2_trans)
# # plt.title('y_sp')
# # plt.show()

def generate_y_aim_data(Times):

    set_y1 = np.full(Times,1500)
    set_y1[40:] = 1505
    set_y1[80:] = 1510
    set_y1[120:] = 1515
    set_y1[160:] = 1520
    set_y1[200:] = 1525
    set_y1[240:] = 1530
    set_y1[280:] = 1535
    set_y1[320:] = 1540
    set_y1[360:] = 1515

    set_y2 = np.full(Times,0.42)
    set_y2[20:] = 0.45
    set_y2[60:] = 0.48
    set_y2[100:] = 0.51
    set_y2[140:] = 0.54
    set_y2[180:] = 0.57
    set_y2[220:] = 0.60
    set_y2[260:] = 0.63
    set_y2[300:] = 0.66
    set_y2[340:] = 0.50


    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,0.667,5+1)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]
    u5   = u5_data[randint  :randint+3  ]
    u6   = u6_data[randint  :randint+3  ]
    u7   = u7_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, u5, u6, u7, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):
    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]
    y1   = k_data[21:24]
    y2   = k_data[24:27]

    
    # 获取猜测值[h U1 U2]
    U1, U2, U3, U4, U5, U6, U7  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M], params[4*M:5*M],params[5*M:6*M], params[6*M:7*M]
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(u5.round(4))
        print(u6.round(4))
        print(u7.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = predict_my(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = predict_my(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u5[j+2],u6[j+2],u7[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                u5[j+1],u6[j+1],u7[j+1],
                                y1[j+1],y2[j+1]))
        x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = predict_my(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],u5[1:4],u6[1:4],u7[1:4],y1[1:4],y2[1:4]),axis=0)
    # k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,0.1,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,0.1,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)
    u5_power = lamda2*np.sum((np.diff(u5[2:]))**2)
    u6_power = lamda3*np.sum((np.diff(u6[2:]))**2)
    u7_power = lamda4*np.sum((np.diff(u7[2:]))**2)

    # y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    # y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    # u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    # u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    # u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    # u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    # u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    # u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    # u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            +u5_power
            +u6_power
            +u7_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 4  # 预测时域长度  增大P能平稳些
M = 2  # 控制时域长度
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data, u5_data, u6_data, u7_data, 
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
all_pred_u5 = []
all_pred_u6 = []
all_pred_u7 = []
# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    # params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    bounds = [(-max_control, max_control) for _ in range(7 * M)]
    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    U1, U2, U3, U4, U5, U6, U7 =    result.x[0:M], result.x[M:2*M], \
                                    result.x[2*M:3*M], result.x[3*M:4*M], \
                                    result.x[4*M:5*M], result.x[5*M:6*M], \
                                    result.x[6*M:7*M]
    # U1, U2, U3, U4 =    result.x[0:M], result.x[M:2*M],result.x[2*M:3*M], result.x[3*M:4*M]
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]
    u5   = k_data[12:15]
    u6   = k_data[15:18]
    u7   = k_data[18:21]
    y1   = k_data[21:24]
    y2   = k_data[24:27]

    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    u5   = np.concatenate((u5,U5,U5[-1]*np.ones(P-M)))
    u6   = np.concatenate((u6,U6,U6[-1]*np.ones(P-M)))
    u7   = np.concatenate((u7,U7,U7[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                            u5[j+2],u6[j+2],u7[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                            u5[j+1],u6[j+1],u7[j+1],
                            y1[j+1],y2[j+1]))
    x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model.my_predict(x)
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    


    # 更新k_data
    params = np.concatenate((U1, U2, U3, U4, U5, U6, U7),axis=0)


    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    all_pred_u5.append(U5[0])
    all_pred_u6.append(U6[0])
    all_pred_u7.append(U7[0])
    k_data2[23] = y1_pred.item()
    k_data2[26] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 2838
# (27,)
# 这是对第0时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [0.1941] 高炉 [0.2542] 高炉与设定误差 [-0.1995] [-15.87034115] 模型误差 [-0.0602] 校正值 [-0.1445]
# 2设定 -0.6234 预测 [-0.2855] 高炉 [-0.2985] 高炉与设定误差 [-0.3249] [-0.27403934] 模型误差 [0.013] 校正值 [-0.0121]
# 这是对第1时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [0.0341] 高炉 [0.3838] 高炉与设定误差 [-0.3291] [-26.18009833] 模型误差 [-0.3498] 校正值 [0.0602]
# 2设定 -0.6234 预测 [-0.5973] 高炉 [-0.4741] 高炉与设定误差 [-0.1493] [-0.1259282] 模型误差 [-0.1232] 校正值 [-0.013]
# 这是对第2时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0189] 高炉 [0.1213] 高炉与设定误差 [-0.0666] [-5.29806911] 模型误差 [-0.1402] 校正值 [0.3498]
# 2设定 -0.6234 预测 [-0.5073] 高炉 [-0.4009] 高炉与设定误差 [-0.2225] [-0.18766929] 模型误差 [-0.1064] 校正值 [0.1232]
# 这是对第3时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0524] 高炉 [0.1429] 高炉与设定误差 [-0.0882] [-7.01636177] 模型误差 [-0.1953] 校正值 [0.1402]
# 2设定 -0.6234 预测 [-0.5269] 高炉 [-0.5049] 高炉与设定误差 [-0.1184] [-0.09986537] 模型误差 [-0.022] 校正值 [0.1064]
# 这是对第4时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1144] 高炉 [0.1611] 高炉与设定误差 [-0.1064] [-8.46418202] 模型误差 [-0.2755] 校正值 [0.1953]
# 2设定 -0.6234 预测 [-0.6386] 高炉 [-0.562] 高炉与设定误差 [-0.0614] [-0.05178829] 模型误差 [-0.0766] 校正值 [0.022]
# 这是对第5时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1349] 高炉 [0.0627] 高炉与设定误差 [-0.008] [-0.63640471] 模型误差 [-0.1975] 校正值 [0.2755]
# 2设定 -0.6234 预测 [-0.5913] 高炉 [-0.5402] 高炉与设定误差 [-0.0832] [-0.07017566] 模型误差 [-0.0511] 校正值 [0.0766]
# 这是对第6时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1301] 高炉 [0.0831] 高炉与设定误差 [-0.0284] [-2.25923661] 模型误差 [-0.2133] 校正值 [0.1975]
# 2设定 -0.6234 预测 [-0.6221] 高炉 [-0.5958] 高炉与设定误差 [-0.0276] [-0.02327943] 模型误差 [-0.0263] 校正值 [0.0511]
# 这是对第7时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1431] 高炉 [0.097] 高炉与设定误差 [-0.0423] [-3.36498978] 模型误差 [-0.2401] 校正值 [0.2133]
# 2设定 -0.6234 预测 [-0.6502] 高炉 [-0.6087] 高炉与设定误差 [-0.0147] [-0.01239883] 模型误差 [-0.0416] 校正值 [0.0263]
# 这是对第8时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1525] 高炉 [0.045] 高炉与设定误差 [0.0097] [0.77164069] 模型误差 [-0.1975] 校正值 [0.2401]
# 2设定 -0.6234 预测 [-0.6241] 高炉 [-0.5842] 高炉与设定误差 [-0.0392] [-0.03306353] 模型误差 [-0.0399] 校正值 [0.0416]
# 这是对第9时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1399] 高炉 [0.0743] 高炉与设定误差 [-0.0196] [-1.55919147] 模型误差 [-0.2142] 校正值 [0.1975]
# 2设定 -0.6234 预测 [-0.6453] 高炉 [-0.6171] 高炉与设定误差 [-0.0063] [-0.00531378] 模型误差 [-0.0281] 校正值 [0.0399]
# 这是对第10时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1447] 高炉 [0.0921] 高炉与设定误差 [-0.0374] [-2.97519184] 模型误差 [-0.2368] 校正值 [0.2142]
# 2设定 -0.6234 预测 [-0.653] 高炉 [-0.6073] 高炉与设定误差 [-0.016] [-0.01349532] 模型误差 [-0.0456] 校正值 [0.0281]
# 这是对第11时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1481] 高炉 [0.0666] 高炉与设定误差 [-0.0119] [-0.94665198] 模型误差 [-0.2147] 校正值 [0.2368]
# 2设定 -0.6234 预测 [-0.6215] 高炉 [-0.5841] 高炉与设定误差 [-0.0392] [-0.03306353] 模型误差 [-0.0374] 校正值 [0.0456]
# 这是对第12时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1485] 高炉 [0.0736] 高炉与设定误差 [-0.0189] [-1.50350601] 模型误差 [-0.2221] 校正值 [0.2147]
# 2设定 -0.6234 预测 [-0.6445] 高炉 [-0.6077] 高炉与设定误差 [-0.0156] [-0.01315794] 模型误差 [-0.0368] 校正值 [0.0374]
# 这是对第13时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1555] 高炉 [0.084] 高炉与设定误差 [-0.0292] [-2.32287712] 模型误差 [-0.2394] 校正值 [0.2221]
# 2设定 -0.6234 预测 [-0.6566] 高炉 [-0.6109] 高炉与设定误差 [-0.0125] [-0.01054322] 模型误差 [-0.0457] 校正值 [0.0368]
# 这是对第14时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1608] 高炉 [0.0514] 高炉与设定误差 [0.0034] [0.27047199] 模型误差 [-0.2122] 校正值 [0.2394]
# 2设定 -0.6234 预测 [-0.6394] 高炉 [-0.6086] 高炉与设定误差 [-0.0148] [-0.01248317] 模型误差 [-0.0309] 校正值 [0.0457]
# 这是对第15时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.15] 高炉 [0.0741] 高炉与设定误差 [-0.0193] [-1.53532634] 模型误差 [-0.224] 校正值 [0.2122]
# 2设定 -0.6234 预测 [-0.6497] 高炉 [-0.6098] 高炉与设定误差 [-0.0136] [-0.01147102] 模型误差 [-0.0399] 校正值 [0.0309]
# 这是对第16时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1493] 高炉 [0.079] 高炉与设定误差 [-0.0243] [-1.93307918] 模型误差 [-0.2283] 校正值 [0.224]
# 2设定 -0.6234 预测 [-0.6447] 高炉 [-0.605] 高炉与设定误差 [-0.0184] [-0.01551962] 模型误差 [-0.0396] 校正值 [0.0399]
# 这是对第17时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1583] 高炉 [0.0553] 高炉与设定误差 [-0.0006] [-0.04773035] 模型误差 [-0.2136] 校正值 [0.2283]
# 2设定 -0.6234 预测 [-0.6498] 高炉 [-0.6197] 高炉与设定误差 [-0.0037] [-0.00312079] 模型误差 [-0.0301] 校正值 [0.0396]
# 这是对第18时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1503] 高炉 [0.0581] 高炉与设定误差 [-0.0034] [-0.27047199] 模型误差 [-0.2084] 校正值 [0.2136]
# 2设定 -0.6234 预测 [-0.652] 高炉 [-0.6205] 高炉与设定误差 [-0.0029] [-0.00244603] 模型误差 [-0.0315] 校正值 [0.0301]
# 这是对第19时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1412] 高炉 [0.0569] 高炉与设定误差 [-0.0022] [-0.17501128] 模型误差 [-0.1981] 校正值 [0.2084]
# 2设定 -0.6234 预测 [-0.6416] 高炉 [-0.6233] 高炉与设定误差 [-1.e-04] [-8.43457479e-05] 模型误差 [-0.0183] 校正值 [0.0315]
# 这是对第20时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1355] 高炉 [0.0484] 高炉与设定误差 [0.0063] [0.50116868] 模型误差 [-0.1839] 校正值 [0.1981]
# 2设定 -0.5878 预测 [-0.6124] 高炉 [-0.6117] 高炉与设定误差 [0.0239] [0.02015863] 模型误差 [-0.0007] 校正值 [0.0183]
# 这是对第21时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1206] 高炉 [0.048] 高炉与设定误差 [0.0067] [0.5329889] 模型误差 [-0.1686] 校正值 [0.1839]
# 2设定 -0.5878 预测 [-0.5889] 高炉 [-0.569] 高炉与设定误差 [-0.0188] [-0.015857] 模型误差 [-0.0198] 校正值 [0.0007]
# 这是对第22时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1062] 高炉 [0.0607] 高炉与设定误差 [-0.006] [-0.47730351] 模型误差 [-0.1669] 校正值 [0.1686]
# 2设定 -0.5878 预测 [-0.5963] 高炉 [-0.5732] 高炉与设定误差 [-0.0146] [-0.01231448] 模型误差 [-0.0231] 校正值 [0.0198]
# 这是对第23时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1034] 高炉 [0.0745] 高炉与设定误差 [-0.0198] [-1.57510156] 模型误差 [-0.1779] 校正值 [0.1669]
# 2设定 -0.5878 预测 [-0.6076] 高炉 [-0.5817] 高炉与设定误差 [-0.0061] [-0.00514509] 模型误差 [-0.0259] 校正值 [0.0231]
# 这是对第24时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1099] 高炉 [0.0637] 高炉与设定误差 [-0.009] [-0.71595523] 模型误差 [-0.1736] 校正值 [0.1779]
# 2设定 -0.5878 预测 [-0.602] 高炉 [-0.5877] 高炉与设定误差 [-1.e-04] [-8.43457479e-05] 模型误差 [-0.0143] 校正值 [0.0259]
# 这是对第25时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1112] 高炉 [0.0541] 高炉与设定误差 [0.0006] [0.04773035] 模型误差 [-0.1653] 校正值 [0.1736]
# 2设定 -0.5878 预测 [-0.602] 高炉 [-0.5916] 高炉与设定误差 [0.0037] [0.00312079] 模型误差 [-0.0105] 校正值 [0.0143]
# 这是对第26时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1022] 高炉 [0.0578] 高炉与设定误差 [-0.0031] [-0.24660682] 模型误差 [-0.16] 校正值 [0.1653]
# 2设定 -0.5878 预测 [-0.5946] 高炉 [-0.5759] 高炉与设定误差 [-0.0119] [-0.01003714] 模型误差 [-0.0187] 校正值 [0.0105]
# 这是对第27时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0968] 高炉 [0.0615] 高炉与设定误差 [-0.0068] [-0.54094398] 模型误差 [-0.1584] 校正值 [0.16]
# 2设定 -0.5878 预测 [-0.5961] 高炉 [-0.5866] 高炉与设定误差 [-0.0012] [-0.00101215] 模型误差 [-0.0094] 校正值 [0.0187]
# 这是对第28时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1014] 高炉 [0.0833] 高炉与设定误差 [-0.0286] [-2.2751467] 模型误差 [-0.1847] 校正值 [0.1584]
# 2设定 -0.5878 预测 [-0.5918] 高炉 [-0.582] 高炉与设定误差 [-0.0058] [-0.00489205] 模型误差 [-0.0098] 校正值 [0.0094]
# 这是对第29时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1155] 高炉 [0.0579] 高炉与设定误差 [-0.0032] [-0.25456186] 模型误差 [-0.1734] 校正值 [0.1847]
# 2设定 -0.5878 预测 [-0.5898] 高炉 [-0.5712] 高炉与设定误差 [-0.0166] [-0.01400139] 模型误差 [-0.0186] 校正值 [0.0098]
# 这是对第30时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1121] 高炉 [0.0519] 高炉与设定误差 [0.0028] [0.22274163] 模型误差 [-0.1639] 校正值 [0.1734]
# 2设定 -0.5878 预测 [-0.5994] 高炉 [-0.5893] 高炉与设定误差 [0.0015] [0.00126519] 模型误差 [-0.0101] 校正值 [0.0186]
# 这是对第31时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1022] 高炉 [0.0657] 高炉与设定误差 [-0.011] [-0.87505642] 模型误差 [-0.1678] 校正值 [0.1639]
# 2设定 -0.5878 预测 [-0.5979] 高炉 [-0.5837] 高炉与设定误差 [-0.0041] [-0.00345818] 模型误差 [-0.0142] 校正值 [0.0101]
# 这是对第32时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1042] 高炉 [0.0624] 高炉与设定误差 [-0.0077] [-0.6125395] 模型误差 [-0.1666] 校正值 [0.1678]
# 2设定 -0.5878 预测 [-0.5925] 高炉 [-0.5804] 高炉与设定误差 [-0.0074] [-0.00624159] 模型误差 [-0.0121] 校正值 [0.0142]
# 这是对第33时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1043] 高炉 [0.0613] 高炉与设定误差 [-0.0066] [-0.52503385] 模型误差 [-0.1656] 校正值 [0.1666]
# 2设定 -0.5878 预测 [-0.5988] 高炉 [-0.5837] 高炉与设定误差 [-0.0041] [-0.00345818] 模型误差 [-0.0151] 校正值 [0.0121]
# 这是对第34时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.1007] 高炉 [0.0612] 高炉与设定误差 [-0.0065] [-0.51707881] 模型误差 [-0.1619] 校正值 [0.1656]
# 2设定 -0.5878 预测 [-0.5943] 高炉 [-0.5792] 高炉与设定误差 [-0.0086] [-0.00725373] 模型误差 [-0.0152] 校正值 [0.0151]
# 这是对第35时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0996] 高炉 [0.0628] 高炉与设定误差 [-0.0081] [-0.64435975] 模型误差 [-0.1624] 校正值 [0.1619]
# 2设定 -0.5878 预测 [-0.599] 高炉 [-0.5814] 高炉与设定误差 [-0.0064] [-0.00539813] 模型误差 [-0.0176] 校正值 [0.0152]
# 这是对第36时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0976] 高炉 [0.0643] 高炉与设定误差 [-0.0096] [-0.76368565] 模型误差 [-0.1619] 校正值 [0.1624]
# 2设定 -0.5878 预测 [-0.596] 高炉 [-0.5843] 高炉与设定误差 [-0.0035] [-0.0029521] 模型误差 [-0.0116] 校正值 [0.0176]
# 这是对第37时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.099] 高炉 [0.0604] 高炉与设定误差 [-0.0057] [-0.45343834] 模型误差 [-0.1594] 校正值 [0.1619]
# 2设定 -0.5878 预测 [-0.5986] 高炉 [-0.5834] 高炉与设定误差 [-0.0044] [-0.00371121] 模型误差 [-0.0152] 校正值 [0.0116]
# 这是对第38时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0953] 高炉 [0.059] 高炉与设定误差 [-0.0043] [-0.34206752] 模型误差 [-0.1543] 校正值 [0.1594]
# 2设定 -0.5878 预测 [-0.5929] 高炉 [-0.5848] 高炉与设定误差 [-0.003] [-0.00253037] 模型误差 [-0.0081] 校正值 [0.0152]
# 这是对第39时刻的最优U1、U2输入求解
# 1设定 0.0547 预测 [-0.0928] 高炉 [0.0585] 高炉与设定误差 [-0.0038] [-0.30229223] 模型误差 [-0.1512] 校正值 [0.1543]
# 2设定 -0.5878 预测 [-0.5956] 高炉 [-0.5874] 高炉与设定误差 [-0.0004] [-0.00033738] 模型误差 [-0.0081] 校正值 [0.0081]
# 这是对第40时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0362] 高炉 [0.0806] 高炉与设定误差 [0.037] [2.94337166] 模型误差 [-0.1168] 校正值 [0.1512]
# 2设定 -0.5878 预测 [-0.5892] 高炉 [-0.5877] 高炉与设定误差 [-1.e-04] [-8.43457479e-05] 模型误差 [-0.0015] 校正值 [0.0081]
# 这是对第41时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [0.0016] 高炉 [0.1243] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1227] 校正值 [0.1168]
# 2设定 -0.5878 预测 [-0.5899] 高炉 [-0.5846] 高炉与设定误差 [-0.0033] [-0.00278341] 模型误差 [-0.0054] 校正值 [0.0015]
# 这是对第42时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [0.0041] 高炉 [0.1311] 高炉与设定误差 [-0.0136] [-1.08188796] 模型误差 [-0.1271] 校正值 [0.1227]
# 2设定 -0.5878 预测 [-0.5864] 高炉 [-0.5703] 高炉与设定误差 [-0.0175] [-0.01476051] 模型误差 [-0.0161] 校正值 [0.0054]
# 这是对第43时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0018] 高炉 [0.121] 高炉与设定误差 [-0.0034] [-0.27047199] 模型误差 [-0.1228] 校正值 [0.1271]
# 2设定 -0.5878 预测 [-0.595] 高炉 [-0.5853] 高炉与设定误差 [-0.0025] [-0.00210864] 模型误差 [-0.0096] 校正值 [0.0161]
# 这是对第44时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [0.0002] 高炉 [0.1246] 高炉与设定误差 [-0.0071] [-0.56480915] 模型误差 [-0.1245] 校正值 [0.1228]
# 2设定 -0.5878 预测 [-0.5973] 高炉 [-0.5873] 高炉与设定误差 [-0.0006] [-0.00050607] 模型误差 [-0.0101] 校正值 [0.0096]
# 这是对第45时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [0.001] 高炉 [0.1268] 高炉与设定误差 [-0.0092] [-0.73186539] 模型误差 [-0.1258] 校正值 [0.1245]
# 2设定 -0.5878 预测 [-0.5925] 高炉 [-0.5772] 高炉与设定误差 [-0.0106] [-0.00894065] 模型误差 [-0.0153] 校正值 [0.0101]
# 这是对第46时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.001] 高炉 [0.126] 高炉与设定误差 [-0.0085] [-0.67618] 模型误差 [-0.1271] 校正值 [0.1258]
# 2设定 -0.5878 预测 [-0.5968] 高炉 [-0.5842] 高炉与设定误差 [-0.0036] [-0.00303645] 模型误差 [-0.0126] 校正值 [0.0153]
# 这是对第47时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0019] 高炉 [0.1305] 高炉与设定误差 [-0.0129] [-1.02620257] 模型误差 [-0.1324] 校正值 [0.1271]
# 2设定 -0.5878 预测 [-0.5984] 高炉 [-0.5799] 高炉与设定误差 [-0.0079] [-0.00666331] 模型误差 [-0.0185] 校正值 [0.0126]
# 这是对第48时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0055] 高炉 [0.1319] 高炉与设定误差 [-0.0144] [-1.1455284] 模型误差 [-0.1375] 校正值 [0.1324]
# 2设定 -0.5878 预测 [-0.5965] 高炉 [-0.5814] 高炉与设定误差 [-0.0064] [-0.00539813] 模型误差 [-0.015] 校正值 [0.0185]
# 这是对第49时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.012] 高炉 [0.1285] 高炉与设定误差 [-0.0109] [-0.86710138] 模型误差 [-0.1405] 校正值 [0.1375]
# 2设定 -0.5878 预测 [-0.6021] 高炉 [-0.5813] 高炉与设定误差 [-0.0066] [-0.00556682] 模型误差 [-0.0208] 校正值 [0.015]
# 这是对第50时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0136] 高炉 [0.1255] 高炉与设定误差 [-0.0079] [-0.62844959] 模型误差 [-0.139] 校正值 [0.1405]
# 2设定 -0.5878 预测 [-0.598] 高炉 [-0.5832] 高炉与设定误差 [-0.0047] [-0.00396425] 模型误差 [-0.0149] 校正值 [0.0208]
# 这是对第51时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0144] 高炉 [0.1383] 高炉与设定误差 [-0.0208] [-1.65465216] 模型误差 [-0.1527] 校正值 [0.139]
# 2设定 -0.5878 预测 [-0.6019] 高炉 [-0.5804] 高炉与设定误差 [-0.0074] [-0.00624159] 模型误差 [-0.0215] 校正值 [0.0149]
# 这是对第52时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0223] 高炉 [0.1363] 高炉与设定误差 [-0.0187] [-1.48759592] 模型误差 [-0.1586] 校正值 [0.1527]
# 2设定 -0.5878 预测 [-0.5988] 高炉 [-0.5743] 高炉与设定误差 [-0.0135] [-0.01138668] 模型误差 [-0.0245] 校正值 [0.0215]
# 这是对第53时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0321] 高炉 [0.1304] 高炉与设定误差 [-0.0129] [-1.02620257] 模型误差 [-0.1626] 校正值 [0.1586]
# 2设定 -0.5878 预测 [-0.61] 高炉 [-0.5804] 高炉与设定误差 [-0.0075] [-0.00632593] 模型误差 [-0.0297] 校正值 [0.0245]
# 这是对第54时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0342] 高炉 [0.1294] 高炉与设定误差 [-0.0118] [-0.93869693] 模型误差 [-0.1636] 校正值 [0.1626]
# 2设定 -0.5878 预测 [-0.6066] 高炉 [-0.5831] 高炉与设定误差 [-0.0047] [-0.00396425] 模型误差 [-0.0234] 校正值 [0.0297]
# 这是对第55时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0377] 高炉 [0.1277] 高炉与设定误差 [-0.0101] [-0.80346087] 模型误差 [-0.1653] 校正值 [0.1636]
# 2设定 -0.5878 预测 [-0.6106] 高炉 [-0.5824] 高炉与设定误差 [-0.0055] [-0.00463902] 模型误差 [-0.0282] 校正值 [0.0234]
# 这是对第56时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0371] 高炉 [0.1243] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1614] 校正值 [0.1653]
# 2设定 -0.5878 预测 [-0.6048] 高炉 [-0.5813] 高炉与设定误差 [-0.0065] [-0.00548247] 模型误差 [-0.0235] 校正值 [0.0282]
# 这是对第57时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0353] 高炉 [0.1304] 高炉与设定误差 [-0.0128] [-1.01824745] 模型误差 [-0.1656] 校正值 [0.1614]
# 2设定 -0.5878 预测 [-0.6106] 高炉 [-0.582] 高炉与设定误差 [-0.0059] [-0.0049764] 模型误差 [-0.0286] 校正值 [0.0235]
# 这是对第58时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0365] 高炉 [0.1377] 高炉与设定误差 [-0.0201] [-1.5989667] 模型误差 [-0.1742] 校正值 [0.1656]
# 2设定 -0.5878 预测 [-0.6071] 高炉 [-0.5732] 高炉与设定误差 [-0.0146] [-0.01231448] 模型误差 [-0.0339] 校正值 [0.0286]
# 这是对第59时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0453] 高炉 [0.1299] 高炉与设定误差 [-0.0124] [-0.98642727] 模型误差 [-0.1752] 校正值 [0.1742]
# 2设定 -0.5878 预测 [-0.614] 高炉 [-0.5812] 高炉与设定误差 [-0.0066] [-0.00556682] 模型误差 [-0.0328] 校正值 [0.0339]
# 这是对第60时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.048] 高炉 [0.1301] 高炉与设定误差 [-0.0125] [-0.99438232] 模型误差 [-0.178] 校正值 [0.1752]
# 2设定 -0.5523 预测 [-0.5889] 高炉 [-0.5602] 高炉与设定误差 [0.008] [0.00674766] 模型误差 [-0.0287] 校正值 [0.0328]
# 这是对第61时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0484] 高炉 [0.1243] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1727] 校正值 [0.178]
# 2设定 -0.5523 预测 [-0.5744] 高炉 [-0.5346] 高炉与设定误差 [-0.0176] [-0.01484485] 模型误差 [-0.0398] 校正值 [0.0287]
# 这是对第62时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0441] 高炉 [0.1375] 高炉与设定误差 [-0.0199] [-1.58305661] 模型误差 [-0.1816] 校正值 [0.1727]
# 2设定 -0.5523 预测 [-0.5808] 高炉 [-0.5443] 高炉与设定误差 [-0.0079] [-0.00666331] 模型误差 [-0.0365] 校正值 [0.0398]
# 这是对第63时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0514] 高炉 [0.1408] 高炉与设定误差 [-0.0233] [-1.85352858] 模型误差 [-0.1922] 校正值 [0.1816]
# 2设定 -0.5523 预测 [-0.5856] 高炉 [-0.5385] 高炉与设定误差 [-0.0138] [-0.01163971] 模型误差 [-0.0471] 校正值 [0.0365]
# 这是对第64时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0601] 高炉 [0.1201] 高炉与设定误差 [-0.0025] [-0.19887646] 模型误差 [-0.1801] 校正值 [0.1922]
# 2设定 -0.5523 预测 [-0.5818] 高炉 [-0.5527] 高炉与设定误差 [0.0004] [0.00033738] 模型误差 [-0.0291] 校正值 [0.0471]
# 这是对第65时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.056] 高炉 [0.1146] 高炉与设定误差 [0.0029] [0.23069669] 模型误差 [-0.1706] 校正值 [0.1801]
# 2设定 -0.5523 预测 [-0.5824] 高炉 [-0.5632] 高炉与设定误差 [0.0109] [0.00919369] 模型误差 [-0.0192] 校正值 [0.0291]
# 这是对第66时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0441] 高炉 [0.1234] 高炉与设定误差 [-0.0058] [-0.46139338] 模型误差 [-0.1676] 校正值 [0.1706]
# 2设定 -0.5523 预测 [-0.5707] 高炉 [-0.5306] 高炉与设定误差 [-0.0217] [-0.01830303] 模型误差 [-0.0401] 校正值 [0.0192]
# 这是对第67时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0394] 高炉 [0.1261] 高炉与设定误差 [-0.0085] [-0.67618] 模型误差 [-0.1655] 校正值 [0.1676]
# 2设定 -0.5523 预测 [-0.575] 高炉 [-0.5453] 高炉与设定误差 [-0.0069] [-0.00581986] 模型误差 [-0.0297] 校正值 [0.0401]
# 这是对第68时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.04] 高炉 [0.1294] 高炉与设定误差 [-0.0118] [-0.93869693] 模型误差 [-0.1694] 校正值 [0.1655]
# 2设定 -0.5523 预测 [-0.5823] 高炉 [-0.5559] 高炉与设定误差 [0.0036] [0.00303645] 模型误差 [-0.0264] 校正值 [0.0297]
# 这是对第69时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0417] 高炉 [0.1627] 高炉与设定误差 [-0.0451] [-3.58773134] 模型误差 [-0.2044] 校正值 [0.1694]
# 2设定 -0.5523 预测 [-0.5731] 高炉 [-0.5307] 高炉与设定误差 [-0.0216] [-0.01821868] 模型误差 [-0.0424] 校正值 [0.0264]
# 这是对第70时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0699] 高炉 [0.1246] 高炉与设定误差 [-0.007] [-0.55685411] 模型误差 [-0.1944] 校正值 [0.2044]
# 2设定 -0.5523 预测 [-0.5793] 高炉 [-0.5525] 高炉与设定误差 [0.0003] [0.00025304] 模型误差 [-0.0268] 校正值 [0.0424]
# 这是对第71时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0694] 高炉 [0.1137] 高炉与设定误差 [0.0039] [0.31024727] 模型误差 [-0.1831] 校正值 [0.1944]
# 2设定 -0.5523 预测 [-0.5796] 高炉 [-0.5627] 高炉与设定误差 [0.0104] [0.00877196] 模型误差 [-0.0169] 校正值 [0.0268]
# 这是对第72时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0568] 高炉 [0.1226] 高炉与设定误差 [-0.0051] [-0.40570799] 模型误差 [-0.1795] 校正值 [0.1831]
# 2设定 -0.5523 预测 [-0.5683] 高炉 [-0.5334] 高炉与设定误差 [-0.0189] [-0.01594135] 模型误差 [-0.0349] 校正值 [0.0169]
# 这是对第73时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0513] 高炉 [0.1195] 高炉与设定误差 [-0.0019] [-0.15114611] 模型误差 [-0.1708] 校正值 [0.1795]
# 2设定 -0.5523 预测 [-0.5726] 高炉 [-0.5435] 高炉与设定误差 [-0.0087] [-0.00733808] 模型误差 [-0.029] 校正值 [0.0349]
# 这是对第74时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0462] 高炉 [0.1245] 高炉与设定误差 [-0.0069] [-0.54889903] 模型误差 [-0.1707] 校正值 [0.1708]
# 2设定 -0.5523 预测 [-0.5806] 高炉 [-0.554] 高炉与设定误差 [0.0018] [0.00151822] 模型误差 [-0.0265] 校正值 [0.029]
# 这是对第75时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0424] 高炉 [0.1255] 高炉与设定误差 [-0.0079] [-0.62844959] 模型误差 [-0.168] 校正值 [0.1707]
# 2设定 -0.5523 预测 [-0.574] 高炉 [-0.536] 高炉与设定误差 [-0.0162] [-0.01366401] 模型误差 [-0.038] 校正值 [0.0265]
# 这是对第76时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0407] 高炉 [0.1368] 高炉与设定误差 [-0.0192] [-1.52737129] 模型误差 [-0.1775] 校正值 [0.168]
# 2设定 -0.5523 预测 [-0.5768] 高炉 [-0.5451] 高炉与设定误差 [-0.0071] [-0.00598855] 模型误差 [-0.0317] 校正值 [0.038]
# 这是对第77时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0484] 高炉 [0.1377] 高炉与设定误差 [-0.0202] [-1.60692174] 模型误差 [-0.1862] 校正值 [0.1775]
# 2设定 -0.5523 预测 [-0.5831] 高炉 [-0.5394] 高炉与设定误差 [-0.0129] [-0.0108806] 模型误差 [-0.0437] 校正值 [0.0317]
# 这是对第78时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0545] 高炉 [0.1202] 高炉与设定误差 [-0.0027] [-0.21478658] 模型误差 [-0.1747] 校正值 [0.1862]
# 2设定 -0.5523 预测 [-0.5774] 高炉 [-0.5507] 高炉与设定误差 [-0.0015] [-0.00126519] 模型误差 [-0.0267] 校正值 [0.0437]
# 这是对第79时刻的最优U1、U2输入求解
# 1设定 0.1176 预测 [-0.0509] 高炉 [0.1138] 高炉与设定误差 [0.0038] [0.30229223] 模型误差 [-0.1647] 校正值 [0.1747]
# 2设定 -0.5523 预测 [-0.58] 高炉 [-0.5645] 高炉与设定误差 [0.0122] [0.01029018] 模型误差 [-0.0155] 校正值 [0.0267]
# 这是对第80时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0127] 高炉 [0.1497] 高炉与设定误差 [0.0307] [2.44220294] 模型误差 [-0.137] 校正值 [0.1647]
# 2设定 -0.5523 预测 [-0.5659] 高炉 [-0.5408] 高炉与设定误差 [-0.0115] [-0.00969976] 模型误差 [-0.0251] 校正值 [0.0155]
# 这是对第81时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.047] 高炉 [0.1912] 高炉与设定误差 [-0.0108] [-0.85914633] 模型误差 [-0.1442] 校正值 [0.137]
# 2设定 -0.5523 预测 [-0.5724] 高炉 [-0.5306] 高炉与设定误差 [-0.0217] [-0.01830303] 模型误差 [-0.0418] 校正值 [0.0251]
# 这是对第82时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.047] 高炉 [0.1953] 高炉与设定误差 [-0.0149] [-1.18530369] 模型误差 [-0.1482] 校正值 [0.1442]
# 2设定 -0.5523 预测 [-0.5786] 高炉 [-0.5474] 高炉与设定误差 [-0.0049] [-0.00413294] 模型误差 [-0.0312] 校正值 [0.0418]
# 这是对第83时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0397] 高炉 [0.1971] 高炉与设定误差 [-0.0167] [-1.32849472] 模型误差 [-0.1574] 校正值 [0.1482]
# 2设定 -0.5523 预测 [-0.5833] 高炉 [-0.5515] 高炉与设定误差 [-0.0008] [-0.00067477] 模型误差 [-0.0318] 校正值 [0.0312]
# 这是对第84时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0345] 高炉 [0.1915] 高炉与设定误差 [-0.0111] [-0.88301147] 模型误差 [-0.157] 校正值 [0.1574]
# 2设定 -0.5523 预测 [-0.5776] 高炉 [-0.5317] 高炉与设定误差 [-0.0205] [-0.01729088] 模型误差 [-0.0459] 校正值 [0.0318]
# 这是对第85时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0325] 高炉 [0.1896] 高炉与设定误差 [-0.0092] [-0.73186539] 模型误差 [-0.1571] 校正值 [0.157]
# 2设定 -0.5523 预测 [-0.5856] 高炉 [-0.5502] 高炉与设定误差 [-0.002] [-0.00168692] 模型误差 [-0.0353] 校正值 [0.0459]
# 这是对第86时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0321] 高炉 [0.202] 高炉与设定误差 [-0.0216] [-1.71829267] 模型误差 [-0.1699] 校正值 [0.1571]
# 2设定 -0.5523 预测 [-0.5882] 高炉 [-0.5469] 高炉与设定误差 [-0.0053] [-0.00447032] 模型误差 [-0.0413] 校正值 [0.0353]
# 这是对第87时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0242] 高炉 [0.1914] 高炉与设定误差 [-0.011] [-0.87505642] 模型误差 [-0.1672] 校正值 [0.1699]
# 2设定 -0.5523 预测 [-0.5814] 高炉 [-0.5372] 高炉与设定误差 [-0.0151] [-0.01273621] 模型误差 [-0.0442] 校正值 [0.0413]
# 这是对第88时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0216] 高炉 [0.1992] 高炉与设定误差 [-0.0188] [-1.49555096] 模型误差 [-0.1776] 校正值 [0.1672]
# 2设定 -0.5523 预测 [-0.592] 高炉 [-0.5443] 高炉与设定误差 [-0.008] [-0.00674766] 模型误差 [-0.0477] 校正值 [0.0442]
# 这是对第89时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0159] 高炉 [0.198] 高炉与设定误差 [-0.0175] [-1.39213523] 模型误差 [-0.1821] 校正值 [0.1776]
# 2设定 -0.5523 预测 [-0.5888] 高炉 [-0.5443] 高炉与设定误差 [-0.0079] [-0.00666331] 模型误差 [-0.0445] 校正值 [0.0477]
# 这是对第90时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0087] 高炉 [0.1898] 高炉与设定误差 [-0.0094] [-0.74777548] 模型误差 [-0.1811] 校正值 [0.1821]
# 2设定 -0.5523 预测 [-0.5942] 高炉 [-0.5436] 高炉与设定误差 [-0.0086] [-0.00725373] 模型误差 [-0.0506] 校正值 [0.0445]
# 这是对第91时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0104] 高炉 [0.1871] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1767] 校正值 [0.1811]
# 2设定 -0.5523 预测 [-0.5897] 高炉 [-0.5492] 高炉与设定误差 [-0.003] [-0.00253037] 模型误差 [-0.0405] 校正值 [0.0506]
# 这是对第92时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0119] 高炉 [0.1906] 高炉与设定误差 [-0.0101] [-0.80346087] 模型误差 [-0.1786] 校正值 [0.1767]
# 2设定 -0.5523 预测 [-0.5927] 高炉 [-0.5482] 高炉与设定误差 [-0.004] [-0.00337383] 模型误差 [-0.0444] 校正值 [0.0405]
# 这是对第93时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0137] 高炉 [0.1875] 高炉与设定误差 [-0.007] [-0.55685411] 模型误差 [-0.1737] 校正值 [0.1786]
# 2设定 -0.5523 预测 [-0.5857] 高炉 [-0.5392] 高炉与设定误差 [-0.0131] [-0.01104929] 模型误差 [-0.0465] 校正值 [0.0444]
# 这是对第94时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.015] 高炉 [0.1902] 高炉与设定误差 [-0.0098] [-0.77959574] 模型误差 [-0.1752] 校正值 [0.1737]
# 2设定 -0.5523 预测 [-0.5942] 高炉 [-0.5463] 高炉与设定误差 [-0.006] [-0.00506075] 模型误差 [-0.048] 校正值 [0.0465]
# 这是对第95时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0163] 高炉 [0.1936] 高炉与设定误差 [-0.0132] [-1.05006771] 模型误差 [-0.1774] 校正值 [0.1752]
# 2设定 -0.5523 预测 [-0.5909] 高炉 [-0.5463] 高炉与设定误差 [-0.0059] [-0.0049764] 模型误差 [-0.0446] 校正值 [0.048]
# 这是对第96时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0132] 高炉 [0.1902] 高炉与设定误差 [-0.0098] [-0.77959574] 模型误差 [-0.177] 校正值 [0.1774]
# 2设定 -0.5523 预测 [-0.5931] 高炉 [-0.5445] 高炉与设定误差 [-0.0077] [-0.00649462] 模型误差 [-0.0486] 校正值 [0.0446]
# 这是对第97时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0142] 高炉 [0.1871] 高炉与设定误差 [-0.0067] [-0.5329889] 模型误差 [-0.1729] 校正值 [0.177]
# 2设定 -0.5523 预测 [-0.5895] 高炉 [-0.5488] 高炉与设定误差 [-0.0034] [-0.00286776] 模型误差 [-0.0407] 校正值 [0.0486]
# 这是对第98时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0158] 高炉 [0.1908] 高炉与设定误差 [-0.0104] [-0.82732608] 模型误差 [-0.175] 校正值 [0.1729]
# 2设定 -0.5523 预测 [-0.5923] 高炉 [-0.546] 高炉与设定误差 [-0.0062] [-0.00522944] 模型误差 [-0.0463] 校正值 [0.0407]
# 这是对第99时刻的最优U1、U2输入求解
# 1设定 0.1804 预测 [0.0157] 高炉 [0.1896] 高炉与设定误差 [-0.0092] [-0.73186539] 模型误差 [-0.174] 校正值 [0.175]
# 2设定 -0.5523 预测 [-0.5877] 高炉 [-0.5474] 高炉与设定误差 [-0.0049] [-0.00413294] 模型误差 [-0.0404] 校正值 [0.0463]

# %%
if iscontrol:
    startt = 20
    endd = 400
    y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
    y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
    plt.subplot(2, 1, 1)
    plt.plot(y1_pred_inverse_transform[startt:endd],'b')
    plt.plot(set_y1[startt:endd],'r')
    
    plt.grid(linestyle='--', alpha=0.7, color='gray')
    plt.subplot(2, 1, 2)
    plt.plot(y2_pred_inverse_transform[startt:endd],'b')
    plt.plot(set_y2[startt:endd],'r')
    
    plt.grid(linestyle='--', alpha=0.7, color='gray')

# %%
# 数据转换、
base.data_tranform_plot_7_2(scalers,Times ,max_control,
                        output_term,input_term,
                        set_y1,set_y2,set_y1_trans,set_y2_trans,
                        all_pred_y1, all_pred_y2,
                        all_pred_u1,
                        all_pred_u2,
                        all_pred_u3,
                        all_pred_u4,
                        all_pred_u5,
                        all_pred_u6,
                        all_pred_u7)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 上线分别是：[2.00736825e+04 2.48731508e-04]、[3.37254652e+01 3.41094835e-06]、[ 4.32087465e-01 -2.78527280e-04]、[235.88697211  37.56529469]、[1220.02980501  575.46498828]、[2.43904875e+01 1.16388021e-02]、[5.35000000e+01 1.43051147e-06]
# 平均误差 1.5389
# 平均误差 0.0154
