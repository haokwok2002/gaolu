# %%
# 库文件
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from skopt import gp_minimize
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.optimize import minimize
from sklearn.metrics.pairwise import rbf_kernel
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
# 设置中文字体
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12)  # 替换为你的中文字体文件路径
import sys
sys.path.append(r"C:\Users\haokw\Documents\GitHub\gaolu\MPC\高炉")


import base

# %%
# 读取Excel文件
excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='原始输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='剔除直线输出') 
# df_sheet_yuansu = pd.read_excel(excel_path, sheet_name='单SI_0.2_0.8') 
# print(df_sheet_yuansu.info())
# print(df_sheet_yuansu.columns)

excel_path = f'C:\\Users\\haokw\\Documents\\GitHub\\gaolu\\MPC\\高炉\\0数据处理\\新输入输出模式\\1h_mean.xlsx'
df_sheet_params = pd.read_excel(excel_path, sheet_name='1h_mean_all') 

# print(df_sheet_params.info())
# print(df_sheet_params.columns)

# %%
import pandas as pd

# 假设 df 是你的 DataFrame

# 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_yuansu.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
    # 检查 DataFrame 中是否包含 NaN 值
contains_nan = df_sheet_params.isna().any().any()

if contains_nan:
    print("数据包含 NaN 值")
else:
    print("数据不包含 NaN 值")
# Out:
# 数据不包含 NaN 值
# 数据不包含 NaN 值

# %%
input_term =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term = ['铁水温度[MIT]', '铁水硅含量[SI]']
time_term= '时间戳h'

# %%
# 异常数据处理-处理前后对比
# 创建数据框副本以避免修改原始数据
df_sheet_yuansu_process = df_sheet_yuansu.copy()
df_sheet_params_process = df_sheet_params.copy()
# 定义一个函数，用前后两个值的差值按照距离进行加权替换异常值
def replace_outliers_with_weighted_diff(x, y):
    # 计算列的中位数
    median_value = y.median()
    # 检测异常值的索引
    outliers_index = (y - median_value).abs() > 2.5 * y.std()
    
    # 遍历异常值的索引
    for idx in outliers_index[outliers_index].index:
        # 获取异常值前一个和后一个值的索引
        prev_idx = idx - 1 if idx - 1 >= 0 else idx
        next_idx = idx + 1 if idx + 1 < len(y) else idx
        # 计算当前 x 与前后两个 x 的距离
        dist_prev = abs(x[idx] - x[prev_idx])
        dist_next = abs(x[next_idx] - x[idx])
        total_dist = dist_prev + dist_next
        # 计算权重
        weight_prev = dist_next / total_dist
        weight_next = dist_prev / total_dist
        # 计算前后两个值的差值
        diff = y[next_idx] - y[prev_idx]
        # 根据权重进行插值
        interpolated_value = y[prev_idx] + weight_prev * diff
        # 用插值结果替代异常值
        y[idx] = interpolated_value

# 画出数据
def plot_subplot(data_x,data_y_yuan,data_y,column):
    plt.plot(data_x,data_y_yuan,'r-')
    plt.plot(data_x,data_y,'m-')
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签
    # 使用中文标签


# 对指定列应用替代异常值的函数
# 对指定列应用替代异常值的函数
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[0]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[1]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[2]])
replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[3]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[4]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[5]])
# replace_outliers_with_weighted_diff(df_sheet_params_process[time_term], df_sheet_params_process[input_term[6]])

# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[0]])
# replace_outliers_with_weighted_diff(df_sheet_yuansu_process[time_term], df_sheet_yuansu_process[output_term[1]])

plt.figure(figsize=(15, 4))
for idx, column in enumerate(input_term):
    plt.subplot(len(input_term), 1, idx+1)
    plot_subplot(df_sheet_params_process[time_term].values,df_sheet_params[column].values,df_sheet_params_process[column].values,column)

plt.figure(figsize=(15, 2))
for idx, column in enumerate(output_term):
    plt.subplot(len(output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu[column].values,df_sheet_yuansu_process[column].values,column)
# Out:
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value
# C:\Users\haokw\AppData\Local\Temp\ipykernel_9676\1395502433.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[idx] = interpolated_value

# %%
# 画出选取的数据
def plot_subplot(data_x,data_y,column,index_predict,index_gaolu):
    plt.plot(data_x,data_y,'-', label='origin_data')
    plt.plot(data_x[index_gaolu],data_y[index_gaolu],'r.', label='gaolu_data')
    plt.plot(data_x[index_predict],data_y[index_predict],'g-', label='predict_data')
    plt.legend()
    # plt.xlabel(time_term, fontproperties=font)  # 使用中文标签
    plt.ylabel(column, fontproperties=font)  # 使用中文标签



length1 = 400
start1 = 0
length2 = 400
start2 = 400


index_gaolu   = range(start1, start1+length1+1, 1)
index_predict     = range(start2, start2+length2+1, 1)
# index = range(1, 7572, 1)


plt.figure(figsize=(15, 6))
for idx, column in enumerate(output_term):
    plt.subplot(len(input_term+output_term), 1, idx+1)
    plot_subplot(df_sheet_yuansu_process[time_term].values,df_sheet_yuansu_process[column].values,column,index_predict,index_gaolu)

# %%
# 数据归一化、逆归一化
from sklearn.preprocessing import MinMaxScaler

# 将数据存储为字典，每个键对应一列数据
original_data_dict = {
    input_term[0]:   df_sheet_params_process[input_term[0]].values,
    input_term[1]:   df_sheet_params_process[input_term[1]].values,
    input_term[2]:   df_sheet_params_process[input_term[2]].values,
    input_term[3]:   df_sheet_params_process[input_term[3]].values,
    # input_term[4]:   df_sheet_params_process[input_term[4]].values,
    # input_term[5]:   df_sheet_params_process[input_term[5]].values,
    # input_term[6]:   df_sheet_params_process[input_term[6]].values,
    output_term[0]:  df_sheet_yuansu_process[output_term[0]].values,
    output_term[1]:  df_sheet_yuansu_process[output_term[1]].values
}

# 初始化缩放器
scalers = {}

# 进行拟合
for column, data in original_data_dict.items():
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(data.reshape(-1, 1))  # 保证数据是列向量
    scalers[column] = scaler

# 进行归一化
normalized_data_dict = {}
for column, scaler in scalers.items():
    normalized_data_dict[column] = scaler.transform(original_data_dict[column].reshape(-1, 1)).flatten()

# 进行反归一化
original_data_dict = {}
for column, scaler in scalers.items():
    original_data_dict[column] = scaler.inverse_transform(normalized_data_dict[column].reshape(-1, 1)).flatten()

# %%
# 标定归一化前后数据
data_point = np.array([1500]).reshape(-1, 1)
data1 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[0]].inverse_transform(data_point).flatten()

data_point = np.array([1510]).reshape(-1, 1)
data3 = scalers[output_term[0]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[0]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_temp = (data3-data1)/(data4-data2)
print('每摄氏度的输出差：',d_temp)



data_point = np.array([0.50]).reshape(-1, 1)
data1 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data1).reshape(-1, 1)
data2 = scalers[output_term[1]].inverse_transform(data_point).flatten()

data_point = np.array([0.60]).reshape(-1, 1)
data3 = scalers[output_term[1]].transform(data_point).flatten()

data_point = np.array(data3).reshape(-1, 1)
data4 = scalers[output_term[1]].inverse_transform(data_point).flatten()

print(data1)
print(data2)
print(data3)
print(data4)
d_yuansu = (data3-data1)/(data4-data2)
print('每浓度的输出差：',(data3-data1))
# Out:
# [0.0341569]
# [1500.]
# [0.1523575]
# [1510.]
# 每摄氏度的输出差： [0.01182006]
# [-0.53242879]
# [0.5]
# [-0.4247456]
# [0.6]
# 每浓度的输出差： [0.1076832]

# %%
isShuffle = True
isShuffle = False
time_steps = 2
test_size = 0.15
val_size = 0.15
train_size = 1-val_size-test_size

# %%
# 组合训练数据--拆分训练、测试集

# 定义时间步数和特征数

# 构成    
# X = [X(t),X(t-1),Y(t-1)]
# Y = [Y(t)]
def make_data(u1_data,u2_data,u3_data,u4_data,y1_data,y2_data,index_fanwei):
    X = np.column_stack((u1_data,u2_data,u3_data,u4_data))
    y = np.column_stack((y1_data, y2_data))

    X_modified = []
    y_modified = []
    
    for i in range(3,len(y1_data)):
        if i in index_fanwei:
            # print(i)
            # print(df_sheet_yuansu[time_term][i])
            yuansu_time = df_sheet_yuansu[time_term][i]
            closest_10 = df_sheet_params[df_sheet_params[time_term] <= yuansu_time].nlargest(time_steps, time_term)
            # print(closest_10)
            
            index = closest_10.index
            # print(index)
            # print(closest_10.iloc[-1][time_term])
            if closest_10.iloc[-1][time_term] < yuansu_time - time_steps + 1:
                print(i,yuansu_time,'errloss')
            else:

                # print(X[index, :])
                new_x_sample = np.concatenate([X[i, :] for i in index],axis=0)
                # print(new_x_sample)
                y_last = y[i-1, :]
                # print(y_last, 'y_last time : ',df_sheet_yuansu[time_term][i-1])
                new_x_sample = np.concatenate([new_x_sample,y_last],axis=0)
                # print(new_x_sample)
                y_sample = y[i, :]  
                X_modified.append(new_x_sample)
                y_modified.append(y_sample)
                print(i,yuansu_time,index[0],index[-1], end='\r')
                # break

    # 将列表转换为 NumPy 数组
    X_modified = np.array(X_modified)
    y_modified = np.array(y_modified)
    X_reshaped = X_modified.reshape((X_modified.shape[0], X_modified.shape[1]))

    # 打印新数据的形状
    print("Modified Input Shape:", X_reshaped.shape)
    print("Modified Output Shape:", y_modified.shape)


    X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y_modified, 
                                                        test_size=test_size, 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    # 将剩余的70%训练数据再次拆分成训练数据和验证数据（20%验证数据，50%训练数据）
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                        test_size=val_size/(train_size+val_size), 
                                                        random_state=42, 
                                                        shuffle=isShuffle)

    print('训练数量：',X_train.shape,y_train.shape)
    print('验证数量：',X_val.shape,y_val.shape)
    print('测试数量：',X_test.shape,y_test.shape)

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
def symmetrical_moving_average(data, N):
    """
    使用对称的移动平均滤波，当前值由其自身及其前后的值决定。
    
    :param data: 输入的数据序列，一般为列表或者NumPy数组。
    :return: 经过滤波处理的数据序列。
    """
    filtered_data = []
    N = 9
    percent = 0.8
    # 遍历数据，从索引1开始到倒数第二个元素结束
    for i in range(1, len(data) - 1):
        # 计算当前值及其前后值的平均
        average = (data[i - 1]*(1-percent)/2 + data[i]*percent + data[i + 1]*(1-percent)/2)
        filtered_data.append(average)
    
    # 对于序列的第一个和最后一个元素，直接使用原始值
    # 或者可以使用其他边界处理策略
    filtered_data.insert(0, data[0])
    filtered_data.append(data[-1])
    
    return np.array(filtered_data)

# 示例数据
data = [2, 4, 6, 8, 10, 12, 14]
filtered_data = symmetrical_moving_average(data,9)
print(filtered_data)
# Out:
# [ 2.  4.  6.  8. 10. 12. 14.]

# %%
# 高炉模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)

print('高炉模型数据')
X_gaolu_train, X_gaolu_val, X_gaolu_test,\
y_gaolu_train, y_gaolu_val, y_gaolu_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_gaolu)



# 预测模型列数据
u1_data = normalized_data_dict[input_term[0]]
u2_data = normalized_data_dict[input_term[1]]
u3_data = normalized_data_dict[input_term[2]]
u4_data = normalized_data_dict[input_term[3]]
y1_data = normalized_data_dict[output_term[0]]
y2_data = normalized_data_dict[output_term[1]]
num_samples = y2_data.shape[0]

# filter_windows = 2
# u1_data = symmetrical_moving_average(u1_data, filter_windows)
# u2_data = symmetrical_moving_average(u2_data, filter_windows)
# u3_data = symmetrical_moving_average(u3_data, filter_windows)
# u4_data = symmetrical_moving_average(u4_data, filter_windows)
# u5_data = symmetrical_moving_average(u5_data, filter_windows)
# u6_data = symmetrical_moving_average(u6_data, filter_windows)
# u7_data = symmetrical_moving_average(u7_data, filter_windows)
# y1_data = symmetrical_moving_average(y1_data, filter_windows)
# y2_data = symmetrical_moving_average(y2_data, filter_windows)
print('预测模型数据')
X_predict_train, X_predict_val, X_predict_test,\
y_predict_train, y_predict_val, y_predict_test = make_data(u1_data,u2_data,u3_data,u4_data,
                                                            y1_data,y2_data,
                                                            index_fanwei=index_predict)
# Out:
# 高炉模型数据
# Modified Input Shape: (398, 10)
# Modified Output Shape: (398, 2)
# 训练数量： (278, 10) (278, 2)
# 验证数量： (60, 10) (60, 2)
# 测试数量： (60, 10) (60, 2)
# 预测模型数据
# Modified Input Shape: (401, 10)
# Modified Output Shape: (401, 2)
# 训练数量： (279, 10) (279, 2)
# 验证数量： (61, 10) (61, 2)
# 测试数量： (61, 10) (61, 2)

# %%
epoch_once_time = 50
ischuangxin = True
# ischuangxin = False
cengshu = 3

# %%
# 定义模型
import torch
import torch.nn as nn
import torch.optim as optim

class MyNeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, if_chuangxin = False,gamma = 0.1):
        self.if_chuangxin = if_chuangxin
        super(MyNeuralNetwork, self).__init__()
        if cengshu == 3:    
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, hidden_size)
                self.fc4 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()
        elif cengshu == 2:  
            if self.if_chuangxin:            
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.relu = nn.ReLU()
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
            else:
                self.fc1 = nn.Linear(input_size, hidden_size)
                self.fc2 = nn.Linear(hidden_size, hidden_size)
                self.fc3 = nn.Linear(hidden_size, output_size)
                self.relu = nn.ReLU()


    def forward(self, x0):
        if cengshu == 3:    
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                x4 = x + x2 + x3
                output = self.fc4(x4)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = self.fc3(x2)
                x3 = self.relu(x3)

                output = self.fc4(x3)
        elif cengshu == 2:  
            if self.if_chuangxin:

                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                x3 = x + x2
                output = self.fc3(x3)
            else:
                x = self.fc1(x0)
                x = self.relu(x)

                x2 = self.fc2(x)
                x2 = self.relu(x2)

                output = self.fc3(x2)
        return output
        
        return output
    
    

    
    def custom_loss(self, y_true, y_pred):

        squared_diff = torch.pow(y_true - y_pred, 2)
        sum_squared_diff = torch.sum(squared_diff)
        mse = sum_squared_diff / len(y_true)
        return mse
    

    def my_fit(self, 
                X_train, y_train, 
                X_val, y_val, 
                train_loss_list,val_loss_list,
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)


        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            # 验证集评估
            self.eval()
            with torch.no_grad():
                val_loss = 0
                for i in range(0, len(X_val), batch_size):
                    x_batch_val = torch.tensor(X_val[i:i+batch_size], dtype=torch.float32)
                    y_batch_val = torch.tensor(y_val[i:i+batch_size], dtype=torch.float32)

                    y_pred_val = self(x_batch_val)
                    val_loss += self.custom_loss(y_batch_val, y_pred_val).item()

                average_epoch_val_loss = val_loss / (len(X_val) / batch_size)

            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}, 验证误差: {average_epoch_val_loss:.4f}', end='\r')
            train_loss_list.append(average_epoch_train_loss)
            val_loss_list.append(average_epoch_val_loss)

        return train_loss_list,val_loss_list
    
    def model_update(self, 
                X_train, y_train, 
                epochs=1, batch_size=32, lr=0.001):
        optimizer = optim.Adam(self.parameters(), lr=lr)
        for epoch in range(epochs):
            epoch_loss = 0
            for i in range(0, len(X_train), batch_size):
                x_batch = torch.tensor(X_train[i:i+batch_size], dtype=torch.float32)
                y_batch = torch.tensor(y_train[i:i+batch_size], dtype=torch.float32)

                optimizer.zero_grad()
                y_pred = self(x_batch)
                loss = self.custom_loss(y_batch, y_pred)
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            average_epoch_train_loss = epoch_loss / (len(X_train) / batch_size)
            print(f'第 {epoch + 1}/{epochs} 轮, 训练误差: {average_epoch_train_loss:.4f}')
            
            
        return 0
    
    

    def my_predict(self, X_test):
        # 设置模型为评估模式，这会关闭 dropout 等层
        self.eval()
        # 将输入数据转换为张量，并设置 requires_grad=True
        x_tensor = torch.tensor(X_test, dtype=torch.float32, requires_grad=True)
        
        # 获取模型的预测输出
        y_pred = self(x_tensor)
        # 保留预测值的梯度信息
        y_pred.retain_grad()
        # 返回预测结果和包含梯度信息的张量
        return y_pred[:,0].detach().numpy(),y_pred[:,1].detach().numpy()

# %%
# 建立高炉模型实例
input_size = 10  # 输入特征大小
hidden_size = 16  # 32
output_size = 2  # 输出大小
# 设置随机种子
torch.manual_seed(0)
model_gaolu = MyNeuralNetwork(input_size, 
                            hidden_size,
                            output_size,
                            ischuangxin,
                            gamma = 0.1)
epoch_sum_gaolu = 0
gaolu_train_loss_list = []
gaolu_val_loss_list = []

# %%
# 高炉模型训练
epoch_once = epoch_once_time
epoch_sum_gaolu = epoch_sum_gaolu + epoch_once
gaolu_train_loss_list,gaolu_val_loss_list = model_gaolu.my_fit(X_gaolu_train, y_gaolu_train,
                                    X_gaolu_val, y_gaolu_val, 
                                    gaolu_train_loss_list, gaolu_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=32,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_gaolu)

# 绘制训练和验证损失曲线
plt.plot(gaolu_train_loss_list, label='Train Loss')
plt.plot(gaolu_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0292, 验证误差: 0.0133
# epoch_sum: 50

# %%
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
input_term333 =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term333 = ['铁水温度MIT', '铁水硅含量[Si]']
time_term= '时间戳h'
print(input_term333)
print(output_term333)
input_term222 =        ['富氧流量/(m\u00b3/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
output_term222 = ['铁水温度MIT/℃', '铁水硅含量[Si]/%']
time_term= '时间戳h'
print(input_term222)
print(output_term222)
# Out:
# ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
# ['铁水温度MIT', '铁水硅含量[Si]']
# ['富氧流量/(m³/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
# ['铁水温度MIT/℃', '铁水硅含量[Si]/%']

# %%
ditem = -0.65

# %%
def double_control_train_test_result(scalers, output_term, y_test, y_pred_0, y_pred_1, y_test_2, y_pred_0_2, y_pred_1_2,ditem,a,b):
    y_test_0 = scalers[output_term[0]].inverse_transform((y_test[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    plt.figure(figsize=(9, 8))
    
    
    ax = plt.subplot(4, 1, 1)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    ax.legend(prop=font, loc='upper right', bbox_to_anchor=(a, b), ncol=4) 
    
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[0]} {output_term333[0]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('训练样本', fontproperties=font)  




    ax = plt.subplot(4, 1, 2)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font) 

    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[1]} {output_term333[1]}建模效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    
    ax.set_xlabel('训练样本', fontproperties=font)  




    y_test_0 = scalers[output_term[0]].inverse_transform((y_test_2[:, 0]).reshape(-1, 1)).flatten()
    y_test_1 = scalers[output_term[1]].inverse_transform((y_test_2[:, 1]).reshape(-1, 1)).flatten()
    y_pred_0_inverse_transform = scalers[output_term[0]].inverse_transform((y_pred_0_2).reshape(-1, 1)).flatten()
    y_pred_1_inverse_transform = scalers[output_term[1]].inverse_transform((y_pred_1_2).reshape(-1, 1)).flatten()

    output0 = y_test_0 - y_pred_0_inverse_transform
    output1 = y_test_1 - y_pred_1_inverse_transform

    ax = plt.subplot(4, 1, 3)
    plt.plot(y_test_0,'k', label="真实值")
    plt.plot(y_pred_0_inverse_transform,'r--', label="预测值")
    plt.ylabel(output_term222[0], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[2]} {output_term333[0]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  



    ax = plt.subplot(4, 1, 4)
    plt.plot(y_test_1,'k')
    plt.plot(y_pred_1_inverse_transform,'r--')
    plt.ylabel(output_term222[1], fontproperties=font)  
    ax.yaxis.set_label_coords(-0.07, 0.5)  
    ax.text(0.5, ditem, f'{subplot_labels[3]} {output_term333[1]}预测效果', 
            transform=ax.transAxes, ha='center', fontproperties=font)  
    ax.set_xlabel('测试样本', fontproperties=font)  




    plt.subplots_adjust(hspace=0.6)  # 调整子图之间的垂直间距
    plt.tight_layout()  # 自动调整子图布局
    plt.show()

# %%
# 高炉模型建模效果
y_train_pred_0,y_train_pred_1 = model_gaolu.my_predict(X_gaolu_train)
y_test_pred_0,y_test_pred_1 = model_gaolu.my_predict(X_gaolu_test)

double_control_train_test_result(scalers,  output_term,
                                        y_gaolu_train,  y_train_pred_0, y_train_pred_1,
                                        y_gaolu_test ,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.63, b = 0.38 )

# base.double_control_train_test_result(scalers,  output_term,
#                                         y_gaolu_train[:-1],  y_train_pred_0[1:], y_train_pred_1[1:],
#                                         y_gaolu_test[:-1] ,   y_test_pred_0[1:],  y_test_pred_1[1:])

# %%
# 创建预测模型实例
# 设置随机种子
torch.manual_seed(0)
model_predict = MyNeuralNetwork(input_size, hidden_size, output_size,ischuangxin)
epoch_sum_predict = 0
predict_train_loss_list = []
predict_val_loss_list = []

# %%
# 预测模型训练
epoch_once = epoch_once_time
epoch_sum = epoch_sum_predict + epoch_once
predict_train_loss_list, predict_val_loss_list = model_predict.my_fit(X_predict_train, y_predict_train,
                                    X_predict_val, y_predict_val, 
                                    predict_train_loss_list, predict_val_loss_list,
                                    epochs=epoch_once, 
                                    batch_size=64,
                                    lr = 0.002)

print('\nepoch_sum:',epoch_sum_predict)


# 绘制训练和验证损失曲线
plt.plot(predict_train_loss_list, label='Train Loss')
plt.plot(predict_val_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# 第 50/50 轮, 训练误差: 0.0279, 验证误差: 0.0335
# epoch_sum: 0

# %%
# 预测模型建模效果
y_train_pred_0,y_train_pred_1 = model_predict.my_predict(X_predict_train)


y_test_pred_0,y_test_pred_1 = model_predict.my_predict(X_predict_test)

double_control_train_test_result(scalers,  output_term,
                                        y_predict_train,  y_train_pred_0, y_train_pred_1,
                                        y_predict_test,   y_test_pred_0,  y_test_pred_1,
                                        ditem = -0.65   ,a = 0.31, b = 0.38 )

# %%
base.gaolu_predict_raw(scalers,output_term,model_predict,model_gaolu,X_predict_test,y_predict_test)

# %%
# 使用NumPy重新构建神经网络架构
class MyNeuralNetworkNumpy:
    def __init__(self, model, input_size, hidden_size, output_size,ifchuangxin):
        self.ifchuangxin = ifchuangxin
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        params = {name: param.detach().numpy() for name, param in model.state_dict().items()}
        if cengshu == 3:    
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
            self.weights_fc4 = params['fc4.weight']
            self.bias_fc4 = params['fc4.bias']
        elif cengshu == 2:  
            self.weights_fc1 = params['fc1.weight']
            self.bias_fc1 = params['fc1.bias']
            self.weights_fc2 = params['fc2.weight']
            self.bias_fc2 = params['fc2.bias']
            self.weights_fc3 = params['fc3.weight']
            self.bias_fc3 = params['fc3.bias']
        
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    def relu(self, x):
        return np.maximum(0, x)

    def forward(self, x):
        if cengshu == 3:    
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                hidden4 = hidden1 + hidden2 + hidden3
                output = np.dot(hidden4, self.weights_fc4.T) + self.bias_fc4

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3
                hidden3 = self.relu(hidden3)

                output = np.dot(hidden3, self.weights_fc4.T) + self.bias_fc4
        elif cengshu == 2:  
            if self.ifchuangxin:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                hidden3 = hidden1 + hidden2
                output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3
                # hidden2 = self.relu(hidden2)

                # hidden3 = np.concatenate([x, hidden1, hidden2], axis=1)  # 按列连接
                # output = np.dot(hidden3, self.weights_fc3.T) + self.bias_fc3

            else:
                hidden1 = np.dot(x, self.weights_fc1.T) + self.bias_fc1
                hidden1 = self.relu(hidden1)

                hidden2 = np.dot(hidden1, self.weights_fc2.T) + self.bias_fc2
                hidden2 = self.relu(hidden2)

                output = np.dot(hidden2, self.weights_fc3.T) + self.bias_fc3


            
        return output
    
    
    def my_predict(self, data_input):
        input = data_input  # 随机初始化一个输入序列
        output_prediction = model_numpy.forward(input)
        return output_prediction[:,0], output_prediction[:,1]

# 使用NumPy模型进行预测
model_numpy = MyNeuralNetworkNumpy(model_predict, input_size, hidden_size, output_size,ischuangxin)


y_pred_0, y_pred_1 = model_numpy.my_predict(X_predict_test)

# 计算 RMSE、MRE
y_test = y_predict_test


base.double_control_predict_result(scalers,output_term,y_test,y_pred_0,y_pred_1)
# Out:
# RMSE:  铁水温度[MIT]: 14.3563 , 铁水硅含量[SI]: 0.1251
# MAPE:  铁水温度[MIT]: 0.8042% , 铁水硅含量[SI]: 30.1320%
# MRE :  铁水温度[MIT]: 0.0080  , 铁水硅含量[SI]: 0.3013
# per :  铁水温度[MIT]: 0.4754  , 铁水硅含量[SI]: 0.7049

# %%
iscontrol = True
# iscontrol = False
Times = 200
# 过度系数  0.1 越小过度越快
rou = 0.1
if_add_noise = 1
if_gaolu_is_predict = 0

# %%
# 生成参考轨迹
def get_yr(aim_value,current_value,alpha,P):
    # 生成设定信号
    setpoint_signal = np.full(10, aim_value)
    # 初始化参数
    alpha = alpha
    y_r = np.zeros(P)
    y_r[0] = current_value
    # 模拟一阶模型
    for k in range(1,P):
        y_r[k] = alpha * y_r[k-1] + (1 - alpha) * aim_value

    # # 绘制结果
    # plt.plot(setpoint_signal, label='Setpoint Signal')
    # plt.plot(y_r,'o-', label='Output Signal (Tracked)')
    # plt.legend()
    # plt.xlabel('Time')
    # plt.ylabel('Amplitude')
    # plt.title('Tracking Setpoint Signal with One-Order Model')
    # plt.show()
    return y_r
# 测试
y_r = get_yr(1,-0.5,rou,20)

# %%
# # 生成期望数据

def generate_y_aim_data(Times):
    if Times == 400:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        
    elif Times == 200:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10+75:410-125]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0+75:400-125]

    elif Times == 1000:
        set_y1 = np.repeat(np.arange(1455, 1560, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.34, 0.76, 0.02), 20)[0:400]
        set_y1 = np.repeat(np.arange(1457.5, 1562.5, 5), 20)[10:410]
        set_y2 = np.repeat(np.arange(0.35, 0.77, 0.02), 20)[0:400]

    else:
        set_y1 = np.full(Times,1500)
        set_y2 = np.full(Times,0.45)

    





    set_y1_trans = scalers[output_term[0]].transform(set_y1.reshape(-1,1)).flatten()
    set_y2_trans = scalers[output_term[1]].transform(set_y2.reshape(-1,1)).flatten()

    return set_y1, set_y2, set_y1_trans, set_y2_trans
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)
print(set_y1.shape)
print(set_y1.shape)
# Out:
# (200,)
# (200,)

# %%
#生成控制时域的数据格式
def generate_k_data(u1_data, u2_data, u3_data, u4_data, y1_data,y2_data, num_samples, P):
    nearest_index = np.abs(y1_data - (-0.5)).argmin()
    # 生成随机索引值
    #从原有数据的randint时刻开始往下进行控制
    randint = np.random.randint(1, num_samples - 2 - P - 1)
    randint = nearest_index  # 如果你希望使用固定的值而不是随机生成
    # randint = 250  # 如果你希望使用固定的值而不是随机生成
    print(randint)
    # 提取数据并构成 k_data
    # 第一次得到下面五个变量，固定好格式构成k_data
    u1   = u1_data[randint  :randint+3  ]
    u2   = u2_data[randint  :randint+3  ]
    u3   = u3_data[randint  :randint+3  ]
    u4   = u4_data[randint  :randint+3  ]

    y1   = y1_data[randint  :randint+3  ]
    y2   = y2_data[randint  :randint+3  ]
    k_data = np.concatenate((u1, u2, u3, u4, y1, y2), axis=0)
    print(k_data.shape)

    k_data = np.zeros_like(k_data)
    return k_data

# %%
# 定义单时刻的MPC问题优化
def my_MPC(k_data,params,M,P,y1_aim,y2_aim,isprint):

    h1 = 1.0
    h2 = 1.0
    lamda1 = 0.001
    lamda2 = 0.001
    lamda3 = 0.001
    lamda4 = 0.001
    y1_percent = 1.0
    y2_percent = 1.0

    # 从固定格式k_data里面读取信息
    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]

    
    # 获取猜测值[h U1 U2]
    # h, U1, U2  =params[0], params[1:M+1],params[M+1:]
    U1, U2, U3, U4  =params[0:M], params[M:2*M],params[2*M:3*M], params[3*M:4*M]
    
    # 整理数据见   MPC推到.escel
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))
    if isprint:
        print(u1.round(4))
        print(u2.round(4))
        print(u3.round(4))
        print(u4.round(4))
        print(y1.round(4))    
        print(y2.round(4))
        print('开始预测')

    y1_k = y1[2]
    y2_k = y2[2]





    # 总共预测 P+1 次
    # 对k时刻进行预测-----1次
    for j in range(1):   # j = 0
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_m_k, y2_m_k = model_numpy.my_predict(x)
        E1_k = y1_k - y1_m_k
        E2_k = y2_k - y2_m_k
        if isprint:
            print(j,'mode = 0')
            print(x.round(4))
            print(y1_k.round(4),y2_k.round(4))
            print(y1_m_k.round(4),y2_m_k.round(4))

    # 对控制时刻进行预测-----M次
    for j in range(1,M+1):  # j = 1,2
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 1')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(u5.round(4))
            print(u6.round(4))
            print(u7.round(4))
            print(y1.round(4))    
            print(y2.round(4))

    # 对控制时域外的部分进行预测-----P-M次
    # 注意：这部分的信号是保持控制不变下进行
    for j in range(M+1,P+1):  #j = 3,4
        x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                                u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                                y1[j+1],y2[j+1]))
        # x = x.reshape((x.shape[0], 1, x.shape[1]))
        y1_k_j, y2_k_j = model_numpy.my_predict(x)
        y1[j+2] = y1_k_j.item()#将预测值作为下一步的输出值
        y2[j+2] = y2_k_j.item()
        if isprint:
            print(j,'mode = 2')
            print(x.round(4))
            print(y1_k_j.round(4),y2_k_j.round(4))
            print('更新后:')
            print(u1.round(4))
            print(u2.round(4))
            print(u3.round(4))
            print(u4.round(4))
            print(y1.round(4))    
            print(y2.round(4))



    k_data2 = np.concatenate((u1[1:4],u2[1:4],u3[1:4],u4[1:4],y1[1:4],y2[1:4]),axis=0)
    if isprint:
        print('更新k_data')
        print(k_data2.round(4))


    #获取参考轨迹
    # 一定要对照好做差的序列
    y1_r_aim  = get_yr(y1_aim,y1_k,rou,P+1)
    y1_r = y1_r_aim[1:] 


    y2_r_aim  = get_yr(y2_aim,y2_k,rou,P+1)
    y2_r = y2_r_aim[1:] 

    y1_M_k = y1[3:]
    y2_M_k = y2[3:]
    if isprint==1:
        print('反馈补偿:')
        print('y1_k',y1_k.round(4))  
        print('y1_m_k',y1_m_k.round(4))    
        print('h*E1_k',(h1*E1_k).round(4)) 
        print('y2_k',y2_k.round(4))  
        print('y2_m_k',y2_m_k.round(4))   
        print('h*E2_k',(h2*E2_k).round(4))

        print('temp:')
        print('y1_aim',y1_aim.round(4))
        print('y1_r_aim',y1_r_aim.round(4))
        print('y1_r',y1_r.round(4))
        print('y1_M_k',y1_M_k.round(4))
        print('y1_M_k+h1*E1_k',(y1_M_k+h1*E1_k).round(4))

        print('Si_percent:')
        print('y2_aim',y2_aim.round(4))
        print('y2_r_aim',y2_r_aim.round(4))
        print('y2_r',y2_r.round(4))
        print('y2_M_k',y2_M_k.round(4))
        print('y2_M_k+h2*E2_k',(y2_M_k+h2*E2_k).round(4))

        print('u:')
        print(u1[2:].round(4))
        print(u2[2:].round(4))
        print(u3[2:].round(4))
        print(u4[2:].round(4))
        
    # 计算mse
    # lamda1太大的话会导致y1_r和y1_M_k的误差加大*****************导致超调的原因\与目标值之间存在间隙


    y1_err = y1_percent*np.sum((y1_r-(y1_M_k+h1*E1_k))**2) 
    y2_err = y2_percent*np.sum((y2_r-(y2_M_k+h2*E2_k))**2) 
    u1_power = lamda1*np.sum((np.diff(u1[2:]))**2)
    u2_power = lamda2*np.sum((np.diff(u2[2:]))**2)
    u3_power = lamda3*np.sum((np.diff(u3[2:]))**2)
    u4_power = lamda4*np.sum((np.diff(u4[2:]))**2)

    # y1_err = y1_percent*np.sum(np.fabs(y1_r-(y1_M_k+h1*E1_k))) 
    # y2_err = y2_percent*np.sum(np.fabs(y2_r-(y2_M_k+h2*E2_k))) 
    # u1_power = lamda1*np.sum((np.fabs(np.diff(u1))))
    # u2_power = lamda2*np.sum((np.fabs(np.diff(u2))))
    # u3_power = lamda3*np.sum((np.fabs(np.diff(u3))))
    # u4_power = lamda4*np.sum((np.fabs(np.diff(u4))))
    # u5_power = lamda2*np.sum((np.fabs(np.diff(u5))))
    # u6_power = lamda3*np.sum((np.fabs(np.diff(u6))))
    # u7_power = lamda4*np.sum((np.fabs(np.diff(u7))))

    mse = (0
            +y1_err
            +y2_err
            +u1_power
            +u2_power
            +u3_power
            +u4_power
            )
    
    # print('mse {:.7f}'.format(mse))
    if isprint==1:
        print('mse {:.7f}'.format(mse))
        print('1111 {:.7f}'.format(y1_err))
        print('2222 {:.7f}'.format(y2_err))
        print('1111 {:.7f}'.format(u1_power))
        print('2222 {:.7f}'.format(u2_power))
        print('3333 {:.7f}'.format(u3_power))
        print('4444 {:.7f}'.format(u4_power))



    return mse , k_data2, E1_k*h1,  E2_k*h2
    # return mse , k_data2, E1_k*h1

# %%
# 生成高斯噪声,设置随机种子，以便结果可重现
np.random.seed(42)
gaussian_noise_SI = np.random.normal(0,d_yuansu*0.001,Times)
gaussian_noise_TEMP = np.random.normal(0,d_temp*0.1,Times)
plt.subplot(2, 1, 1)
plt.plot(gaussian_noise_SI)
plt.subplot(2, 1, 2)
plt.plot(gaussian_noise_TEMP)

# %%
if_update_model = True
# if_update_model = False

# %%
def update_model(model_predict,model_gaolu,x,gaolu_data_past_x,gaolu_data_past_y):
    y1_pred, y2_pred = model_gaolu.my_predict(x)
    y_label = np.column_stack((y1_pred, y2_pred))
    gaolu_data_past_x.append(x)
    gaolu_data_past_y.append(y_label)

    
    X_modified = np.array(gaolu_data_past_x)
    y_modified = np.array(gaolu_data_past_y)
    # print(X_modified)
    # print(y_modified)
    X = X_modified.reshape(X_modified.shape[0],X_modified.shape[2])
    Y = y_modified.reshape(y_modified.shape[0],y_modified.shape[2])
    print(X_modified.shape)
    print(y_modified.shape)
    if y_modified.shape[0]% 1 == 0:
        model_predict.model_update(X, Y,
                                epochs=10, 
                                batch_size=64,
                                lr = 0.002)
        # gaolu_data_past_x = []
        # gaolu_data_past_y = []

    return model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y

# %%
# 对未来Times周期预测控制
max_control = 1.0
# 期望设定值
set_y1, set_y2, set_y1_trans, set_y2_trans = generate_y_aim_data(Times)

# MPC参数
P = 3  # 预测时域长度  3
M = 3  # 4
#生成控制时域的数据格式
k_data = generate_k_data(u1_data, u2_data, u3_data, u4_data,
                        y1_data, y2_data, num_samples, P)


# MPC控制循环   迭代的只有：k_data
all_pred_y1 = []
all_pred_y2 = []
all_pred_u1 = []
all_pred_u2 = []
all_pred_u3 = []
all_pred_u4 = []
gaolu_data_past_x = []
gaolu_data_past_y = []


# MPC控制循环40
for k in range(Times):
    if iscontrol == False:
        break

    print(f"这是对第{k}时刻的最优U1、U2输入求解")

    # 定义优化目标函数
    def objective_function(params, *k_data):
        mse, k_data2, E1_k_0, E2_k_0 = my_MPC(k_data=k_data[0], params=params, 
                                M=M, P=P, 
                                y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                                isprint = 0) 
        return mse
    
    # 初始猜测值[h U1 U2]   定义参数的上下限    设置退出条件
    params = np.concatenate([np.ones(M), np.ones(M),np.ones(M), np.ones(M)])
    bounds = [(-max_control, max_control) for _ in range(4 * M)]
    exit_conditions = {'maxiter': 1000} 
    # 进行优化
    result = minimize(objective_function, params, method='L-BFGS-B', 
                    bounds=bounds, args=k_data)#args传进来的是一个元组


    U1, U2, U3, U4 =    result.x[0:M], result.x[M:2*M], \
                        result.x[2*M:3*M], result.x[3*M:4*M]
    

    u1   = k_data[0:3]
    u2   = k_data[3:6]
    u3   = k_data[6:9]
    u4   = k_data[9:12]

    y1   = k_data[12:15]
    y2   = k_data[15:18]
    u1   = np.concatenate((u1,U1,U1[-1]*np.ones(P-M)))
    u2   = np.concatenate((u2,U2,U2[-1]*np.ones(P-M)))
    u3   = np.concatenate((u3,U3,U3[-1]*np.ones(P-M)))
    u4   = np.concatenate((u4,U4,U4[-1]*np.ones(P-M)))
    y1   = np.concatenate((y1,np.zeros(P)))
    y2   = np.concatenate((y2,np.zeros(P)))



    # 将控制序列第一个数作用于高炉
    j = 1
    x = np.column_stack((   u1[j+2],u2[j+2],u3[j+2],u4[j+2],
                            u1[j+1],u2[j+1],u3[j+1],u4[j+1],
                            y1[j+1],y2[j+1]))
    # x = x.reshape((x.shape[0], 1, x.shape[1]))
    y1_pred0, y2_pred0 = model_predict.my_predict(x)
    if if_gaolu_is_predict:
        y1_pred, y2_pred = model_predict.my_predict(x)
        if if_add_noise:
            y1_pred = y1_pred+gaussian_noise_TEMP[k].item()
            y2_pred = y2_pred+gaussian_noise_SI[k].item()
    else:
        y1_pred, y2_pred = model_gaolu.my_predict(x)
        if if_update_model:
            model_predict,model_gaolu,gaolu_data_past_x,gaolu_data_past_y = update_model(model_predict,model_gaolu,x,gaolu_data_past_x,gaolu_data_past_y)




    # 更新k_data
    params = np.concatenate((U1, U2, U3, U4),axis=0)
    mse, k_data2, E1_k_0, E2_k_0 =my_MPC(k_data=k_data,params=params,
                            M=M,P=P, 
                            y1_aim = set_y1_trans[k], y2_aim = set_y2_trans[k],
                            isprint = 0) 


    print(  '1设定',set_y1_trans[k].round(4),\
            '预测',y1_pred0.round(4),\
            '高炉', y1_pred.round(4),\
            '高炉与设定误差',(set_y1_trans[k]-y1_pred).round(4),(set_y1_trans[k]-y1_pred).round(4)/d_temp,\
            '模型误差',(y1_pred0 - y1_pred).round(4),\
            '校正值',E1_k_0.round(4))
    print(  '2设定',set_y2_trans[k].round(4),\
            '预测',y2_pred0.round(4),\
            '高炉', y2_pred.round(4),\
            '高炉与设定误差',(set_y2_trans[k]-y2_pred).round(4),(set_y2_trans[k]-y2_pred).round(4)/d_yuansu,\
            '模型误差',(y2_pred0 - y2_pred).round(4),\
            '校正值',E2_k_0.round(4))



    all_pred_y1.append(y1_pred)
    all_pred_y2.append(y2_pred)
    all_pred_u1.append(U1[0])
    all_pred_u2.append(U2[0])
    all_pred_u3.append(U3[0])
    all_pred_u4.append(U4[0])
    k_data2[14] = y1_pred.item()
    k_data2[17] = y2_pred.item()
    k_data = k_data2
    # 进入下一时刻，更新预测时域、控制时域，即k_data
# Out:
# 579
# (18,)
# 这是对第0时刻的最优U1、U2输入求解
# (1, 1, 10)
# (1, 1, 2)
# 第 1/10 轮, 训练误差: 8.9536
# 第 2/10 轮, 训练误差: 6.8088
# 第 3/10 轮, 训练误差: 5.1205
# 第 4/10 轮, 训练误差: 3.7261
# 第 5/10 轮, 训练误差: 2.6079
# 第 6/10 轮, 训练误差: 1.7401
# 第 7/10 轮, 训练误差: 1.0912
# 第 8/10 轮, 训练误差: 0.6288
# 第 9/10 轮, 训练误差: 0.3240
# 第 10/10 轮, 训练误差: 0.1522
# 1设定 -0.2613 预测 [-0.0484] 高炉 [0.3131] 高炉与设定误差 [-0.5745] [-48.60381659] 模型误差 [-0.3615] 校正值 [-0.5267]
# 2设定 -0.6401 预测 [-0.4304] 高炉 [-0.3344] 高炉与设定误差 [-0.3057] [-0.28388831] 模型误差 [-0.096] 校正值 [0.0471]
# 这是对第1时刻的最优U1、U2输入求解
# (2, 1, 10)
# (2, 1, 2)
# 第 1/10 轮, 训练误差: 1.0871
# 第 2/10 轮, 训练误差: 0.6606
# 第 3/10 轮, 训练误差: 0.3800
# 第 4/10 轮, 训练误差: 0.2078
# 第 5/10 轮, 训练误差: 0.1061
# 第 6/10 轮, 训练误差: 0.0543
# 第 7/10 轮, 训练误差: 0.0384
# 第 8/10 轮, 训练误差: 0.0460
# 第 9/10 轮, 训练误差: 0.0670
# 第 10/10 轮, 训练误差: 0.0934
# 1设定 -0.2613 预测 [0.6785] 高炉 [0.4272] 高炉与设定误差 [-0.6885] [-58.2484346] 模型误差 [0.2513] 校正值 [-0.0145]
# 2设定 -0.6401 预测 [-0.3061] 高炉 [-0.3642] 高炉与设定误差 [-0.2759] [-0.25621454] 模型误差 [0.0582] 校正值 [-0.0216]
# 这是对第2时刻的最优U1、U2输入求解
# (3, 1, 10)
# (3, 1, 2)
# 第 1/10 轮, 训练误差: 1.2667
# 第 2/10 轮, 训练误差: 0.7390
# 第 3/10 轮, 训练误差: 0.3855
# 第 4/10 轮, 训练误差: 0.1888
# 第 5/10 轮, 训练误差: 0.1063
# 第 6/10 轮, 训练误差: 0.0959
# 第 7/10 轮, 训练误差: 0.1147
# 第 8/10 轮, 训练误差: 0.1327
# 第 9/10 轮, 训练误差: 0.1370
# 第 10/10 轮, 训练误差: 0.1292
# 1设定 -0.2613 预测 [-0.1049] 高炉 [0.2037] 高炉与设定误差 [-0.4651] [-39.34836148] 模型误差 [-0.3086] 校正值 [0.0037]
# 2设定 -0.6401 预测 [-0.6851] 高炉 [-0.4104] 高炉与设定误差 [-0.2298] [-0.21340377] 模型误差 [-0.2748] 校正值 [-0.0171]
# 这是对第3时刻的最优U1、U2输入求解
# (4, 1, 10)
# (4, 1, 2)
# 第 1/10 轮, 训练误差: 0.0992
# 第 2/10 轮, 训练误差: 0.0253
# 第 3/10 轮, 训练误差: 0.0124
# 第 4/10 轮, 训练误差: 0.0222
# 第 5/10 轮, 训练误差: 0.0274
# 第 6/10 轮, 训练误差: 0.0230
# 第 7/10 轮, 训练误差: 0.0139
# 第 8/10 轮, 训练误差: 0.0058
# 第 9/10 轮, 训练误差: 0.0022
# 第 10/10 轮, 训练误差: 0.0041
# 1设定 -0.2613 预测 [0.0007] 高炉 [0.0753] 高炉与设定误差 [-0.3366] [-28.47701348] 模型误差 [-0.0746] 校正值 [-0.0278]
# 2设定 -0.6401 预测 [-0.235] 高炉 [-0.2899] 高炉与设定误差 [-0.3502] [-0.32521323] 模型误差 [0.0549] 校正值 [-0.0133]
# 这是对第4时刻的最优U1、U2输入求解
# (5, 1, 10)
# (5, 1, 2)
# 第 1/10 轮, 训练误差: 0.1148
# 第 2/10 轮, 训练误差: 0.0797
# 第 3/10 轮, 训练误差: 0.0606
# 第 4/10 轮, 训练误差: 0.0413
# 第 5/10 轮, 训练误差: 0.0277
# 第 6/10 轮, 训练误差: 0.0214
# 第 7/10 轮, 训练误差: 0.0155
# 第 8/10 轮, 训练误差: 0.0093
# 第 9/10 轮, 训练误差: 0.0055
# 第 10/10 轮, 训练误差: 0.0048
# 1设定 -0.2613 预测 [0.0604] 高炉 [-0.0734] 高炉与设定误差 [-0.1879] [-15.8967051] 模型误差 [0.1338] 校正值 [-0.0008]
# 2设定 -0.6401 预测 [-0.3748] 高炉 [-0.532] 高炉与设定误差 [-0.1082] [-0.10047993] 模型误差 [0.1572] 校正值 [-0.0168]
# 这是对第5时刻的最优U1、U2输入求解
# (6, 1, 10)
# (6, 1, 2)
# 第 1/10 轮, 训练误差: 0.0040
# 第 2/10 轮, 训练误差: 0.0150
# 第 3/10 轮, 训练误差: 0.0051
# 第 4/10 轮, 训练误差: 0.0046
# 第 5/10 轮, 训练误差: 0.0058
# 第 6/10 轮, 训练误差: 0.0056
# 第 7/10 轮, 训练误差: 0.0033
# 第 8/10 轮, 训练误差: 0.0018
# 第 9/10 轮, 训练误差: 0.0024
# 第 10/10 轮, 训练误差: 0.0037
# 1设定 -0.2613 预测 [-0.2285] 高炉 [-0.2375] 高炉与设定误差 [-0.0239] [-2.0219864] 模型误差 [0.009] 校正值 [0.0025]
# 2设定 -0.6186 预测 [-0.6225] 高炉 [-0.6364] 高炉与设定误差 [0.0178] [0.01652997] 模型误差 [0.0138] 校正值 [0.0163]
# 这是对第6时刻的最优U1、U2输入求解
# (7, 1, 10)
# (7, 1, 2)
# 第 1/10 轮, 训练误差: 0.0201
# 第 2/10 轮, 训练误差: 0.0129
# 第 3/10 轮, 训练误差: 0.0118
# 第 4/10 轮, 训练误差: 0.0084
# 第 5/10 轮, 训练误差: 0.0052
# 第 6/10 轮, 训练误差: 0.0054
# 第 7/10 轮, 训练误差: 0.0070
# 第 8/10 轮, 训练误差: 0.0059
# 第 9/10 轮, 训练误差: 0.0033
# 第 10/10 轮, 训练误差: 0.0020
# 1设定 -0.2613 预测 [-0.2735] 高炉 [-0.1998] 高炉与设定误差 [-0.0616] [-5.21147948] 模型误差 [-0.0737] 校正值 [-0.0048]
# 2设定 -0.6186 预测 [-0.6389] 高炉 [-0.5486] 高炉与设定误差 [-0.0699] [-0.06491263] 模型误差 [-0.0903] 校正值 [-0.0275]
# 这是对第7时刻的最优U1、U2输入求解
# (8, 1, 10)
# (8, 1, 2)
# 第 1/10 轮, 训练误差: 0.0028
# 第 2/10 轮, 训练误差: 0.0134
# 第 3/10 轮, 训练误差: 0.0021
# 第 4/10 轮, 训练误差: 0.0036
# 第 5/10 轮, 训练误差: 0.0069
# 第 6/10 轮, 训练误差: 0.0045
# 第 7/10 轮, 训练误差: 0.0011
# 第 8/10 轮, 训练误差: 0.0010
# 第 9/10 轮, 训练误差: 0.0032
# 第 10/10 轮, 训练误差: 0.0035
# 1设定 -0.2613 预测 [-0.2166] 高炉 [-0.1887] 高炉与设定误差 [-0.0727] [-6.15056115] 模型误差 [-0.0279] 校正值 [-0.0106]
# 2设定 -0.6186 预测 [-0.6035] 高炉 [-0.5964] 高炉与设定误差 [-0.0222] [-0.02061603] 模型误差 [-0.0071] 校正值 [0.0204]
# 这是对第8时刻的最优U1、U2输入求解
# (9, 1, 10)
# (9, 1, 2)
# 第 1/10 轮, 训练误差: 0.0018
# 第 2/10 轮, 训练误差: 0.0084
# 第 3/10 轮, 训练误差: 0.0017
# 第 4/10 轮, 训练误差: 0.0016
# 第 5/10 轮, 训练误差: 0.0040
# 第 6/10 轮, 训练误差: 0.0027
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0008
# 第 9/10 轮, 训练误差: 0.0020
# 第 10/10 轮, 训练误差: 0.0020
# 1设定 -0.2613 预测 [-0.2362] 高炉 [-0.2481] 高炉与设定误差 [-0.0133] [-1.12520578] 模型误差 [0.0119] 校正值 [0.0107]
# 2设定 -0.6186 预测 [-0.629] 高炉 [-0.6131] 高炉与设定误差 [-0.0054] [-0.00501471] 模型误差 [-0.0159] 校正值 [-0.0095]
# 这是对第9时刻的最优U1、U2输入求解
# (10, 1, 10)
# (10, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0087
# 第 3/10 轮, 训练误差: 0.0023
# 第 4/10 轮, 训练误差: 0.0011
# 第 5/10 轮, 训练误差: 0.0042
# 第 6/10 轮, 训练误差: 0.0036
# 第 7/10 轮, 训练误差: 0.0010
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0015
# 第 10/10 轮, 训练误差: 0.0022
# 1设定 -0.2613 预测 [-0.266] 高炉 [-0.2513] 高炉与设定误差 [-0.01] [-0.84601938] 模型误差 [-0.0147] 校正值 [-0.0175]
# 2设定 -0.6186 预测 [-0.6145] 高炉 [-0.621] 高炉与设定误差 [0.0025] [0.00232162] 模型误差 [0.0066] 校正值 [0.0111]
# 这是对第10时刻的最优U1、U2输入求解
# (11, 1, 10)
# (11, 1, 2)
# 第 1/10 轮, 训练误差: 0.0016
# 第 2/10 轮, 训练误差: 0.0073
# 第 3/10 轮, 训练误差: 0.0038
# 第 4/10 轮, 训练误差: 0.0016
# 第 5/10 轮, 训练误差: 0.0020
# 第 6/10 轮, 训练误差: 0.0035
# 第 7/10 轮, 训练误差: 0.0025
# 第 8/10 轮, 训练误差: 0.0008
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0015
# 1设定 -0.2613 预测 [-0.2429] 高炉 [-0.2582] 高炉与设定误差 [-0.0032] [-0.2707262] 模型误差 [0.0153] 校正值 [0.01]
# 2设定 -0.6186 预测 [-0.6268] 高炉 [-0.6178] 高炉与设定误差 [-0.0008] [-0.00074292] 模型误差 [-0.009] 校正值 [-0.0157]
# 这是对第11时刻的最优U1、U2输入求解
# (12, 1, 10)
# (12, 1, 2)
# 第 1/10 轮, 训练误差: 0.0015
# 第 2/10 轮, 训练误差: 0.0066
# 第 3/10 轮, 训练误差: 0.0015
# 第 4/10 轮, 训练误差: 0.0009
# 第 5/10 轮, 训练误差: 0.0030
# 第 6/10 轮, 训练误差: 0.0024
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0013
# 第 10/10 轮, 训练误差: 0.0016
# 1设定 -0.2613 预测 [-0.2728] 高炉 [-0.2592] 高炉与设定误差 [-0.0021] [-0.17766407] 模型误差 [-0.0136] 校正值 [-0.0073]
# 2设定 -0.6186 预测 [-0.6025] 高炉 [-0.6167] 高炉与设定误差 [-0.0019] [-0.00176444] 模型误差 [0.0142] 校正值 [0.0101]
# 这是对第12时刻的最优U1、U2输入求解
# (13, 1, 10)
# (13, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0070
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0019
# 第 5/10 轮, 训练误差: 0.0034
# 第 6/10 轮, 训练误差: 0.0020
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0011
# 第 9/10 轮, 训练误差: 0.0017
# 第 10/10 轮, 训练误差: 0.0014
# 1设定 -0.2613 预测 [-0.2546] 高炉 [-0.2448] 高炉与设定误差 [-0.0165] [-1.395932] 模型误差 [-0.0098] 校正值 [0.007]
# 2设定 -0.6186 预测 [-0.6297] 高炉 [-0.6187] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [-0.011] 校正值 [-0.0072]
# 这是对第13时刻的最优U1、U2输入求解
# (14, 1, 10)
# (14, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0065
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0026
# 第 5/10 轮, 训练误差: 0.0033
# 第 6/10 轮, 训练误差: 0.0019
# 第 7/10 轮, 训练误差: 0.0010
# 第 8/10 轮, 训练误差: 0.0016
# 第 9/10 轮, 训练误差: 0.0020
# 第 10/10 轮, 训练误差: 0.0014
# 1设定 -0.2613 预测 [-0.271] 高炉 [-0.2325] 高炉与设定误差 [-0.0288] [-2.43653583] 模型误差 [-0.0385] 校正值 [0.0046]
# 2设定 -0.6186 预测 [-0.6167] 高炉 [-0.6197] 高炉与设定误差 [0.0011] [0.00102151] 模型误差 [0.003] 校正值 [0.0043]
# 这是对第14时刻的最优U1、U2输入求解
# (15, 1, 10)
# (15, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0076
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0023
# 第 5/10 轮, 训练误差: 0.0042
# 第 6/10 轮, 训练误差: 0.0024
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0010
# 第 9/10 轮, 训练误差: 0.0020
# 第 10/10 轮, 训练误差: 0.0020
# 1设定 -0.2613 预测 [-0.2666] 高炉 [-0.2549] 高炉与设定误差 [-0.0064] [-0.5414524] 模型误差 [-0.0117] 校正值 [0.0227]
# 2设定 -0.6186 预测 [-0.6263] 高炉 [-0.6196] 高炉与设定误差 [0.0011] [0.00102151] 模型误差 [-0.0067] 校正值 [-0.0095]
# 这是对第15时刻的最优U1、U2输入求解
# (16, 1, 10)
# (16, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0054
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0015
# 第 5/10 轮, 训练误差: 0.0027
# 第 6/10 轮, 训练误差: 0.0017
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0008
# 第 9/10 轮, 训练误差: 0.0015
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2022 预测 [-0.2667] 高炉 [-0.2544] 高炉与设定误差 [0.0521] [4.40776099] 模型误差 [-0.0124] 校正值 [0.0018]
# 2设定 -0.6186 预测 [-0.5842] 高炉 [-0.5888] 高炉与设定误差 [-0.0298] [-0.02767377] 模型误差 [0.0045] 校正值 [0.0111]
# 这是对第16时刻的最优U1、U2输入求解
# (17, 1, 10)
# (17, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0057
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0015
# 第 5/10 轮, 训练误差: 0.0029
# 第 6/10 轮, 训练误差: 0.0018
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0008
# 第 9/10 轮, 训练误差: 0.0015
# 第 10/10 轮, 训练误差: 0.0014
# 1设定 -0.2022 预测 [-0.2099] 高炉 [-0.2386] 高炉与设定误差 [0.0364] [3.07951074] 模型误差 [0.0287] 校正值 [0.0137]
# 2设定 -0.6186 预测 [-0.6281] 高炉 [-0.6265] 高炉与设定误差 [0.008] [0.0074292] 模型误差 [-0.0015] 校正值 [-0.0031]
# 这是对第17时刻的最优U1、U2输入求解
# (18, 1, 10)
# (18, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0049
# 第 3/10 轮, 训练误差: 0.0010
# 第 4/10 轮, 训练误差: 0.0014
# 第 5/10 轮, 训练误差: 0.0024
# 第 6/10 轮, 训练误差: 0.0016
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0007
# 第 9/10 轮, 训练误差: 0.0013
# 第 10/10 轮, 训练误差: 0.0012
# 1设定 -0.2022 预测 [-0.2305] 高炉 [-0.2179] 高炉与设定误差 [0.0156] [1.31979023] 模型误差 [-0.0127] 校正值 [-0.0202]
# 2设定 -0.6186 预测 [-0.6046] 高炉 [-0.6023] 高炉与设定误差 [-0.0163] [-0.015137] 模型误差 [-0.0024] 校正值 [0.0066]
# 这是对第18时刻的最优U1、U2输入求解
# (19, 1, 10)
# (19, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0042
# 第 3/10 轮, 训练误差: 0.0018
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0024
# 第 6/10 轮, 训练误差: 0.0018
# 第 7/10 轮, 训练误差: 0.0007
# 第 8/10 轮, 训练误差: 0.0007
# 第 9/10 轮, 训练误差: 0.0011
# 第 10/10 轮, 训练误差: 0.0012
# 1设定 -0.2022 预测 [-0.1857] 高炉 [-0.2135] 高炉与设定误差 [0.0112] [0.94754169] 模型误差 [0.0278] 校正值 [0.0214]
# 2设定 -0.6186 预测 [-0.6357] 高炉 [-0.6566] 高炉与设定误差 [0.038] [0.0352887] 模型误差 [0.0209] 校正值 [0.0072]
# 这是对第19时刻的最优U1、U2输入求解
# (20, 1, 10)
# (20, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0051
# 第 3/10 轮, 训练误差: 0.0022
# 第 4/10 轮, 训练误差: 0.0011
# 第 5/10 轮, 训练误差: 0.0018
# 第 6/10 轮, 训练误差: 0.0026
# 第 7/10 轮, 训练误差: 0.0017
# 第 8/10 轮, 训练误差: 0.0006
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2022 预测 [-0.2119] 高炉 [-0.193] 高炉与设定误差 [-0.0093] [-0.78679804] 模型误差 [-0.0189] 校正值 [-0.0242]
# 2设定 -0.6186 预测 [-0.5934] 高炉 [-0.5865] 高炉与设定误差 [-0.0321] [-0.02980966] 模型误差 [-0.007] 校正值 [-0.003]
# 这是对第20时刻的最优U1、U2输入求解
# (21, 1, 10)
# (21, 1, 2)
# 第 1/10 轮, 训练误差: 0.0014
# 第 2/10 轮, 训练误差: 0.0036
# 第 3/10 轮, 训练误差: 0.0020
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0020
# 第 7/10 轮, 训练误差: 0.0012
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0011
# 1设定 -0.2022 预测 [-0.1871] 高炉 [-0.2041] 高炉与设定误差 [0.0019] [0.16074369] 模型误差 [0.017] 校正值 [0.0139]
# 2设定 -0.6186 预测 [-0.6397] 高炉 [-0.6437] 高炉与设定误差 [0.0251] [0.02330912] 模型误差 [0.004] 校正值 [-0.0027]
# 这是对第21时刻的最优U1、U2输入求解
# (22, 1, 10)
# (22, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0034
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0016
# 第 6/10 轮, 训练误差: 0.0016
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0010
# 1设定 -0.2022 预测 [-0.2143] 高炉 [-0.2067] 高炉与设定误差 [0.0044] [0.37224853] 模型误差 [-0.0076] 校正值 [-0.0109]
# 2设定 -0.6186 预测 [-0.5962] 高炉 [-0.6027] 高炉与设定误差 [-0.0159] [-0.01476554] 模型误差 [0.0064] 校正值 [-0.0045]
# 这是对第22时刻的最优U1、U2输入求解
# (23, 1, 10)
# (23, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0042
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0020
# 第 6/10 轮, 训练误差: 0.0017
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0009
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2022 预测 [-0.197] 高炉 [-0.209] 高炉与设定误差 [0.0068] [0.5752932] 模型误差 [0.012] 校正值 [0.0069]
# 2设定 -0.6186 预测 [-0.6315] 高炉 [-0.6289] 高炉与设定误差 [0.0103] [0.0095651] 模型误差 [-0.0026] 校正值 [-0.0076]
# 这是对第23时刻的最优U1、U2输入求解
# (24, 1, 10)
# (24, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0038
# 第 3/10 轮, 训练误差: 0.0015
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0015
# 第 6/10 轮, 训练误差: 0.0019
# 第 7/10 轮, 训练误差: 0.0010
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0011
# 1设定 -0.2022 预测 [-0.2078] 高炉 [-0.2008] 高炉与设定误差 [-0.0015] [-0.12690291] 模型误差 [-0.0071] 校正值 [-0.0194]
# 2设定 -0.6186 预测 [-0.5978] 高炉 [-0.6098] 高炉与设定误差 [-0.0088] [-0.00817212] 模型误差 [0.012] 校正值 [0.0015]
# 这是对第24时刻的最优U1、U2输入求解
# (25, 1, 10)
# (25, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0023
# 第 3/10 轮, 训练误差: 0.0018
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0012
# 第 6/10 轮, 训练误差: 0.0014
# 第 7/10 轮, 训练误差: 0.0006
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2022 预测 [-0.185] 高炉 [-0.2047] 高炉与设定误差 [0.0024] [0.20304467] 模型误差 [0.0196] 校正值 [0.0127]
# 2设定 -0.6186 预测 [-0.6297] 高炉 [-0.624] 高炉与设定误差 [0.0055] [0.00510757] 模型误差 [-0.0056] 校正值 [-0.0056]
# 这是对第25时刻的最优U1、U2输入求解
# (26, 1, 10)
# (26, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0039
# 第 3/10 轮, 训练误差: 0.0025
# 第 4/10 轮, 训练误差: 0.0012
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0019
# 第 7/10 轮, 训练误差: 0.0020
# 第 8/10 轮, 训练误差: 0.0010
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.2022 预测 [-0.2109] 高炉 [-0.1873] 高炉与设定误差 [-0.015] [-1.26902907] 模型误差 [-0.0237] 校正值 [-0.0088]
# 2设定 -0.597 预测 [-0.5895] 高炉 [-0.5829] 高炉与设定误差 [-0.0141] [-0.01309397] 模型误差 [-0.0066] 校正值 [0.014]
# 这是对第26时刻的最优U1、U2输入求解
# (27, 1, 10)
# (27, 1, 2)
# 第 1/10 轮, 训练误差: 0.0011
# 第 2/10 轮, 训练误差: 0.0026
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0011
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2022 预测 [-0.1955] 高炉 [-0.2019] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0063] 校正值 [0.0112]
# 2设定 -0.597 预测 [-0.6297] 高炉 [-0.6145] 高炉与设定误差 [0.0175] [0.01625138] 模型误差 [-0.0151] 校正值 [0.0026]
# 这是对第27时刻的最优U1、U2输入求解
# (28, 1, 10)
# (28, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0042
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0010
# 第 5/10 轮, 训练误差: 0.0023
# 第 6/10 轮, 训练误差: 0.0015
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0010
# 第 10/10 轮, 训练误差: 0.0013
# 1设定 -0.2022 预测 [-0.2086] 高炉 [-0.1984] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [-0.0102] 校正值 [-0.0074]
# 2设定 -0.597 预测 [-0.5835] 高炉 [-0.5829] 高炉与设定误差 [-0.0141] [-0.01309397] 模型误差 [-0.0006] 校正值 [0.0113]
# 这是对第28时刻的最优U1、U2输入求解
# (29, 1, 10)
# (29, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0028
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0014
# 第 6/10 轮, 训练误差: 0.0010
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0008
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.2022 预测 [-0.1978] 高炉 [-0.2041] 高炉与设定误差 [0.0019] [0.16074369] 模型误差 [0.0063] 校正值 [0.0099]
# 2设定 -0.597 预测 [-0.6226] 高炉 [-0.6081] 高炉与设定误差 [0.011] [0.01021515] 模型误差 [-0.0145] 校正值 [-0.0007]
# 这是对第29时刻的最优U1、U2输入求解
# (30, 1, 10)
# (30, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0038
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0020
# 第 6/10 轮, 训练误差: 0.0014
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0009
# 第 10/10 轮, 训练误差: 0.0011
# 1设定 -0.2022 预测 [-0.209] 高炉 [-0.2016] 高炉与设定误差 [-0.0006] [-0.05076117] 模型误差 [-0.0074] 校正值 [-0.0047]
# 2设定 -0.597 预测 [-0.5853] 高炉 [-0.5889] 高炉与设定误差 [-0.0082] [-0.00761493] 模型误差 [0.0035] 校正值 [0.0138]
# 这是对第30时刻的最优U1、U2输入求解
# (31, 1, 10)
# (31, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0026
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.2022 预测 [-0.1993] 高炉 [-0.2032] 高炉与设定误差 [0.001] [0.08460194] 模型误差 [0.0039] 校正值 [0.0069]
# 2设定 -0.597 预测 [-0.6192] 高炉 [-0.6034] 高炉与设定误差 [0.0064] [0.00594336] 模型误差 [-0.0158] 校正值 [-0.003]
# 这是对第31时刻的最优U1、U2输入求解
# (32, 1, 10)
# (32, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0036
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0020
# 第 6/10 轮, 训练误差: 0.0013
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0008
# 第 10/10 轮, 训练误差: 0.0011
# 1设定 -0.2022 预测 [-0.2071] 高炉 [-0.2022] 高炉与设定误差 [-0.] [-0.] 模型误差 [-0.0048] 校正值 [-0.0047]
# 2设定 -0.597 预测 [-0.5879] 高炉 [-0.5937] 高炉与设定误差 [-0.0033] [-0.00306454] 模型误差 [0.0058] 校正值 [0.0155]
# 这是对第32时刻的最优U1、U2输入求解
# (33, 1, 10)
# (33, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0023
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0012
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.1983] 高炉 [-0.2023] 高炉与设定误差 [0.] [0.] 模型误差 [0.004] 校正值 [0.0037]
# 2设定 -0.597 预测 [-0.6163] 高炉 [-0.5993] 高炉与设定误差 [0.0023] [0.0021359] 模型误差 [-0.017] 校正值 [-0.0068]
# 这是对第33时刻的最优U1、U2输入求解
# (34, 1, 10)
# (34, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0033
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0018
# 第 6/10 轮, 训练误差: 0.0012
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0008
# 第 10/10 轮, 训练误差: 0.0010
# 1设定 -0.2022 预测 [-0.2052] 高炉 [-0.2025] 高炉与设定误差 [0.0002] [0.01692039] 模型误差 [-0.0027] 校正值 [-0.0033]
# 2设定 -0.597 预测 [-0.588] 高炉 [-0.5963] 高炉与设定误差 [-0.0007] [-0.00065005] 模型误差 [0.0083] 校正值 [0.0167]
# 这是对第34时刻的最优U1、U2输入求解
# (35, 1, 10)
# (35, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0022
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.2022 预测 [-0.199] 高炉 [-0.202] 高炉与设定误差 [-0.0002] [-0.01692039] 模型误差 [0.003] 校正值 [0.0027]
# 2设定 -0.597 预测 [-0.6144] 高炉 [-0.5968] 高炉与设定误差 [-0.0002] [-0.00018573] 模型误差 [-0.0176] 校正值 [-0.0087]
# 这是对第35时刻的最优U1、U2输入求解
# (36, 1, 10)
# (36, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0030
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0007
# 第 5/10 轮, 训练误差: 0.0016
# 第 6/10 轮, 训练误差: 0.0011
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0009
# 1设定 -0.1431 预测 [-0.1935] 高炉 [-0.1777] 高炉与设定误差 [0.0345] [2.91876686] 模型误差 [-0.0158] 校正值 [-0.0034]
# 2设定 -0.597 预测 [-0.5713] 高炉 [-0.5783] 高炉与设定误差 [-0.0187] [-0.01736575] 模型误差 [0.007] 校正值 [0.0171]
# 这是对第36时刻的最优U1、U2输入求解
# (37, 1, 10)
# (37, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0021
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.1431 预测 [-0.1403] 高炉 [-0.1493] 高炉与设定误差 [0.0061] [0.51607182] 模型误差 [0.0089] 校正值 [0.0145]
# 2设定 -0.597 预测 [-0.6201] 高炉 [-0.624] 高炉与设定误差 [0.0269] [0.02498069] 模型误差 [0.0039] 校正值 [-0.0068]
# 这是对第37时刻的最优U1、U2输入求解
# (38, 1, 10)
# (38, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0028
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0015
# 第 6/10 轮, 训练误差: 0.0010
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0007
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.1431 预测 [-0.1507] 高炉 [-0.1507] 高炉与设定误差 [0.0076] [0.64297475] 模型误差 [0.] 校正值 [-0.0071]
# 2设定 -0.597 预测 [-0.573] 高炉 [-0.5924] 高炉与设定误差 [-0.0047] [-0.00436465] 模型误差 [0.0193] 校正值 [-0.001]
# 这是对第38时刻的最优U1、U2输入求解
# (39, 1, 10)
# (39, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1385] 高炉 [-0.1433] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [0.0048] 校正值 [0.0006]
# 2设定 -0.597 预测 [-0.6024] 高炉 [-0.5993] 高炉与设定误差 [0.0023] [0.0021359] 模型误差 [-0.003] 校正值 [-0.0176]
# 这是对第39时刻的最优U1、U2输入求解
# (40, 1, 10)
# (40, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0026
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0014
# 第 6/10 轮, 训练误差: 0.0010
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0008
# 1设定 -0.1431 预测 [-0.1454] 高炉 [-0.1458] 高炉与设定误差 [0.0027] [0.22842524] 模型误差 [0.0004] 校正值 [-0.0033]
# 2设定 -0.597 预测 [-0.5796] 高炉 [-0.6003] 高炉与设定误差 [0.0033] [0.00306454] 模型误差 [0.0207] 校正值 [0.0056]
# 这是对第40时刻的最优U1、U2输入求解
# (41, 1, 10)
# (41, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0019
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1385] 高炉 [-0.1436] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [0.0051] 校正值 [0.001]
# 2设定 -0.597 预测 [-0.6001] 高炉 [-0.5942] 高炉与设定误差 [-0.0029] [-0.00269308] 模型误差 [-0.0059] 校正值 [-0.0178]
# 这是对第41时刻的最优U1、U2输入求解
# (42, 1, 10)
# (42, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0025
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0014
# 第 6/10 轮, 训练误差: 0.0009
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.1431 预测 [-0.1451] 高炉 [-0.1442] 高炉与设定误差 [0.001] [0.08460194] 模型误差 [-0.001] 校正值 [-0.0043]
# 2设定 -0.597 预测 [-0.5801] 高炉 [-0.5981] 高炉与设定误差 [0.001] [0.00092865] 模型误差 [0.018] 校正值 [0.0079]
# 这是对第42时刻的最优U1、U2输入求解
# (43, 1, 10)
# (43, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0017
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1381] 高炉 [-0.1437] 高炉与设定误差 [0.0005] [0.04230097] 模型误差 [0.0056] 校正值 [0.0025]
# 2设定 -0.597 预测 [-0.6023] 高炉 [-0.5972] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [-0.0051] 校正值 [-0.0162]
# 这是对第43时刻的最优U1、U2输入求解
# (44, 1, 10)
# (44, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0023
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0012
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0006
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.1431 预测 [-0.1462] 高炉 [-0.1427] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [-0.0035] 校正值 [-0.0041]
# 2设定 -0.597 预测 [-0.5805] 高炉 [-0.5966] 高炉与设定误差 [-0.0005] [-0.00046433] 模型误差 [0.0161] 校正值 [0.0066]
# 这是对第44时刻的最优U1、U2输入求解
# (45, 1, 10)
# (45, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.1431 预测 [-0.1387] 高炉 [-0.1424] 高炉与设定误差 [-0.0008] [-0.06768155] 模型误差 [0.0036] 校正值 [0.0048]
# 2设定 -0.597 预测 [-0.6046] 高炉 [-0.5975] 高炉与设定误差 [0.0005] [0.00046433] 模型误差 [-0.007] 校正值 [-0.0132]
# 这是对第45时刻的最优U1、U2输入求解
# (46, 1, 10)
# (46, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0022
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0012
# 第 6/10 轮, 训练误差: 0.0008
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0007
# 1设定 -0.1431 预测 [-0.14] 高炉 [-0.1401] 高炉与设定误差 [-0.0031] [-0.26226602] 模型误差 [1.e-04] 校正值 [-0.0022]
# 2设定 -0.5755 预测 [-0.5687] 高炉 [-0.5818] 高炉与设定误差 [0.0063] [0.0058505] 模型误差 [0.0131] 校正值 [0.0094]
# 这是对第46时刻的最优U1、U2输入求解
# (47, 1, 10)
# (47, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0015
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.1431 预测 [-0.1407] 高炉 [-0.1424] 高炉与设定误差 [-0.0008] [-0.06768155] 模型误差 [0.0017] 校正值 [-0.0011]
# 2设定 -0.5755 预测 [-0.5849] 高炉 [-0.5743] 高炉与设定误差 [-0.0012] [-0.00111438] 模型误差 [-0.0106] 校正值 [-0.0127]
# 这是对第47时刻的最优U1、U2输入求解
# (48, 1, 10)
# (48, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0020
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.1431 预测 [-0.146] 高炉 [-0.1392] 高炉与设定误差 [-0.0039] [-0.32994756] 模型误差 [-0.0068] 校正值 [-0.0005]
# 2设定 -0.5755 预测 [-0.5668] 高炉 [-0.5752] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [0.0084] 校正值 [0.0118]
# 这是对第48时刻的最优U1、U2输入求解
# (49, 1, 10)
# (49, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.1431 预测 [-0.1427] 高炉 [-0.1439] 高炉与设定误差 [0.0008] [0.06768155] 模型误差 [0.0013] 校正值 [0.0066]
# 2设定 -0.5755 预测 [-0.5895] 高炉 [-0.5771] 高炉与设定误差 [0.0016] [0.00148584] 模型误差 [-0.0124] 校正值 [-0.0075]
# 这是对第49时刻的最优U1、U2输入求解
# (50, 1, 10)
# (50, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0019
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0011
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0006
# 1设定 -0.1431 预测 [-0.1491] 高炉 [-0.1443] 高炉与设定误差 [0.0012] [0.10152233] 模型误差 [-0.0048] 校正值 [-0.0015]
# 2设定 -0.5755 预测 [-0.5663] 高炉 [-0.5753] 高炉与设定误差 [-0.0002] [-0.00018573] 模型误差 [0.009] 校正值 [0.013]
# 这是对第50时刻的最优U1、U2输入求解
# (51, 1, 10)
# (51, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0013
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1409] 高炉 [-0.1427] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0018] 校正值 [0.0045]
# 2设定 -0.5755 预测 [-0.5886] 高炉 [-0.5758] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [-0.0128] 校正值 [-0.009]
# 这是对第51时刻的最优U1、U2输入求解
# (52, 1, 10)
# (52, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0018
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.148] 高炉 [-0.1433] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [-0.0047] 校正值 [-0.0022]
# 2设定 -0.5755 预测 [-0.5662] 高炉 [-0.5755] 高炉与设定误差 [0.] [0.] 模型误差 [0.0093] 校正值 [0.0129]
# 这是对第52时刻的最优U1、U2输入求解
# (53, 1, 10)
# (53, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0012
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1403] 高炉 [-0.1426] 高炉与设定误差 [-0.0006] [-0.05076117] 模型误差 [0.0023] 校正值 [0.0058]
# 2设定 -0.5755 预测 [-0.5887] 高炉 [-0.5761] 高炉与设定误差 [0.0006] [0.00055719] 模型误差 [-0.0126] 校正值 [-0.0085]
# 这是对第53时刻的最优U1、U2输入求解
# (54, 1, 10)
# (54, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0018
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.1431 预测 [-0.1492] 高炉 [-0.1435] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [-0.0056] 校正值 [-0.001]
# 2设定 -0.5755 预测 [-0.5666] 高炉 [-0.5756] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [0.009] 校正值 [0.0134]
# 这是对第54时刻的最优U1、U2输入求解
# (55, 1, 10)
# (55, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.1431 预测 [-0.1414] 高炉 [-0.1426] 高炉与设定误差 [-0.0005] [-0.04230097] 模型误差 [0.0012] 校正值 [0.0047]
# 2设定 -0.5755 预测 [-0.589] 高炉 [-0.5762] 高炉与设定误差 [0.0007] [0.00065005] 模型误差 [-0.0128] 校正值 [-0.0096]
# 这是对第55时刻的最优U1、U2输入求解
# (56, 1, 10)
# (56, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.084 预测 [-0.1139] 高炉 [-0.0909] 高炉与设定误差 [0.0069] [0.58375338] 模型误差 [-0.023] 校正值 [-0.0022]
# 2设定 -0.5755 预测 [-0.5424] 高炉 [-0.5321] 高炉与设定误差 [-0.0434] [-0.04030341] 模型误差 [-0.0102] 校正值 [0.0112]
# 这是对第56时刻的最优U1、U2输入求解
# (57, 1, 10)
# (57, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0891] 高炉 [-0.0921] 高炉与设定误差 [0.008] [0.67681555] 模型误差 [0.003] 校正值 [0.0124]
# 2设定 -0.5755 预测 [-0.5935] 高炉 [-0.5935] 高炉与设定误差 [0.018] [0.0167157] 模型误差 [-0.] 校正值 [0.0054]
# 这是对第57时刻的最优U1、U2输入求解
# (58, 1, 10)
# (58, 1, 2)
# 第 1/10 轮, 训练误差: 0.0002
# 第 2/10 轮, 训练误差: 0.0016
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.084 预测 [-0.0858] 高炉 [-0.0901] 高炉与设定误差 [0.006] [0.50761164] 模型误差 [0.0043] 校正值 [-0.0039]
# 2设定 -0.5755 预测 [-0.5589] 高炉 [-0.5927] 高炉与设定误差 [0.0172] [0.01597278] 模型误差 [0.0339] 校正值 [0.0019]
# 这是对第58时刻的最优U1、U2输入求解
# (59, 1, 10)
# (59, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.074] 高炉 [-0.0759] 高炉与设定误差 [-0.0081] [-0.68527573] 模型误差 [0.002] 校正值 [-0.0027]
# 2设定 -0.5755 预测 [-0.5657] 高炉 [-0.5727] 高炉与设定误差 [-0.0028] [-0.00260022] 模型误差 [0.007] 校正值 [-0.0313]
# 这是对第59时刻的最优U1、U2输入求解
# (60, 1, 10)
# (60, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0015
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0005
# 1设定 -0.084 预测 [-0.0854] 高炉 [-0.0741] 高炉与设定误差 [-0.01] [-0.84601938] 模型误差 [-0.0113] 校正值 [-0.0016]
# 2设定 -0.5755 预测 [-0.5513] 高炉 [-0.5744] 高炉与设定误差 [-0.0011] [-0.00102151] 模型误差 [0.0231] 校正值 [-0.0051]
# 这是对第60时刻的最优U1、U2输入求解
# (61, 1, 10)
# (61, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0835] 高炉 [-0.0831] 高炉与设定误差 [-0.0009] [-0.07614174] 模型误差 [-0.0004] 校正值 [0.0111]
# 2设定 -0.5755 预测 [-0.5751] 高炉 [-0.5817] 高炉与设定误差 [0.0062] [0.00575763] 模型误差 [0.0066] 校正值 [-0.0213]
# 这是对第61时刻的最优U1、U2输入求解
# (62, 1, 10)
# (62, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.084 预测 [-0.0924] 高炉 [-0.0845] 高炉与设定误差 [0.0005] [0.04230097] 模型误差 [-0.0079] 校正值 [0.0003]
# 2设定 -0.5755 预测 [-0.5504] 高炉 [-0.5756] 高炉与设定误差 [1.e-04] [9.28649977e-05] 模型误差 [0.0252] 校正值 [-0.0047]
# 这是对第62时刻的最优U1、U2输入求解
# (63, 1, 10)
# (63, 1, 2)
# 第 1/10 轮, 训练误差: 0.0003
# 第 2/10 轮, 训练误差: 0.0010
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0836] 高炉 [-0.0806] 高炉与设定误差 [-0.0034] [-0.2876466] 模型误差 [-0.0029] 校正值 [0.0077]
# 2设定 -0.5755 预测 [-0.5717] 高炉 [-0.5754] 高炉与设定误差 [-1.e-04] [-9.28649977e-05] 模型误差 [0.0037] 校正值 [-0.0233]
# 这是对第63时刻的最优U1、U2输入求解
# (64, 1, 10)
# (64, 1, 2)
# 第 1/10 轮, 训练误差: 0.0001
# 第 2/10 轮, 训练误差: 0.0014
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0004
# 第 10/10 轮, 训练误差: 0.0004
# 1设定 -0.084 预测 [-0.0924] 高炉 [-0.0826] 高炉与设定误差 [-0.0015] [-0.12690291] 模型误差 [-0.0098] 校正值 [0.0027]
# 2设定 -0.5755 预测 [-0.5538] 高炉 [-0.577] 高炉与设定误差 [0.0015] [0.00139298] 模型误差 [0.0232] 校正值 [-0.0017]
# 这是对第64时刻的最优U1、U2输入求解
# (65, 1, 10)
# (65, 1, 2)
# 第 1/10 轮, 训练误差: 0.0022
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0008
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0852] 高炉 [-0.0824] 高炉与设定误差 [-0.0017] [-0.1438233] 模型误差 [-0.0028] 校正值 [0.0046]
# 2设定 -0.5755 预测 [-0.574] 高炉 [-0.5769] 高炉与设定误差 [0.0014] [0.00130011] 模型误差 [0.0028] 校正值 [-0.0099]
# 这是对第65时刻的最优U1、U2输入求解
# (66, 1, 10)
# (66, 1, 2)
# 第 1/10 轮, 训练误差: 0.0025
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0031
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0013
# 第 6/10 轮, 训练误差: 0.0011
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0009
# 第 9/10 轮, 训练误差: 0.0005
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.084 预测 [-0.0806] 高炉 [-0.077] 高炉与设定误差 [-0.0071] [-0.60067378] 模型误差 [-0.0036] 校正值 [0.0134]
# 2设定 -0.554 预测 [-0.551] 高炉 [-0.5582] 高炉与设定误差 [0.0043] [0.0039932] 模型误差 [0.0073] 校正值 [0.0032]
# 这是对第66时刻的最优U1、U2输入求解
# (67, 1, 10)
# (67, 1, 2)
# 第 1/10 轮, 训练误差: 0.0017
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0976] 高炉 [-0.0782] 高炉与设定误差 [-0.0058] [-0.49069125] 模型误差 [-0.0194] 校正值 [-0.0068]
# 2设定 -0.554 预测 [-0.5591] 高炉 [-0.5531] 高炉与设定误差 [-0.0009] [-0.00083578] 模型误差 [-0.0061] 校正值 [-0.0085]
# 这是对第67时刻的最优U1、U2输入求解
# (68, 1, 10)
# (68, 1, 2)
# 第 1/10 轮, 训练误差: 0.0022
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0021
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0010
# 第 6/10 轮, 训练误差: 0.0007
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0007
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0773] 高炉 [-0.0764] 高炉与设定误差 [-0.0077] [-0.65143493] 模型误差 [-0.001] 校正值 [0.0156]
# 2设定 -0.554 预测 [-0.5493] 高炉 [-0.5547] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [0.0055] 校正值 [0.0052]
# 这是对第68时刻的最优U1、U2输入求解
# (69, 1, 10)
# (69, 1, 2)
# 第 1/10 轮, 训练误差: 0.0015
# 第 2/10 轮, 训练误差: 0.0010
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.1013] 高炉 [-0.086] 高炉与设定误差 [0.002] [0.16920389] 模型误差 [-0.0152] 校正值 [-0.0003]
# 2设定 -0.554 预测 [-0.5614] 高炉 [-0.556] 高炉与设定误差 [0.0021] [0.00195016] 模型误差 [-0.0054] 校正值 [-0.0068]
# 这是对第69时刻的最优U1、U2输入求解
# (70, 1, 10)
# (70, 1, 2)
# 第 1/10 轮, 训练误差: 0.0019
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0018
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.081] 高炉 [-0.0843] 高炉与设定误差 [0.0002] [0.01692039] 模型误差 [0.0033] 校正值 [0.0095]
# 2设定 -0.554 预测 [-0.5452] 高炉 [-0.554] 高炉与设定误差 [0.] [0.] 模型误差 [0.0087] 校正值 [0.0068]
# 这是对第70时刻的最优U1、U2输入求解
# (71, 1, 10)
# (71, 1, 2)
# 第 1/10 轮, 训练误差: 0.0016
# 第 2/10 轮, 训练误差: 0.0011
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0933] 高炉 [-0.0848] 高炉与设定误差 [0.0007] [0.05922136] 模型误差 [-0.0086] 校正值 [-0.0037]
# 2设定 -0.554 预测 [-0.5612] 高炉 [-0.5547] 高炉与设定误差 [0.0007] [0.00065005] 模型误差 [-0.0065] 校正值 [-0.0069]
# 这是对第71时刻的最优U1、U2输入求解
# (72, 1, 10)
# (72, 1, 2)
# 第 1/10 轮, 训练误差: 0.0019
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0019
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0006
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0006
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0794] 高炉 [-0.0815] 高炉与设定误差 [-0.0025] [-0.21150485] 模型误差 [0.0021] 校正值 [0.0133]
# 2设定 -0.554 预测 [-0.5467] 高炉 [-0.5529] 高炉与设定误差 [-0.0011] [-0.00102151] 模型误差 [0.0062] 校正值 [0.0054]
# 这是对第72时刻的最优U1、U2输入求解
# (73, 1, 10)
# (73, 1, 2)
# 第 1/10 轮, 训练误差: 0.0014
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0015
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0983] 高炉 [-0.085] 高炉与设定误差 [0.0009] [0.07614174] 模型误差 [-0.0134] 校正值 [-0.0048]
# 2设定 -0.554 预测 [-0.561] 高炉 [-0.5559] 高炉与设定误差 [0.0019] [0.00176444] 模型误差 [-0.0052] 校正值 [-0.0045]
# 这是对第73时刻的最优U1、U2输入求解
# (74, 1, 10)
# (74, 1, 2)
# 第 1/10 轮, 训练误差: 0.0017
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0017
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.084 预测 [-0.0771] 高炉 [-0.0836] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0065] 校正值 [0.0124]
# 2设定 -0.554 预测 [-0.5481] 高炉 [-0.5542] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [0.0061] 校正值 [0.0049]
# 这是对第74时刻的最优U1、U2输入求解
# (75, 1, 10)
# (75, 1, 2)
# 第 1/10 轮, 训练误差: 0.0013
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0015
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.084 预测 [-0.0969] 高炉 [-0.0846] 高炉与设定误差 [0.0005] [0.04230097] 模型误差 [-0.0123] 校正值 [-0.0081]
# 2设定 -0.554 预测 [-0.5589] 高炉 [-0.5543] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [-0.0046] 校正值 [-0.0051]
# 这是对第75时刻的最优U1、U2输入求解
# (76, 1, 10)
# (76, 1, 2)
# 第 1/10 轮, 训练误差: 0.0018
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0017
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0474] 高炉 [-0.0335] 高炉与设定误差 [0.0086] [0.72757671] 模型误差 [-0.0139] 校正值 [0.0109]
# 2设定 -0.554 预测 [-0.5296] 高炉 [-0.5165] 高炉与设定误差 [-0.0375] [-0.03482438] 模型误差 [-0.0131] 校正值 [0.0033]
# 这是对第76时刻的最优U1、U2输入求解
# (77, 1, 10)
# (77, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0010
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0009
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0004
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.0249 预测 [-0.0397] 高炉 [-0.0133] 高炉与设定误差 [-0.0116] [-0.98138249] 模型误差 [-0.0264] 校正值 [0.0032]
# 2设定 -0.554 预测 [-0.5653] 高炉 [-0.542] 高炉与设定误差 [-0.012] [-0.0111438] 模型误差 [-0.0233] 校正值 [0.0094]
# 这是对第77时刻的最优U1、U2输入求解
# (78, 1, 10)
# (78, 1, 2)
# 第 1/10 轮, 训练误差: 0.0018
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0003
# 1设定 -0.0249 预测 [-0.0277] 高炉 [-0.0359] 高炉与设定误差 [0.0109] [0.92216116] 模型误差 [0.0082] 校正值 [0.0195]
# 2设定 -0.554 预测 [-0.5668] 高炉 [-0.5603] 高炉与设定误差 [0.0064] [0.00594336] 模型误差 [-0.0064] 校正值 [0.0206]
# 这是对第78时刻的最优U1、U2输入求解
# (79, 1, 10)
# (79, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0389] 高炉 [-0.0327] 高炉与设定误差 [0.0077] [0.65143493] 模型误差 [-0.0062] 校正值 [-0.0008]
# 2设定 -0.554 预测 [-0.5648] 高炉 [-0.5566] 高炉与设定误差 [0.0027] [0.00250736] 模型误差 [-0.0081] 校正值 [-0.0054]
# 这是对第79时刻的最优U1、U2输入求解
# (80, 1, 10)
# (80, 1, 2)
# 第 1/10 轮, 训练误差: 0.0018
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0016
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0005
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0213] 高炉 [-0.0183] 高炉与设定误差 [-0.0066] [-0.5583728] 模型误差 [-0.0029] 校正值 [0.0059]
# 2设定 -0.554 预测 [-0.5465] 高炉 [-0.5467] 高炉与设定误差 [-0.0073] [-0.00677915] 模型误差 [1.e-04] 校正值 [0.0068]
# 这是对第80时刻的最优U1、U2输入求解
# (81, 1, 10)
# (81, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0351] 高炉 [-0.0207] 高炉与设定误差 [-0.0042] [-0.35532814] 模型误差 [-0.0144] 校正值 [0.]
# 2设定 -0.554 预测 [-0.5684] 高炉 [-0.5542] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [-0.0141] 校正值 [-0.0017]
# 这是对第81时刻的最优U1、U2输入求解
# (82, 1, 10)
# (82, 1, 2)
# 第 1/10 轮, 训练误差: 0.0016
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0246] 高炉 [-0.0251] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [0.0005] 校正值 [0.0105]
# 2设定 -0.554 预测 [-0.5528] 高炉 [-0.5559] 高炉与设定误差 [0.0019] [0.00176444] 模型误差 [0.0031] 校正值 [0.0129]
# 这是对第82时刻的最优U1、U2输入求解
# (83, 1, 10)
# (83, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0007
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0344] 高炉 [-0.0283] 高炉与设定误差 [0.0034] [0.2876466] 模型误差 [-0.0061] 校正值 [-0.0001]
# 2设定 -0.554 预测 [-0.5655] 高炉 [-0.5554] 高炉与设定误差 [0.0014] [0.00130011] 模型误差 [-0.0101] 校正值 [-0.0044]
# 这是对第83时刻的最优U1、U2输入求解
# (84, 1, 10)
# (84, 1, 2)
# 第 1/10 轮, 训练误差: 0.0016
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0014
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0004
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.023] 高炉 [-0.0245] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0015] 校正值 [0.0064]
# 2设定 -0.554 预测 [-0.5478] 高炉 [-0.553] 高炉与设定误差 [-0.0009] [-0.00083578] 模型误差 [0.0052] 校正值 [0.0082]
# 这是对第84时刻的最优U1、U2输入求解
# (85, 1, 10)
# (85, 1, 2)
# 第 1/10 轮, 训练误差: 0.0012
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0012
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0006
# 第 6/10 轮, 训练误差: 0.0004
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0319] 高炉 [-0.024] 高炉与设定误差 [-0.001] [-0.08460194] 模型误差 [-0.0079] 校正值 [-0.0001]
# 2设定 -0.554 预测 [-0.5632] 高炉 [-0.5536] 高炉与设定误差 [-0.0003] [-0.0002786] 模型误差 [-0.0095] 校正值 [-0.0067]
# 这是对第85时刻的最优U1、U2输入求解
# (86, 1, 10)
# (86, 1, 2)
# 第 1/10 轮, 训练误差: 0.0013
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0011
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0003
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 -0.0249 预测 [-0.0171] 高炉 [-0.0212] 高炉与设定误差 [-0.0038] [-0.32148738] 模型误差 [0.004] 校正值 [0.0029]
# 2设定 -0.5324 预测 [-0.5337] 高炉 [-0.5425] 高炉与设定误差 [0.01] [0.0092865] 模型误差 [0.0088] 校正值 [0.0055]
# 这是对第86时刻的最优U1、U2输入求解
# (87, 1, 10)
# (87, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0259] 高炉 [-0.0227] 高炉与设定误差 [-0.0022] [-0.18612427] 模型误差 [-0.0031] 校正值 [0.0033]
# 2设定 -0.5324 预测 [-0.5357] 高炉 [-0.5313] 高炉与设定误差 [-0.0011] [-0.00102151] 模型误差 [-0.0043] 校正值 [-0.0064]
# 这是对第87时刻的最优U1、U2输入求解
# (88, 1, 10)
# (88, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0293] 高炉 [-0.018] 高炉与设定误差 [-0.0069] [-0.58375338] 模型误差 [-0.0112] 校正值 [-0.0027]
# 2设定 -0.5324 预测 [-0.5284] 高炉 [-0.5301] 高炉与设定误差 [-0.0023] [-0.0021359] 模型误差 [0.0018] 校正值 [0.0066]
# 这是对第88时刻的最优U1、U2输入求解
# (89, 1, 10)
# (89, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.024] 高炉 [-0.0239] 高炉与设定误差 [-0.0011] [-0.09306213] 模型误差 [-1.e-04] 校正值 [0.0102]
# 2设定 -0.5324 预测 [-0.5432] 高炉 [-0.5339] 高炉与设定误差 [0.0015] [0.00139298] 模型误差 [-0.0093] 校正值 [-0.0015]
# 这是对第89时刻的最优U1、U2输入求解
# (90, 1, 10)
# (90, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0347] 高炉 [-0.0274] 高炉与设定误差 [0.0025] [0.21150485] 模型误差 [-0.0072] 校正值 [-0.0033]
# 2设定 -0.5324 预测 [-0.5295] 高炉 [-0.5339] 高炉与设定误差 [0.0014] [0.00130011] 模型误差 [0.0044] 校正值 [0.0063]
# 这是对第90时刻的最优U1、U2输入求解
# (91, 1, 10)
# (91, 1, 2)
# 第 1/10 轮, 训练误差: 0.0010
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0201] 高炉 [-0.0258] 高炉与设定误差 [0.0008] [0.06768155] 模型误差 [0.0057] 校正值 [0.0032]
# 2设定 -0.5324 预测 [-0.5379] 高炉 [-0.5328] 高炉与设定误差 [0.0004] [0.00037146] 模型误差 [-0.0051] 校正值 [-0.0047]
# 这是对第91时刻的最优U1、U2输入求解
# (92, 1, 10)
# (92, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0289] 高炉 [-0.0258] 高炉与设定误差 [0.0008] [0.06768155] 模型误差 [-0.0031] 校正值 [-0.0014]
# 2设定 -0.5324 预测 [-0.5273] 高炉 [-0.5326] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [0.0053] 校正值 [0.0097]
# 这是对第92时刻的最优U1、U2输入求解
# (93, 1, 10)
# (93, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.023] 高炉 [-0.0228] 高炉与设定误差 [-0.0021] [-0.17766407] 模型误差 [-0.0002] 校正值 [0.0027]
# 2设定 -0.5324 预测 [-0.5418] 高炉 [-0.5314] 高炉与设定误差 [-0.001] [-0.00092865] 模型误差 [-0.0104] 校正值 [-0.0059]
# 这是对第93时刻的最优U1、U2输入求解
# (94, 1, 10)
# (94, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0287] 高炉 [-0.0249] 高炉与设定误差 [0.] [0.] 模型误差 [-0.0038] 校正值 [0.0002]
# 2设定 -0.5324 预测 [-0.5278] 高炉 [-0.5331] 高炉与设定误差 [0.0006] [0.00055719] 模型误差 [0.0052] 校正值 [0.0101]
# 这是对第94时刻的最优U1、U2输入求解
# (95, 1, 10)
# (95, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 -0.0249 预测 [-0.0244] 高炉 [-0.0256] 高炉与设定误差 [0.0007] [0.05922136] 模型误差 [0.0012] 校正值 [0.0035]
# 2设定 -0.5324 预测 [-0.5422] 高炉 [-0.5332] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [-0.0089] 校正值 [-0.0055]
# 这是对第95时刻的最优U1、U2输入求解
# (96, 1, 10)
# (96, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0008
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0002
# 1设定 0.0342 预测 [0.0194] 高炉 [-0.0191] 高炉与设定误差 [0.0532] [4.50082313] 模型误差 [0.0384] 校正值 [-0.0039]
# 2设定 -0.5324 预测 [-0.526] 高炉 [-0.6001] 高炉与设定误差 [0.0676] [0.06277674] 模型误差 [0.0741] 校正值 [0.0076]
# 这是对第96时刻的最优U1、U2输入求解
# (97, 1, 10)
# (97, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.032] 高炉 [0.023] 高炉与设定误差 [0.0111] [0.93908151] 模型误差 [0.009] 校正值 [0.0035]
# 2设定 -0.5324 预测 [-0.5217] 高炉 [-0.5248] 高炉与设定误差 [-0.0077] [-0.0071506] 模型误差 [0.0031] 校正值 [-0.0279]
# 这是对第97时刻的最优U1、U2输入求解
# (98, 1, 10)
# (98, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.0181] 高炉 [0.0276] 高炉与设定误差 [0.0066] [0.5583728] 模型误差 [-0.0095] 校正值 [-0.0051]
# 2设定 -0.5324 预测 [-0.5194] 高炉 [-0.5336] 高炉与设定误差 [0.0012] [0.00111438] 模型误差 [0.0142] 校正值 [-0.0007]
# 这是对第98时刻的最优U1、U2输入求解
# (99, 1, 10)
# (99, 1, 2)
# 第 1/10 轮, 训练误差: 0.0009
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.0403] 高炉 [0.0594] 高炉与设定误差 [-0.0252] [-2.13196889] 模型误差 [-0.0191] 校正值 [0.003]
# 2设定 -0.5324 预测 [-0.5337] 高炉 [-0.531] 高炉与设定误差 [-0.0014] [-0.00130011] 模型误差 [-0.0027] 校正值 [-0.0118]
# 这是对第99时刻的最优U1、U2输入求解
# (100, 1, 10)
# (100, 1, 2)
# 第 1/10 轮, 训练误差: 0.0008
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0005
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0003
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.0329] 高炉 [0.0492] 高炉与设定误差 [-0.0151] [-1.27748933] 模型误差 [-0.0163] 校正值 [-0.0008]
# 2设定 -0.5324 预测 [-0.5311] 高炉 [-0.5276] 高炉与设定误差 [-0.0048] [-0.00445752] 模型误差 [-0.0035] 校正值 [0.0047]
# 这是对第100时刻的最优U1、U2输入求解
# (101, 1, 10)
# (101, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0005
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.0323] 高炉 [0.0319] 高炉与设定误差 [0.0023] [0.19458447] 模型误差 [0.0004] 校正值 [0.0065]
# 2设定 -0.5324 预测 [-0.5459] 高炉 [-0.5395] 高炉与设定误差 [0.0071] [0.00659342] 模型误差 [-0.0064] 校正值 [-0.0007]
# 这是对第101时刻的最优U1、U2输入求解
# (102, 1, 10)
# (102, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0007
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.0321] 高炉 [0.032] 高炉与设定误差 [0.0022] [0.18612427] 模型误差 [0.0002] 校正值 [-0.0023]
# 2设定 -0.5324 预测 [-0.5254] 高炉 [-0.5363] 高炉与设定误差 [0.0039] [0.00362173] 模型误差 [0.0109] 校正值 [0.0048]
# 这是对第102时刻的最优U1、U2输入求解
# (103, 1, 10)
# (103, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0006
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0003
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.0342 预测 [0.038] 高炉 [0.0353] 高炉与设定误差 [-0.0011] [-0.09306213] 模型误差 [0.0027] 校正值 [0.001]
# ...
# 2设定 -0.4463 预测 [-0.443] 高炉 [-0.4481] 高炉与设定误差 [0.0018] [0.00167157] 模型误差 [0.005] 校正值 [-0.0045]
# 这是对第166时刻的最优U1、U2输入求解
# (167, 1, 10)
# (167, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2078] 高炉 [0.2036] 高炉与设定误差 [0.0079] [0.66835529] 模型误差 [0.0042] 校正值 [0.0034]
# 2设定 -0.4463 预测 [-0.4477] 高炉 [-0.4465] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [-0.0012] 校正值 [0.0062]
# 这是对第167时刻的最优U1、U2输入求解
# (168, 1, 10)
# (168, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0000
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2099] 高炉 [0.2113] 高炉与设定误差 [1.e-04] [0.00846019] 模型误差 [-0.0014] 校正值 [-0.0032]
# 2设定 -0.4463 预测 [-0.4514] 高炉 [-0.4484] 高炉与设定误差 [0.0022] [0.00204303] 模型误差 [-0.003] 校正值 [-0.0023]
# 这是对第168时刻的最优U1、U2输入求解
# (169, 1, 10)
# (169, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2136] 高炉 [0.2186] 高炉与设定误差 [-0.0071] [-0.60067378] 模型误差 [-0.0049] 校正值 [-0.0009]
# 2设定 -0.4463 预测 [-0.442] 高炉 [-0.4392] 高炉与设定误差 [-0.0071] [-0.00659342] 模型误差 [-0.0028] 校正值 [0.0025]
# 这是对第169时刻的最优U1、U2输入求解
# (170, 1, 10)
# (170, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2123] 高炉 [0.205] 高炉与设定误差 [0.0065] [0.54991262] 模型误差 [0.0074] 校正值 [0.006]
# 2设定 -0.4463 预测 [-0.4553] 高炉 [-0.4478] 高炉与设定误差 [0.0015] [0.00139298] 模型误差 [-0.0075] 校正值 [0.0085]
# 这是对第170时刻的最优U1、U2输入求解
# (171, 1, 10)
# (171, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2139] 高炉 [0.2075] 高炉与设定误差 [0.004] [0.33840778] 模型误差 [0.0064] 校正值 [-0.0019]
# 2设定 -0.4463 预测 [-0.4512] 高炉 [-0.4493] 高炉与设定误差 [0.0031] [0.00287882] 模型误差 [-0.0019] 校正值 [0.0004]
# 这是对第171时刻的最优U1、U2输入求解
# (172, 1, 10)
# (172, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2091] 高炉 [0.2093] 高炉与设定误差 [0.0021] [0.17766407] 模型误差 [-0.0002] 校正值 [-0.0043]
# 2设定 -0.4463 预测 [-0.4445] 高炉 [-0.4447] 高炉与设定误差 [-0.0015] [-0.00139298] 模型误差 [0.0002] 校正值 [0.0048]
# 这是对第172时刻的最优U1、U2输入求解
# (173, 1, 10)
# (173, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0002
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2138] 高炉 [0.2148] 高炉与设定误差 [-0.0034] [-0.2876466] 模型误差 [-0.001] 校正值 [-0.0007]
# 2设定 -0.4463 预测 [-0.452] 高炉 [-0.4463] 高炉与设定误差 [-0.] [-0.] 模型误差 [-0.0058] 校正值 [-0.0037]
# 这是对第173时刻的最优U1、U2输入求解
# (174, 1, 10)
# (174, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2115 预测 [0.2139] 高炉 [0.2116] 高炉与设定误差 [-0.0002] [-0.01692039] 模型误差 [0.0022] 校正值 [0.0014]
# 2设定 -0.4463 预测 [-0.4443] 高炉 [-0.4448] 高炉与设定误差 [-0.0015] [-0.00139298] 模型误差 [0.0004] 校正值 [0.0045]
# 这是对第174时刻的最优U1、U2输入求解
# (175, 1, 10)
# (175, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2115 预测 [0.2115] 高炉 [0.2071] 高炉与设定误差 [0.0043] [0.36378835] 模型误差 [0.0044] 校正值 [0.0003]
# 2设定 -0.4463 预测 [-0.4532] 高炉 [-0.4479] 高炉与设定误差 [0.0016] [0.00148584] 模型误差 [-0.0052] 校正值 [0.0033]
# 这是对第175时刻的最优U1、U2输入求解
# (176, 1, 10)
# (176, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2594] 高炉 [0.2776] 高炉与设定误差 [-0.0071] [-0.60067378] 模型误差 [-0.0183] 校正值 [-0.0028]
# 2设定 -0.4463 预测 [-0.4475] 高炉 [-0.4324] 高炉与设定误差 [-0.0139] [-0.01290823] 模型误差 [-0.0151] 校正值 [-0.0018]
# 这是对第176时刻的最优U1、U2输入求解
# (177, 1, 10)
# (177, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2619] 高炉 [0.2915] 高炉与设定误差 [-0.0209] [-1.76818054] 模型误差 [-0.0296] 校正值 [0.0048]
# 2设定 -0.4463 预测 [-0.448] 高炉 [-0.4569] 高炉与设定误差 [0.0106] [0.00984369] 模型误差 [0.0089] 校正值 [0.0102]
# 这是对第177时刻的最优U1、U2输入求解
# (178, 1, 10)
# (178, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2547] 高炉 [0.2759] 高炉与设定误差 [-0.0053] [-0.44839027] 模型误差 [-0.0212] 校正值 [0.0084]
# 2设定 -0.4463 预测 [-0.4468] 高炉 [-0.4518] 高炉与设定误差 [0.0055] [0.00510757] 模型误差 [0.005] 校正值 [0.001]
# 这是对第178时刻的最优U1、U2输入求解
# (179, 1, 10)
# (179, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2623] 高炉 [0.2642] 高炉与设定误差 [0.0064] [0.5414524] 模型误差 [-0.0019] 校正值 [0.0095]
# 2设定 -0.4463 预测 [-0.4409] 高炉 [-0.4481] 高炉与设定误差 [0.0018] [0.00167157] 模型误差 [0.0071] 校正值 [-0.0116]
# 这是对第179时刻的最优U1、U2输入求解
# (180, 1, 10)
# (180, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2706 预测 [0.2672] 高炉 [0.2669] 高炉与设定误差 [0.0036] [0.30456698] 模型误差 [0.0003] 校正值 [0.0055]
# 2设定 -0.4463 预测 [-0.4349] 高炉 [-0.4443] 高炉与设定误差 [-0.002] [-0.0018573] 模型误差 [0.0094] 校正值 [-0.0065]
# 这是对第180时刻的最优U1、U2输入求解
# (181, 1, 10)
# (181, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2671] 高炉 [0.2702] 高炉与设定误差 [0.0004] [0.03384078] 模型误差 [-0.0031] 校正值 [-0.0011]
# 2设定 -0.4463 预测 [-0.442] 高炉 [-0.4465] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [0.0045] 校正值 [-0.0028]
# 这是对第181时刻的最优U1、U2输入求解
# (182, 1, 10)
# (182, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0006
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2714] 高炉 [0.2736] 高炉与设定误差 [-0.003] [-0.25380582] 模型误差 [-0.0022] 校正值 [-0.0025]
# 2设定 -0.4463 预测 [-0.4431] 高炉 [-0.4454] 高炉与设定误差 [-0.0009] [-0.00083578] 模型误差 [0.0023] 校正值 [-0.0008]
# 这是对第182时刻的最优U1、U2输入求解
# (183, 1, 10)
# (183, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2704] 高炉 [0.2709] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [-0.0006] 校正值 [0.0064]
# 2设定 -0.4463 预测 [-0.4464] 高炉 [-0.4471] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [0.0008] 校正值 [-0.0049]
# 这是对第183时刻的最优U1、U2输入求解
# (184, 1, 10)
# (184, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2643] 高炉 [0.2698] 高炉与设定误差 [0.0008] [0.06768155] 模型误差 [-0.0054] 校正值 [-0.0017]
# 2设定 -0.4463 预测 [-0.4406] 高炉 [-0.4461] 高炉与设定误差 [-0.0002] [-0.00018573] 模型误差 [0.0055] 校正值 [-0.0023]
# 这是对第184时刻的最优U1、U2输入求解
# (185, 1, 10)
# (185, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0005
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2729] 高炉 [0.2692] 高炉与设定误差 [0.0013] [0.10998252] 模型误差 [0.0036] 校正值 [-0.001]
# 2设定 -0.4463 预测 [-0.4443] 高炉 [-0.4465] 高炉与设定误差 [0.0003] [0.0002786] 模型误差 [0.0022] 校正值 [0.0012]
# 这是对第185时刻的最优U1、U2输入求解
# (186, 1, 10)
# (186, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0005
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2727] 高炉 [0.2805] 高炉与设定误差 [-0.01] [-0.84601938] 模型误差 [-0.0078] 校正值 [-0.0048]
# 2设定 -0.4247 预测 [-0.4284] 高炉 [-0.4227] 高炉与设定误差 [-0.002] [-0.0018573] 模型误差 [-0.0057] 校正值 [-0.0049]
# 这是对第186时刻的最优U1、U2输入求解
# (187, 1, 10)
# (187, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2668] 高炉 [0.2672] 高炉与设定误差 [0.0033] [0.2791864] 模型误差 [-0.0004] 校正值 [0.0033]
# 2设定 -0.4247 预测 [-0.4244] 高炉 [-0.429] 高炉与设定误差 [0.0042] [0.00390033] 模型误差 [0.0046] 校正值 [-0.0008]
# 这是对第187时刻的最优U1、U2输入求解
# (188, 1, 10)
# (188, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2706 预测 [0.2738] 高炉 [0.2621] 高炉与设定误差 [0.0085] [0.71911653] 模型误差 [0.0117] 校正值 [-0.0017]
# 2设定 -0.4247 预测 [-0.4179] 高炉 [-0.4256] 高炉与设定误差 [0.0008] [0.00074292] 模型误差 [0.0076] 校正值 [-0.0029]
# 这是对第188时刻的最优U1、U2输入求解
# (189, 1, 10)
# (189, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2772] 高炉 [0.2628] 高炉与设定误差 [0.0077] [0.65143493] 模型误差 [0.0144] 校正值 [-0.0037]
# 2设定 -0.4247 预测 [-0.4223] 高炉 [-0.4252] 高炉与设定误差 [0.0004] [0.00037146] 模型误差 [0.0028] 校正值 [-0.0027]
# 这是对第189时刻的最优U1、U2输入求解
# (190, 1, 10)
# (190, 1, 2)
# 第 1/10 轮, 训练误差: 0.0006
# 第 2/10 轮, 训练误差: 0.0007
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2775] 高炉 [0.2738] 高炉与设定误差 [-0.0033] [-0.2791864] 模型误差 [0.0036] 校正值 [-0.0048]
# 2设定 -0.4247 预测 [-0.4218] 高炉 [-0.4225] 高炉与设定误差 [-0.0022] [-0.00204303] 模型误差 [0.0007] 校正值 [-0.0009]
# 这是对第190时刻的最优U1、U2输入求解
# (191, 1, 10)
# (191, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0001
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2717] 高炉 [0.2737] 高炉与设定误差 [-0.0031] [-0.26226602] 模型误差 [-0.002] 校正值 [-0.0029]
# 2设定 -0.4247 预测 [-0.4261] 高炉 [-0.4265] 高炉与设定误差 [0.0017] [0.00157871] 模型误差 [0.0004] 校正值 [0.0005]
# 这是对第191时刻的最优U1、U2输入求解
# (192, 1, 10)
# (192, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0002
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.2706 预测 [0.2715] 高炉 [0.271] 高炉与设定误差 [-0.0004] [-0.03384078] 模型误差 [0.0005] 校正值 [-0.004]
# 2设定 -0.4247 预测 [-0.4243] 高炉 [-0.4243] 高炉与设定误差 [-0.0004] [-0.00037146] 模型误差 [1.e-04] 校正值 [-0.0008]
# 这是对第192时刻的最优U1、U2输入求解
# (193, 1, 10)
# (193, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0002
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0001
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0000
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2706 预测 [0.2745] 高炉 [0.2661] 高炉与设定误差 [0.0045] [0.38070871] 模型误差 [0.0085] 校正值 [0.0011]
# 2设定 -0.4247 预测 [-0.424] 高炉 [-0.4259] 高炉与设定误差 [0.0012] [0.00111438] 模型误差 [0.0019] 校正值 [0.0004]
# 这是对第193时刻的最优U1、U2输入求解
# (194, 1, 10)
# (194, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2706 预测 [0.2732] 高炉 [0.2695] 高炉与设定误差 [0.0011] [0.09306213] 模型误差 [0.0037] 校正值 [-0.0024]
# 2设定 -0.4247 预测 [-0.4238] 高炉 [-0.4242] 高炉与设定误差 [-0.0006] [-0.00055719] 模型误差 [0.0003] 校正值 [0.0012]
# 这是对第194时刻的最优U1、U2输入求解
# (195, 1, 10)
# (195, 1, 2)
# 第 1/10 轮, 训练误差: 0.0004
# 第 2/10 轮, 训练误差: 0.0004
# 第 3/10 轮, 训练误差: 0.0003
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0000
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.2706 预测 [0.2733] 高炉 [0.2735] 高炉与设定误差 [-0.0029] [-0.24534562] 模型误差 [-0.0002] 校正值 [-0.0037]
# 2设定 -0.4247 预测 [-0.4277] 高炉 [-0.4249] 高炉与设定误差 [0.0002] [0.00018573] 模型误差 [-0.0028] 校正值 [0.0035]
# 这是对第195时刻的最优U1、U2输入求解
# (196, 1, 10)
# (196, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0006
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0003
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0000
# 第 10/10 轮, 训练误差: 0.0000
# 1设定 0.3297 预测 [0.3018] 高炉 [0.3072] 高炉与设定误差 [0.0224] [1.89508339] 模型误差 [-0.0054] 校正值 [-0.0001]
# 2设定 -0.4247 预测 [-0.4196] 高炉 [-0.4005] 高炉与设定误差 [-0.0242] [-0.02247333] 模型误差 [-0.0191] 校正值 [-0.0012]
# 这是对第196时刻的最优U1、U2输入求解
# (197, 1, 10)
# (197, 1, 2)
# 第 1/10 轮, 训练误差: 0.0021
# 第 2/10 轮, 训练误差: 0.0026
# 第 3/10 轮, 训练误差: 0.0013
# 第 4/10 轮, 训练误差: 0.0012
# 第 5/10 轮, 训练误差: 0.0008
# 第 6/10 轮, 训练误差: 0.0005
# 第 7/10 轮, 训练误差: 0.0003
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0002
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.3297 预测 [0.3371] 高炉 [0.4937] 高炉与设定误差 [-0.1641] [-13.88317888] 模型误差 [-0.1567] 校正值 [-0.0065]
# 2设定 -0.4247 预测 [-0.4204] 高炉 [-0.3884] 高炉与设定误差 [-0.0364] [-0.03380286] 模型误差 [-0.0321] 校正值 [-0.0044]
# 这是对第197时刻的最优U1、U2输入求解
# (198, 1, 10)
# (198, 1, 2)
# 第 1/10 轮, 训练误差: 0.0014
# 第 2/10 轮, 训练误差: 0.0008
# 第 3/10 轮, 训练误差: 0.0009
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0004
# 第 6/10 轮, 训练误差: 0.0003
# 第 7/10 轮, 训练误差: 0.0002
# 第 8/10 轮, 训练误差: 0.0002
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.3297 预测 [0.4218] 高炉 [0.5265] 高炉与设定误差 [-0.1968] [-16.64966124] 模型误差 [-0.1047] 校正值 [-0.0101]
# 2设定 -0.4247 预测 [-0.4152] 高炉 [-0.3714] 高炉与设定误差 [-0.0533] [-0.04949705] 模型误差 [-0.0438] 校正值 [-0.002]
# 这是对第198时刻的最优U1、U2输入求解
# (199, 1, 10)
# (199, 1, 2)
# 第 1/10 轮, 训练误差: 0.0007
# 第 2/10 轮, 训练误差: 0.0009
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0004
# 第 5/10 轮, 训练误差: 0.0002
# 第 6/10 轮, 训练误差: 0.0002
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.3297 预测 [0.4201] 高炉 [0.4116] 高炉与设定误差 [-0.082] [-6.93735927] 模型误差 [0.0085] 校正值 [0.0163]
# 2设定 -0.4247 预测 [-0.4767] 高炉 [-0.4809] 高炉与设定误差 [0.0561] [0.05209726] 模型误差 [0.0042] 校正值 [0.0016]
# 这是对第199时刻的最优U1、U2输入求解
# (200, 1, 10)
# (200, 1, 2)
# 第 1/10 轮, 训练误差: 0.0005
# 第 2/10 轮, 训练误差: 0.0003
# 第 3/10 轮, 训练误差: 0.0004
# 第 4/10 轮, 训练误差: 0.0002
# 第 5/10 轮, 训练误差: 0.0001
# 第 6/10 轮, 训练误差: 0.0001
# 第 7/10 轮, 训练误差: 0.0001
# 第 8/10 轮, 训练误差: 0.0001
# 第 9/10 轮, 训练误差: 0.0001
# 第 10/10 轮, 训练误差: 0.0001
# 1设定 0.3297 预测 [0.342] 高炉 [0.3234] 高炉与设定误差 [0.0063] [0.53299222] 模型误差 [0.0186] 校正值 [-0.0021]
# 2设定 -0.4247 预测 [-0.4308] 高炉 [-0.449] 高炉与设定误差 [0.0243] [0.02256619] 模型误差 [0.0183] 校正值 [0.0007]

# %%
if iscontrol:
    y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1).reshape(-1, 1)).flatten()
    y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2).reshape(-1, 1)).flatten()
    
    startt = 0
    endd = 400
    
    plt.figure(figsize=(7, 6))
    plt.subplot(2, 1, 1)
    plt.plot(set_y1[startt:endd],'r', label='设定值')
    plt.plot(y1_pred_inverse_transform[startt:endd],'b', label='实际值')
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')
    plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
    plt.legend(prop=font)
    plt.title(f"模型:MLP 训练次数:{epoch_sum_gaolu} 隐含层数:{3} 改进:{ischuangxin} 动态更新:{if_update_model} P:{P} M:{M} ", fontproperties=font)

    plt.subplot(2, 1, 2)
    plt.plot(set_y2[startt:endd],'r')
    plt.plot(y2_pred_inverse_transform[startt:endd],'b')
    plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
    plt.grid(linestyle='--', alpha=0.7, color='gray')

# %%
startt = 50
endd = 150


font222 = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=10)  # 替换为你的中文字体文件路径

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()


a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))









# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(8, 13))

# 第一个维度的曲线
ax = plt.subplot(6, 1, 1)
plt.plot(set_y1[startt:endd], 'k.-', label='设定值')
plt.plot(y1_pred_inverse_transform, 'r', label='SC-MLP-U')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('铁水温度MIT/℃', fontproperties=font)  # 使用中文标签
plt.legend(prop=font222)
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边

input_term222 =        ['富氧流量/(m\u00b3/h)', '设定喷煤量/(t/h)', '热风压力/kPa', '热风温度/℃']
output_term222 = ['铁水温度MIT/℃', '铁水硅含量[Si]/%']
time_term= '时间戳h'
input_term333 =        ['富氧流量', '设定喷煤量', '热风压力', '热风温度']
output_term333 = ['铁水温度MIT', '铁水硅含量[Si]']
time_term= '时间戳h'
# 用于子图编号的字母序列
subplot_labels = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)']
dtiem = -0.5




ax.text(0.5, dtiem, f'{subplot_labels[0]} {output_term333[0]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签




# 第二个维度的曲线
ax = plt.subplot(6, 1, 2)
plt.plot(set_y2[startt:endd], 'k.-')
plt.plot(y2_pred_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel('铁水硅含量[Si]/%', fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.text(0.5, dtiem, f'{subplot_labels[1]} {output_term333[1]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签
# 第一个维度的u1曲线
ax = plt.subplot(6, 1, 3)
plt.plot(all_pred_u1_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[0], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[2]} {input_term333[0]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第二个维度的u2曲线
ax = plt.subplot(6, 1, 4)
plt.plot(all_pred_u2_inverse_transform, 'r')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[1], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[3]} {input_term333[1]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第三个维度的u3曲线
ax = plt.subplot(6, 1, 5)
plt.plot(all_pred_u3_inverse_transform, 'r')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[2], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[4]} {input_term333[2]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签

# 第四个维度的u4曲线
ax = plt.subplot(6, 1, 6)
plt.plot(all_pred_u4_inverse_transform, 'r')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term222[3], fontproperties=font)  # 使用中文标签
plt.grid(linestyle='--', alpha=0.7, color='gray')
ax.yaxis.set_label_coords(-0.07, 0.5)  # 固定纵坐标标签在最左边
ax.text(0.5, dtiem, f'{subplot_labels[5]} {input_term333[3]}数据', 
            transform=ax.transAxes, ha='center', fontproperties=font)  # 添加每个子图的标题在下方
    # 添加横坐标标题
ax.set_xlabel('控制周期', fontproperties=font)  # 只给最下面的子图添加横坐标标签



# 调整子图布局
plt.tight_layout()
plt.show()
# Out:
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[5.35000000e+01 1.97641697e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 0.4735
# 平均误差 0.0046

# %%
startt = 50
endd = 150

y1_pred_inverse_transform = scalers[output_term[0]].inverse_transform(np.array(all_pred_y1[startt:endd]).reshape(-1, 1)).flatten()
y2_pred_inverse_transform = scalers[output_term[1]].inverse_transform(np.array(all_pred_y2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u1_inverse_transform = scalers[input_term[0]].inverse_transform(np.array(all_pred_u1[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u2_inverse_transform = scalers[input_term[1]].inverse_transform(np.array(all_pred_u2[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u3_inverse_transform = scalers[input_term[2]].inverse_transform(np.array(all_pred_u3[startt:endd]).reshape(-1, 1)).flatten()
all_pred_u4_inverse_transform = scalers[input_term[3]].inverse_transform(np.array(all_pred_u4[startt:endd]).reshape(-1, 1)).flatten()

# # 将数据转换为DataFrame
# data = {
#     'set_y1': set_y1,
#     'set_y2': set_y2,
#     'RES_MLP_U_y1': y1_pred_inverse_transform,
#     'MLP_U_y2': y2_pred_inverse_transform,
#     'RES_MLP_U_u1': all_pred_u1_inverse_transform,
#     'RES_MLP_U_u2': all_pred_u2_inverse_transform,
#     'RES_MLP_U_u3': all_pred_u3_inverse_transform,
#     'RES_MLP_U_u4': all_pred_u4_inverse_transform
# }

# df = pd.DataFrame(data)

# # 保存DataFrame到Excel文件
# df.to_excel('pred_data_RES_MLP_U_'+str(cengshu)+'.xlsx', index=False)




a1 = scalers[input_term[0]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a2 = scalers[input_term[1]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a3 = scalers[input_term[2]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
a4 = scalers[input_term[3]].inverse_transform(np.array([1,-1]).reshape(-1, 1)).flatten()
print(f'上线分别是：{a1}、{a2}、{a3}、{a4}')


rmse_1 = np.mean(np.fabs(set_y1[startt:endd]-y1_pred_inverse_transform))
rmse_2 = np.mean(np.fabs(set_y2[startt:endd]-y2_pred_inverse_transform))
print('平均误差',rmse_1.round(4))
print('平均误差',rmse_2.round(4))

# 模型预测控制结果可视化
# 创建两个子图，分别绘制每个维度
plt.figure(figsize=(10, 6))

# 第一个维度的曲线
plt.subplot(2, 1, 1)
plt.plot(set_y1[startt:endd], 'ro-', label='设定值')
plt.plot(y1_pred_inverse_transform, 'bo-', label='RES_MLP_U 实际值')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[0], fontproperties=font)  # 使用中文标签
plt.legend(prop=font)
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的曲线
plt.subplot(2, 1, 2)
plt.plot(set_y2[startt:endd], 'ro-')
plt.plot(y2_pred_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(output_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 调整子图布局
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 8))
# 第一个维度的u1曲线
plt.subplot(4, 1, 1)
plt.plot(all_pred_u1_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[0], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第二个维度的u2曲线
plt.subplot(4, 1, 2)
plt.plot(all_pred_u2_inverse_transform, 'bo-')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[1], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第三个维度的u3曲线
plt.subplot(4, 1, 3)
plt.plot(all_pred_u3_inverse_transform, 'bo-')  # 修改标签为 'u3'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[2], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')

# 第四个维度的u4曲线
plt.subplot(4, 1, 4)
plt.plot(all_pred_u4_inverse_transform, 'bo-')  # 修改标签为 'u4'
plt.axvline(x=0, color='gray', linestyle='--', linewidth=1.5)
plt.xlim((0,endd-startt))
plt.ylabel(input_term[3], fontproperties=font)  # 使用中文标签
plt.legend()
plt.grid(linestyle='--', alpha=0.7, color='gray')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 上线分别是：[2.00736825e+04 3.17145274e-04]、[5.35000000e+01 1.97641697e-06]、[ 4.32087465e-01 -2.78527280e-04]、[1220.02980501  575.46495619]
# 平均误差 0.4735
# 平均误差 0.0046
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
